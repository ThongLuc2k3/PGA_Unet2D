# %% [markdown]
# **Full environment, dataset, and code setup**

# %%
# =========================================================
# CELL 1 - FULL SETUP COLAB
# =========================================================
# ===== CHANGE DIRECTORY (auto-detect Colab / Kaggle) =====
import os
BASE = "/kaggle/working" if os.path.exists("/kaggle/working") else "/content"
# %cd $BASE
# ===== CHECK GPU =====
import torch

print("=" * 50)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("=" * 50)

# =========================================================
# CLONE GITHUB
# =========================================================

# !rm -rf $BASE/PGA_Unet2D
# !git clone https://github.com/ThongLuc2k3/PGA_Unet2D.git

# =========================================================
# DOWNLOAD DATASET ZIP FROM GOOGLE DRIVE
# =========================================================

# !gdown --id 1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx

# =========================================================
# UNZIP DATASET
# =========================================================

# !unzip -oq dataset_BTXRD.zip

# =========================================================
# INSPECT DATASET
# =========================================================

print("\nDATASET STRUCTURE:")
# !ls dataset_BTXRD

# =========================================================
# COPY DATASET INTO THE PROJECT
# =========================================================

# !rm -rf PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/dataset_BTXRD
# !mv dataset_BTXRD PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/

# =========================================================
# ENTER THE PROJECT DIRECTORY
# =========================================================

# %cd PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation

# =========================================================
# INSTALL REQUIREMENTS
# =========================================================

# !pip install -q tqdm opencv-python matplotlib scikit-image gdown scipy

print("\nSETUP DONE!")
# Out:
# /kaggle/working
# ==================================================
# CUDA: True
# GPU: Tesla T4
# ==================================================
# Cloning into 'PGA_Unet2D'...
# remote: Enumerating objects: 4076, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 4076 (delta 1), reused 9 (delta 1), pack-reused 4025 (from 2)
# Receiving objects: 100% (4076/4076), 1.23 GiB | 43.81 MiB/s, done.
# Resolving deltas: 100% (2354/2354), done.
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx
# From (redirected): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx&confirm=t&uuid=4e7f22e7-afd1-4468-90e1-0d49629ed1a8
# To: /kaggle/working/dataset_BTXRD.zip
# 100%|███████████████████████████████████████| 1.71G/1.71G [00:13<00:00, 124MB/s]
#
# DATASET STRUCTURE:
# test  train  val
# /kaggle/working/PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation
#
# SETUP DONE!

# %% [markdown]
# **Train**
#
# `train.py` currently hardcodes `TRAIN_PROMPT_MODE='mixed'` (each training sample independently gets `zoom_out` or `shift` with 50/50 probability) and `USE_ENCODER_PROMPT=True`; only `PROMPT_DATASET_ROOT` and `PROMPT_IMG_SIZE` are read from the environment. `PROMPT_IMG_SIZE=128` is the only thing this notebook changes versus `pga-train-512.ipynb`/`pga-train-256.ipynb`. Checkpoint saved as `checkpoints/pga_unet_mixed_128_best.pth`.

# %%
# =========================================================
# TRAIN
# =========================================================

# !PROMPT_DATASET_ROOT=dataset_BTXRD PROMPT_IMG_SIZE=128 python train.py
# Out:
# ==========================================================================================
# TrainPrompt: mixed | Device: cuda | EncoderPrompt: True | ImgSize: 128 | DatasetRoot: dataset_BTXRD
# ==========================================================================================
# Epoch 1/100 [Train]: 100%|███████| 462/462 [00:59<00:00,  7.73it/s, loss=1.4866]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.5616 | [ZOOM_OU] Dice:0.4054 IoU:0.2734 CBL:0.6546 | [SHIFT] Dice:0.4083 IoU:0.2760 CBL:0.6482 | LR:1.0e-04
# Epoch 2/100 [Train]: 100%|███████| 462/462 [00:57<00:00,  8.07it/s, loss=1.3592]
# 🥇 [BEST] Epoch   2 | T_Loss: 1.3863 | [ZOOM_OU] Dice:0.5501 IoU:0.4088 CBL:0.7799 | [SHIFT] Dice:0.5572 IoU:0.4165 CBL:0.7823 | LR:1.0e-04
# Epoch 3/100 [Train]: 100%|███████| 462/462 [00:56<00:00,  8.24it/s, loss=1.2666]
# 🥇 [BEST] Epoch   3 | T_Loss: 1.2680 | [ZOOM_OU] Dice:0.5705 IoU:0.4415 CBL:0.7342 | [SHIFT] Dice:0.5830 IoU:0.4553 CBL:0.7605 | LR:1.0e-04
# Epoch 4/100 [Train]: 100%|███████| 462/462 [00:56<00:00,  8.24it/s, loss=1.0594]
# 🥇 [BEST] Epoch   4 | T_Loss: 1.1631 | [ZOOM_OU] Dice:0.6250 IoU:0.4865 CBL:0.8287 | [SHIFT] Dice:0.6143 IoU:0.4732 CBL:0.8156 | LR:1.0e-04
# Epoch 5/100 [Train]: 100%|███████| 462/462 [00:55<00:00,  8.36it/s, loss=1.1359]
# 🥇 [BEST] Epoch   5 | T_Loss: 1.0800 | [ZOOM_OU] Dice:0.6316 IoU:0.4898 CBL:0.8295 | [SHIFT] Dice:0.6303 IoU:0.4892 CBL:0.8262 | LR:1.0e-04
# Epoch 6/100 [Train]: 100%|███████| 462/462 [00:55<00:00,  8.27it/s, loss=0.9563]
# Epoch   6 | T_Loss: 1.0020 | [ZOOM_OU] Dice:0.6110 IoU:0.4691 CBL:0.8379 | [SHIFT] Dice:0.6103 IoU:0.4676 CBL:0.8418 | LR:1.0e-04
# Epoch 7/100 [Train]: 100%|███████| 462/462 [00:56<00:00,  8.25it/s, loss=0.9627]
# Epoch   7 | T_Loss: 0.9448 | [ZOOM_OU] Dice:0.6210 IoU:0.4794 CBL:0.8203 | [SHIFT] Dice:0.6177 IoU:0.4766 CBL:0.8230 | LR:1.0e-04
# Epoch 8/100 [Train]: 100%|███████| 462/462 [00:57<00:00,  8.01it/s, loss=1.0439]
# 🥇 [BEST] Epoch   8 | T_Loss: 0.8821 | [ZOOM_OU] Dice:0.6614 IoU:0.5269 CBL:0.8648 | [SHIFT] Dice:0.6393 IoU:0.4972 CBL:0.8341 | LR:1.0e-04
# Epoch 9/100 [Train]: 100%|███████| 462/462 [00:57<00:00,  8.08it/s, loss=0.5480]
# Epoch   9 | T_Loss: 0.8256 | [ZOOM_OU] Dice:0.6518 IoU:0.5073 CBL:0.8776 | [SHIFT] Dice:0.6555 IoU:0.5134 CBL:0.8809 | LR:1.0e-04
# Epoch 10/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.05it/s, loss=0.6232]
# 🥇 [BEST] Epoch  10 | T_Loss: 0.7618 | [ZOOM_OU] Dice:0.7245 IoU:0.5944 CBL:0.8757 | [SHIFT] Dice:0.7103 IoU:0.5723 CBL:0.8654 | LR:1.0e-04
# Epoch 11/100 [Train]: 100%|██████| 462/462 [00:58<00:00,  7.95it/s, loss=0.6321]
# Epoch  11 | T_Loss: 0.7020 | [ZOOM_OU] Dice:0.6963 IoU:0.5605 CBL:0.8670 | [SHIFT] Dice:0.6833 IoU:0.5423 CBL:0.8539 | LR:1.0e-04
# Epoch 12/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.12it/s, loss=0.6335]
# Epoch  12 | T_Loss: 0.6468 | [ZOOM_OU] Dice:0.6956 IoU:0.5586 CBL:0.8765 | [SHIFT] Dice:0.6685 IoU:0.5222 CBL:0.8542 | LR:1.0e-04
# Epoch 13/100 [Train]: 100%|██████| 462/462 [00:58<00:00,  7.93it/s, loss=0.7906]
# Epoch  13 | T_Loss: 0.5950 | [ZOOM_OU] Dice:0.7207 IoU:0.5875 CBL:0.8701 | [SHIFT] Dice:0.7285 IoU:0.5940 CBL:0.8781 | LR:1.0e-04
# Epoch 14/100 [Train]: 100%|██████| 462/462 [00:58<00:00,  7.94it/s, loss=0.3493]
# 🥇 [BEST] Epoch  14 | T_Loss: 0.5721 | [ZOOM_OU] Dice:0.7492 IoU:0.6230 CBL:0.8884 | [SHIFT] Dice:0.7184 IoU:0.5793 CBL:0.8721 | LR:1.0e-04
# Epoch 15/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.04it/s, loss=0.5056]
# Epoch  15 | T_Loss: 0.5385 | [ZOOM_OU] Dice:0.7426 IoU:0.6128 CBL:0.8888 | [SHIFT] Dice:0.7390 IoU:0.6061 CBL:0.8889 | LR:1.0e-04
# Epoch 16/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  7.97it/s, loss=0.3617]
# 🥇 [BEST] Epoch  16 | T_Loss: 0.5178 | [ZOOM_OU] Dice:0.7537 IoU:0.6264 CBL:0.8957 | [SHIFT] Dice:0.7417 IoU:0.6083 CBL:0.8868 | LR:1.0e-04
# Epoch 17/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.08it/s, loss=0.5674]
# Epoch  17 | T_Loss: 0.5141 | [ZOOM_OU] Dice:0.7406 IoU:0.6077 CBL:0.8759 | [SHIFT] Dice:0.7319 IoU:0.5939 CBL:0.8668 | LR:1.0e-04
# Epoch 18/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.11it/s, loss=0.4194]
# 🥇 [BEST] Epoch  18 | T_Loss: 0.4986 | [ZOOM_OU] Dice:0.7583 IoU:0.6308 CBL:0.8859 | [SHIFT] Dice:0.7510 IoU:0.6179 CBL:0.8785 | LR:1.0e-04
# Epoch 19/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.12it/s, loss=0.2960]
# 🥇 [BEST] Epoch  19 | T_Loss: 0.4519 | [ZOOM_OU] Dice:0.7662 IoU:0.6398 CBL:0.8959 | [SHIFT] Dice:0.7396 IoU:0.6035 CBL:0.8789 | LR:1.0e-04
# Epoch 20/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.16it/s, loss=0.3093]
# Epoch  20 | T_Loss: 0.4853 | [ZOOM_OU] Dice:0.7622 IoU:0.6345 CBL:0.8963 | [SHIFT] Dice:0.7470 IoU:0.6136 CBL:0.8904 | LR:1.0e-04
# Epoch 21/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.04it/s, loss=0.2895]
# Epoch  21 | T_Loss: 0.4588 | [ZOOM_OU] Dice:0.7560 IoU:0.6263 CBL:0.8880 | [SHIFT] Dice:0.7513 IoU:0.6173 CBL:0.8782 | LR:1.0e-04
# Epoch 22/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.13it/s, loss=0.4550]
# Epoch  22 | T_Loss: 0.4402 | [ZOOM_OU] Dice:0.7598 IoU:0.6320 CBL:0.8879 | [SHIFT] Dice:0.7569 IoU:0.6244 CBL:0.8819 | LR:1.0e-04
# Epoch 23/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.12it/s, loss=0.3295]
# Epoch  23 | T_Loss: 0.4377 | [ZOOM_OU] Dice:0.7404 IoU:0.6076 CBL:0.8737 | [SHIFT] Dice:0.7365 IoU:0.5999 CBL:0.8635 | LR:1.0e-04
# Epoch 24/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.19it/s, loss=1.0448]
# 🥇 [BEST] Epoch  24 | T_Loss: 0.4276 | [ZOOM_OU] Dice:0.7674 IoU:0.6414 CBL:0.8910 | [SHIFT] Dice:0.7579 IoU:0.6274 CBL:0.8868 | LR:1.0e-04
# Epoch 25/100 [Train]: 100%|██████| 462/462 [00:55<00:00,  8.28it/s, loss=0.4475]
# 🥇 [BEST] Epoch  25 | T_Loss: 0.4216 | [ZOOM_OU] Dice:0.7723 IoU:0.6476 CBL:0.8981 | [SHIFT] Dice:0.7383 IoU:0.6014 CBL:0.8818 | LR:1.0e-04
# Epoch 26/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.23it/s, loss=0.3576]
# Epoch  26 | T_Loss: 0.4279 | [ZOOM_OU] Dice:0.7570 IoU:0.6297 CBL:0.8833 | [SHIFT] Dice:0.7578 IoU:0.6278 CBL:0.8851 | LR:1.0e-04
# Epoch 27/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.00it/s, loss=0.4617]
# Epoch  27 | T_Loss: 0.4537 | [ZOOM_OU] Dice:0.7653 IoU:0.6378 CBL:0.8877 | [SHIFT] Dice:0.7532 IoU:0.6200 CBL:0.8757 | LR:1.0e-04
# Epoch 28/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.13it/s, loss=0.9689]
# Epoch  28 | T_Loss: 0.4266 | [ZOOM_OU] Dice:0.7343 IoU:0.6023 CBL:0.8710 | [SHIFT] Dice:0.7594 IoU:0.6297 CBL:0.8860 | LR:1.0e-04
# Epoch 29/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.24it/s, loss=1.0688]
# Epoch  29 | T_Loss: 0.4307 | [ZOOM_OU] Dice:0.7493 IoU:0.6180 CBL:0.8803 | [SHIFT] Dice:0.7631 IoU:0.6332 CBL:0.8876 | LR:1.0e-04
# Epoch 30/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.13it/s, loss=0.3172]
# Epoch  30 | T_Loss: 0.4259 | [ZOOM_OU] Dice:0.7650 IoU:0.6371 CBL:0.8825 | [SHIFT] Dice:0.7839 IoU:0.6586 CBL:0.8916 | LR:1.0e-04
# Epoch 31/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.19it/s, loss=0.3602]
# 🥇 [BEST] Epoch  31 | T_Loss: 0.4274 | [ZOOM_OU] Dice:0.7736 IoU:0.6508 CBL:0.8900 | [SHIFT] Dice:0.7673 IoU:0.6371 CBL:0.8870 | LR:1.0e-04
# Epoch 32/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.04it/s, loss=0.4437]
# Epoch  32 | T_Loss: 0.4193 | [ZOOM_OU] Dice:0.7620 IoU:0.6327 CBL:0.8783 | [SHIFT] Dice:0.7621 IoU:0.6306 CBL:0.8694 | LR:1.0e-04
# Epoch 33/100 [Train]: 100%|██████| 462/462 [00:58<00:00,  7.94it/s, loss=0.3851]
# Epoch  33 | T_Loss: 0.4311 | [ZOOM_OU] Dice:0.7460 IoU:0.6138 CBL:0.8762 | [SHIFT] Dice:0.7603 IoU:0.6303 CBL:0.8779 | LR:1.0e-04
# Epoch 34/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.01it/s, loss=0.2840]
# 🥇 [BEST] Epoch  34 | T_Loss: 0.4168 | [ZOOM_OU] Dice:0.7769 IoU:0.6536 CBL:0.8910 | [SHIFT] Dice:0.7448 IoU:0.6100 CBL:0.8644 | LR:1.0e-04
# Epoch 35/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.01it/s, loss=0.3215]
# 🥇 [BEST] Epoch  35 | T_Loss: 0.4184 | [ZOOM_OU] Dice:0.7865 IoU:0.6649 CBL:0.8971 | [SHIFT] Dice:0.7736 IoU:0.6458 CBL:0.8874 | LR:1.0e-04
# Epoch 36/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.09it/s, loss=0.4053]
# Epoch  36 | T_Loss: 0.4145 | [ZOOM_OU] Dice:0.7509 IoU:0.6234 CBL:0.8782 | [SHIFT] Dice:0.7663 IoU:0.6374 CBL:0.8799 | LR:1.0e-04
# Epoch 37/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.07it/s, loss=1.0423]
# Epoch  37 | T_Loss: 0.4171 | [ZOOM_OU] Dice:0.7534 IoU:0.6233 CBL:0.8773 | [SHIFT] Dice:0.7768 IoU:0.6507 CBL:0.8885 | LR:1.0e-04
# Epoch 38/100 [Train]: 100%|██████| 462/462 [00:56<00:00,  8.16it/s, loss=0.3365]
# Epoch  38 | T_Loss: 0.4023 | [ZOOM_OU] Dice:0.7532 IoU:0.6268 CBL:0.8767 | [SHIFT] Dice:0.7746 IoU:0.6488 CBL:0.8910 | LR:1.0e-04
# Epoch 39/100 [Train]: 100%|██████| 462/462 [00:58<00:00,  7.84it/s, loss=0.4104]
# Epoch  39 | T_Loss: 0.4113 | [ZOOM_OU] Dice:0.7527 IoU:0.6277 CBL:0.8740 | [SHIFT] Dice:0.7757 IoU:0.6502 CBL:0.8929 | LR:1.0e-04
# Epoch 40/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  7.98it/s, loss=0.3137]
# 🥇 [BEST] Epoch  40 | T_Loss: 0.4071 | [ZOOM_OU] Dice:0.7893 IoU:0.6696 CBL:0.8992 | [SHIFT] Dice:0.7705 IoU:0.6433 CBL:0.8960 | LR:1.0e-04
# Epoch 41/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  7.99it/s, loss=1.0740]
# Epoch  41 | T_Loss: 0.3969 | [ZOOM_OU] Dice:0.7455 IoU:0.6136 CBL:0.8756 | [SHIFT] Dice:0.7602 IoU:0.6304 CBL:0.8897 | LR:1.0e-04
# Epoch 42/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.04it/s, loss=0.1865]
# Epoch  42 | T_Loss: 0.4013 | [ZOOM_OU] Dice:0.7741 IoU:0.6516 CBL:0.8882 | [SHIFT] Dice:0.7749 IoU:0.6495 CBL:0.8892 | LR:1.0e-04
# Epoch 43/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.02it/s, loss=0.2281]
# Epoch  43 | T_Loss: 0.4259 | [ZOOM_OU] Dice:0.7505 IoU:0.6237 CBL:0.8539 | [SHIFT] Dice:0.7667 IoU:0.6394 CBL:0.8649 | LR:1.0e-04
# Epoch 44/100 [Train]: 100%|██████| 462/462 [00:58<00:00,  7.91it/s, loss=0.2512]
# Epoch  44 | T_Loss: 0.4012 | [ZOOM_OU] Dice:0.7843 IoU:0.6625 CBL:0.8960 | [SHIFT] Dice:0.7750 IoU:0.6497 CBL:0.8907 | LR:1.0e-04
# Epoch 45/100 [Train]: 100%|██████| 462/462 [00:58<00:00,  7.84it/s, loss=0.4011]
# Epoch  45 | T_Loss: 0.4070 | [ZOOM_OU] Dice:0.7499 IoU:0.6221 CBL:0.8737 | [SHIFT] Dice:0.7726 IoU:0.6480 CBL:0.8910 | LR:1.0e-04
# Epoch 46/100 [Train]: 100%|██████| 462/462 [00:58<00:00,  7.84it/s, loss=0.9298]
# Epoch  46 | T_Loss: 0.4228 | [ZOOM_OU] Dice:0.7431 IoU:0.6115 CBL:0.8727 | [SHIFT] Dice:0.7595 IoU:0.6290 CBL:0.8756 | LR:5.0e-05
# Epoch 47/100 [Train]: 100%|██████| 462/462 [01:00<00:00,  7.68it/s, loss=0.2950]
# Epoch  47 | T_Loss: 0.4064 | [ZOOM_OU] Dice:0.7640 IoU:0.6391 CBL:0.8825 | [SHIFT] Dice:0.7718 IoU:0.6455 CBL:0.8868 | LR:5.0e-05
# Epoch 48/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.03it/s, loss=0.4746]
# Epoch  48 | T_Loss: 0.4153 | [ZOOM_OU] Dice:0.7636 IoU:0.6364 CBL:0.8794 | [SHIFT] Dice:0.7896 IoU:0.6693 CBL:0.8998 | LR:5.0e-05
# Epoch 49/100 [Train]: 100%|██████| 462/462 [00:58<00:00,  7.91it/s, loss=0.9612]
# Epoch  49 | T_Loss: 0.3975 | [ZOOM_OU] Dice:0.7674 IoU:0.6441 CBL:0.8853 | [SHIFT] Dice:0.7764 IoU:0.6521 CBL:0.8906 | LR:5.0e-05
# Epoch 50/100 [Train]: 100%|██████| 462/462 [00:58<00:00,  7.90it/s, loss=0.2747]
# Epoch  50 | T_Loss: 0.4201 | [ZOOM_OU] Dice:0.7704 IoU:0.6446 CBL:0.8846 | [SHIFT] Dice:0.7796 IoU:0.6545 CBL:0.8894 | LR:5.0e-05
# Epoch 51/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.03it/s, loss=0.3135]
# Epoch  51 | T_Loss: 0.3819 | [ZOOM_OU] Dice:0.7720 IoU:0.6512 CBL:0.8859 | [SHIFT] Dice:0.7797 IoU:0.6554 CBL:0.8911 | LR:5.0e-05
# Epoch 52/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.02it/s, loss=0.3511]
# Epoch  52 | T_Loss: 0.4088 | [ZOOM_OU] Dice:0.7601 IoU:0.6348 CBL:0.8771 | [SHIFT] Dice:0.7705 IoU:0.6443 CBL:0.8913 | LR:2.5e-05
# Epoch 53/100 [Train]: 100%|██████| 462/462 [00:59<00:00,  7.83it/s, loss=0.2099]
# Epoch  53 | T_Loss: 0.3832 | [ZOOM_OU] Dice:0.7692 IoU:0.6482 CBL:0.8841 | [SHIFT] Dice:0.7831 IoU:0.6601 CBL:0.8923 | LR:2.5e-05
# Epoch 54/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.08it/s, loss=0.2359]
# Epoch  54 | T_Loss: 0.3887 | [ZOOM_OU] Dice:0.7663 IoU:0.6438 CBL:0.8815 | [SHIFT] Dice:0.7752 IoU:0.6488 CBL:0.8851 | LR:2.5e-05
# Epoch 55/100 [Train]: 100%|██████| 462/462 [00:57<00:00,  8.05it/s, loss=0.4539]
# Epoch  55 | T_Loss: 0.4025 | [ZOOM_OU] Dice:0.7713 IoU:0.6503 CBL:0.8853 | [SHIFT] Dice:0.7787 IoU:0.6542 CBL:0.8869 | LR:2.5e-05
# Early stopping at epoch 55.
#
# Best Dice (zoom_out): 0.7893
# Checkpoint: checkpoints/pga_unet_mixed_128_best.pth

# %% [markdown]
# ## Test - zoom-out and shift scenarios (128x128)

# %%
# @title
"""
test_exp_scenarios.py
=====================
Evaluation of two prompt scenarios: 100% zoom-out | 100% shift
Visualize the image list: each image is shown under two scenarios (zoom-out and shift)

Usage:
    python test_exp_scenarios.py
"""

import os
import sys
import cv2
import json
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from scipy.ndimage import binary_erosion, distance_transform_edt

import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset
from models.networks.prompt_unet_2D import PGA_UNet

# =========================================================
# CONFIGURATION - edit here
# =========================================================
DEVICE             = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_PATH         = "checkpoints/pga_unet_mixed_128_best.pth"
IMG_SIZE           = 128
BATCH_SIZE         = 4
USE_ENCODER_PROMPT = True   # must match train.py's USE_ENCODER_PROMPT

TEST_IMAGE_DIR = "dataset_BTXRD/test/images"
TEST_JSON_DIR  = "dataset_BTXRD/test/annotations"


# =========================================================
# METRIC HELPERS & POST-PROCESSING
# =========================================================

def extract_lcc(binary_map: np.ndarray) -> np.ndarray:
    if binary_map.sum() == 0:
        return binary_map
    mask_uint8 = binary_map.astype(np.uint8)
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(mask_uint8, connectivity=8)
    if num_labels <= 1:
        return binary_map
    largest_label = 1 + np.argmax(stats[1:, cv2.CC_STAT_AREA])
    return (labels == largest_label).astype(np.float32)

def calc_hd95(pred: np.ndarray, gt: np.ndarray) -> float:
    pred, gt = pred.astype(bool), gt.astype(bool)
    if not pred.any() and not gt.any():
        return 0.0
    if not pred.any() or not gt.any():
        return float(IMG_SIZE)
    pe = pred ^ binary_erosion(pred)
    ge = gt   ^ binary_erosion(gt)
    d1 = distance_transform_edt(~ge)[pe]
    d2 = distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2):
        return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))

def calc_cbl(pred_bin: np.ndarray, gt_bin: np.ndarray):
    if gt_bin.sum() == 0:
        return None
    ys, xs = np.where(gt_bin)
    gt_diag = np.sqrt((ys.max() - ys.min()) ** 2 +
                      (xs.max() - xs.min()) ** 2) + 1e-6
    if pred_bin.sum() == 0:
        return 0.0
    yp, xp = np.where(pred_bin)
    d = np.sqrt((xp.mean() - xs.mean()) ** 2 +
                (yp.mean() - ys.mean()) ** 2)
    return float(np.clip(1.0 - d / gt_diag, 0.0, 1.0))

def get_centroid(binary_map: np.ndarray):
    if binary_map.sum() == 0:
        return None, None
    ys, xs = np.where(binary_map)
    return float(xs.mean()), float(ys.mean())

# =========================================================
# SINGLE-SCENARIO EVALUATION
# =========================================================

def run_eval(model: torch.nn.Module, prompt_mode: str) -> dict:
    ds = PromptSegmentationDataset(
        image_dir=TEST_IMAGE_DIR,
        json_dir=TEST_JSON_DIR,
        img_size=IMG_SIZE,
        is_train=False,
        prompt_mode=prompt_mode,
    )
    loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

    smooth = 1e-5
    all_dice, all_iou, all_pre, all_rec, all_hd95, all_cbl = [], [], [], [], [], []

    model.eval()
    with torch.no_grad():
        for images, masks, prompts in loader:
            images  = images.to(DEVICE)
            masks   = masks.to(DEVICE)
            prompts = prompts.to(DEVICE)
            preds   = (torch.sigmoid(model(images, prompts)) > 0.5).float()

            for b in range(images.size(0)):
                pm = preds[b, 0].cpu().numpy()
                gm = masks[b, 0].cpu().numpy()
                pm = extract_lcc(pm)

                tp = (pm * gm).sum()
                fp = (pm * (1 - gm)).sum()
                fn = ((1 - pm) * gm).sum()

                all_dice.append((2 * tp + smooth) / (2 * tp + fp + fn + smooth))
                all_iou.append( (tp + smooth) / (tp + fp + fn + smooth))
                all_pre.append( (tp + smooth) / (tp + fp + smooth))
                all_rec.append( (tp + smooth) / (tp + fn + smooth))
                all_hd95.append(calc_hd95(pm.astype(bool), gm.astype(bool)))

                cbl = calc_cbl(pm.astype(bool), gm.astype(bool))
                if cbl is not None:
                    all_cbl.append(cbl)

    return {
        'dice': np.mean(all_dice),
        'iou':  np.mean(all_iou),
        'pre':  np.mean(all_pre),
        'rec':  np.mean(all_rec),
        'hd95': np.mean(all_hd95),
        'cbl':  np.mean(all_cbl) if all_cbl else 0.0,
        'n':    len(all_dice),
    }

# =========================================================
# TWO-SCENARIO EVALUATION
# =========================================================

def evaluate_all(model: torch.nn.Module) -> dict:
    enc_tag = 'ON' if USE_ENCODER_PROMPT else 'OFF'
    print("\n" + "=" * 72)
    print(f"  TWO-SCENARIO EVALUATION  |  encoder_prompt = {enc_tag}")
    print("=" * 72)

    scenarios = {
        '100% Zoom-out': 'zoom_out',
        '100% Shift':    'shift',

    }

    results = {}
    for name, mode in scenarios.items():
        results[name] = run_eval(model, mode)
        print(f"  [{name}]  {results[name]['n']} samples, completed.")

    header = (f"\n{'Scenario':<16} {'Dice↑':>7} {'IoU↑':>7} "
              f"{'Pre↑':>7} {'Rec↑':>7} {'HD95↓':>8} {'CBL↑':>7} {'N':>5}")
    print(header)
    print("-" * 68)
    for name, r in results.items():
        print(f"{name:<16} {r['dice']:>7.4f} {r['iou']:>7.4f} "
              f"{r['pre']:>7.4f} {r['rec']:>7.4f} "
              f"{r['hd95']:>8.2f} {r['cbl']:>7.4f} {r['n']:>5}")
    return results

# =========================================================
# LOAD MODEL
# =========================================================
model = PGA_UNet(use_encoder_prompt=USE_ENCODER_PROMPT).to(DEVICE)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval()
print(f"Model loaded from: {MODEL_PATH}")

# =========================================================
# TWO-SCENARIO EVALUATION: summary table
# =========================================================
results = evaluate_all(model)

# =========================================================
# VISUALIZATION - first 10 samples in order (zoom_out)
# =========================================================
from IPython.display import display as _ipy_display
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from torch.utils.data import DataLoader
import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset

N_SHOW  = 10
_vis_dl = DataLoader(
    PromptSegmentationDataset(TEST_IMAGE_DIR, TEST_JSON_DIR, img_size=IMG_SIZE, is_train=False, prompt_mode="zoom_out"),
    batch_size=1, shuffle=False, num_workers=0)

fig, axes = plt.subplots(N_SHOW, 5, figsize=(20, 4 * N_SHOW))
fig.suptitle("PGA-UNet Train (128) - Visualization (zoom_out, first 10 samples)", fontsize=13, y=1.001)
for ax, ct in zip(axes[0], ["Input image", "Image + prompt", "Prediction", "Ground truth", "TP/FP/FN"]):
    ax.set_title(ct, fontsize=10, fontweight="bold")

model.eval()
count = 0
with torch.no_grad():
    for _img, _gt, _hm in _vis_dl:
        if count >= N_SHOW: break
        img_np  = (_img[0,0].cpu().numpy() * 0.5 + 0.5)
        hm_np   = _hm[0,0].cpu().numpy()
        gt_np   = (_gt[0,0].cpu().numpy() > 0.5).astype(float)
        prob_np = torch.sigmoid(model(_img.to(DEVICE), _hm.to(DEVICE)))[0,0].cpu().numpy()
        pred_np = (prob_np > 0.5).astype(float)

        tp=(pred_np*gt_np).sum(); fp=(pred_np*(1-gt_np)).sum(); fn=((1-pred_np)*gt_np).sum(); e=1e-6
        dice=float((2*tp+e)/(2*tp+fp+fn+e)); iou=float((tp+e)/(tp+fp+fn+e))
        pre=float((tp+e)/(tp+fp+e));         rec=float((tp+e)/(tp+fn+e))

        row = axes[count]
        bg  = np.stack([img_np]*3, axis=-1)

        row[0].imshow(img_np, cmap="gray", vmin=0, vmax=1)
        row[0].set_ylabel(f"#{count+1} Dice={dice:.3f}", fontsize=8)

        row[1].imshow(img_np, cmap="gray", vmin=0, vmax=1)
        row[1].imshow(hm_np, cmap="hot", alpha=0.4, vmin=0, vmax=1)

        pr_ov = bg.copy()
        pr_ov[...,0] = np.clip(pr_ov[...,0] + pred_np*0.55, 0, 1)
        pr_ov[...,1] = np.clip(pr_ov[...,1] - pred_np*0.2,  0, 1)
        row[2].imshow(pr_ov)
        row[2].set_title(f"Dice={dice:.3f} IoU={iou:.3f}", fontsize=7, color="darkred", pad=2)

        gt_ov = bg.copy()
        gt_ov[...,1] = np.clip(gt_ov[...,1] + gt_np*0.55, 0, 1)
        gt_ov[...,0] = np.clip(gt_ov[...,0] - gt_np*0.2,  0, 1)
        row[3].imshow(gt_ov)

        inter = bg.copy() * 0.25
        inter[...,1] = np.clip(inter[...,1] + pred_np*gt_np*0.9,     0, 1)
        inter[...,0] = np.clip(inter[...,0] + pred_np*(1-gt_np)*1.0, 0, 1)
        inter[...,2] = np.clip(inter[...,2] + (1-pred_np)*gt_np*1.0, 0, 1)
        row[4].imshow(inter)
        row[4].set_title(f"Pre={pre:.3f} Rec={rec:.3f}", fontsize=7, color="saddlebrown", pad=2)

        for ax in row: ax.axis("off")
        count += 1

fig.legend(handles=[Patch(facecolor="green",label="TP"),Patch(facecolor="red",label="FP"),Patch(facecolor="blue",label="FN")],
           loc="lower center", ncol=3, fontsize=9, bbox_to_anchor=(0.5,-0.01))
plt.tight_layout()
_ipy_display(fig)
plt.close(fig)
# Out:
# Model loaded from: checkpoints/pga_unet_mixed_128_best.pth
#
# ========================================================================
#   TWO-SCENARIO EVALUATION  |  encoder_prompt = ON
# ========================================================================
#   [100% Zoom-out]  232 samples, completed.
#   [100% Shift]  232 samples, completed.
#
# Scenario           Dice↑    IoU↑    Pre↑    Rec↑    HD95↓    CBL↑     N
# --------------------------------------------------------------------
# 100% Zoom-out     0.7841  0.6592  0.7140  0.8972     3.64  0.9088   232
# 100% Shift        0.7740  0.6442  0.7139  0.8741     3.99  0.8924   232
