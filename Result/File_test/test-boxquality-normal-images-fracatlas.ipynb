# %% [markdown]
# # Box quality on normal (lesion-free) images
#
# Sanity check requested by the advisor: when a box is drawn on an image that has
# no lesion at all, does the training-free self-assessment score $Q$ (already used
# for Claim 9/10) reliably stay low? This notebook does not train anything; it
# only runs inference with the already-trained PGA-UNet checkpoint on images with
# no ground-truth lesion, so no coverage/Dice can be computed here, only the
# distribution of $Q$ itself. Set `DS_NAME` below and rerun for the other dataset.
#
# Expected input: a Google Drive zip whose extracted folder contains only plain
# image files (png/jpg), no annotation JSON needed.

# %%
# -- Setup ---------------------------------------------------------------
# %cd /kaggle/working
import os, gdown, torch

print("CUDA:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

if not os.path.exists('PGA_Unet2D'):
    # !git clone --branch main --single-branch https://github.com/ThongLuc2k3/PGA_Unet2D.git
else:
    # !cd PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation && git pull -q

PGA_PATH = '/kaggle/working/PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation'
os.chdir(PGA_PATH)
# !pip install -q tqdm opencv-python matplotlib gdown scipy

# ── Choose dataset here, rerun the notebook for the other one ──────────────
DS_NAME = 'FracAtlas'   # or 'FracAtlas'

CKPT_ID_BY_DS = {
    'BTXRD':     '19WuyMmN9anS3ErDxfMFj8cOIAJYpxfI0',   # PGA-512 `00` (Dice+BCE, has QualityHead)
    'FracAtlas': '1ZUyhKEKqCZmPyGDBBOpsfQ7BuqJGFBhU',
}
CKPT_ID = CKPT_ID_BY_DS[DS_NAME]
CKPT_PATH = f'{PGA_PATH}/checkpoints/pga_unet_center_mixed_x3_shift05_qhead_512_best.pth'
os.makedirs(os.path.dirname(CKPT_PATH), exist_ok=True)
if not os.path.exists(CKPT_PATH):
    gdown.download(f'https://drive.google.com/uc?id={CKPT_ID}', CKPT_PATH, quiet=False)
assert os.path.exists(CKPT_PATH)

# ── Fill in once each normal-image zip is ready on Drive (separate id per
# dataset - BTXRD is entirely diseased so its zip has to come from an external
# source; FracAtlas's can be repackaged from its native non-fracture images) ──
# Expected zip layout: `Dataset_normal_{dataset}.zip`, images directly inside
# (flat or in subfolders), no annotation file needed.
NORMAL_IMAGES_ID_BY_DS = {
    'BTXRD':     '1SDl-TWl2PgNHxr2aABONtbHe605uGaOm',
    'FracAtlas': '19w_xQSHGOUZUQWwf2iqaw43yMyzCGuMy',
}
NORMAL_IMAGES_DRIVE_ID = NORMAL_IMAGES_ID_BY_DS[DS_NAME]
NORMAL_DIR = f'{PGA_PATH}/normal_images_{DS_NAME.lower()}'
if not os.path.exists(NORMAL_DIR):
    _zip = f'/kaggle/working/normal_images_{DS_NAME.lower()}.zip'
    gdown.download(f'https://drive.google.com/uc?id={NORMAL_IMAGES_DRIVE_ID}', _zip, quiet=False)
    os.makedirs(NORMAL_DIR, exist_ok=True)
    # !unzip -oq {_zip} -d {NORMAL_DIR}

RESULT_DIR = f'{PGA_PATH}/results'
os.makedirs(RESULT_DIR, exist_ok=True)
print(f'\nSetup complete | dataset={DS_NAME} | checkpoint {os.path.getsize(CKPT_PATH)//1024} KB')
# Out:
# /kaggle/working
# CUDA: True
# GPU: Tesla T4
# Cloning into 'PGA_Unet2D'...
# remote: Enumerating objects: 4786, done.
# remote: Counting objects: 100% (568/568), done.
# remote: Compressing objects: 100% (179/179), done.
# remote: Total 4786 (delta 427), reused 459 (delta 389), pack-reused 4218 (from 1)
# Receiving objects: 100% (4786/4786), 1.22 GiB | 33.58 MiB/s, done.
# Resolving deltas: 100% (2951/2951), done.
# Downloading...
# From: https://drive.google.com/uc?id=1ZUyhKEKqCZmPyGDBBOpsfQ7BuqJGFBhU
# To: /kaggle/working/PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/checkpoints/pga_unet_center_mixed_x3_shift05_qhead_512_best.pth
# 100%|██████████| 11.9M/11.9M [00:00<00:00, 46.4MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=19w_xQSHGOUZUQWwf2iqaw43yMyzCGuMy
# From (redirected): https://drive.google.com/uc?id=19w_xQSHGOUZUQWwf2iqaw43yMyzCGuMy&confirm=t&uuid=7a43fef2-bf01-4d0e-9d90-60adb38b72b1
# To: /kaggle/working/normal_images_fracatlas.zip
# 100%|██████████| 640M/640M [00:08<00:00, 76.0MB/s]
# Setup complete | dataset=FracAtlas | checkpoint 11645 KB

# %%
# -- Model + shared helpers (same Q definition as Claim 9/10) -------------
import sys, csv, glob
import numpy as np
import torch
import cv2
import matplotlib.pyplot as plt

for _k in list(sys.modules.keys()):
    if any(x in _k for x in ('dataset', 'models', 'prompt_unet')):
        del sys.modules[_k]
if PGA_PATH in sys.path: sys.path.remove(PGA_PATH)
sys.path.insert(0, PGA_PATH)
from models.networks.prompt_unet_2D import PGA_UNet

DEVICE   = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
IMG_SIZE = 512
KERNEL   = 31
N_CANDIDATES = 50
SIZE_FRAC    = (0.15, 0.55)   # same box-size distribution as Part B of the Claim-10 notebook
K_STAB       = 4
JITTER_SHIFT = 0.12
JITTER_SCALE = 0.10
SEED         = 22120196

model = PGA_UNet(in_channels=1, n_classes=1, use_encoder_prompt=True, use_quality_head=True).to(DEVICE)
model.load_state_dict(torch.load(CKPT_PATH, map_location=DEVICE, weights_only=True))
model.eval()

def resize_and_pad(arr, size, interp, pad=0):
    h, w = arr.shape[:2]
    sc = min(size / w, size / h)
    nw, nh = max(1, round(w * sc)), max(1, round(h * sc))
    r = cv2.resize(arr, (nw, nh), interpolation=interp)
    out = np.full((size, size), pad, dtype=r.dtype)
    pl, pt = (size - nw) // 2, (size - nh) // 2
    out[pt:pt + nh, pl:pl + nw] = r
    return out

def load_normal_image(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    canvas = resize_and_pad(img, IMG_SIZE, cv2.INTER_LINEAR, 0)
    canvas = (canvas.astype(np.float32) / 255.0 - 0.5) / 0.5
    return canvas

def plateau_heatmap(box, size=IMG_SIZE, kernel=KERNEL):
    hm = np.zeros((size, size), dtype=np.float32)
    x0, y0, x1, y1 = [int(round(v)) for v in box]
    x0, y0 = max(0, x0), max(0, y0); x1, y1 = min(size, x1), min(size, y1)
    if x1 > x0 and y1 > y0:
        hm[y0:y1, x0:x1] = 1.0
        hm = cv2.GaussianBlur(hm, (kernel, kernel), 0)
    return hm

def jitter_boxes(box, k, rng):
    x0, y0, x1, y1 = box
    w, h = x1 - x0, y1 - y0
    out = []
    for _ in range(k):
        sx = rng.uniform(-JITTER_SHIFT, JITTER_SHIFT) * w
        sy = rng.uniform(-JITTER_SHIFT, JITTER_SHIFT) * h
        fs = 1.0 + rng.uniform(-JITTER_SCALE, JITTER_SCALE)
        nw, nh = w * fs, h * fs
        cx, cy = (x0 + x1) / 2 + sx, (y0 + y1) / 2 + sy
        out.append([cx - nw / 2, cy - nh / 2, cx + nw / 2, cy + nh / 2])
    return out

def masks_from_boxes(img_t, boxes, batch=24):
    out = []
    with torch.no_grad():
        for i in range(0, len(boxes), batch):
            chunk = boxes[i:i + batch]
            hm = np.stack([plateau_heatmap(b) for b in chunk])
            hm_t = torch.from_numpy(hm).unsqueeze(1).float().to(DEVICE)
            rep = img_t.expand(len(chunk), 1, IMG_SIZE, IMG_SIZE)
            logits = model(rep, hm_t)
            p = torch.sigmoid(logits)[:, 0].cpu().numpy()
            out.extend([(pi > 0.5) for pi in p])
    return out

def iou(a, b):
    a, b = a.astype(bool), b.astype(bool)
    u = (a | b).sum()
    if u == 0:
        return 0.0
    return float((a & b).sum() / u)

def s_sharp(p, m):
    if m.sum() == 0:
        return 0.0
    return float(np.clip(2 * p[m].mean() - 1, 0, 1))

def stab_scores(img_t, boxes, base_masks, k, rng):
    jitter_all, owner = [], []
    for bi, b in enumerate(boxes):
        for jb in jitter_boxes(b, k, rng):
            jitter_all.append(jb); owner.append(bi)
    jmasks = masks_from_boxes(img_t, jitter_all)
    acc = [[] for _ in boxes]
    for o, jm in zip(owner, jmasks):
        acc[o].append(iou(base_masks[o], jm))
    return np.array([np.mean(a) if a else 0.0 for a in acc])

print('helpers ready | device', DEVICE)
# Out:
# helpers ready | device cuda

# %% [markdown]
# ## Part N - Q on random boxes drawn over lesion-free images
#
# For each normal image, sample the same 50 random boxes (same size/position
# distribution as the candidate-suggestion experiment) and score each with $Q =
# \mathrm{mean}(S_\mathrm{sharp}, S_\mathrm{stab})$. No coverage/Dice is defined
# here since there is no lesion; the only question is whether $Q$ stays low.

# %%
# -- Part N -----------------------------------------------------------
rng = np.random.default_rng(SEED)
paths = sorted(p for p in glob.glob(os.path.join(NORMAL_DIR, '**', '*'), recursive=True)
               if p.lower().endswith(('.png', '.jpg', '.jpeg')))
assert len(paths) > 0, f'No images found under {NORMAL_DIR} - check NORMAL_IMAGES_DRIVE_ID'

per_box = []
for n_done, path in enumerate(paths):
    canvas = load_normal_image(path)
    img_t = torch.from_numpy(canvas).unsqueeze(0).unsqueeze(0).to(DEVICE)
    boxes = []
    for _ in range(N_CANDIDATES):
        bw = rng.uniform(*SIZE_FRAC) * IMG_SIZE; bh = rng.uniform(*SIZE_FRAC) * IMG_SIZE
        bx = rng.uniform(0, IMG_SIZE - bw); by = rng.uniform(0, IMG_SIZE - bh)
        boxes.append([bx, by, bx + bw, by + bh])
    base_masks = masks_from_boxes(img_t, boxes)
    hm = np.stack([plateau_heatmap(b) for b in boxes])
    with torch.no_grad():
        probs = []
        for i in range(0, len(boxes), 24):
            ch = hm[i:i + 24]
            lt = model(img_t.expand(len(ch), 1, IMG_SIZE, IMG_SIZE),
                       torch.from_numpy(ch).unsqueeze(1).float().to(DEVICE))
            probs.append(torch.sigmoid(lt)[:, 0].cpu().numpy())
        probs = np.concatenate(probs)
    ss = np.array([s_sharp(p, m) for p, m in zip(probs, base_masks)])
    st = stab_scores(img_t, boxes, base_masks, K_STAB, rng)
    q_scores = np.mean(np.stack([ss, st]), axis=0)
    img_name = os.path.basename(path)
    for bi in range(len(boxes)):
        per_box.append(dict(dataset=DS_NAME, image=img_name, box_idx=bi, q=float(q_scores[bi])))
    if (n_done + 1) % 10 == 0:
        print(f'  {n_done + 1}/{len(paths)} normal images')

with open(f'{RESULT_DIR}/boxquality_normal_{DS_NAME.lower()}.csv', 'w', newline='') as f:
    w = csv.DictWriter(f, fieldnames=list(per_box[0].keys())); w.writeheader(); w.writerows(per_box)
print(f'\nSaved {len(per_box)} box scores across {len(paths)} normal images')
# Out:
#   10/3366 normal images
#   20/3366 normal images
#   30/3366 normal images
#   40/3366 normal images
#   50/3366 normal images
#   60/3366 normal images
#   70/3366 normal images
#   80/3366 normal images
#   90/3366 normal images
#   100/3366 normal images
#   110/3366 normal images
#   120/3366 normal images
#   130/3366 normal images
#   140/3366 normal images
#   150/3366 normal images
#   160/3366 normal images
#   170/3366 normal images
#   180/3366 normal images
#   190/3366 normal images
#   200/3366 normal images
#   210/3366 normal images
#   220/3366 normal images
#   230/3366 normal images
#   240/3366 normal images
#   250/3366 normal images
#   260/3366 normal images
#   270/3366 normal images
#   280/3366 normal images
#   290/3366 normal images
#   300/3366 normal images
#   310/3366 normal images
#   320/3366 normal images
#   330/3366 normal images
#   340/3366 normal images
#   350/3366 normal images
#   360/3366 normal images
#   370/3366 normal images
#   380/3366 normal images
#   390/3366 normal images
#   400/3366 normal images
#   410/3366 normal images
#   420/3366 normal images
#   430/3366 normal images
#   440/3366 normal images
#   450/3366 normal images
#   460/3366 normal images
#   470/3366 normal images
#   480/3366 normal images
#   490/3366 normal images
#   500/3366 normal images
#   510/3366 normal images
#   520/3366 normal images
#   530/3366 normal images
#   540/3366 normal images
#   550/3366 normal images
#   560/3366 normal images
#   570/3366 normal images
#   580/3366 normal images
#   590/3366 normal images
#   600/3366 normal images
#   610/3366 normal images
#   620/3366 normal images
#   630/3366 normal images
#   640/3366 normal images
#   650/3366 normal images
#   660/3366 normal images
#   670/3366 normal images
#   680/3366 normal images
#   690/3366 normal images
#   700/3366 normal images
#   710/3366 normal images
#   720/3366 normal images
#   730/3366 normal images
#   740/3366 normal images
#   750/3366 normal images
#   760/3366 normal images
#   770/3366 normal images
#   780/3366 normal images
#   790/3366 normal images
#   800/3366 normal images
#   810/3366 normal images
#   820/3366 normal images
#   830/3366 normal images
#   840/3366 normal images
#   850/3366 normal images
#   860/3366 normal images
#   870/3366 normal images
#   880/3366 normal images
#   890/3366 normal images
#   900/3366 normal images
#   910/3366 normal images
#   920/3366 normal images
#   930/3366 normal images
#   940/3366 normal images
#   950/3366 normal images
#   960/3366 normal images
#   970/3366 normal images
#   980/3366 normal images
#   990/3366 normal images
#   1000/3366 normal images
#   1010/3366 normal images
#   1020/3366 normal images
#   1030/3366 normal images
#   1040/3366 normal images
#   1050/3366 normal images
#   1060/3366 normal images
#   1070/3366 normal images
#   1080/3366 normal images
#   1090/3366 normal images
#   1100/3366 normal images
#   1110/3366 normal images
#   1120/3366 normal images
#   1130/3366 normal images
#   1140/3366 normal images
#   1150/3366 normal images
#   1160/3366 normal images
#   1170/3366 normal images
#   1180/3366 normal images
#   1190/3366 normal images
#   1200/3366 normal images
#   1210/3366 normal images
#   1220/3366 normal images
#   1230/3366 normal images
#   1240/3366 normal images
#   1250/3366 normal images
#   1260/3366 normal images
#   1270/3366 normal images
#   1280/3366 normal images
#   1290/3366 normal images
#   1300/3366 normal images
#   1310/3366 normal images
#   1320/3366 normal images
#   1330/3366 normal images
#   1340/3366 normal images
#   1350/3366 normal images
#   1360/3366 normal images
#   1370/3366 normal images
#   1380/3366 normal images
#   1390/3366 normal images
#   1400/3366 normal images
#   1410/3366 normal images
#   1420/3366 normal images
#   1430/3366 normal images
#   1440/3366 normal images
#   1450/3366 normal images
#   1460/3366 normal images
#   1470/3366 normal images
#   1480/3366 normal images
#   1490/3366 normal images
#   1500/3366 normal images
#   1510/3366 normal images
#   1520/3366 normal images
#   1530/3366 normal images
#   1540/3366 normal images
#   1550/3366 normal images
#   1560/3366 normal images
#   1570/3366 normal images
#   1580/3366 normal images
#   1590/3366 normal images
#   1600/3366 normal images
#   1610/3366 normal images
#   1620/3366 normal images
#   1630/3366 normal images
#   1640/3366 normal images
#   1650/3366 normal images
#   1660/3366 normal images
#   1670/3366 normal images
#   1680/3366 normal images
#   1690/3366 normal images
#   1700/3366 normal images
#   1710/3366 normal images
#   1720/3366 normal images
#   1730/3366 normal images
#   1740/3366 normal images
#   1750/3366 normal images
#   1760/3366 normal images
#   1770/3366 normal images
#   1780/3366 normal images
#   1790/3366 normal images
#   1800/3366 normal images
#   1810/3366 normal images
#   1820/3366 normal images
#   1830/3366 normal images
#   1840/3366 normal images
#   1850/3366 normal images
#   1860/3366 normal images
#   1870/3366 normal images
#   1880/3366 normal images
#   1890/3366 normal images
#   1900/3366 normal images
#   1910/3366 normal images
#   1920/3366 normal images
#   1930/3366 normal images
#   1940/3366 normal images
#   1950/3366 normal images
#   1960/3366 normal images
#   1970/3366 normal images
#   1980/3366 normal images
#   1990/3366 normal images
#   2000/3366 normal images
#   2010/3366 normal images
#   2020/3366 normal images
#   2030/3366 normal images
#   2040/3366 normal images
#   2050/3366 normal images
#   2060/3366 normal images
#   2070/3366 normal images
#   2080/3366 normal images
#   2090/3366 normal images
#   2100/3366 normal images
#   2110/3366 normal images
#   2120/3366 normal images
#   2130/3366 normal images
#   2140/3366 normal images
#   2150/3366 normal images
#   2160/3366 normal images
#   2170/3366 normal images
#   2180/3366 normal images
#   2190/3366 normal images
#   2200/3366 normal images
#   2210/3366 normal images
#   2220/3366 normal images
#   2230/3366 normal images
#   2240/3366 normal images
#   2250/3366 normal images
#   2260/3366 normal images
#   2270/3366 normal images
#   2280/3366 normal images
#   2290/3366 normal images
#   2300/3366 normal images
#   2310/3366 normal images
#   2320/3366 normal images
#   2330/3366 normal images
#   2340/3366 normal images
#   2350/3366 normal images
#   2360/3366 normal images
#   2370/3366 normal images
#   2380/3366 normal images
#   2390/3366 normal images
#   2400/3366 normal images
#   2410/3366 normal images
#   2420/3366 normal images
#   2430/3366 normal images
#   2440/3366 normal images
#   2450/3366 normal images
#   2460/3366 normal images
#   2470/3366 normal images
#   2480/3366 normal images
#   2490/3366 normal images
#   2500/3366 normal images
#   2510/3366 normal images
#   2520/3366 normal images
#   2530/3366 normal images
#   2540/3366 normal images
#   2550/3366 normal images
#   2560/3366 normal images
#   2570/3366 normal images
#   2580/3366 normal images
#   2590/3366 normal images
#   2600/3366 normal images
#   2610/3366 normal images
#   2620/3366 normal images
#   2630/3366 normal images
#   2640/3366 normal images
#   2650/3366 normal images
#   2660/3366 normal images
#   2670/3366 normal images
#   2680/3366 normal images
#   2690/3366 normal images
#   2700/3366 normal images
#   2710/3366 normal images
#   2720/3366 normal images
#   2730/3366 normal images
#   2740/3366 normal images
#   2750/3366 normal images
#   2760/3366 normal images
#   2770/3366 normal images
#   2780/3366 normal images
#   2790/3366 normal images
#   2800/3366 normal images
#   2810/3366 normal images
#   2820/3366 normal images
#   2830/3366 normal images
#   2840/3366 normal images
#   2850/3366 normal images
#   2860/3366 normal images
#   2870/3366 normal images
#   2880/3366 normal images
#   2890/3366 normal images
#   2900/3366 normal images
#   2910/3366 normal images
#   2920/3366 normal images
#   2930/3366 normal images
#   2940/3366 normal images
#   2950/3366 normal images
#   2960/3366 normal images
#   2970/3366 normal images
#   2980/3366 normal images
#   2990/3366 normal images
#   3000/3366 normal images
#   3010/3366 normal images
#   3020/3366 normal images
#   3030/3366 normal images
#   3040/3366 normal images
#   3050/3366 normal images
#   3060/3366 normal images
#   3070/3366 normal images
#   3080/3366 normal images
#   3090/3366 normal images
#   3100/3366 normal images
#   3110/3366 normal images
#   3120/3366 normal images
#   3130/3366 normal images
#   3140/3366 normal images
#   3150/3366 normal images
#   3160/3366 normal images
#   3170/3366 normal images
#   3180/3366 normal images
#   3190/3366 normal images
#   3200/3366 normal images
#   3210/3366 normal images
#   3220/3366 normal images
#   3230/3366 normal images
#   3240/3366 normal images
#   3250/3366 normal images
#   3260/3366 normal images
#   3270/3366 normal images
#   3280/3366 normal images
#   3290/3366 normal images
#   3300/3366 normal images
#   3310/3366 normal images
#   3320/3366 normal images
#   3330/3366 normal images
#   3340/3366 normal images
#   3350/3366 normal images
#   3360/3366 normal images
#
# Saved 168300 box scores across 3366 normal images

# %%
# -- Part N summary -----------------------------------------------------
import pandas as pd

df = pd.DataFrame(per_box)
qs = df['q'].to_numpy()
print(f'{DS_NAME} normal images: {df.image.nunique()} images, {len(df)} boxes\n')
print(f'mean Q   = {qs.mean():.3f}')
print(f'median Q = {np.median(qs):.3f}')
print(f'p90 Q    = {np.percentile(qs, 90):.3f}')
for thr in (0.5, 0.6, 0.7):
    frac = float((qs >= thr).mean())
    print(f'fraction of boxes with Q >= {thr}: {frac:.1%}')

# Per-image worst case: the single highest Q seen for each normal image
# (a conservative check - if even the highest-scoring box per normal image
# stays low, no box drawn there would look falsely confident)
worst = df.groupby('image')['q'].max()
print(f'\nmean of per-image MAX Q = {worst.mean():.3f} (worst-case per image)')
# Out:
# FracAtlas normal images: 3366 images, 168300 boxes
#
# mean Q   = 0.336
# median Q = 0.074
# p90 Q    = 0.821
# fraction of boxes with Q >= 0.5: 42.1%
# fraction of boxes with Q >= 0.6: 35.7%
# fraction of boxes with Q >= 0.7: 26.1%
#
# mean of per-image MAX Q = 0.899 (worst-case per image)

# %%
# -- Part N qualitative: a few normal images with their highest-Q box ---
from matplotlib.patches import Rectangle

picks = sorted(set(df['image']))[:6]
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
for ax, img_name in zip(axes.ravel(), picks):
    canvas = load_normal_image(os.path.join(NORMAL_DIR, img_name)) if os.path.exists(os.path.join(NORMAL_DIR, img_name)) \
             else load_normal_image(next(p for p in paths if os.path.basename(p) == img_name))
    sub = df[df.image == img_name].sort_values('q', ascending=False)
    ax.imshow(canvas, cmap='gray')
    ax.set_title(f'{img_name}\nmax Q={sub.q.iloc[0]:.2f}', fontsize=9)
    ax.axis('off')
plt.tight_layout()
plt.savefig(f'{RESULT_DIR}/boxquality_normal_{DS_NAME.lower()}_examples.png', dpi=150)
plt.show()
