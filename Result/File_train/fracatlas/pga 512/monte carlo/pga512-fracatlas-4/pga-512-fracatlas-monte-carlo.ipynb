# %% [markdown]
# **Full environment, dataset, and code setup**

# %%
# =========================================================
# CELL 1 - FULL SETUP COLAB
# =========================================================
# ===== CHANGE DIRECTORY (auto-detect Colab / Kaggle) =====
import os
BASE = "/kaggle/working" if os.path.exists("/kaggle/working") else "/content"
# %cd $BASE
# ===== CHECK GPU =====
import torch

print("=" * 50)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("=" * 50)

# =========================================================
# CLONE GITHUB
# =========================================================

# !rm -rf $BASE/PGA_Unet2D
# !git clone --branch main --single-branch https://github.com/ThongLuc2k3/PGA_Unet2D.git

# =========================================================
# DOWNLOAD DATASET ZIP FROM GOOGLE DRIVE
# =========================================================

# !gdown --id 1QfvGXmU8Z93Kwq0CeKDqBWC493aExDTP -O dataset_FracAtlas.zip

# =========================================================
# UNZIP DATASET
# =========================================================

# !unzip -oq dataset_FracAtlas.zip

# =========================================================
# INSPECT DATASET
# =========================================================

print("\nDATASET STRUCTURE:")
# !ls dataset_FracAtlas

# =========================================================
# COPY DATASET INTO THE PROJECT
# =========================================================

# !rm -rf PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/dataset_FracAtlas
# !mv dataset_FracAtlas PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/

# =========================================================
# ENTER THE PROJECT DIRECTORY
# =========================================================

# %cd PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation

# =========================================================
# INSTALL REQUIREMENTS
# =========================================================

# !pip install -q tqdm opencv-python matplotlib scikit-image gdown scipy

print("\nSETUP DONE!")
# Out:
# /kaggle/working
# ==================================================
# CUDA: True
# GPU: Tesla T4
# ==================================================
# Cloning into 'PGA_Unet2D'...
# remote: Enumerating objects: 4345, done.
# remote: Counting objects: 100% (582/582), done.
# remote: Compressing objects: 100% (280/280), done.
# remote: Total 4345 (delta 391), reused 433 (delta 301), pack-reused 3763 (from 2)
# Receiving objects: 100% (4345/4345), 1.21 GiB | 43.32 MiB/s, done.
# Resolving deltas: 100% (2605/2605), done.
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1QfvGXmU8Z93Kwq0CeKDqBWC493aExDTP
# From (redirected): https://drive.google.com/uc?id=1QfvGXmU8Z93Kwq0CeKDqBWC493aExDTP&confirm=t&uuid=b1d32391-ac08-40d3-8cd2-7612b9abdd49
# To: /kaggle/working/dataset_FracAtlas.zip
# 100%|████████████████████████████████████████| 231M/231M [00:03<00:00, 59.2MB/s]
#
# DATASET STRUCTURE:
# test  train  val
# /kaggle/working/PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation
#
# SETUP DONE!

# %% [markdown]
# **Train** (center_mixed x3/shift0.5, 80% shift / 20% zoom, QualityHead)

# %%
# =========================================================
# TRAIN - center_mixed (80% shift / 20% zoom) x3/shift0.5, QualityHead
# =========================================================
# Loss switch: set exactly one of these to 1 to compare against the baseline
# (both 0 = plain Dice + BCE, the default). Setting both to 1 raises a
# ValueError in train.py (they both replace dice_loss).
USE_SIZE_TVERSKY = 0   # size-conditioned Tversky: penalizes false positives more on small lesions
USE_FOCAL_DICE   = 0   # Focal Dice: amplifies gradient on the hardest samples

# !PROMPT_DATASET_ROOT=dataset_FracAtlas PROMPT_IMG_SIZE=512 \
 PROMPT_MODE=center_mixed PROMPT_SCALE_FACTOR=3.0 PROMPT_SHIFT_RATIO=0.5 PROMPT_MIXED_SHIFT_PROB=0.8 \
 USE_QUALITY_HEAD=1 LOSS_CONFIDENCE_WEIGHT=1.0 PROMPT_EPOCHS=150 PROMPT_SEED=22120196 \
 USE_SIZE_TVERSKY={USE_SIZE_TVERSKY} USE_FOCAL_DICE={USE_FOCAL_DICE} \
 python train.py
# Out:
# ==========================================================================================
# TrainPrompt: center_mixed | Device: cuda | EncoderPrompt: True | ImgSize: 512 | DatasetRoot: dataset_FracAtlas | Seed: 22120196 | ScaleFactor: 3.0 | ShiftRatio: 0.5 | MixedShiftProb: 0.8 | QualityHead: ConfidenceLossWeight=1.0
# ==========================================================================================
# Epoch 1/150 [Train]: 100%|███████| 183/183 [00:54<00:00,  3.36it/s, loss=1.4690]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.6015 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0415 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0415 | LR:1.0e-04
# Epoch 2/150 [Train]: 100%|███████| 183/183 [00:57<00:00,  3.20it/s, loss=1.3959]
# 🥇 [BEST] Epoch   2 | T_Loss: 1.4212 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0141 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0144 | LR:1.0e-04
# Epoch 3/150 [Train]: 100%|███████| 183/183 [01:01<00:00,  2.98it/s, loss=1.4983]
# 🥇 [BEST] Epoch   3 | T_Loss: 1.3936 | [CENTER_] Dice:0.2997 IoU:0.2101 CBL:0.5699 | [CENTER_] Dice:0.2806 IoU:0.1935 CBL:0.5381 | LR:1.0e-04
# Epoch 4/150 [Train]: 100%|███████| 183/183 [01:00<00:00,  3.01it/s, loss=1.3390]
# 🥇 [BEST] Epoch   4 | T_Loss: 1.4026 | [CENTER_] Dice:0.5856 IoU:0.4378 CBL:0.8324 | [CENTER_] Dice:0.5480 IoU:0.3986 CBL:0.7924 | LR:1.0e-04
# Epoch 5/150 [Train]: 100%|███████| 183/183 [01:00<00:00,  3.03it/s, loss=1.3419]
# Epoch   5 | T_Loss: 1.3437 | [CENTER_] Dice:0.5503 IoU:0.3935 CBL:0.8625 | [CENTER_] Dice:0.5231 IoU:0.3684 CBL:0.8017 | LR:1.0e-04
# Epoch 6/150 [Train]: 100%|███████| 183/183 [01:00<00:00,  3.02it/s, loss=1.2699]
# Epoch   6 | T_Loss: 1.3046 | [CENTER_] Dice:0.5034 IoU:0.3441 CBL:0.9064 | [CENTER_] Dice:0.5019 IoU:0.3448 CBL:0.8409 | LR:1.0e-04
# Epoch 7/150 [Train]: 100%|███████| 183/183 [01:00<00:00,  3.04it/s, loss=1.4017]
# Epoch   7 | T_Loss: 1.2715 | [CENTER_] Dice:0.5178 IoU:0.3585 CBL:0.8226 | [CENTER_] Dice:0.5145 IoU:0.3570 CBL:0.7634 | LR:1.0e-04
# Epoch 8/150 [Train]: 100%|███████| 183/183 [01:00<00:00,  3.05it/s, loss=1.1979]
# Epoch   8 | T_Loss: 1.2454 | [CENTER_] Dice:0.5210 IoU:0.3611 CBL:0.9055 | [CENTER_] Dice:0.5169 IoU:0.3593 CBL:0.8483 | LR:1.0e-04
# Epoch 9/150 [Train]: 100%|███████| 183/183 [01:00<00:00,  3.03it/s, loss=1.1729]
# Epoch   9 | T_Loss: 1.2140 | [CENTER_] Dice:0.4699 IoU:0.3128 CBL:0.8945 | [CENTER_] Dice:0.4728 IoU:0.3166 CBL:0.8614 | LR:1.0e-04
# Epoch 10/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=1.1706]
# 🥇 [BEST] Epoch  10 | T_Loss: 1.1893 | [CENTER_] Dice:0.5833 IoU:0.4211 CBL:0.8797 | [CENTER_] Dice:0.5483 IoU:0.3888 CBL:0.8273 | LR:1.0e-04
# Epoch 11/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.03it/s, loss=1.1305]
# Epoch  11 | T_Loss: 1.1571 | [CENTER_] Dice:0.5275 IoU:0.3654 CBL:0.9162 | [CENTER_] Dice:0.5160 IoU:0.3560 CBL:0.8503 | LR:1.0e-04
# Epoch 12/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.01it/s, loss=1.2966]
# Epoch  12 | T_Loss: 1.1435 | [CENTER_] Dice:0.5442 IoU:0.3825 CBL:0.9169 | [CENTER_] Dice:0.5405 IoU:0.3808 CBL:0.8544 | LR:1.0e-04
# Epoch 13/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=1.0852]
# Epoch  13 | T_Loss: 1.1283 | [CENTER_] Dice:0.5067 IoU:0.3468 CBL:0.9148 | [CENTER_] Dice:0.5088 IoU:0.3500 CBL:0.8496 | LR:1.0e-04
# Epoch 14/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss
| LR:1.0e-04
# Epoch 31/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.01it/s, loss=0.7020]
# 🥇 [BEST] Epoch  31 | T_Loss: 0.6973 | [CENTER_] Dice:0.7072 IoU:0.5642 CBL:0.9165 | [CENTER_] Dice:0.7008 IoU:0.5595 CBL:0.8867 | LR:1.0e-04
# Epoch 32/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.01it/s, loss=0.5891]
# Epoch  32 | T_Loss: 0.6558 | [CENTER_] Dice:0.7020 IoU:0.5524 CBL:0.9063 | [CENTER_] Dice:0.6955 IoU:0.5458 CBL:0.8920 | LR:1.0e-04
# Epoch 33/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.6482]
# 🥇 [BEST] Epoch  33 | T_Loss: 0.6443 | [CENTER_] Dice:0.7189 IoU:0.5769 CBL:0.9198 | [CENTER_] Dice:0.7123 IoU:0.5706 CBL:0.9074 | LR:1.0e-04
# Epoch 34/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.8956]
# Epoch  34 | T_Loss: 0.6313 | [CENTER_] Dice:0.6957 IoU:0.5453 CBL:0.9041 | [CENTER_] Dice:0.6748 IoU:0.5240 CBL:0.8728 | LR:1.0e-04
# Epoch 35/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.03it/s, loss=0.4514]
# Epoch  35 | T_Loss: 0.5765 | [CENTER_] Dice:0.7126 IoU:0.5705 CBL:0.8981 | [CENTER_] Dice:0.6911 IoU:0.5482 CBL:0.8756 | LR:1.0e-04
# Epoch 36/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.03it/s, loss=0.5223]
# Epoch  36 | T_Loss: 0.5982 | [CENTER_] Dice:0.7191 IoU:0.5790 CBL:0.9193 | [CENTER_] Dice:0.7000 IoU:0.5601 CBL:0.8849 | LR:1.0e-04
# Epoch 37/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.5195]
# Epoch  37 | T_Loss: 0.5850 | [CENTER_] Dice:0.7194 IoU:0.5895 CBL:0.8972 | [CENTER_] Dice:0.7004 IoU:0.5668 CBL:0.8842 | LR:1.0e-04
# Epoch 38/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.01it/s, loss=0.4551]
# Epoch  38 | T_Loss: 0.5382 | [CENTER_] Dice:0.7304 IoU:0.5918 CBL:0.9203 | [CENTER_] Dice:0.7021 IoU:0.5628 CBL:0.8931 | LR:1.0e-04
# Epoch 39/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.01it/s, loss=0.3844]
# 🥇 [BEST] Epoch  39 | T_Loss: 0.5503 | [CENTER_] Dice:0.7243 IoU:0.5851 CBL:0.9077 | [CENTER_] Dice:0.7169 IoU:0.5799 CBL:0.8907 | LR:1.0e-04
# Epoch 40/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.03it/s, loss=0.3481]
# 🥇 [BEST] Epoch  40 | T_Loss: 0.5026 | [CENTER_] Dice:0.7430 IoU:0.6051 CBL:0.9217 | [CENTER_] Dice:0.7249 IoU:0.5848 CBL:0.8917 | LR:1.0e-04
# Epoch 41/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.03it/s, loss=0.6940]
# Epoch  41 | T_Loss: 0.4994 | [CENTER_] Dice:0.7184 IoU:0.5766 CBL:0.9110 | [CENTER_] Dice:0.6860 IoU:0.5438 CBL:0.8754 | LR:1.0e-04
# Epoch 42/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.7872]
# Epoch  42 | T_Loss: 0.5093 | [CENTER_] Dice:0.7589 IoU:0.6263 CBL:0.9265 | [CENTER_] Dice:0.7221 IoU:0.5815 CBL:0.8986 | LR:1.0e-04
# Epoch 43/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.01it/s, loss=0.8943]
# Epoch  43 | T_Loss: 0.4871 | [CENTER_] Dice:0.7288 IoU:0.5889 CBL:0.9098 | [CENTER_] Dice:0.7199 IoU:0.5795 CBL:0.8902 | LR:1.0e-04
# Epoch 44/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.2784]
# Epoch  44 | T_Loss: 0.4993 | [CENTER_] Dice:0.7331 IoU:0.5949 CBL:0.9222 | [CENTER_] Dice:0.7147 IoU:0.5771 CBL:0.8950 | LR:1.0e-04
# Epoch 45/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.3371]
# Epoch  45 | T_Loss: 0.4672 | [CENTER_] Dice:0.7276 IoU:0.5886 CBL:0.9106 | [CENTER_] Dice:0.7147 IoU:0.5739 CBL:0.8908 | LR:1.0e-04
# Epoch 46/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.8569]
# Epoch  46 | T_Loss: 0.4845 | [CENTER_] Dice:0.7227 IoU:0.5855 CBL:0.9014 | [CENTER_] Dice:0.6982 IoU:0.5563 CBL:0.8741 | LR:5.0e-05
# Epoch 47/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.01it/s, loss=0.2955]
# Epoch  47 | T_Loss: 0.4691 | [CENTER_] Dice:0.7319 IoU:0.5973 CBL:0.9115 | [CENTER_] Dice:0.7131 IoU:0.5750 CBL:0.8896 | LR:5.0e-05
# Epoch 48/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.4269]
# Epoch  48 | T_Loss: 0.4453 | [CENTER_] Dice:0.7267 IoU:0.5921 CBL:0.9002 | [CENTER_] Dice:0.7020 IoU:0.5636 CBL:0.8793 | LR:5.0e-05
# Epoch 49/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.01it/s, loss=0.4377]
# Epoch  49 | T_Loss: 0.4208 | [CENTER_] Dice:0.7351 IoU:0.6002 CBL:0.9027 | [CENTER_] Dice:0.7087 IoU:0.5700 CBL:0.8828 | LR:5.0e-05
# Epoch 50/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.2689]
# Epoch  50 | T_Loss: 0.4361 | [CENTER_] Dice:0.7316 IoU:0.5951 CBL:0.9144 | [CENTER_] Dice:0.7171 IoU:0.5802 CBL:0.8911 | LR:5.0e-05
# Epoch 51/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.04it/s, loss=0.2761]
# Epoch  51 | T_Loss: 0.4559 | [CENTER_] Dice:0.7273 IoU:0.5912 CBL:0.9068 | [CENTER_] Dice:0.7101 IoU:0.5708 CBL:0.8858 | LR:5.0e-05
# Epoch 52/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.4075]
# Epoch  52 | T_Loss: 0.4242 | [CENTER_] Dice:0.7355 IoU:0.6025 CBL:0.8953 | [CENTER_] Dice:0.7176 IoU:0.5811 CBL:0.8819 | LR:2.5e-05
# Epoch 53/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.02it/s, loss=0.5672]
# Epoch  53 | T_Loss: 0.4111 | [CENTER_] Dice:0.7437 IoU:0.6150 CBL:0.9052 | [CENTER_] Dice:0.7241 IoU:0.5911 CBL:0.8958 | LR:2.5e-05
# Epoch 54/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.01it/s, loss=0.3273]
# Epoch  54 | T_Loss: 0.4361 | [CENTER_] Dice:0.7299 IoU:0.5989 CBL:0.9033 | [CENTER_] Dice:0.7161 IoU:0.5836 CBL:0.8853 | LR:2.5e-05
# Epoch 55/150 [Train]: 100%|██████| 183/183 [01:00<00:00,  3.03it/s, loss=1.1575]
# Epoch  55 | T_Loss: 0.4404 | [CENTER_] Dice:0.7338 IoU:0.6022 CBL:0.9042 | [CENTER_] Dice:0.7071 IoU:0.5708 CBL:0.8836 | LR:2.5e-05
# Early stopping at epoch 55.
#
# Best Dice (center_shift): 0.7249
# Checkpoint: checkpoints/pga_unet_center_mixed_x3_shift05_qhead_512_best.pth

# %% [markdown]
# ## Test - two-scenario evaluation (center_zoom / center_shift) + no-GT confidence + sample visualization
# Reports the six metrics under both scenarios, the model's own no-GT confidence (CAD prompt-confidence gate + QualityHead), and two 10-sample visualization grids, one per scenario (each sample's Dice/confidence/quality shown next to it).

# %%
from qualitative_visualization import select_shared_stems, records_for_stems
from qualitative_visualization import export_qualitative_rows
# @title
"""
test_exp_scenarios.py
=====================
Evaluation of two prompt scenarios: 100% center_zoom | 100% center_shift
(center_mixed x3/shift0.5, 80% shift / 20% zoom, QualityHead), alongside the
model's own no-GT confidence (CAD prompt-confidence gate + QualityHead), on
the full test set. PromptSegmentationDataset yields one sample per lesion
polygon, so predictions/GT/prompts for the same image are grouped and
merged (elementwise max) before computing Dice/IoU/etc., then averaged over
images rather than raw polygon-samples, matching the convention used by
test-pga-dataset-1234-*.ipynb and test-pga-vs-attunet-variants-r512-*.ipynb.
Saves a CSV under results/ and visualizes 10 images per scenario (two
separate figures). Small-lesion subset analysis lives in its own dedicated
test notebook (test-subcat-small-r256 and test-subcat-small-r512), not duplicated here.

MODEL_PATH and LOSS_LABEL are derived automatically from USE_SIZE_TVERSKY/
USE_FOCAL_DICE (reused from the train cell above if this notebook is run
top-to-bottom in one session; default to the baseline, both 0, if this test
cell is run standalone in a fresh kernel).

Usage:
    python test_exp_scenarios.py
"""

import os
import sys
import cv2
import csv
import json
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from scipy.ndimage import binary_erosion, distance_transform_edt

import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset
from models.networks.prompt_unet_2D import PGA_UNet
from collections import OrderedDict

# =========================================================
# CONFIGURATION - edit here
# =========================================================
DEVICE             = torch.device("cuda" if torch.cuda.is_available() else "cpu")
IMG_SIZE           = 512
USE_ENCODER_PROMPT = True   # must match the training config above
USE_QUALITY_HEAD   = True   # must match the training config above

SCALE_FACTOR = 3.0
SHIFT_RATIO  = 0.5

TEST_IMAGE_DIR = "dataset_FracAtlas/test/images"
TEST_JSON_DIR  = "dataset_FracAtlas/test/annotations"

# Reuses USE_SIZE_TVERSKY/USE_FOCAL_DICE from the train cell above (falls
# back to the baseline, both 0, if this cell is run standalone).
_use_size_tversky = globals().get('USE_SIZE_TVERSKY', 0)
_use_focal_dice   = globals().get('USE_FOCAL_DICE', 0)
if _use_size_tversky:
    LOSS_LABEL  = "size_tversky"
    _loss_ckpt_suffix = "_sizetversky"
elif _use_focal_dice:
    LOSS_LABEL  = "focal_dice"
    _loss_ckpt_suffix = "_focaldice133"
else:
    LOSS_LABEL  = "baseline_dice"
    _loss_ckpt_suffix = ""
MODEL_PATH = f"checkpoints/pga_unet_center_mixed_x3_shift05_qhead{_loss_ckpt_suffix}_512_best.pth"


# =========================================================
# METRIC HELPERS & POST-PROCESSING
# =========================================================


def calc_hd95(pred: np.ndarray, gt: np.ndarray) -> float:
    pred, gt = pred.astype(bool), gt.astype(bool)
    if not pred.any() and not gt.any():
        return 0.0
    if not pred.any() or not gt.any():
        return float(IMG_SIZE)
    pe = pred ^ binary_erosion(pred)
    ge = gt   ^ binary_erosion(gt)
    d1 = distance_transform_edt(~ge)[pe]
    d2 = distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2):
        return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))

def calc_cbl(pred_bin: np.ndarray, gt_bin: np.ndarray):
    if gt_bin.sum() == 0:
        return None
    ys, xs = np.where(gt_bin)
    gt_diag = np.sqrt((ys.max() - ys.min()) ** 2 +
                      (xs.max() - xs.min()) ** 2) + 1e-6
    if pred_bin.sum() == 0:
        return 0.0
    yp, xp = np.where(pred_bin)
    d = np.sqrt((xp.mean() - xs.mean()) ** 2 +
                (yp.mean() - ys.mean()) ** 2)
    return float(np.clip(1.0 - d / gt_diag, 0.0, 1.0))

def get_centroid(binary_map: np.ndarray):
    if binary_map.sum() == 0:
        return None, None
    ys, xs = np.where(binary_map)
    return float(xs.mean()), float(ys.mean())

# =========================================================
# SINGLE-SCENARIO EVALUATION (+ no-GT confidence, averaged over the scenario)
# =========================================================

def run_eval(model: torch.nn.Module, prompt_mode: str, **ds_kwargs) -> dict:
    """Per-image-merged evaluation: PromptSegmentationDataset yields one
    sample per lesion polygon, so predictions/GT/prompts for the same image
    are grouped and merged (elementwise max) before computing metrics, then
    averaged over images rather than raw polygon-samples. This matches the
    convention used by test-pga-dataset-1234-*.ipynb and
    test-pga-vs-attunet-variants-r512-*.ipynb. Returns per-image records
    (img_recs) too, reused directly by visualize_scenario() below instead of
    re-running the model on a second pass.
    """
    ds = PromptSegmentationDataset(
        image_dir=TEST_IMAGE_DIR,
        json_dir=TEST_JSON_DIR,
        img_size=IMG_SIZE,
        is_train=False,
        prompt_mode=prompt_mode,
        **ds_kwargs,
    )
    loader = DataLoader(ds, batch_size=1, shuffle=False, num_workers=0)

    groups = OrderedDict()
    model.eval()
    with torch.no_grad():
        for i, (images, masks, prompts) in enumerate(loader):
            img_name = ds.all_samples[i][0]
            gt_np = masks[0, 0].numpy()
            prompt_np = prompts[0, 0].numpy()
            img_np = images[0, 0].numpy()

            if USE_QUALITY_HEAD:
                logits, prompt_conf, quality = model(
                    images.to(DEVICE), prompts.to(DEVICE),
                    return_confidence=True, return_quality=True)
                prompt_conf_val = prompt_conf.item()
                quality_val = quality.item()
            else:
                logits = model(images.to(DEVICE), prompts.to(DEVICE))
                prompt_conf_val, quality_val = None, None
            prob = torch.sigmoid(logits)[0, 0].cpu().numpy()

            if img_name not in groups:
                groups[img_name] = dict(
                    img=img_np, gt_union=gt_np.copy(), prob_max=prob.copy(),
                    prompts=[prompt_np], n_samples=1,
                    prompt_conf_sum=(prompt_conf_val or 0.0),
                    quality_sum=(quality_val or 0.0),
                )
            else:
                g = groups[img_name]
                np.maximum(g['gt_union'], gt_np, out=g['gt_union'])
                np.maximum(g['prob_max'], prob, out=g['prob_max'])
                g['prompts'].append(prompt_np)
                g['n_samples'] += 1
                if prompt_conf_val is not None:
                    g['prompt_conf_sum'] += prompt_conf_val
                    g['quality_sum'] += quality_val

    smooth = 1e-5
    img_recs = []
    for img_name in sorted(groups.keys()):
        g = groups[img_name]
        pm = (g['prob_max'] > 0.5).astype(np.float32)
        gm = g['gt_union']

        tp = (pm * gm).sum()
        fp = (pm * (1 - gm)).sum()
        fn = ((1 - pm) * gm).sum()
        dice = (2 * tp + smooth) / (2 * tp + fp + fn + smooth)
        iou  = (tp + smooth) / (tp + fp + fn + smooth)
        pre  = tp / (tp + fp + smooth)
        rec  = (tp + smooth) / (tp + fn + smooth)
        hd95 = calc_hd95(pm.astype(bool), gm.astype(bool))
        cbl  = calc_cbl(pm.astype(bool), gm.astype(bool))

        img_recs.append(dict(
            img_name=img_name, img=g['img'], gt=gm, prob=g['prob_max'],
            prompts=g['prompts'], n_samples=g['n_samples'],
            dice=float(dice), iou=float(iou), pre=float(pre), rec=float(rec),
            hd95=float(hd95), cbl=cbl,
            prompt_conf=(g['prompt_conf_sum'] / g['n_samples']) if USE_QUALITY_HEAD else None,
            quality=(g['quality_sum'] / g['n_samples']) if USE_QUALITY_HEAD else None,
        ))

    cbl_vals  = [r['cbl'] for r in img_recs if r['cbl'] is not None]
    conf_vals = [r['prompt_conf'] for r in img_recs if r['prompt_conf'] is not None]
    qual_vals = [r['quality'] for r in img_recs if r['quality'] is not None]

    return {
        'dice': np.mean([r['dice'] for r in img_recs]),
        'iou':  np.mean([r['iou'] for r in img_recs]),
        'pre':  np.mean([r['pre'] for r in img_recs]),
        'rec':  np.mean([r['rec'] for r in img_recs]),
        'hd95': np.mean([r['hd95'] for r in img_recs]),
        'hd95_normalized': np.mean([r['hd95'] for r in img_recs]) / (np.sqrt(2.0) * IMG_SIZE),
        'cbl':  np.mean(cbl_vals) if cbl_vals else 0.0,
        'prompt_conf': np.mean(conf_vals) if conf_vals else None,
        'quality':     np.mean(qual_vals) if qual_vals else None,
        'n_img':     len(img_recs),
        'n_samples': sum(r['n_samples'] for r in img_recs),
        'img_recs':  img_recs,
    }

# =========================================================
# TWO-SCENARIO EVALUATION
# =========================================================

def evaluate_all(model: torch.nn.Module) -> dict:
    enc_tag = 'ON' if USE_ENCODER_PROMPT else 'OFF'
    print("\n" + "=" * 72)
    print(f"  TWO-SCENARIO EVALUATION  |  encoder_prompt = {enc_tag}  |  loss = {LOSS_LABEL}")
    print("=" * 72)

    scenarios = {
        '100% Zoom (center_zoom)':  dict(prompt_mode='center_zoom', scale_factor=SCALE_FACTOR),
        '100% Shift (center_shift)': dict(prompt_mode='center_shift', scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO),
    }

    results = {}
    for name, kwargs in scenarios.items():
        results[name] = run_eval(model, **kwargs)
        print(f"  [{name}]  {results[name]['n_img']} images, {results[name]['n_samples']} samples, completed.")

    header = (f"\n{'Scenario':<24} {'Dice↑':>7} {'IoU↑':>7} "
              f"{'Pre↑':>7} {'Rec↑':>7} {'HD95px↓':>8} {'HD95n↓':>8} {'CBL↑':>7} "
              f"{'PromptConf':>10} {'Quality':>8} {'N_img':>6} {'N_smp':>6}")
    print(header)
    print("-" * 113)
    for name, r in results.items():
        conf_str = f"{r['prompt_conf']:>10.4f}" if r['prompt_conf'] is not None else f"{'n/a':>10}"
        qual_str = f"{r['quality']:>8.4f}" if r['quality'] is not None else f"{'n/a':>8}"
        print(f"{name:<24} {r['dice']:>7.4f} {r['iou']:>7.4f} "
              f"{r['pre']:>7.4f} {r['rec']:>7.4f} "
              f"{r['hd95']:>8.2f} {r['hd95_normalized']:>8.6f} {r['cbl']:>7.4f} "
              f"{conf_str} {qual_str} {r['n_img']:>6} {r['n_samples']:>6}")
    return results

# =========================================================
# LOAD MODEL
# =========================================================
model = PGA_UNet(use_encoder_prompt=USE_ENCODER_PROMPT, use_quality_head=USE_QUALITY_HEAD).to(DEVICE)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval()
print(f"Model loaded from: {MODEL_PATH}  (loss = {LOSS_LABEL})")

# =========================================================
# TWO-SCENARIO EVALUATION: summary table
# =========================================================
results = evaluate_all(model)

# =========================================================
# SAVE CSV - one row per scenario, tagged by loss variant so multiple runs
# (baseline / size_tversky / focal_dice) can be compared side by side.
# Per-image-merged: n_img/n_samples are reported separately since an image
# with multiple lesion polygons now contributes one merged row, not one row
# per polygon.
# =========================================================
os.makedirs('results', exist_ok=True)
csv_path = f'results/pga_{LOSS_LABEL}_{IMG_SIZE}.csv'
with open(csv_path, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['loss', 'scenario', 'dice', 'iou', 'pre', 'rec', 'hd95', 'hd95_normalized', 'cbl',
                     'prompt_conf', 'quality', 'n_img', 'n_samples'])
    for name, r in results.items():
        writer.writerow([LOSS_LABEL, name,
                         f"{r['dice']:.4f}", f"{r['iou']:.4f}", f"{r['pre']:.4f}", f"{r['rec']:.4f}",
                         f"{r['hd95']:.4f}", f"{r['hd95_normalized']:.6f}", f"{r['cbl']:.4f}",
                         f"{r['prompt_conf']:.4f}" if r['prompt_conf'] is not None else '',
                         f"{r['quality']:.4f}" if r['quality'] is not None else '',
                         r['n_img'], r['n_samples']])
print(f"\nSaved CSV: {csv_path}")

# =========================================================
# VISUALIZATION - 10 images per scenario, two separate figures, with
# no-GT confidence (CAD prompt-confidence + QualityHead, averaged per image
# when an image has multiple polygons) shown per image. Reuses the
# per-image img_recs already computed by evaluate_all()/run_eval() above
# instead of re-running the model on a second pass.
# =========================================================
from IPython.display import display as _ipy_display
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

N_SHOW = 10
TRAIN_SHARED_STEMS = select_shared_stems(
    results['100% Zoom (center_zoom)']['img_recs'], n_multi=5, n_single=5)

def visualize_scenario(scenario_name, title_suffix):
    img_recs = records_for_stems(
        results[scenario_name]['img_recs'], TRAIN_SHARED_STEMS,
        context=f'{scenario_name} qualitative records')
    n_show = len(img_recs)

    fig, axes = plt.subplots(n_show, 5, figsize=(20, 4 * n_show))
    if n_show == 1:
        axes = axes[np.newaxis, :]
    fig.suptitle(f"PGA-UNet Train ({IMG_SIZE}, loss={LOSS_LABEL}) - Visualization "
                 f"({title_suffix}, image-level merged, first {n_show} images)",
                 fontsize=13, y=1.001)

    col_titles = ["Input image", "Image + prompts", "Prediction (merged)", "Ground truth", "TP/FP/FN"]
    for ax, ct in zip(axes[0], col_titles):
        ax.set_title(ct, fontsize=10, fontweight="bold")

    for count, rec in enumerate(img_recs):
        img_np = rec['img'] * 0.5 + 0.5
        gt_np = (rec['gt'] > 0.5).astype(float)
        pred_np = (rec['prob'] > 0.5).astype(float)
        prompt_merged = np.max(np.stack(rec['prompts'], axis=0), axis=0)

        conf_label = (f" | Conf={rec['prompt_conf']:.2f} Qual={rec['quality']:.2f}"
                      if rec['prompt_conf'] is not None else "")

        row = axes[count]
        bg = np.stack([img_np] * 3, axis=-1)

        row[0].imshow(img_np, cmap="gray", vmin=0, vmax=1)
        row[0].set_ylabel(f"#{count+1} [{rec['n_samples']} poly]\nDice={rec['dice']:.3f}{conf_label}", fontsize=8)

        row[1].imshow(img_np, cmap="gray", vmin=0, vmax=1)
        row[1].imshow(np.where(prompt_merged > 0, prompt_merged, np.nan), cmap="hot", alpha=0.4, vmin=0, vmax=1)
        row[1].set_title(rec['img_name'], fontsize=6, pad=2)

        pr_ov = bg.copy()
        pr_ov[..., 0] = np.clip(pr_ov[..., 0] + pred_np * 0.55, 0, 1)
        pr_ov[..., 1] = np.clip(pr_ov[..., 1] - pred_np * 0.2, 0, 1)
        row[2].imshow(pr_ov)
        row[2].set_title(f"Dice={rec['dice']:.3f} IoU={rec['iou']:.3f}", fontsize=7, color="darkred", pad=2)

        gt_ov = bg.copy()
        gt_ov[..., 1] = np.clip(gt_ov[..., 1] + gt_np * 0.55, 0, 1)
        gt_ov[..., 0] = np.clip(gt_ov[..., 0] - gt_np * 0.2, 0, 1)
        row[3].imshow(gt_ov)

        inter = bg.copy()
        inter[..., 1] = np.clip(inter[..., 1] + pred_np * gt_np * 0.9, 0, 1)
        inter[..., 0] = np.clip(inter[..., 0] + pred_np * (1 - gt_np) * 1.0, 0, 1)
        inter[..., 2] = np.clip(inter[..., 2] + (1 - pred_np) * gt_np * 1.0, 0, 1)
        row[4].imshow(inter)
        row[4].set_title(f"Pre={rec['pre']:.3f} Rec={rec['rec']:.3f}", fontsize=7, color="saddlebrown", pad=2)

        for ax in row:
            ax.axis("off")
            ax.add_patch(plt.Rectangle((0, 0), 1, 1, transform=ax.transAxes, fill=False, edgecolor='#555555', linewidth=1.0, clip_on=False))

    fig.legend(handles=[Patch(facecolor="green", label="TP"), Patch(facecolor="red", label="FP"),
                        Patch(facecolor="blue", label="FN")],
               loc="lower center", ncol=3, fontsize=9, bbox_to_anchor=(0.5, -0.01))
    plt.tight_layout()
    export_qualitative_rows(fig, axes, img_recs)
    plt.close(fig)

visualize_scenario('100% Zoom (center_zoom)', 'center_zoom')
visualize_scenario('100% Shift (center_shift)', 'center_shift')
# Out:
# Model loaded from: checkpoints/pga_unet_center_mixed_x3_shift05_qhead_512_best.pth  (loss = baseline_dice)
#
# ========================================================================
#   TWO-SCENARIO EVALUATION  |  encoder_prompt = ON  |  loss = baseline_dice
# ========================================================================
#   [100% Zoom (center_zoom)]  72 images, 90 samples, completed.
#   [100% Shift (center_shift)]  72 images, 90 samples, completed.
#
# Scenario                   Dice↑    IoU↑    Pre↑    Rec↑  HD95px↓   HD95n↓    CBL↑ PromptConf  Quality  N_img  N_smp
# -----------------------------------------------------------------------------------------------------------------
# 100% Zoom (center_zoom)   0.7311  0.5979  0.6904  0.8146    18.25 0.025210  0.9017     0.8015   0.6686     72     90
# 100% Shift (center_shift)  0.7125  0.5737  0.6843  0.7797    22.32 0.030828  0.8833     0.8013   0.6684     72     90
#
# Saved CSV: results/pga_baseline_dice_512.csv
