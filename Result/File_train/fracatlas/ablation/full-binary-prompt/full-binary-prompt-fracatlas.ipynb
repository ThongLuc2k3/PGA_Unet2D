# %% [markdown]
# # Ablation - Full PGA with binary prompt
# Full PSG + CAD configuration trained with a binary prompt rather than Gaussian blur.

# %%
import os, sys, shutil
import gdown

BASE = '/kaggle/working' if os.path.exists('/kaggle/working') else '/content'
os.chdir(BASE)

REPO = 'https://github.com/ThongLuc2k3/PGA_Unet2D.git'
REPO_ROOT = f'{BASE}/PGA_Unet2D'
PGA_ROOT = f'{REPO_ROOT}/Source/Prompt-Guided-XRay-Segmentation'
DATASET_NAME = 'dataset_FracAtlas'
DATASET_ID = '1sfMPFQvADmZLCPJC3xPyYDrblnFZ4kQv'
DS_ZIP = f'{BASE}/{DATASET_NAME}.zip'
DS_PATH = f'{PGA_ROOT}/{DATASET_NAME}'

if os.path.exists(REPO_ROOT):
    shutil.rmtree(REPO_ROOT)
# !git clone -q --branch main --single-branch {REPO} {REPO_ROOT}
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)

if not os.path.exists(DS_ZIP):
    gdown.download(f'https://drive.google.com/uc?id={DATASET_ID}', DS_ZIP, quiet=False)
if os.path.exists(DS_PATH):
    shutil.rmtree(DS_PATH)
# !unzip -oq {DS_ZIP} -d {PGA_ROOT}/

os.makedirs(f'{PGA_ROOT}/checkpoints', exist_ok=True)
os.chdir(PGA_ROOT)
# !pip install -q tqdm opencv-python timm scipy gdown
print(f'✅ Setup completed | base={BASE} | dataset={DATASET_NAME}')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1sfMPFQvADmZLCPJC3xPyYDrblnFZ4kQv
# From (redirected): https://drive.google.com/uc?id=1sfMPFQvADmZLCPJC3xPyYDrblnFZ4kQv&confirm=t&uuid=588ba5bb-8414-4f79-acdc-05f165583357
# To: /kaggle/working/dataset_FracAtlas.zip
# 100%|██████████| 231M/231M [00:01<00:00, 224MB/s]
# ✅ Setup completed | base=/kaggle/working | dataset=dataset_FracAtlas

# %% [markdown]
# ## Ablation training via the shared `train.py`
#
# **Configuration: Full PGA-UNet with a binary prompt.** Full PGA-UNet (PSG + CAD, QualityHead on); the prompt is a hard binary box instead of the Gaussian-smoothed plateau (`BINARY_PROMPT=1`).
#
# Every ablation configuration is trained through the same `train.py` as the full PGA-UNet, so batch size, optimizer, scheduler, gradient clipping, the 150-epoch / patience-15 early stopping, and **image-level merged `center_shift` validation for checkpoint selection** are identical across the study. Repeat the training cell with `SEED = 1`, `2`, `3` for the multi-seed ablation; `RUN_TAG` keeps the per-seed checkpoints from overwriting each other.
#
# A quick image-level metrics table on the held-out test set is printed by the last cell. For the full qualitative panels and per-image CSVs, run the matching notebook under `Source/File_Test/fracatlas/Ablation/`.

# %%
# Repeat with SEED = 1, 2, 3 ... for the multi-seed ablation.
SEED = 22120196
RUN_TAG = f"seed{SEED}"

import os, glob
os.chdir(PGA_ROOT)
os.environ.update({
    "PROMPT_DATASET_ROOT": "dataset_FracAtlas",
    "PROMPT_IMG_SIZE": "512",
    "PROMPT_MODE": "center_mixed",
    "PROMPT_SCALE_FACTOR": "3.0",
    "PROMPT_SHIFT_RATIO": "0.5",
    "PROMPT_MIXED_SHIFT_PROB": "0.8",
    "PROMPT_EPOCHS": "150",
    "PROMPT_SEED": str(SEED),
    "RUN_TAG": RUN_TAG,
    "PROMPT_VARIANT": "full",
    "USE_ENCODER_PROMPT": "1",
    "BINARY_PROMPT": "1",
    "USE_QUALITY_HEAD": "1",
})

# !python train.py

print(sorted(glob.glob(f"checkpoints/pga_unet_center_mixed_x3_shift05_qhead_binaryprompt_512_{RUN_TAG}_best.pth")))
# Out:
# ==========================================================================================
# TrainPrompt: center_mixed | Device: cuda | Variant: full | EncoderPrompt: True | BinaryPrompt: True | ImgSize: 512 | DatasetRoot: dataset_FracAtlas | Seed: 22120196 | RunTag: seed22120196 | ScaleFactor: 3.0 | ShiftRatio: 0.5 | MixedShiftProb: 0.8 | QualityHead: ConfidenceLossWeight=1.0
# ==========================================================================================
# Epoch 1/150 [Train]: 100%|███████| 183/183 [00:55<00:00,  3.28it/s, loss=1.4620]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.6073 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0569 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0569 | LR:1.0e-04
# Epoch 2/150 [Train]: 100%|███████| 183/183 [00:58<00:00,  3.14it/s, loss=1.5025]
# 🥇 [BEST] Epoch   2 | T_Loss: 1.4293 | [CENTER_] Dice:0.0085 IoU:0.0043 CBL:0.2122 | [CENTER_] Dice:0.0077 IoU:0.0039 CBL:0.2071 | LR:1.0e-04
# Epoch 3/150 [Train]: 100%|███████| 183/183 [00:58<00:00,  3.12it/s, loss=1.5121]
# 🥇 [BEST] Epoch   3 | T_Loss: 1.4411 | [CENTER_] Dice:0.5564 IoU:0.4008 CBL:0.6917 | [CENTER_] Dice:0.5338 IoU:0.3791 CBL:0.6818 | LR:1.0e-04
# Epoch 4/150 [Train]: 100%|███████| 183/183 [00:59<00:00,  3.10it/s, loss=1.3339]
# Epoch   4 | T_Loss: 1.3905 | [CENTER_] Dice:0.6059 IoU:0.4556 CBL:0.6635 | [CENTER_] Dice:0.5188 IoU:0.3661 CBL:0.6086 | LR:1.0e-04
# Epoch 5/150 [Train]: 100%|███████| 183/183 [00:58<00:00,  3.12it/s, loss=1.3803]
# 🥇 [BEST] Epoch   5 | T_Loss: 1.3501 | [CENTER_] Dice:0.6066 IoU:0.4427 CBL:0.8790 | [CENTER_] Dice:0.5550 IoU:0.3924 CBL:0.8212 | LR:1.0e-04
# Epoch 6/150 [Train]: 100%|███████| 183/183 [00:58<00:00,  3.12it/s, loss=1.2528]
# Epoch   6 | T_Loss: 1.3160 | [CENTER_] Dice:0.5752 IoU:0.4085 CBL:0.8580 | [CENTER_] Dice:0.5500 IoU:0.3853 CBL:0.8394 | LR:1.0e-04
# Epoch 7/150 [Train]: 100%|███████| 183/183 [00:58<00:00,  3.11it/s, loss=1.4103]
# 🥇 [BEST] Epoch   7 | T_Loss: 1.2830 | [CENTER_] Dice:0.6342 IoU:0.4733 CBL:0.8345 | [CENTER_] Dice:0.5632 IoU:0.4008 CBL:0.7935 | LR:1.0e-04
# Epoch 8/150 [Train]: 100%|███████| 183/183 [00:58<00:00,  3.12it/s, loss=1.2164]
# Epoch   8 | T_Loss: 1.2556 | [CENTER_] Dice:0.6185 IoU:0.4609 CBL:0.8539 | [CENTER_] Dice:0.5481 IoU:0.3923 CBL:0.7881 | LR:1.0e-04
# Epoch 9/150 [Train]: 100%|███████| 183/183 [00:58<00:00,  3.12it/s, loss=1.1996]
# Epoch   9 | T_Loss: 1.2269 | [CENTER_] Dice:0.5420 IoU:0.3764 CBL:0.9133 | [CENTER_] Dice:0.5207 IoU:0.3576 CBL:0.8401 | LR:1.0e-04
# Epoch 10/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.1575]
# 🥇 [BEST] Epoch  10 | T_Loss: 1.2005 | [CENTER_] Dice:0.5978 IoU:0.4334 CBL:0.9032 | [CENTER_] Dice:0.5707 IoU:0.4101 CBL:0.8471 | LR:1.0e-04
# Epoch 11/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.1210]
# Epoch  11 | T_Loss: 1.1602 | [CENTER_] Dice:0.5357 IoU:0.3707 CBL:0.8625 | [CENTER_] Dice:0.5163 IoU:0.3536 CBL:0.8139 | LR:1.0e-04
# Epoch 12/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.2886]
# Epoch  12 | T_Loss: 1.1449 | [CENTER_] Dice:0.5483 IoU:0.3830 CBL:0.9128 | [CENTER_] Dice:0.5177 IoU:0.3551 CBL:0.8392 | LR:1.0e-04
# Epoch 13/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.12it/s, loss=1.0824]
# Epoch  13 | T_Loss: 1.1266 | [CENTER_] Dice:0.5309 IoU:0.3695 CBL:0.8910 | [CENTER_] Dice:0.5049 IoU:0.3447 CBL:0.8294 | LR:1.0e-04
# Epoch 14/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.0843]
# Epoch  14 | T_Loss: 1.1132 | [CENTER_] Dice:0.4849 IoU:0.3250 CBL:0.9061 | [CENTER_] Dice:0.4841 IoU:0.3252 CBL:0.8664 | LR:1.0e-04
# Epoch 15/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.0552]
# Epoch  15 | T_Loss: 1.0835 | [CENTER_] Dice:0.4581 IoU:0.2999 CBL:0.9014 | [CENTER_] Dice:0.4591 IoU:0.3011 CBL:0.8570 | LR:1.0e-04
# Epoch 16/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.0255]
# Epoch  16 | T_Loss: 1.0678 | [CENTER_] Dice:0.5328 IoU:0.3704 CBL:0.8820 | [CENTER_] Dice:0.5324 IoU:0.3706 CBL:0.8477 | LR:5.0e-05
# Epoch 17/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.0347]
# Epoch  17 | T_Loss: 1.0430 | [CENTER_] Dice:0.5535 IoU:0.3896 CBL:0.9036 | [CENTER_] Dice:0.5421 IoU:0.3792 CBL:0.8468 | LR:5.0e-05
# Epoch 18/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9903]
# Epoch  18 | T_Loss: 1.0405 | [CENTER_] Dice:0.5238 IoU:0.3591 CBL:0.9077 | [CENTER_] Dice:0.5214 IoU:0.3575 CBL:0.8723 | LR:5.0e-05
# Epoch 19/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.1467]
# Epoch  19 | T_Loss: 1.0311 | [CENTER_] Dice:0.5864 IoU:0.4222 CBL:0.8872 | [CENTER_] Dice:0.5553 IoU:0.3919 CBL:0.8328 | LR:5.0e-05
# Epoch 20/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.10it/s, loss=0.9994]
# 🥇 [BEST] Epoch  20 | T_Loss: 1.0203 | [CENTER_] Dice:0.5845 IoU:0.4191 CBL:0.8961 | [CENTER_] Dice:0.5792 IoU:0.4139 CBL:0.8578 | LR:5.0e-05
# Epoch 21/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9820]
# Epoch  21 | T_Loss: 1.0118 | [CENTER_] Dice:0.5286 IoU:0.3645 CBL:0.9121 | [CENTER_] Dice:0.5262 IoU:0.3625 CBL:0.8676 | LR:5.0e-05
# Epoch 22/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9539]
# Epoch  22 | T_Loss: 1.0015 | [CENTER_] Dice:0.5579 IoU:0.3951 CBL:0.8907 | [CENTER_] Dice:0.5465 IoU:0.3834 CBL:0.8508 | LR:5.0e-05
# Epoch 23/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9848]
# Epoch  23 | T_Loss: 0.9920 | [CENTER_] Dice:0.5333 IoU:0.3696 CBL:0.9169 | [CENTER_] Dice:0.5275 IoU:0.3631 CBL:0.8790 | LR:5.0e-05
# Epoch 24/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.8570]
# Epoch  24 | T_Loss: 0.9749 | [CENTER_] Dice:0.5546 IoU:0.3931 CBL:0.8872 | [CENTER_] Dice:0.5398 IoU:0.3777 CBL:0.8463 | LR:5.0e-05
# Epoch 25/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.0880]
# Epoch  25 | T_Loss: 0.9655 | [CENTER_] Dice:0.5497 IoU:0.3863 CBL:0.8862 | [CENTER_] Dice:0.5448 IoU:0.3815 CBL:0.8499 | LR:5.0e-05
# Epoch 26/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.0246]
# Epoch  26 | T_Loss: 0.9633 | [CENTER_] Dice:0.5782 IoU:0.4145 CBL:0.9062 | [CENTER_] Dice:0.5775 IoU:0.4131 CBL:0.8746 | LR:2.5e-05
# Epoch 27/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9871]
# Epoch  27 | T_Loss: 0.9433 | [CENTER_] Dice:0.5229 IoU:0.3613 CBL:0.9093 | [CENTER_] Dice:0.5122 IoU:0.3509 CBL:0.8497 | LR:2.5e-05
# Epoch 28/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9178]
# 🥇 [BEST] Epoch  28 | T_Loss: 0.9431 | [CENTER_] Dice:0.5863 IoU:0.4216 CBL:0.9168 | [CENTER_] Dice:0.5851 IoU:0.4203 CBL:0.8819 | LR:2.5e-05
# Epoch 29/150 [Train]: 100%|██████| 183/183 [00:59<00:00,  3.10it/s, loss=0.8878]
# 🥇 [BEST] Epoch  29 | T_Loss: 0.9271 | [CENTER_] Dice:0.6037 IoU:0.4412 CBL:0.9017 | [CENTER_] Dice:0.6009 IoU:0.4379 CBL:0.8727 | LR:2.5e-05
# Epoch 30/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.8928]
# Epoch  30 | T_Loss: 0.9287 | [CENTER_] Dice:0.5820 IoU:0.4181 CBL:0.9189 | [CENTER_] Dice:0.5823 IoU:0.4177 CBL:0.8850 | LR:2.5e-05
# Epoch 31/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.8954]
# Epoch  31 | T_Loss: 0.9178 | [CENTER_] Dice:0.5855 IoU:0.4233 CBL:0.9065 | [CENTER_] Dice:0.5857 IoU:0.4231 CBL:0.8845 | LR:2.5e-05
# Epoch 32/150 [Train]: 100%|██████| 183/183 [00:59<00:00,  3.10it/s, loss=0.8895]
# Epoch  32 | T_Loss: 0.9091 | [CENTER_] Dice:0.6011 IoU:0.4390 CBL:0.9105 | [CENTER_] Dice:0.5975 IoU:0.4350 CBL:0.8777 | LR:2.5e-05
# Epoch 33/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9092]
# 🥇 [BEST] Epoch  33 | T_Loss: 0.9057 | [CENTER_] Dice:0.6220 IoU:0.4601 CBL:0.9048 | [CENTER_] Dice:0.6139 IoU:0.4535 CBL:0.8784 | LR:2.5e-05
# Epoch 34/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.7432]
# Epoch  34 | T_Loss: 0.9074 | [CENTER_] Dice:0.5679 IoU:0.4045 CBL:0.9024 | [CENTER_] Dice:0.5662 IoU:0.4020 CBL:0.8634 | LR:2.5e-05
# Epoch 35/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9173]
# 🥇 [BEST] Epoch  35 | T_Loss: 0.8835 | [CENTER_] Dice:0.6258 IoU:0.4644 CBL:0.9071 | [CENTER_] Dice:0.6240 IoU:0.4647 CBL:0.8801 | LR:2.5e-05
# Epoch 36/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.8415]
# Epoch  36 | T_Loss: 0.8872 | [CENTER_] Dice:0.5918 IoU:0.4287 CBL:0.9120 | [CENTER_] Dice:0.5984 IoU:0.4357 CBL:0.8963 | LR:2.5e-05
# Epoch 37/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.12it/s, loss=1.1403]
# 🥇 [BEST] Epoch  37 | T_Loss: 0.8875 | [CENTER_] Dice:0.6317 IoU:0.4715 CBL:0.9072 | [CENTER_] Dice:0.6268 IoU:0.4683 CBL:0.8802 | LR:2.5e-05
# Epoch 38/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.10it/s, loss=0.8634]
# Epoch  38 | T_Loss: 0.8620 | [CENTER_] Dice:0.6360 IoU:0.4765 CBL:0.9034 | [CENTER_] Dice:0.6244 IoU:0.4656 CBL:0.8663 | LR:2.5e-05
# Epoch 39/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.12it/s, loss=0.7023]
# 🥇 [BEST] Epoch  39 | T_Loss: 0.8601 | [CENTER_] Dice:0.6338 IoU:0.4732 CBL:0.9090 | [CENTER_] Dice:0.6280 IoU:0.4691 CBL:0.8856 | LR:2.5e-05
# Epoch 40/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.8055]
# Epoch  40 | T_Loss: 0.8364 | [CENTER_] Dice:0.6353 IoU:0.4781 CBL:0.9062 | [CENTER_] Dice:0.6212 IoU:0.4635 CBL:0.8675 | LR:2.5e-05
# Epoch 41/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.8796]
# 🥇 [BEST] Epoch  41 | T_Loss: 0.8466 | [CENTER_] Dice:0.6501 IoU:0.4916 CBL:0.9064 | [CENTER_] Dice:0.6483 IoU:0.4924 CBL:0.8812 | LR:2.5e-05
# Epoch 42/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9402]
# Epoch  42 | T_Loss: 0.8403 | [CENTER_] Dice:0.6369 IoU:0.4791 CBL:0.9111 | [CENTER_] Dice:0.6434 IoU:0.4863 CBL:0.8913 | LR:2.5e-05
# Epoch 43/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.1921]
# Epoch  43 | T_Loss: 0.8302 | [CENTER_] Dice:0.6385 IoU:0.4803 CBL:0.8984 | [CENTER_] Dice:0.6337 IoU:0.4760 CBL:0.8737 | LR:2.5e-05
# Epoch 44/150 [Train]: 100%|██████| 183/183 [00:59<00:00,  3.10it/s, loss=0.6173]
# Epoch  44 | T_Loss: 0.8259 | [CENTER_] Dice:0.6320 IoU:0.4732 CBL:0.9113 | [CENTER_] Dice:0.6311 IoU:0.4730 CBL:0.8858 | LR:2.5e-05
# Epoch 45/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.7644]
# Epoch  45 | T_Loss: 0.8047 | [CENTER_] Dice:0.6388 IoU:0.4806 CBL:0.9048 | [CENTER_] Dice:0.6292 IoU:0.4716 CBL:0.8721 | LR:2.5e-05
# Epoch 46/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.3824]
# Epoch  46 | T_Loss: 0.8066 | [CENTER_] Dice:0.6197 IoU:0.4587 CBL:0.9161 | [CENTER_] Dice:0.6237 IoU:0.4641 CBL:0.8943 | LR:2.5e-05
# Epoch 47/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.10it/s, loss=0.8138]
# Epoch  47 | T_Loss: 0.8040 | [CENTER_] Dice:0.6479 IoU:0.4894 CBL:0.9174 | [CENTER_] Dice:0.6478 IoU:0.4907 CBL:0.8961 | LR:1.3e-05
# Epoch 48/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.8046]
# 🥇 [BEST] Epoch  48 | T_Loss: 0.7770 | [CENTER_] Dice:0.6717 IoU:0.5169 CBL:0.9022 | [CENTER_] Dice:0.6642 IoU:0.5107 CBL:0.8791 | LR:1.3e-05
# Epoch 49/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9300]
# Epoch  49 | T_Loss: 0.7704 | [CENTER_] Dice:0.6627 IoU:0.5066 CBL:0.9104 | [CENTER_] Dice:0.6612 IoU:0.5059 CBL:0.8890 | LR:1.3e-05
# Epoch 50/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.5975]
# Epoch  50 | T_Loss: 0.7667 | [CENTER_] Dice:0.6467 IoU:0.4895 CBL:0.9130 | [CENTER_] Dice:0.6517 IoU:0.4954 CBL:0.8993 | LR:1.3e-05
# Epoch 51/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.7056]
# 🥇 [BEST] Epoch  51 | T_Loss: 0.7770 | [CENTER_] Dice:0.6828 IoU:0.5301 CBL:0.9099 | [CENTER_] Dice:0.6816 IoU:0.5310 CBL:0.8917 | LR:1.3e-05
# Epoch 52/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9737]
# Epoch  52 | T_Loss: 0.7663 | [CENTER_] Dice:0.6707 IoU:0.5163 CBL:0.9104 | [CENTER_] Dice:0.6675 IoU:0.5152 CBL:0.8861 | LR:1.3e-05
# Epoch 53/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.7004]
# 🥇 [BEST] Epoch  53 | T_Loss: 0.7509 | [CENTER_] Dice:0.6920 IoU:0.5407 CBL:0.9111 | [CENTER_] Dice:0.6866 IoU:0.5365 CBL:0.8894 | LR:1.3e-05
# Epoch 54/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.7934]
# Epoch  54 | T_Loss: 0.7653 | [CENTER_] Dice:0.6718 IoU:0.5169 CBL:0.9030 | [CENTER_] Dice:0.6722 IoU:0.5197 CBL:0.8879 | LR:1.3e-05
# Epoch 55/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.9792]
# Epoch  55 | T_Loss: 0.7567 | [CENTER_] Dice:0.6562 IoU:0.4997 CBL:0.9095 | [CENTER_] Dice:0.6577 IoU:0.5028 CBL:0.8887 | LR:1.3e-05
# Epoch 56/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.10it/s, loss=0.7919]
# Epoch  56 | T_Loss: 0.7309 | [CENTER_] Dice:0.6680 IoU:0.5128 CBL:0.9092 | [CENTER_] Dice:0.6667 IoU:0.5126 CBL:0.8909 | LR:1.3e-05
# Epoch 57/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=1.4215]
# Epoch  57 | T_Loss: 0.7373 | [CENTER_] Dice:0.6889 IoU:0.5368 CBL:0.9058 | [CENTER_] Dice:0.6849 IoU:0.5348 CBL:0.8851 | LR:1.3e-05
# Epoch 58/150 [Train]: 100%|██████| 183/183 [00:59<00:00,  3.10it/s, loss=0.8335]
# Epoch  58 | T_Loss: 0.7292 | [CENTER_] Dice:0.6731 IoU:0.5202 CBL:0.9107 | [CENTER_] Dice:0.6713 IoU:0.5194 CBL:0.8911 | LR:1.3e-05
# Epoch 59/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.5393]
# Epoch  59 | T_Loss: 0.7545 | [CENTER_] Dice:0.6813 IoU:0.5283 CBL:0.9057 | [CENTER_] Dice:0.6711 IoU:0.5207 CBL:0.8793 | LR:6.3e-06
# Epoch 60/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.6094]
# Epoch  60 | T_Loss: 0.7231 | [CENTER_] Dice:0.6725 IoU:0.5184 CBL:0.9068 | [CENTER_] Dice:0.6704 IoU:0.5191 CBL:0.8864 | LR:6.3e-06
# Epoch 61/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.6286]
# Epoch  61 | T_Loss: 0.7140 | [CENTER_] Dice:0.6719 IoU:0.5184 CBL:0.9075 | [CENTER_] Dice:0.6723 IoU:0.5207 CBL:0.8917 | LR:6.3e-06
# Epoch 62/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.7447]
# Epoch  62 | T_Loss: 0.7213 | [CENTER_] Dice:0.6741 IoU:0.5200 CBL:0.9089 | [CENTER_] Dice:0.6725 IoU:0.5198 CBL:0.8911 | LR:6.3e-06
# Epoch 63/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.6468]
# Epoch  63 | T_Loss: 0.7257 | [CENTER_] Dice:0.6645 IoU:0.5105 CBL:0.9082 | [CENTER_] Dice:0.6664 IoU:0.5131 CBL:0.8957 | LR:6.3e-06
# Epoch 64/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.7339]
# Epoch  64 | T_Loss: 0.7226 | [CENTER_] Dice:0.6855 IoU:0.5337 CBL:0.9050 | [CENTER_] Dice:0.6813 IoU:0.5314 CBL:0.8877 | LR:6.3e-06
# Epoch 65/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.5602]
# Epoch  65 | T_Loss: 0.7069 | [CENTER_] Dice:0.6736 IoU:0.5201 CBL:0.9065 | [CENTER_] Dice:0.6755 IoU:0.5240 CBL:0.8888 | LR:3.1e-06
# Epoch 66/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.7901]
# Epoch  66 | T_Loss: 0.7024 | [CENTER_] Dice:0.6770 IoU:0.5242 CBL:0.9056 | [CENTER_] Dice:0.6767 IoU:0.5256 CBL:0.8878 | LR:3.1e-06
# Epoch 67/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.11it/s, loss=0.6357]
# Epoch  67 | T_Loss: 0.7006 | [CENTER_] Dice:0.6792 IoU:0.5262 CBL:0.9090 | [CENTER_] Dice:0.6782 IoU:0.5278 CBL:0.8903 | LR:3.1e-06
# Epoch 68/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.10it/s, loss=0.8657]
# Epoch  68 | T_Loss: 0.6958 | [CENTER_] Dice:0.6908 IoU:0.5402 CBL:0.9084 | [CENTER_] Dice:0.6842 IoU:0.5353 CBL:0.8857 | LR:3.1e-06
# Early stopping at epoch 68.
#
# Best Dice (center_shift): 0.6866
# Checkpoint: checkpoints/pga_unet_center_mixed_x3_shift05_qhead_binaryprompt_512_seed22120196_best.pth
# ['checkpoints/pga_unet_center_mixed_x3_shift05_qhead_binaryprompt_512_seed22120196_best.pth']

# %%
# -- Quick test on the held-out set: image-level merged, 2 prompt scenarios --
# Loads the checkpoint train.py just wrote in this session (no Drive download).
# Full qualitative panels + per-image CSVs live in Source/File_Test/*/Ablation/.
import os, sys, csv
import numpy as np, torch
from collections import OrderedDict
from torch.utils.data import DataLoader
from tqdm import tqdm
from scipy.ndimage import binary_erosion, distance_transform_edt

os.chdir(PGA_ROOT)
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)
from dataset import PromptSegmentationDataset

IMG_SIZE, SCALE_FACTOR, SHIFT_RATIO = 512, 3.0, 0.5
DEVICE  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DS_ROOT = f"{PGA_ROOT}/dataset_FracAtlas"
CKPT    = f"checkpoints/pga_unet_center_mixed_x3_shift05_qhead_binaryprompt_512_{RUN_TAG}_best.pth"

VARIANT, ENC, QH, BINP = "full", 1, 1, 1
if VARIANT == "psg_only":
    from models.networks.prompt_unet_psg_only import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
elif VARIANT == "psg_attention":
    from models.networks.prompt_unet_psg_attention import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
else:
    from models.networks.prompt_unet_2D import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1,
                     use_encoder_prompt=bool(ENC), use_quality_head=bool(QH))
model.load_state_dict(torch.load(CKPT, map_location=DEVICE, weights_only=True))
model.to(DEVICE).eval()
print("loaded", CKPT)


def _hd95(p, g):
    p, g = p.astype(bool), g.astype(bool)
    if not p.any() and not g.any(): return 0.0
    if not p.any() or not g.any():  return float(IMG_SIZE)
    pe, ge = p ^ binary_erosion(p), g ^ binary_erosion(g)
    d1, d2 = distance_transform_edt(~ge)[pe], distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2): return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))


def _metrics(prob, gt):
    pm, gm, eps = (prob > 0.5), (gt > 0.5), 1e-6
    tp, fp, fn = float((pm & gm).sum()), float((pm & ~gm).sum()), float((~pm & gm).sum())
    cbl = 0.0
    if gm.any() and pm.any():
        ys, xs = np.where(gm); yp, xp = np.where(pm)
        diag = np.hypot(ys.max() - ys.min(), xs.max() - xs.min()) + eps
        cbl = float(np.clip(1 - np.hypot(xp.mean() - xs.mean(), yp.mean() - ys.mean()) / diag, 0, 1))
    return dict(dice=(2*tp+eps)/(2*tp+fp+fn+eps), iou=(tp+eps)/(tp+fp+fn+eps),
                pre=tp/(tp+fp+eps), rec=(tp+eps)/(tp+fn+eps), hd95=_hd95(pm, gm), cbl=cbl)


os.makedirs("results", exist_ok=True)
per_image, rows = [], []
for mode in ("center_zoom", "center_shift"):
    ds = PromptSegmentationDataset(f"{DS_ROOT}/test/images", f"{DS_ROOT}/test/annotations",
                                   img_size=IMG_SIZE, is_train=False, prompt_mode=mode,
                                   scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO,
                                   binary_prompt=bool(BINP))
    groups = OrderedDict()
    with torch.no_grad():
        for i, (img, msk, prm) in enumerate(tqdm(DataLoader(ds, batch_size=1, num_workers=2), desc=mode)):
            prob = torch.sigmoid(model(img.to(DEVICE), prm.to(DEVICE)))[0, 0].cpu().numpy()
            gt   = msk[0, 0].numpy()
            name = ds.all_samples[i][0]
            if name not in groups:
                groups[name] = [prob.copy(), gt.copy()]
            else:
                np.maximum(groups[name][0], prob, out=groups[name][0])
                np.maximum(groups[name][1], gt,   out=groups[name][1])
    recs = []
    for name, (p, g) in groups.items():
        m = _metrics(p, g); recs.append(m)
        per_image.append([mode, name] + [m[k] for k in ("dice", "iou", "pre", "rec", "hd95", "cbl")])
    avg = {k: float(np.mean([r[k] for r in recs])) for k in recs[0]}
    rows.append((mode, len(recs), avg))

print(f"\n{'scenario':<14}{'N':>5}{'Dice':>9}{'IoU':>9}{'Prec':>9}{'Rec':>9}{'HD95':>9}{'CBL':>9}")
for mode, n, a in rows:
    print(f"{mode:<14}{n:>5}{a['dice']:>9.4f}{a['iou']:>9.4f}{a['pre']:>9.4f}{a['rec']:>9.4f}{a['hd95']:>9.2f}{a['cbl']:>9.4f}")

csv_path = f"results/ablation_qhead_binaryprompt_{RUN_TAG}_per_image.csv"
with open(csv_path, "w", newline="") as fh:
    w = csv.writer(fh); w.writerow(["scenario", "img_name", "dice", "iou", "pre", "rec", "hd95", "cbl"])
    w.writerows(per_image)
print("saved", csv_path)
# Out:
# loaded checkpoints/pga_unet_center_mixed_x3_shift05_qhead_binaryprompt_512_seed22120196_best.pth
# center_zoom: 100%|██████████| 92/92 [00:02<00:00, 31.05it/s]
# center_shift: 100%|██████████| 92/92 [00:02<00:00, 34.56it/s]
# scenario          N     Dice      IoU     Prec      Rec     HD95      CBL
# center_zoom      72   0.6680   0.5141   0.5598   0.8947    12.05   0.9040
# center_shift     72   0.6571   0.5045   0.5609   0.8631    13.17   0.8857
# saved results/ablation_qhead_binaryprompt_seed22120196_per_image.csv
