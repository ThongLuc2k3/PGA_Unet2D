# %% [markdown]
# # Ablation - CAD only (no PSG)
# `use_encoder_prompt=False`: uses only the Conditioned Attention Decoder.

# %%
import os, sys, shutil
import gdown

BASE = '/kaggle/working' if os.path.exists('/kaggle/working') else '/content'
os.chdir(BASE)

REPO = 'https://github.com/ThongLuc2k3/PGA_Unet2D.git'
REPO_ROOT = f'{BASE}/PGA_Unet2D'
PGA_ROOT = f'{REPO_ROOT}/Source/Prompt-Guided-XRay-Segmentation'
DATASET_NAME = 'dataset_FracAtlas'
DATASET_ID = '1sfMPFQvADmZLCPJC3xPyYDrblnFZ4kQv'
DS_ZIP = f'{BASE}/{DATASET_NAME}.zip'
DS_PATH = f'{PGA_ROOT}/{DATASET_NAME}'

if os.path.exists(REPO_ROOT):
    shutil.rmtree(REPO_ROOT)
# !git clone -q --branch main --single-branch {REPO} {REPO_ROOT}
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)

if not os.path.exists(DS_ZIP):
    gdown.download(f'https://drive.google.com/uc?id={DATASET_ID}', DS_ZIP, quiet=False)
if os.path.exists(DS_PATH):
    shutil.rmtree(DS_PATH)
# !unzip -oq {DS_ZIP} -d {PGA_ROOT}/

os.makedirs(f'{PGA_ROOT}/checkpoints', exist_ok=True)
os.chdir(PGA_ROOT)
# !pip install -q tqdm opencv-python timm scipy gdown
print(f'✅ Setup completed | base={BASE} | dataset={DATASET_NAME}')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1sfMPFQvADmZLCPJC3xPyYDrblnFZ4kQv
# From (redirected): https://drive.google.com/uc?id=1sfMPFQvADmZLCPJC3xPyYDrblnFZ4kQv&confirm=t&uuid=fe1bbdf9-71ba-4073-bb53-c5b3bc1fdcb1
# To: /kaggle/working/dataset_FracAtlas.zip
# 100%|██████████| 231M/231M [00:01<00:00, 155MB/s]
# ✅ Setup completed | base=/kaggle/working | dataset=dataset_FracAtlas

# %% [markdown]
# ## Ablation training via the shared `train.py`
#
# **Configuration: CAD only (no PSG).** CAD decoder attention only, PSG encoder gate disabled (`USE_ENCODER_PROMPT=0`). QualityHead stays on so this row matches the main PGA-UNet training objective.
#
# Every ablation configuration is trained through the same `train.py` as the full PGA-UNet, so batch size, optimizer, scheduler, gradient clipping, the 150-epoch / patience-15 early stopping, and **image-level merged `center_shift` validation for checkpoint selection** are identical across the study. Repeat the training cell with `SEED = 1`, `2`, `3` for the multi-seed ablation; `RUN_TAG` keeps the per-seed checkpoints from overwriting each other.
#
# A quick image-level metrics table on the held-out test set is printed by the last cell. For the full qualitative panels and per-image CSVs, run the matching notebook under `Source/File_Test/fracatlas/Ablation/`.

# %%
# Repeat with SEED = 1, 2, 3 ... for the multi-seed ablation.
SEED = 22120196
RUN_TAG = f"seed{SEED}"

import os, glob
os.chdir(PGA_ROOT)
os.environ.update({
    "PROMPT_DATASET_ROOT": "dataset_FracAtlas",
    "PROMPT_IMG_SIZE": "512",
    "PROMPT_MODE": "center_mixed",
    "PROMPT_SCALE_FACTOR": "3.0",
    "PROMPT_SHIFT_RATIO": "0.5",
    "PROMPT_MIXED_SHIFT_PROB": "0.8",
    "PROMPT_EPOCHS": "150",
    "PROMPT_SEED": str(SEED),
    "RUN_TAG": RUN_TAG,
    "PROMPT_VARIANT": "full",
    "USE_ENCODER_PROMPT": "0",
    "BINARY_PROMPT": "0",
    "USE_QUALITY_HEAD": "1",
})

# !python train.py

print(sorted(glob.glob(f"checkpoints/pga_unet_center_mixed_x3_shift05_qhead_nopsg_512_{RUN_TAG}_best.pth")))
# Out:
# ==========================================================================================
# TrainPrompt: center_mixed | Device: cuda | Variant: full | EncoderPrompt: False | BinaryPrompt: False | ImgSize: 512 | DatasetRoot: dataset_FracAtlas | Seed: 22120196 | RunTag: seed22120196 | ScaleFactor: 3.0 | ShiftRatio: 0.5 | MixedShiftProb: 0.8 | QualityHead: ConfidenceLossWeight=1.0
# ==========================================================================================
# Epoch 1/150 [Train]: 100%|███████| 183/183 [00:51<00:00,  3.56it/s, loss=1.4726]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.6569 | [CENTER_] Dice:0.0261 IoU:0.0134 CBL:0.2070 | [CENTER_] Dice:0.0247 IoU:0.0127 CBL:0.2051 | LR:1.0e-04
# Epoch 2/150 [Train]: 100%|███████| 183/183 [00:51<00:00,  3.53it/s, loss=1.3845]
# Epoch   2 | T_Loss: 1.4208 | [CENTER_] Dice:0.0248 IoU:0.0132 CBL:0.5081 | [CENTER_] Dice:0.0246 IoU:0.0131 CBL:0.4903 | LR:1.0e-04
# Epoch 3/150 [Train]: 100%|███████| 183/183 [00:53<00:00,  3.45it/s, loss=1.3497]
# 🥇 [BEST] Epoch   3 | T_Loss: 1.4176 | [CENTER_] Dice:0.5417 IoU:0.3846 CBL:0.8342 | [CENTER_] Dice:0.5401 IoU:0.3835 CBL:0.8220 | LR:1.0e-04
# Epoch 4/150 [Train]: 100%|███████| 183/183 [00:53<00:00,  3.40it/s, loss=1.4533]
# Epoch   4 | T_Loss: 1.3756 | [CENTER_] Dice:0.5934 IoU:0.4349 CBL:0.8711 | [CENTER_] Dice:0.5093 IoU:0.3516 CBL:0.7586 | LR:1.0e-04
# Epoch 5/150 [Train]: 100%|███████| 183/183 [00:54<00:00,  3.36it/s, loss=1.2937]
# Epoch   5 | T_Loss: 1.3426 | [CENTER_] Dice:0.4703 IoU:0.3112 CBL:0.8642 | [CENTER_] Dice:0.4652 IoU:0.3089 CBL:0.7799 | LR:1.0e-04
# Epoch 6/150 [Train]: 100%|███████| 183/183 [00:54<00:00,  3.35it/s, loss=1.2600]
# Epoch   6 | T_Loss: 1.3137 | [CENTER_] Dice:0.4993 IoU:0.3378 CBL:0.8453 | [CENTER_] Dice:0.4933 IoU:0.3330 CBL:0.7876 | LR:1.0e-04
# Epoch 7/150 [Train]: 100%|███████| 183/183 [00:54<00:00,  3.33it/s, loss=1.2632]
# 🥇 [BEST] Epoch   7 | T_Loss: 1.2817 | [CENTER_] Dice:0.5738 IoU:0.4083 CBL:0.8620 | [CENTER_] Dice:0.5622 IoU:0.3992 CBL:0.8290 | LR:1.0e-04
# Epoch 8/150 [Train]: 100%|███████| 183/183 [00:55<00:00,  3.32it/s, loss=1.2363]
# Epoch   8 | T_Loss: 1.2538 | [CENTER_] Dice:0.5622 IoU:0.3964 CBL:0.8974 | [CENTER_] Dice:0.5508 IoU:0.3879 CBL:0.8345 | LR:1.0e-04
# Epoch 9/150 [Train]: 100%|███████| 183/183 [00:55<00:00,  3.32it/s, loss=1.2016]
# Epoch   9 | T_Loss: 1.2278 | [CENTER_] Dice:0.5015 IoU:0.3392 CBL:0.8762 | [CENTER_] Dice:0.4928 IoU:0.3321 CBL:0.8224 | LR:1.0e-04
# Epoch 10/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.32it/s, loss=1.1888]
# Epoch  10 | T_Loss: 1.2052 | [CENTER_] Dice:0.5771 IoU:0.4115 CBL:0.8801 | [CENTER_] Dice:0.5161 IoU:0.3549 CBL:0.7810 | LR:1.0e-04
# Epoch 11/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.30it/s, loss=1.3178]
# Epoch  11 | T_Loss: 1.1808 | [CENTER_] Dice:0.4966 IoU:0.3359 CBL:0.9126 | [CENTER_] Dice:0.4895 IoU:0.3300 CBL:0.8418 | LR:1.0e-04
# Epoch 12/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.12it/s, loss=1.1195]
# Epoch  12 | T_Loss: 1.1617 | [CENTER_] Dice:0.5300 IoU:0.3650 CBL:0.8874 | [CENTER_] Dice:0.5164 IoU:0.3534 CBL:0.8211 | LR:1.0e-04
# Epoch 13/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=1.1157]
# Epoch  13 | T_Loss: 1.1363 | [CENTER_] Dice:0.5305 IoU:0.3649 CBL:0.9128 | [CENTER_] Dice:0.5119 IoU:0.3496 CBL:0.8491 | LR:5.0e-05
# Epoch 14/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.20it/s, loss=1.0906]
# Epoch  14 | T_Loss: 1.1140 | [CENTER_] Dice:0.5778 IoU:0.4112 CBL:0.9143 | [CENTER_] Dice:0.5582 IoU:0.3929 CBL:0.8735 | LR:5.0e-05
# Epoch 15/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.22it/s, loss=1.0893]
# Epoch  15 | T_Loss: 1.1201 | [CENTER_] Dice:0.5370 IoU:0.3724 CBL:0.9174 | [CENTER_] Dice:0.5197 IoU:0.3566 CBL:0.8510 | LR:5.0e-05
# Epoch 16/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.26it/s, loss=1.0005]
# Epoch  16 | T_Loss: 1.1082 | [CENTER_] Dice:0.5057 IoU:0.3428 CBL:0.9188 | [CENTER_] Dice:0.4953 IoU:0.3339 CBL:0.8704 | LR:5.0e-05
# Epoch 17/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.27it/s, loss=1.1759]
# Epoch  17 | T_Loss: 1.0888 | [CENTER_] Dice:0.5318 IoU:0.3668 CBL:0.9091 | [CENTER_] Dice:0.5255 IoU:0.3614 CBL:0.8722 | LR:5.0e-05
# Epoch 18/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.26it/s, loss=1.0118]
# Epoch  18 | T_Loss: 1.0806 | [CENTER_] Dice:0.4638 IoU:0.3050 CBL:0.9201 | [CENTER_] Dice:0.4576 IoU:0.3002 CBL:0.8599 | LR:5.0e-05
# Epoch 19/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.26it/s, loss=1.0510]
# 🥇 [BEST] Epoch  19 | T_Loss: 1.0618 | [CENTER_] Dice:0.5825 IoU:0.4165 CBL:0.9331 | [CENTER_] Dice:0.5672 IoU:0.4025 CBL:0.8750 | LR:5.0e-05
# Epoch 20/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.26it/s, loss=1.0487]
# Epoch  20 | T_Loss: 1.0521 | [CENTER_] Dice:0.5325 IoU:0.3682 CBL:0.9130 | [CENTER_] Dice:0.5201 IoU:0.3569 CBL:0.8447 | LR:5.0e-05
# Epoch 21/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.26it/s, loss=1.0217]
# Epoch  21 | T_Loss: 1.0511 | [CENTER_] Dice:0.5399 IoU:0.3755 CBL:0.9192 | [CENTER_] Dice:0.5323 IoU:0.3691 CBL:0.8600 | LR:5.0e-05
# Epoch 22/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.27it/s, loss=1.2752]
# Epoch  22 | T_Loss: 1.0439 | [CENTER_] Dice:0.5434 IoU:0.3791 CBL:0.8872 | [CENTER_] Dice:0.5263 IoU:0.3633 CBL:0.8274 | LR:5.0e-05
# Epoch 23/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.27it/s, loss=1.0414]
# Epoch  23 | T_Loss: 1.0333 | [CENTER_] Dice:0.4957 IoU:0.3324 CBL:0.9258 | [CENTER_] Dice:0.4918 IoU:0.3292 CBL:0.8551 | LR:5.0e-05
# Epoch 24/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.27it/s, loss=1.0017]
# 🥇 [BEST] Epoch  24 | T_Loss: 1.0257 | [CENTER_] Dice:0.5829 IoU:0.4167 CBL:0.9229 | [CENTER_] Dice:0.5748 IoU:0.4093 CBL:0.8670 | LR:5.0e-05
# Epoch 25/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=1.1568]
# Epoch  25 | T_Loss: 1.0124 | [CENTER_] Dice:0.4999 IoU:0.3376 CBL:0.9088 | [CENTER_] Dice:0.4872 IoU:0.3267 CBL:0.8367 | LR:5.0e-05
# Epoch 26/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.27it/s, loss=1.0071]
# Epoch  26 | T_Loss: 1.0039 | [CENTER_] Dice:0.4800 IoU:0.3209 CBL:0.9011 | [CENTER_] Dice:0.4744 IoU:0.3162 CBL:0.8450 | LR:5.0e-05
# Epoch 27/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=1.1667]
# Epoch  27 | T_Loss: 0.9922 | [CENTER_] Dice:0.5169 IoU:0.3534 CBL:0.9089 | [CENTER_] Dice:0.5056 IoU:0.3430 CBL:0.8583 | LR:5.0e-05
# Epoch 28/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.8418]
# 🥇 [BEST] Epoch  28 | T_Loss: 0.9894 | [CENTER_] Dice:0.5966 IoU:0.4340 CBL:0.9170 | [CENTER_] Dice:0.5770 IoU:0.4137 CBL:0.8701 | LR:5.0e-05
# Epoch 29/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.27it/s, loss=1.2594]
# Epoch  29 | T_Loss: 0.9722 | [CENTER_] Dice:0.5470 IoU:0.3828 CBL:0.9185 | [CENTER_] Dice:0.5413 IoU:0.3778 CBL:0.8682 | LR:5.0e-05
# Epoch 30/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.8468]
# Epoch  30 | T_Loss: 0.9617 | [CENTER_] Dice:0.5611 IoU:0.3972 CBL:0.9139 | [CENTER_] Dice:0.5488 IoU:0.3852 CBL:0.8673 | LR:5.0e-05
# Epoch 31/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.8304]
# Epoch  31 | T_Loss: 0.9562 | [CENTER_] Dice:0.5704 IoU:0.4077 CBL:0.9050 | [CENTER_] Dice:0.5609 IoU:0.3982 CBL:0.8759 | LR:5.0e-05
# Epoch 32/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.9556]
# Epoch  32 | T_Loss: 0.9386 | [CENTER_] Dice:0.5365 IoU:0.3718 CBL:0.9143 | [CENTER_] Dice:0.5258 IoU:0.3626 CBL:0.8573 | LR:5.0e-05
# Epoch 33/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.8609]
# Epoch  33 | T_Loss: 0.9317 | [CENTER_] Dice:0.5615 IoU:0.3961 CBL:0.9192 | [CENTER_] Dice:0.5516 IoU:0.3873 CBL:0.8687 | LR:5.0e-05
# Epoch 34/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.9246]
# Epoch  34 | T_Loss: 0.9159 | [CENTER_] Dice:0.5592 IoU:0.3949 CBL:0.9016 | [CENTER_] Dice:0.5449 IoU:0.3815 CBL:0.8575 | LR:2.5e-05
# Epoch 35/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=1.1249]
# Epoch  35 | T_Loss: 0.9027 | [CENTER_] Dice:0.5669 IoU:0.4037 CBL:0.9065 | [CENTER_] Dice:0.5585 IoU:0.3951 CBL:0.8669 | LR:2.5e-05
# Epoch 36/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=1.1860]
# 🥇 [BEST] Epoch  36 | T_Loss: 0.8969 | [CENTER_] Dice:0.5935 IoU:0.4320 CBL:0.9180 | [CENTER_] Dice:0.5804 IoU:0.4179 CBL:0.8774 | LR:2.5e-05
# Epoch 37/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.27it/s, loss=0.8791]
# 🥇 [BEST] Epoch  37 | T_Loss: 0.8890 | [CENTER_] Dice:0.6149 IoU:0.4529 CBL:0.9124 | [CENTER_] Dice:0.5968 IoU:0.4348 CBL:0.8724 | LR:2.5e-05
# Epoch 38/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.27it/s, loss=0.8227]
# 🥇 [BEST] Epoch  38 | T_Loss: 0.8798 | [CENTER_] Dice:0.6163 IoU:0.4530 CBL:0.9198 | [CENTER_] Dice:0.6027 IoU:0.4392 CBL:0.8786 | LR:2.5e-05
# Epoch 39/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.26it/s, loss=0.8400]
# Epoch  39 | T_Loss: 0.8908 | [CENTER_] Dice:0.6176 IoU:0.4548 CBL:0.9063 | [CENTER_] Dice:0.5969 IoU:0.4332 CBL:0.8708 | LR:2.5e-05
# Epoch 40/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.27it/s, loss=0.8394]
# Epoch  40 | T_Loss: 0.8754 | [CENTER_] Dice:0.6075 IoU:0.4453 CBL:0.9092 | [CENTER_] Dice:0.5967 IoU:0.4346 CBL:0.8795 | LR:2.5e-05
# Epoch 41/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.23it/s, loss=0.8444]
# 🥇 [BEST] Epoch  41 | T_Loss: 0.8734 | [CENTER_] Dice:0.6395 IoU:0.4818 CBL:0.9166 | [CENTER_] Dice:0.6248 IoU:0.4677 CBL:0.8827 | LR:2.5e-05
# Epoch 42/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.24it/s, loss=0.9647]
# 🥇 [BEST] Epoch  42 | T_Loss: 0.8545 | [CENTER_] Dice:0.6523 IoU:0.4931 CBL:0.9139 | [CENTER_] Dice:0.6330 IoU:0.4725 CBL:0.8793 | LR:2.5e-05
# Epoch 43/150 [Train]: 100%|██████| 183/183 [00:56<00:00,  3.27it/s, loss=0.8846]
# Epoch  43 | T_Loss: 0.8380 | [CENTER_] Dice:0.6259 IoU:0.4662 CBL:0.9132 | [CENTER_] Dice:0.6125 IoU:0.4515 CBL:0.8785 | LR:2.5e-05
# Epoch 44/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.9395]
# Epoch  44 | T_Loss: 0.8456 | [CENTER_] Dice:0.6283 IoU:0.4673 CBL:0.9138 | [CENTER_] Dice:0.6075 IoU:0.4456 CBL:0.8783 | LR:2.5e-05
# Epoch 45/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.27it/s, loss=1.0875]
# 🥇 [BEST] Epoch  45 | T_Loss: 0.8383 | [CENTER_] Dice:0.6474 IoU:0.4912 CBL:0.9169 | [CENTER_] Dice:0.6346 IoU:0.4775 CBL:0.8976 | LR:2.5e-05
# Epoch 46/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.29it/s, loss=0.7329]
# Epoch  46 | T_Loss: 0.8284 | [CENTER_] Dice:0.6459 IoU:0.4873 CBL:0.9085 | [CENTER_] Dice:0.6220 IoU:0.4627 CBL:0.8735 | LR:2.5e-05
# Epoch 47/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.9950]
# Epoch  47 | T_Loss: 0.8270 | [CENTER_] Dice:0.6420 IoU:0.4826 CBL:0.9081 | [CENTER_] Dice:0.6325 IoU:0.4730 CBL:0.8830 | LR:2.5e-05
# Epoch 48/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.8757]
# Epoch  48 | T_Loss: 0.8213 | [CENTER_] Dice:0.6484 IoU:0.4895 CBL:0.9082 | [CENTER_] Dice:0.6262 IoU:0.4658 CBL:0.8718 | LR:2.5e-05
# Epoch 49/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.8696]
# Epoch  49 | T_Loss: 0.8162 | [CENTER_] Dice:0.6417 IoU:0.4826 CBL:0.9045 | [CENTER_] Dice:0.6267 IoU:0.4681 CBL:0.8800 | LR:2.5e-05
# Epoch 50/150 [Train]: 100%|██████| 183/183 [00:55<00:00,  3.28it/s, loss=0.7735]
# Epoch  50 | T_Loss: 0.8063 | [CENTER_] Dice:0.6546 IoU:0.4969 CBL:0.9053 | [CENTER_] Dice:0.6330 IoU:0.4740 CBL:0.8726 | LR:2.5e-05
# Epoch 51/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.9418]
# Epoch  51 | T_Loss: 0.7937 | [CENTER_] Dice:0.6408 IoU:0.4828 CBL:0.9168 | [CENTER_] Dice:0.6336 IoU:0.4751 CBL:0.8914 | LR:1.3e-05
# Epoch 52/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.16it/s, loss=0.5716]
# 🥇 [BEST] Epoch  52 | T_Loss: 0.7743 | [CENTER_] Dice:0.6619 IoU:0.5061 CBL:0.9113 | [CENTER_] Dice:0.6465 IoU:0.4902 CBL:0.8799 | LR:1.3e-05
# Epoch 53/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.6677]
# Epoch  53 | T_Loss: 0.7836 | [CENTER_] Dice:0.6648 IoU:0.5085 CBL:0.9153 | [CENTER_] Dice:0.6452 IoU:0.4890 CBL:0.8838 | LR:1.3e-05
# Epoch 54/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.19it/s, loss=0.7767]
# Epoch  54 | T_Loss: 0.7868 | [CENTER_] Dice:0.6615 IoU:0.5053 CBL:0.9123 | [CENTER_] Dice:0.6432 IoU:0.4875 CBL:0.8828 | LR:1.3e-05
# Epoch 55/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.7984]
# Epoch  55 | T_Loss: 0.7721 | [CENTER_] Dice:0.6464 IoU:0.4887 CBL:0.9118 | [CENTER_] Dice:0.6355 IoU:0.4788 CBL:0.8833 | LR:1.3e-05
# Epoch 56/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.16it/s, loss=0.7060]
# 🥇 [BEST] Epoch  56 | T_Loss: 0.7672 | [CENTER_] Dice:0.6701 IoU:0.5158 CBL:0.9136 | [CENTER_] Dice:0.6488 IoU:0.4946 CBL:0.8839 | LR:1.3e-05
# Epoch 57/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.7230]
# 🥇 [BEST] Epoch  57 | T_Loss: 0.7764 | [CENTER_] Dice:0.6645 IoU:0.5092 CBL:0.9199 | [CENTER_] Dice:0.6535 IoU:0.4988 CBL:0.8956 | LR:1.3e-05
# Epoch 58/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.6137]
# Epoch  58 | T_Loss: 0.7561 | [CENTER_] Dice:0.6709 IoU:0.5160 CBL:0.9128 | [CENTER_] Dice:0.6523 IoU:0.4970 CBL:0.8831 | LR:1.3e-05
# Epoch 59/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.7282]
# 🥇 [BEST] Epoch  59 | T_Loss: 0.7522 | [CENTER_] Dice:0.6778 IoU:0.5240 CBL:0.9132 | [CENTER_] Dice:0.6576 IoU:0.5038 CBL:0.8804 | LR:1.3e-05
# Epoch 60/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.8197]
# Epoch  60 | T_Loss: 0.7544 | [CENTER_] Dice:0.6761 IoU:0.5223 CBL:0.9067 | [CENTER_] Dice:0.6550 IoU:0.5007 CBL:0.8770 | LR:1.3e-05
# Epoch 61/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.7406]
# Epoch  61 | T_Loss: 0.7473 | [CENTER_] Dice:0.6671 IoU:0.5121 CBL:0.9126 | [CENTER_] Dice:0.6460 IoU:0.4908 CBL:0.8843 | LR:1.3e-05
# Epoch 62/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.7084]
# Epoch  62 | T_Loss: 0.7504 | [CENTER_] Dice:0.6643 IoU:0.5101 CBL:0.9129 | [CENTER_] Dice:0.6490 IoU:0.4942 CBL:0.8870 | LR:1.3e-05
# Epoch 63/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.5528]
# Epoch  63 | T_Loss: 0.7390 | [CENTER_] Dice:0.6725 IoU:0.5184 CBL:0.9122 | [CENTER_] Dice:0.6566 IoU:0.5025 CBL:0.8880 | LR:1.3e-05
# Epoch 64/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.6127]
# 🥇 [BEST] Epoch  64 | T_Loss: 0.7297 | [CENTER_] Dice:0.6789 IoU:0.5265 CBL:0.9131 | [CENTER_] Dice:0.6622 IoU:0.5088 CBL:0.8855 | LR:1.3e-05
# Epoch 65/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.5776]
# Epoch  65 | T_Loss: 0.7369 | [CENTER_] Dice:0.6608 IoU:0.5054 CBL:0.9056 | [CENTER_] Dice:0.6426 IoU:0.4866 CBL:0.8783 | LR:1.3e-05
# Epoch 66/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.6403]
# Epoch  66 | T_Loss: 0.7366 | [CENTER_] Dice:0.6749 IoU:0.5228 CBL:0.9121 | [CENTER_] Dice:0.6567 IoU:0.5038 CBL:0.8890 | LR:1.3e-05
# Epoch 67/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.7332]
# 🥇 [BEST] Epoch  67 | T_Loss: 0.7302 | [CENTER_] Dice:0.6809 IoU:0.5281 CBL:0.9085 | [CENTER_] Dice:0.6624 IoU:0.5082 CBL:0.8828 | LR:1.3e-05
# Epoch 68/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.7104]
# 🥇 [BEST] Epoch  68 | T_Loss: 0.7112 | [CENTER_] Dice:0.6869 IoU:0.5359 CBL:0.9117 | [CENTER_] Dice:0.6701 IoU:0.5185 CBL:0.8942 | LR:1.3e-05
# Epoch 69/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=1.3220]
# Epoch  69 | T_Loss: 0.7233 | [CENTER_] Dice:0.6659 IoU:0.5112 CBL:0.9101 | [CENTER_] Dice:0.6465 IoU:0.4909 CBL:0.8851 | LR:1.3e-05
# Epoch 70/150 [Train]: 100%|██████| 183/183 [00:58<00:00,  3.15it/s, loss=0.7833]
# Epoch  70 | T_Loss: 0.7063 | [CENTER_] Dice:0.6780 IoU:0.5242 CBL:0.9078 | [CENTER_] Dice:0.6583 IoU:0.5035 CBL:0.8829 | LR:1.3e-05
# Epoch 71/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.5789]
# Epoch  71 | T_Loss: 0.6967 | [CENTER_] Dice:0.6927 IoU:0.5418 CBL:0.9105 | [CENTER_] Dice:0.6637 IoU:0.5098 CBL:0.8812 | LR:1.3e-05
# Epoch 72/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.19it/s, loss=0.6331]
# 🥇 [BEST] Epoch  72 | T_Loss: 0.7191 | [CENTER_] Dice:0.6943 IoU:0.5454 CBL:0.9122 | [CENTER_] Dice:0.6747 IoU:0.5234 CBL:0.8913 | LR:1.3e-05
# Epoch 73/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.7193]
# Epoch  73 | T_Loss: 0.7087 | [CENTER_] Dice:0.6811 IoU:0.5284 CBL:0.9131 | [CENTER_] Dice:0.6640 IoU:0.5096 CBL:0.8900 | LR:1.3e-05
# Epoch 74/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.5180]
# Epoch  74 | T_Loss: 0.7057 | [CENTER_] Dice:0.6880 IoU:0.5368 CBL:0.9088 | [CENTER_] Dice:0.6610 IoU:0.5080 CBL:0.8799 | LR:1.3e-05
# Epoch 75/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.5962]
# 🥇 [BEST] Epoch  75 | T_Loss: 0.6788 | [CENTER_] Dice:0.6948 IoU:0.5452 CBL:0.9106 | [CENTER_] Dice:0.6791 IoU:0.5272 CBL:0.8931 | LR:1.3e-05
# Epoch 76/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.7982]
# Epoch  76 | T_Loss: 0.6906 | [CENTER_] Dice:0.6803 IoU:0.5303 CBL:0.9115 | [CENTER_] Dice:0.6732 IoU:0.5235 CBL:0.8957 | LR:1.3e-05
# Epoch 77/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.5449]
# Epoch  77 | T_Loss: 0.6799 | [CENTER_] Dice:0.6893 IoU:0.5385 CBL:0.9152 | [CENTER_] Dice:0.6748 IoU:0.5227 CBL:0.8915 | LR:1.3e-05
# Epoch 78/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=1.3330]
# Epoch  78 | T_Loss: 0.6797 | [CENTER_] Dice:0.6726 IoU:0.5194 CBL:0.9026 | [CENTER_] Dice:0.6557 IoU:0.5024 CBL:0.8819 | LR:1.3e-05
# Epoch 79/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.6408]
# Epoch  79 | T_Loss: 0.6769 | [CENTER_] Dice:0.6591 IoU:0.5032 CBL:0.9043 | [CENTER_] Dice:0.6442 IoU:0.4886 CBL:0.8778 | LR:1.3e-05
# Epoch 80/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.5495]
# Epoch  80 | T_Loss: 0.6860 | [CENTER_] Dice:0.6950 IoU:0.5466 CBL:0.9109 | [CENTER_] Dice:0.6711 IoU:0.5228 CBL:0.8822 | LR:1.3e-05
# Epoch 81/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.7098]
# Epoch  81 | T_Loss: 0.6787 | [CENTER_] Dice:0.6948 IoU:0.5449 CBL:0.9079 | [CENTER_] Dice:0.6778 IoU:0.5274 CBL:0.8894 | LR:6.3e-06
# Epoch 82/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.16it/s, loss=0.5186]
# Epoch  82 | T_Loss: 0.6773 | [CENTER_] Dice:0.6830 IoU:0.5315 CBL:0.9098 | [CENTER_] Dice:0.6659 IoU:0.5134 CBL:0.8849 | LR:6.3e-06
# Epoch 83/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.6040]
# 🥇 [BEST] Epoch  83 | T_Loss: 0.6703 | [CENTER_] Dice:0.6967 IoU:0.5476 CBL:0.9071 | [CENTER_] Dice:0.6793 IoU:0.5296 CBL:0.8889 | LR:6.3e-06
# Epoch 84/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.19it/s, loss=0.7902]
# Epoch  84 | T_Loss: 0.6686 | [CENTER_] Dice:0.6822 IoU:0.5314 CBL:0.9077 | [CENTER_] Dice:0.6676 IoU:0.5176 CBL:0.8851 | LR:6.3e-06
# Epoch 85/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.4177]
# Epoch  85 | T_Loss: 0.6577 | [CENTER_] Dice:0.6983 IoU:0.5503 CBL:0.9046 | [CENTER_] Dice:0.6779 IoU:0.5280 CBL:0.8841 | LR:6.3e-06
# Epoch 86/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.5083]
# Epoch  86 | T_Loss: 0.6851 | [CENTER_] Dice:0.6979 IoU:0.5496 CBL:0.9131 | [CENTER_] Dice:0.6764 IoU:0.5255 CBL:0.8875 | LR:6.3e-06
# Epoch 87/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.6073]
# Epoch  87 | T_Loss: 0.6449 | [CENTER_] Dice:0.6809 IoU:0.5299 CBL:0.9106 | [CENTER_] Dice:0.6614 IoU:0.5083 CBL:0.8858 | LR:6.3e-06
# Epoch 88/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.20it/s, loss=0.6377]
# 🥇 [BEST] Epoch  88 | T_Loss: 0.6589 | [CENTER_] Dice:0.6980 IoU:0.5495 CBL:0.9124 | [CENTER_] Dice:0.6836 IoU:0.5338 CBL:0.8935 | LR:6.3e-06
# Epoch 89/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.4575]
# Epoch  89 | T_Loss: 0.6417 | [CENTER_] Dice:0.6968 IoU:0.5475 CBL:0.9118 | [CENTER_] Dice:0.6820 IoU:0.5312 CBL:0.8906 | LR:6.3e-06
# Epoch 90/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.4513]
# Epoch  90 | T_Loss: 0.6565 | [CENTER_] Dice:0.6900 IoU:0.5397 CBL:0.9107 | [CENTER_] Dice:0.6746 IoU:0.5228 CBL:0.8909 | LR:6.3e-06
# Epoch 91/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.4098]
# Epoch  91 | T_Loss: 0.6669 | [CENTER_] Dice:0.6754 IoU:0.5234 CBL:0.9081 | [CENTER_] Dice:0.6633 IoU:0.5108 CBL:0.8891 | LR:6.3e-06
# Epoch 92/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.5402]
# 🥇 [BEST] Epoch  92 | T_Loss: 0.6413 | [CENTER_] Dice:0.7027 IoU:0.5557 CBL:0.9078 | [CENTER_] Dice:0.6838 IoU:0.5343 CBL:0.8868 | LR:6.3e-06
# Epoch 93/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.5589]
# 🥇 [BEST] Epoch  93 | T_Loss: 0.6371 | [CENTER_] Dice:0.7062 IoU:0.5614 CBL:0.9117 | [CENTER_] Dice:0.6908 IoU:0.5454 CBL:0.8930 | LR:6.3e-06
# Epoch 94/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.6621]
# Epoch  94 | T_Loss: 0.6502 | [CENTER_] Dice:0.6982 IoU:0.5499 CBL:0.9074 | [CENTER_] Dice:0.6810 IoU:0.5317 CBL:0.8873 | LR:6.3e-06
# Epoch 95/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.6438]
# Epoch  95 | T_Loss: 0.6360 | [CENTER_] Dice:0.6936 IoU:0.5441 CBL:0.9096 | [CENTER_] Dice:0.6813 IoU:0.5321 CBL:0.8918 | LR:6.3e-06
# Epoch 96/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.17it/s, loss=0.4796]
# 🥇 [BEST] Epoch  96 | T_Loss: 0.6519 | [CENTER_] Dice:0.7046 IoU:0.5568 CBL:0.9129 | [CENTER_] Dice:0.6927 IoU:0.5451 CBL:0.8956 | LR:6.3e-06
# Epoch 97/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.7549]
# Epoch  97 | T_Loss: 0.6563 | [CENTER_] Dice:0.7033 IoU:0.5552 CBL:0.9101 | [CENTER_] Dice:0.6848 IoU:0.5352 CBL:0.8901 | LR:6.3e-06
# Epoch 98/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.4535]
# Epoch  98 | T_Loss: 0.6267 | [CENTER_] Dice:0.7087 IoU:0.5619 CBL:0.9134 | [CENTER_] Dice:0.6855 IoU:0.5370 CBL:0.8902 | LR:6.3e-06
# Epoch 99/150 [Train]: 100%|██████| 183/183 [00:57<00:00,  3.18it/s, loss=0.6967]
# Epoch  99 | T_Loss: 0.6498 | [CENTER_] Dice:0.6993 IoU:0.5504 CBL:0.9122 | [CENTER_] Dice:0.6813 IoU:0.5305 CBL:0.8911 | LR:6.3e-06
# Epoch 100/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.18it/s, loss=0.5780]
# Epoch 100 | T_Loss: 0.6206 | [CENTER_] Dice:0.7023 IoU:0.5546 CBL:0.9098 | [CENTER_] Dice:0.6840 IoU:0.5367 CBL:0.8893 | LR:6.3e-06
# Epoch 101/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.17it/s, loss=0.5183]
# Epoch 101 | T_Loss: 0.6246 | [CENTER_] Dice:0.6983 IoU:0.5494 CBL:0.9122 | [CENTER_] Dice:0.6827 IoU:0.5332 CBL:0.8902 | LR:6.3e-06
# Epoch 102/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.16it/s, loss=1.0790]
# Epoch 102 | T_Loss: 0.6189 | [CENTER_] Dice:0.6998 IoU:0.5511 CBL:0.9068 | [CENTER_] Dice:0.6796 IoU:0.5299 CBL:0.8854 | LR:3.1e-06
# Epoch 103/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.17it/s, loss=0.7668]
# Epoch 103 | T_Loss: 0.6379 | [CENTER_] Dice:0.6970 IoU:0.5478 CBL:0.9097 | [CENTER_] Dice:0.6801 IoU:0.5303 CBL:0.8886 | LR:3.1e-06
# Epoch 104/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.17it/s, loss=0.5373]
# 🥇 [BEST] Epoch 104 | T_Loss: 0.6159 | [CENTER_] Dice:0.7074 IoU:0.5600 CBL:0.9102 | [CENTER_] Dice:0.6930 IoU:0.5452 CBL:0.8909 | LR:3.1e-06
# Epoch 105/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.17it/s, loss=0.5075]
# Epoch 105 | T_Loss: 0.6265 | [CENTER_] Dice:0.7034 IoU:0.5563 CBL:0.9116 | [CENTER_] Dice:0.6860 IoU:0.5382 CBL:0.8917 | LR:3.1e-06
# Epoch 106/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.17it/s, loss=0.7318]
# Epoch 106 | T_Loss: 0.6183 | [CENTER_] Dice:0.7057 IoU:0.5585 CBL:0.9110 | [CENTER_] Dice:0.6873 IoU:0.5389 CBL:0.8909 | LR:3.1e-06
# Epoch 107/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.18it/s, loss=0.6601]
# Epoch 107 | T_Loss: 0.6288 | [CENTER_] Dice:0.7039 IoU:0.5563 CBL:0.9092 | [CENTER_] Dice:0.6868 IoU:0.5385 CBL:0.8922 | LR:3.1e-06
# Epoch 108/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.17it/s, loss=0.5743]
# Epoch 108 | T_Loss: 0.6100 | [CENTER_] Dice:0.6997 IoU:0.5514 CBL:0.9079 | [CENTER_] Dice:0.6842 IoU:0.5352 CBL:0.8914 | LR:3.1e-06
# Epoch 109/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.19it/s, loss=0.5942]
# Epoch 109 | T_Loss: 0.6217 | [CENTER_] Dice:0.7023 IoU:0.5544 CBL:0.9103 | [CENTER_] Dice:0.6855 IoU:0.5371 CBL:0.8925 | LR:3.1e-06
# Epoch 110/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.19it/s, loss=0.4892]
# Epoch 110 | T_Loss: 0.6203 | [CENTER_] Dice:0.7075 IoU:0.5606 CBL:0.9080 | [CENTER_] Dice:0.6921 IoU:0.5440 CBL:0.8908 | LR:1.6e-06
# Epoch 111/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.16it/s, loss=0.3308]
# Epoch 111 | T_Loss: 0.6185 | [CENTER_] Dice:0.7068 IoU:0.5598 CBL:0.9103 | [CENTER_] Dice:0.6901 IoU:0.5417 CBL:0.8928 | LR:1.6e-06
# Epoch 112/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.17it/s, loss=0.6064]
# 🥇 [BEST] Epoch 112 | T_Loss: 0.6105 | [CENTER_] Dice:0.7122 IoU:0.5664 CBL:0.9101 | [CENTER_] Dice:0.6947 IoU:0.5474 CBL:0.8919 | LR:1.6e-06
# Epoch 113/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.17it/s, loss=0.6315]
# Epoch 113 | T_Loss: 0.6327 | [CENTER_] Dice:0.7043 IoU:0.5576 CBL:0.9106 | [CENTER_] Dice:0.6850 IoU:0.5368 CBL:0.8922 | LR:1.6e-06
# Epoch 114/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.18it/s, loss=0.5539]
# Epoch 114 | T_Loss: 0.6022 | [CENTER_] Dice:0.7052 IoU:0.5582 CBL:0.9110 | [CENTER_] Dice:0.6858 IoU:0.5370 CBL:0.8912 | LR:1.6e-06
# Epoch 115/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.18it/s, loss=0.5147]
# Epoch 115 | T_Loss: 0.6079 | [CENTER_] Dice:0.7064 IoU:0.5593 CBL:0.9094 | [CENTER_] Dice:0.6893 IoU:0.5411 CBL:0.8914 | LR:1.6e-06
# Epoch 116/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.16it/s, loss=0.4158]
# Epoch 116 | T_Loss: 0.6229 | [CENTER_] Dice:0.7044 IoU:0.5566 CBL:0.9093 | [CENTER_] Dice:0.6897 IoU:0.5411 CBL:0.8916 | LR:1.6e-06
# Epoch 117/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.19it/s, loss=0.6182]
# Epoch 117 | T_Loss: 0.6074 | [CENTER_] Dice:0.7021 IoU:0.5542 CBL:0.9086 | [CENTER_] Dice:0.6859 IoU:0.5372 CBL:0.8911 | LR:1.6e-06
# Epoch 118/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.19it/s, loss=0.5983]
# Epoch 118 | T_Loss: 0.5937 | [CENTER_] Dice:0.7040 IoU:0.5560 CBL:0.9102 | [CENTER_] Dice:0.6869 IoU:0.5376 CBL:0.8915 | LR:7.8e-07
# Epoch 119/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.16it/s, loss=0.5735]
# Epoch 119 | T_Loss: 0.6112 | [CENTER_] Dice:0.7045 IoU:0.5574 CBL:0.9112 | [CENTER_] Dice:0.6867 IoU:0.5389 CBL:0.8919 | LR:7.8e-07
# Epoch 120/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.17it/s, loss=0.4882]
# Epoch 120 | T_Loss: 0.6014 | [CENTER_] Dice:0.7044 IoU:0.5568 CBL:0.9106 | [CENTER_] Dice:0.6852 IoU:0.5365 CBL:0.8905 | LR:7.8e-07
# Epoch 121/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.16it/s, loss=0.5298]
# Epoch 121 | T_Loss: 0.6153 | [CENTER_] Dice:0.7034 IoU:0.5552 CBL:0.9088 | [CENTER_] Dice:0.6861 IoU:0.5368 CBL:0.8905 | LR:7.8e-07
# Epoch 122/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.16it/s, loss=1.0088]
# Epoch 122 | T_Loss: 0.6084 | [CENTER_] Dice:0.7032 IoU:0.5544 CBL:0.9104 | [CENTER_] Dice:0.6867 IoU:0.5369 CBL:0.8907 | LR:7.8e-07
# Epoch 123/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.18it/s, loss=0.5444]
# Epoch 123 | T_Loss: 0.6230 | [CENTER_] Dice:0.7078 IoU:0.5610 CBL:0.9110 | [CENTER_] Dice:0.6878 IoU:0.5393 CBL:0.8894 | LR:7.8e-07
# Epoch 124/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.18it/s, loss=0.4280]
# Epoch 124 | T_Loss: 0.6145 | [CENTER_] Dice:0.7088 IoU:0.5616 CBL:0.9101 | [CENTER_] Dice:0.6924 IoU:0.5445 CBL:0.8908 | LR:3.9e-07
# Epoch 125/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.16it/s, loss=0.5429]
# Epoch 125 | T_Loss: 0.5978 | [CENTER_] Dice:0.7160 IoU:0.5712 CBL:0.9106 | [CENTER_] Dice:0.6924 IoU:0.5455 CBL:0.8892 | LR:3.9e-07
# Epoch 126/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.19it/s, loss=0.3280]
# Epoch 126 | T_Loss: 0.6173 | [CENTER_] Dice:0.7102 IoU:0.5631 CBL:0.9112 | [CENTER_] Dice:0.6935 IoU:0.5451 CBL:0.8913 | LR:3.9e-07
# Epoch 127/150 [Train]: 100%|█████| 183/183 [00:57<00:00,  3.18it/s, loss=0.5742]
# Epoch 127 | T_Loss: 0.5993 | [CENTER_] Dice:0.7025 IoU:0.5541 CBL:0.9103 | [CENTER_] Dice:0.6862 IoU:0.5365 CBL:0.8921 | LR:3.9e-07
# Early stopping at epoch 127.
#
# Best Dice (center_shift): 0.6947
# Checkpoint: checkpoints/pga_unet_center_mixed_x3_shift05_qhead_nopsg_512_seed22120196_best.pth
# ['checkpoints/pga_unet_center_mixed_x3_shift05_qhead_nopsg_512_seed22120196_best.pth']

# %%
# -- Quick test on the held-out set: image-level merged, 2 prompt scenarios --
# Loads the checkpoint train.py just wrote in this session (no Drive download).
# Full qualitative panels + per-image CSVs live in Source/File_Test/*/Ablation/.
import os, sys, csv
import numpy as np, torch
from collections import OrderedDict
from torch.utils.data import DataLoader
from tqdm import tqdm
from scipy.ndimage import binary_erosion, distance_transform_edt

os.chdir(PGA_ROOT)
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)
from dataset import PromptSegmentationDataset

IMG_SIZE, SCALE_FACTOR, SHIFT_RATIO = 512, 3.0, 0.5
DEVICE  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DS_ROOT = f"{PGA_ROOT}/dataset_FracAtlas"
CKPT    = f"checkpoints/pga_unet_center_mixed_x3_shift05_qhead_nopsg_512_{RUN_TAG}_best.pth"

VARIANT, ENC, QH, BINP = "full", 0, 1, 0
if VARIANT == "psg_only":
    from models.networks.prompt_unet_psg_only import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
elif VARIANT == "psg_attention":
    from models.networks.prompt_unet_psg_attention import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
else:
    from models.networks.prompt_unet_2D import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1,
                     use_encoder_prompt=bool(ENC), use_quality_head=bool(QH))
model.load_state_dict(torch.load(CKPT, map_location=DEVICE, weights_only=True))
model.to(DEVICE).eval()
print("loaded", CKPT)


def _hd95(p, g):
    p, g = p.astype(bool), g.astype(bool)
    if not p.any() and not g.any(): return 0.0
    if not p.any() or not g.any():  return float(IMG_SIZE)
    pe, ge = p ^ binary_erosion(p), g ^ binary_erosion(g)
    d1, d2 = distance_transform_edt(~ge)[pe], distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2): return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))


def _metrics(prob, gt):
    pm, gm, eps = (prob > 0.5), (gt > 0.5), 1e-6
    tp, fp, fn = float((pm & gm).sum()), float((pm & ~gm).sum()), float((~pm & gm).sum())
    cbl = 0.0
    if gm.any() and pm.any():
        ys, xs = np.where(gm); yp, xp = np.where(pm)
        diag = np.hypot(ys.max() - ys.min(), xs.max() - xs.min()) + eps
        cbl = float(np.clip(1 - np.hypot(xp.mean() - xs.mean(), yp.mean() - ys.mean()) / diag, 0, 1))
    return dict(dice=(2*tp+eps)/(2*tp+fp+fn+eps), iou=(tp+eps)/(tp+fp+fn+eps),
                pre=tp/(tp+fp+eps), rec=(tp+eps)/(tp+fn+eps), hd95=_hd95(pm, gm), cbl=cbl)


os.makedirs("results", exist_ok=True)
per_image, rows = [], []
for mode in ("center_zoom", "center_shift"):
    ds = PromptSegmentationDataset(f"{DS_ROOT}/test/images", f"{DS_ROOT}/test/annotations",
                                   img_size=IMG_SIZE, is_train=False, prompt_mode=mode,
                                   scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO,
                                   binary_prompt=bool(BINP))
    groups = OrderedDict()
    with torch.no_grad():
        for i, (img, msk, prm) in enumerate(tqdm(DataLoader(ds, batch_size=1, num_workers=2), desc=mode)):
            prob = torch.sigmoid(model(img.to(DEVICE), prm.to(DEVICE)))[0, 0].cpu().numpy()
            gt   = msk[0, 0].numpy()
            name = ds.all_samples[i][0]
            if name not in groups:
                groups[name] = [prob.copy(), gt.copy()]
            else:
                np.maximum(groups[name][0], prob, out=groups[name][0])
                np.maximum(groups[name][1], gt,   out=groups[name][1])
    recs = []
    for name, (p, g) in groups.items():
        m = _metrics(p, g); recs.append(m)
        per_image.append([mode, name] + [m[k] for k in ("dice", "iou", "pre", "rec", "hd95", "cbl")])
    avg = {k: float(np.mean([r[k] for r in recs])) for k in recs[0]}
    rows.append((mode, len(recs), avg))

print(f"\n{'scenario':<14}{'N':>5}{'Dice':>9}{'IoU':>9}{'Prec':>9}{'Rec':>9}{'HD95':>9}{'CBL':>9}")
for mode, n, a in rows:
    print(f"{mode:<14}{n:>5}{a['dice']:>9.4f}{a['iou']:>9.4f}{a['pre']:>9.4f}{a['rec']:>9.4f}{a['hd95']:>9.2f}{a['cbl']:>9.4f}")

csv_path = f"results/ablation_qhead_nopsg_{RUN_TAG}_per_image.csv"
with open(csv_path, "w", newline="") as fh:
    w = csv.writer(fh); w.writerow(["scenario", "img_name", "dice", "iou", "pre", "rec", "hd95", "cbl"])
    w.writerows(per_image)
print("saved", csv_path)
# Out:
# loaded checkpoints/pga_unet_center_mixed_x3_shift05_qhead_nopsg_512_seed22120196_best.pth
# center_zoom: 100%|██████████| 92/92 [00:03<00:00, 28.44it/s]
# center_shift: 100%|██████████| 92/92 [00:02<00:00, 31.87it/s]
# scenario          N     Dice      IoU     Prec      Rec     HD95      CBL
# center_zoom      72   0.6959   0.5511   0.6175   0.8681    18.03   0.9029
# center_shift     72   0.6851   0.5403   0.6091   0.8407    11.95   0.8853
# saved results/ablation_qhead_nopsg_seed22120196_per_image.csv
