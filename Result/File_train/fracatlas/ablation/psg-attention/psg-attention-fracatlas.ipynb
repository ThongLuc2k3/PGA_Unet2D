# %% [markdown]
# # Ablation - PSG with vanilla attention gate (no CAD)
# PromptSpatialGate is used in the encoder (matched to the PSG-only encoder setting); the decoder uses the original attention gate (GridAttentionBlock2D, matching the original Attention U-Net gate) without injecting the prompt into the gating signal. Relative to CAD, the only change is the removal of prompt conditioning.

# %%
import os, sys, shutil
import gdown

BASE = '/kaggle/working' if os.path.exists('/kaggle/working') else '/content'
os.chdir(BASE)

REPO = 'https://github.com/ThongLuc2k3/PGA_Unet2D.git'
REPO_ROOT = f'{BASE}/PGA_Unet2D'
PGA_ROOT = f'{REPO_ROOT}/Source/Prompt-Guided-XRay-Segmentation'
DATASET_NAME = 'dataset_FracAtlas'
DATASET_ID = '1sfMPFQvADmZLCPJC3xPyYDrblnFZ4kQv'
DS_ZIP = f'{BASE}/{DATASET_NAME}.zip'
DS_PATH = f'{PGA_ROOT}/{DATASET_NAME}'

if os.path.exists(REPO_ROOT):
    shutil.rmtree(REPO_ROOT)
# !git clone -q --branch main --single-branch {REPO} {REPO_ROOT}
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)

if not os.path.exists(DS_ZIP):
    gdown.download(f'https://drive.google.com/uc?id={DATASET_ID}', DS_ZIP, quiet=False)
if os.path.exists(DS_PATH):
    shutil.rmtree(DS_PATH)
# !unzip -oq {DS_ZIP} -d {PGA_ROOT}/

os.makedirs(f'{PGA_ROOT}/checkpoints', exist_ok=True)
os.chdir(PGA_ROOT)
# !pip install -q tqdm opencv-python timm scipy gdown
print(f'✅ Setup completed | base={BASE} | dataset={DATASET_NAME}')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1sfMPFQvADmZLCPJC3xPyYDrblnFZ4kQv
# From (redirected): https://drive.google.com/uc?id=1sfMPFQvADmZLCPJC3xPyYDrblnFZ4kQv&confirm=t&uuid=32e77b65-8b3a-4aef-b951-1caf72748255
# To: /kaggle/working/dataset_FracAtlas.zip
# 100%|██████████| 231M/231M [00:03<00:00, 69.7MB/s]
# ✅ Setup completed | base=/kaggle/working | dataset=dataset_FracAtlas

# %% [markdown]
# ## Ablation training via the shared `train.py`
#
# **Configuration: PSG + vanilla attention gate (no CAD).** PSG encoder gate plus an unconditioned attention gate in the decoder, no CAD. The `psg_attention` network class has no QualityHead branch, so `USE_QUALITY_HEAD=0`.
#
# Every ablation configuration is trained through the same `train.py` as the full PGA-UNet, so batch size, optimizer, scheduler, gradient clipping, the 150-epoch / patience-15 early stopping, and **image-level merged `center_shift` validation for checkpoint selection** are identical across the study. Repeat the training cell with `SEED = 1`, `2`, `3` for the multi-seed ablation; `RUN_TAG` keeps the per-seed checkpoints from overwriting each other.
#
# A quick image-level metrics table on the held-out test set is printed by the last cell. For the full qualitative panels and per-image CSVs, run the matching notebook under `Source/File_Test/fracatlas/Ablation/`.

# %%
# Repeat with SEED = 1, 2, 3 ... for the multi-seed ablation.
SEED = 22120196
RUN_TAG = f"seed{SEED}"

import os, glob
os.chdir(PGA_ROOT)
os.environ.update({
    "PROMPT_DATASET_ROOT": "dataset_FracAtlas",
    "PROMPT_IMG_SIZE": "512",
    "PROMPT_MODE": "center_mixed",
    "PROMPT_SCALE_FACTOR": "3.0",
    "PROMPT_SHIFT_RATIO": "0.5",
    "PROMPT_MIXED_SHIFT_PROB": "0.8",
    "PROMPT_EPOCHS": "150",
    "PROMPT_SEED": str(SEED),
    "RUN_TAG": RUN_TAG,
    "PROMPT_VARIANT": "psg_attention",
    "USE_ENCODER_PROMPT": "1",
    "BINARY_PROMPT": "0",
    "USE_QUALITY_HEAD": "0",
})

# !python train.py

print(sorted(glob.glob(f"checkpoints/pga_unet_center_mixed_x3_shift05_psg_attention_512_{RUN_TAG}_best.pth")))
# Out:
# ==========================================================================================
# TrainPrompt: center_mixed | Device: cuda | Variant: psg_attention | EncoderPrompt: True | BinaryPrompt: False | ImgSize: 512 | DatasetRoot: dataset_FracAtlas | Seed: 22120196 | RunTag: seed22120196 | ScaleFactor: 3.0 | ShiftRatio: 0.5 | MixedShiftProb: 0.8
# ==========================================================================================
# Epoch 1/150 [Train]: 100%|███████| 183/183 [00:46<00:00,  3.93it/s, loss=1.5571]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.6365 | [CENTER_] Dice:0.0001 IoU:0.0001 CBL:0.2021 | [CENTER_] Dice:0.0001 IoU:0.0001 CBL:0.2021 | LR:1.0e-04
# Epoch 2/150 [Train]: 100%|███████| 183/183 [00:50<00:00,  3.61it/s, loss=1.5085]
# 🥇 [BEST] Epoch   2 | T_Loss: 1.5341 | [CENTER_] Dice:0.0002 IoU:0.0001 CBL:0.1650 | [CENTER_] Dice:0.0002 IoU:0.0001 CBL:0.1650 | LR:1.0e-04
# Epoch 3/150 [Train]: 100%|███████| 183/183 [00:49<00:00,  3.70it/s, loss=1.4710]
# Epoch   3 | T_Loss: 1.4909 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.1896 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.1894 | LR:1.0e-04
# Epoch 4/150 [Train]: 100%|███████| 183/183 [00:50<00:00,  3.64it/s, loss=1.4387]
# Epoch   4 | T_Loss: 1.4533 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0479 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0479 | LR:1.0e-04
# Epoch 5/150 [Train]: 100%|███████| 183/183 [00:49<00:00,  3.67it/s, loss=1.4023]
# Epoch   5 | T_Loss: 1.4190 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0369 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0369 | LR:1.0e-04
# Epoch 6/150 [Train]: 100%|███████| 183/183 [00:50<00:00,  3.64it/s, loss=1.3728]
# 🥇 [BEST] Epoch   6 | T_Loss: 1.3857 | [CENTER_] Dice:0.0003 IoU:0.0002 CBL:0.0072 | [CENTER_] Dice:0.0003 IoU:0.0002 CBL:0.0072 | LR:1.0e-04
# Epoch 7/150 [Train]: 100%|███████| 183/183 [00:50<00:00,  3.65it/s, loss=1.3440]
# 🥇 [BEST] Epoch   7 | T_Loss: 1.3551 | [CENTER_] Dice:0.0032 IoU:0.0016 CBL:0.0569 | [CENTER_] Dice:0.0031 IoU:0.0016 CBL:0.0550 | LR:1.0e-04
# Epoch 8/150 [Train]: 100%|███████| 183/183 [00:49<00:00,  3.67it/s, loss=1.3023]
# 🥇 [BEST] Epoch   8 | T_Loss: 1.3209 | [CENTER_] Dice:0.0029 IoU:0.0014 CBL:0.1382 | [CENTER_] Dice:0.0034 IoU:0.0017 CBL:0.1409 | LR:1.0e-04
# Epoch 9/150 [Train]: 100%|███████| 183/183 [00:50<00:00,  3.66it/s, loss=1.2722]
# Epoch   9 | T_Loss: 1.2846 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0087 | [CENTER_] Dice:0.0001 IoU:0.0000 CBL:0.0194 | LR:1.0e-04
# Epoch 10/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=1.2343]
# 🥇 [BEST] Epoch  10 | T_Loss: 1.2532 | [CENTER_] Dice:0.0088 IoU:0.0046 CBL:0.1369 | [CENTER_] Dice:0.0089 IoU:0.0046 CBL:0.1489 | LR:1.0e-04
# Epoch 11/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=1.2105]
# Epoch  11 | T_Loss: 1.2247 | [CENTER_] Dice:0.0002 IoU:0.0001 CBL:0.0239 | [CENTER_] Dice:0.0001 IoU:0.0000 CBL:0.0207 | LR:1.0e-04
# Epoch 12/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=1.1582]
# Epoch  12 | T_Loss: 1.2000 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0053 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0000 | LR:1.0e-04
# Epoch 13/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=1.1495]
# 🥇 [BEST] Epoch  13 | T_Loss: 1.1766 | [CENTER_] Dice:0.2818 IoU:0.1821 CBL:0.6213 | [CENTER_] Dice:0.2782 IoU:0.1794 CBL:0.6194 | LR:1.0e-04
# Epoch 14/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.64it/s, loss=1.1615]
# 🥇 [BEST] Epoch  14 | T_Loss: 1.1560 | [CENTER_] Dice:0.3021 IoU:0.1957 CBL:0.5755 | [CENTER_] Dice:0.3008 IoU:0.1942 CBL:0.5527 | LR:1.0e-04
# Epoch 15/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=1.1503]
# Epoch  15 | T_Loss: 1.1353 | [CENTER_] Dice:0.1019 IoU:0.0548 CBL:0.3872 | [CENTER_] Dice:0.1027 IoU:0.0553 CBL:0.3802 | LR:1.0e-04
# Epoch 16/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=1.0578]
# 🥇 [BEST] Epoch  16 | T_Loss: 1.1145 | [CENTER_] Dice:0.3416 IoU:0.2133 CBL:0.7887 | [CENTER_] Dice:0.3353 IoU:0.2079 CBL:0.7637 | LR:1.0e-04
# Epoch 17/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=1.0989]
# 🥇 [BEST] Epoch  17 | T_Loss: 1.0978 | [CENTER_] Dice:0.4173 IoU:0.2867 CBL:0.7216 | [CENTER_] Dice:0.4070 IoU:0.2779 CBL:0.6860 | LR:1.0e-04
# Epoch 18/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.68it/s, loss=1.0716]
# 🥇 [BEST] Epoch  18 | T_Loss: 1.0803 | [CENTER_] Dice:0.4779 IoU:0.3297 CBL:0.8045 | [CENTER_] Dice:0.4618 IoU:0.3153 CBL:0.7770 | LR:1.0e-04
# Epoch 19/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.64it/s, loss=1.1008]
# Epoch  19 | T_Loss: 1.0651 | [CENTER_] Dice:0.3822 IoU:0.2588 CBL:0.7027 | [CENTER_] Dice:0.3776 IoU:0.2536 CBL:0.6813 | LR:1.0e-04
# Epoch 20/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=1.0351]
# 🥇 [BEST] Epoch  20 | T_Loss: 1.0459 | [CENTER_] Dice:0.4740 IoU:0.3230 CBL:0.8186 | [CENTER_] Dice:0.4713 IoU:0.3208 CBL:0.7929 | LR:1.0e-04
# Epoch 21/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=1.0534]
# Epoch  21 | T_Loss: 1.0332 | [CENTER_] Dice:0.4024 IoU:0.2591 CBL:0.7738 | [CENTER_] Dice:0.4044 IoU:0.2606 CBL:0.7824 | LR:1.0e-04
# Epoch 22/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.69it/s, loss=1.0072]
# Epoch  22 | T_Loss: 1.0210 | [CENTER_] Dice:0.3182 IoU:0.1947 CBL:0.6003 | [CENTER_] Dice:0.3163 IoU:0.1935 CBL:0.5946 | LR:1.0e-04
# Epoch 23/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=1.0422]
# 🥇 [BEST] Epoch  23 | T_Loss: 1.0034 | [CENTER_] Dice:0.4792 IoU:0.3276 CBL:0.8233 | [CENTER_] Dice:0.4807 IoU:0.3281 CBL:0.8131 | LR:1.0e-04
# Epoch 24/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.69it/s, loss=0.9143]
# Epoch  24 | T_Loss: 0.9874 | [CENTER_] Dice:0.4187 IoU:0.2745 CBL:0.7612 | [CENTER_] Dice:0.4164 IoU:0.2725 CBL:0.7405 | LR:1.0e-04
# Epoch 25/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.9563]
# Epoch  25 | T_Loss: 0.9726 | [CENTER_] Dice:0.4820 IoU:0.3260 CBL:0.8275 | [CENTER_] Dice:0.4699 IoU:0.3155 CBL:0.8014 | LR:1.0e-04
# Epoch 26/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=1.0194]
# Epoch  26 | T_Loss: 0.9609 | [CENTER_] Dice:0.4625 IoU:0.3099 CBL:0.8481 | [CENTER_] Dice:0.4491 IoU:0.2973 CBL:0.8108 | LR:1.0e-04
# Epoch 27/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=1.0162]
# 🥇 [BEST] Epoch  27 | T_Loss: 0.9434 | [CENTER_] Dice:0.5097 IoU:0.3544 CBL:0.8398 | [CENTER_] Dice:0.4955 IoU:0.3409 CBL:0.8010 | LR:1.0e-04
# Epoch 28/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=0.9278]
# 🥇 [BEST] Epoch  28 | T_Loss: 0.9238 | [CENTER_] Dice:0.5412 IoU:0.3857 CBL:0.8351 | [CENTER_] Dice:0.5290 IoU:0.3752 CBL:0.7952 | LR:1.0e-04
# Epoch 29/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.64it/s, loss=0.9153]
# 🥇 [BEST] Epoch  29 | T_Loss: 0.9067 | [CENTER_] Dice:0.5770 IoU:0.4271 CBL:0.8302 | [CENTER_] Dice:0.5392 IoU:0.3956 CBL:0.7916 | LR:1.0e-04
# Epoch 30/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.8345]
# 🥇 [BEST] Epoch  30 | T_Loss: 0.8837 | [CENTER_] Dice:0.5487 IoU:0.3911 CBL:0.8377 | [CENTER_] Dice:0.5481 IoU:0.3911 CBL:0.8289 | LR:1.0e-04
# Epoch 31/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.64it/s, loss=0.8836]
# Epoch  31 | T_Loss: 0.8637 | [CENTER_] Dice:0.5307 IoU:0.3722 CBL:0.8578 | [CENTER_] Dice:0.5032 IoU:0.3474 CBL:0.8067 | LR:1.0e-04
# Epoch 32/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.7699]
# 🥇 [BEST] Epoch  32 | T_Loss: 0.8494 | [CENTER_] Dice:0.5774 IoU:0.4191 CBL:0.8737 | [CENTER_] Dice:0.5716 IoU:0.4141 CBL:0.8485 | LR:1.0e-04
# Epoch 33/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.66it/s, loss=0.7581]
# 🥇 [BEST] Epoch  33 | T_Loss: 0.8224 | [CENTER_] Dice:0.5935 IoU:0.4435 CBL:0.8671 | [CENTER_] Dice:0.5987 IoU:0.4518 CBL:0.8615 | LR:1.0e-04
# Epoch 34/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.9574]
# 🥇 [BEST] Epoch  34 | T_Loss: 0.8038 | [CENTER_] Dice:0.6279 IoU:0.4764 CBL:0.8796 | [CENTER_] Dice:0.6173 IoU:0.4674 CBL:0.8620 | LR:1.0e-04
# Epoch 35/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.66it/s, loss=0.6592]
# Epoch  35 | T_Loss: 0.7834 | [CENTER_] Dice:0.6106 IoU:0.4602 CBL:0.8612 | [CENTER_] Dice:0.5947 IoU:0.4443 CBL:0.8434 | LR:1.0e-04
# Epoch 36/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.7609]
# Epoch  36 | T_Loss: 0.7615 | [CENTER_] Dice:0.6003 IoU:0.4457 CBL:0.8596 | [CENTER_] Dice:0.6077 IoU:0.4539 CBL:0.8628 | LR:1.0e-04
# Epoch 37/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.9349]
# 🥇 [BEST] Epoch  37 | T_Loss: 0.7333 | [CENTER_] Dice:0.6531 IoU:0.5046 CBL:0.8882 | [CENTER_] Dice:0.6404 IoU:0.4925 CBL:0.8727 | LR:1.0e-04
# Epoch 38/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.8719]
# Epoch  38 | T_Loss: 0.7178 | [CENTER_] Dice:0.6133 IoU:0.4592 CBL:0.8697 | [CENTER_] Dice:0.5916 IoU:0.4381 CBL:0.8348 | LR:1.0e-04
# Epoch 39/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.68it/s, loss=0.6408]
# Epoch  39 | T_Loss: 0.6779 | [CENTER_] Dice:0.6380 IoU:0.4964 CBL:0.8296 | [CENTER_] Dice:0.6382 IoU:0.4966 CBL:0.8260 | LR:1.0e-04
# Epoch 40/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=0.6347]
# Epoch  40 | T_Loss: 0.6646 | [CENTER_] Dice:0.5918 IoU:0.4378 CBL:0.8662 | [CENTER_] Dice:0.5826 IoU:0.4281 CBL:0.8303 | LR:1.0e-04
# Epoch 41/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.6111]
# Epoch  41 | T_Loss: 0.6637 | [CENTER_] Dice:0.6316 IoU:0.4819 CBL:0.8805 | [CENTER_] Dice:0.6320 IoU:0.4834 CBL:0.8726 | LR:1.0e-04
# Epoch 42/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.66it/s, loss=0.4969]
# Epoch  42 | T_Loss: 0.6383 | [CENTER_] Dice:0.6554 IoU:0.5085 CBL:0.8827 | [CENTER_] Dice:0.6358 IoU:0.4886 CBL:0.8506 | LR:1.0e-04
# Epoch 43/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.6421]
# Epoch  43 | T_Loss: 0.6028 | [CENTER_] Dice:0.6516 IoU:0.5074 CBL:0.8748 | [CENTER_] Dice:0.6306 IoU:0.4888 CBL:0.8550 | LR:5.0e-05
# Epoch 44/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.68it/s, loss=0.4147]
# 🥇 [BEST] Epoch  44 | T_Loss: 0.5895 | [CENTER_] Dice:0.6676 IoU:0.5203 CBL:0.8847 | [CENTER_] Dice:0.6520 IoU:0.5043 CBL:0.8605 | LR:5.0e-05
# Epoch 45/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.63it/s, loss=0.6058]
# 🥇 [BEST] Epoch  45 | T_Loss: 0.5553 | [CENTER_] Dice:0.6696 IoU:0.5255 CBL:0.8658 | [CENTER_] Dice:0.6591 IoU:0.5159 CBL:0.8615 | LR:5.0e-05
# Epoch 46/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=0.3877]
# 🥇 [BEST] Epoch  46 | T_Loss: 0.5460 | [CENTER_] Dice:0.7049 IoU:0.5646 CBL:0.9007 | [CENTER_] Dice:0.6841 IoU:0.5416 CBL:0.8784 | LR:5.0e-05
# Epoch 47/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.5943]
# Epoch  47 | T_Loss: 0.5512 | [CENTER_] Dice:0.6849 IoU:0.5432 CBL:0.8937 | [CENTER_] Dice:0.6627 IoU:0.5190 CBL:0.8683 | LR:5.0e-05
# Epoch 48/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=0.4178]
# Epoch  48 | T_Loss: 0.5312 | [CENTER_] Dice:0.6658 IoU:0.5158 CBL:0.8925 | [CENTER_] Dice:0.6540 IoU:0.5031 CBL:0.8647 | LR:5.0e-05
# Epoch 49/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=0.5254]
# Epoch  49 | T_Loss: 0.5313 | [CENTER_] Dice:0.6782 IoU:0.5323 CBL:0.8803 | [CENTER_] Dice:0.6587 IoU:0.5112 CBL:0.8632 | LR:5.0e-05
# Epoch 50/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.66it/s, loss=0.3883]
# 🥇 [BEST] Epoch  50 | T_Loss: 0.5026 | [CENTER_] Dice:0.6959 IoU:0.5525 CBL:0.8892 | [CENTER_] Dice:0.6886 IoU:0.5459 CBL:0.8805 | LR:5.0e-05
# Epoch 51/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.6083]
# Epoch  51 | T_Loss: 0.5227 | [CENTER_] Dice:0.6819 IoU:0.5375 CBL:0.8920 | [CENTER_] Dice:0.6580 IoU:0.5144 CBL:0.8614 | LR:5.0e-05
# Epoch 52/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.9246]
# Epoch  52 | T_Loss: 0.5163 | [CENTER_] Dice:0.6875 IoU:0.5461 CBL:0.8934 | [CENTER_] Dice:0.6781 IoU:0.5373 CBL:0.8837 | LR:5.0e-05
# Epoch 53/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.8400]
# Epoch  53 | T_Loss: 0.5006 | [CENTER_] Dice:0.7011 IoU:0.5605 CBL:0.8941 | [CENTER_] Dice:0.6872 IoU:0.5475 CBL:0.8762 | LR:5.0e-05
# Epoch 54/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.66it/s, loss=0.5446]
# Epoch  54 | T_Loss: 0.4834 | [CENTER_] Dice:0.6988 IoU:0.5555 CBL:0.8927 | [CENTER_] Dice:0.6809 IoU:0.5378 CBL:0.8689 | LR:5.0e-05
# Epoch 55/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.66it/s, loss=0.3738]
# Epoch  55 | T_Loss: 0.4786 | [CENTER_] Dice:0.6854 IoU:0.5412 CBL:0.8760 | [CENTER_] Dice:0.6756 IoU:0.5307 CBL:0.8642 | LR:5.0e-05
# Epoch 56/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.64it/s, loss=0.3559]
# Epoch  56 | T_Loss: 0.4788 | [CENTER_] Dice:0.6952 IoU:0.5488 CBL:0.8945 | [CENTER_] Dice:0.6795 IoU:0.5335 CBL:0.8786 | LR:2.5e-05
# Epoch 57/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.4551]
# 🥇 [BEST] Epoch  57 | T_Loss: 0.4630 | [CENTER_] Dice:0.7222 IoU:0.5835 CBL:0.9041 | [CENTER_] Dice:0.6976 IoU:0.5583 CBL:0.8861 | LR:2.5e-05
# Epoch 58/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.3848]
# Epoch  58 | T_Loss: 0.4655 | [CENTER_] Dice:0.7049 IoU:0.5628 CBL:0.9022 | [CENTER_] Dice:0.6959 IoU:0.5544 CBL:0.8849 | LR:2.5e-05
# Epoch 59/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.3620]
# Epoch  59 | T_Loss: 0.4468 | [CENTER_] Dice:0.7073 IoU:0.5665 CBL:0.9014 | [CENTER_] Dice:0.6930 IoU:0.5539 CBL:0.8830 | LR:2.5e-05
# Epoch 60/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.64it/s, loss=0.2660]
# 🥇 [BEST] Epoch  60 | T_Loss: 0.4509 | [CENTER_] Dice:0.7127 IoU:0.5722 CBL:0.9035 | [CENTER_] Dice:0.7003 IoU:0.5605 CBL:0.8864 | LR:2.5e-05
# Epoch 61/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.66it/s, loss=0.3252]
# 🥇 [BEST] Epoch  61 | T_Loss: 0.4466 | [CENTER_] Dice:0.7101 IoU:0.5693 CBL:0.9035 | [CENTER_] Dice:0.7094 IoU:0.5712 CBL:0.9013 | LR:2.5e-05
# Epoch 62/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.63it/s, loss=0.4583]
# Epoch  62 | T_Loss: 0.4533 | [CENTER_] Dice:0.7188 IoU:0.5816 CBL:0.9040 | [CENTER_] Dice:0.6990 IoU:0.5619 CBL:0.8876 | LR:2.5e-05
# Epoch 63/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.68it/s, loss=0.3833]
# Epoch  63 | T_Loss: 0.4305 | [CENTER_] Dice:0.7049 IoU:0.5627 CBL:0.8984 | [CENTER_] Dice:0.6970 IoU:0.5574 CBL:0.8850 | LR:2.5e-05
# Epoch 64/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.69it/s, loss=0.4206]
# Epoch  64 | T_Loss: 0.4426 | [CENTER_] Dice:0.7153 IoU:0.5761 CBL:0.9023 | [CENTER_] Dice:0.7037 IoU:0.5665 CBL:0.8866 | LR:2.5e-05
# Epoch 65/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.2104]
# Epoch  65 | T_Loss: 0.4079 | [CENTER_] Dice:0.7127 IoU:0.5743 CBL:0.8975 | [CENTER_] Dice:0.6903 IoU:0.5515 CBL:0.8777 | LR:2.5e-05
# Epoch 66/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=1.0156]
# Epoch  66 | T_Loss: 0.4360 | [CENTER_] Dice:0.7082 IoU:0.5685 CBL:0.8997 | [CENTER_] Dice:0.7009 IoU:0.5620 CBL:0.8869 | LR:2.5e-05
# Epoch 67/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.4580]
# Epoch  67 | T_Loss: 0.4473 | [CENTER_] Dice:0.7143 IoU:0.5757 CBL:0.9004 | [CENTER_] Dice:0.6925 IoU:0.5539 CBL:0.8811 | LR:1.3e-05
# Epoch 68/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.63it/s, loss=0.3354]
# Epoch  68 | T_Loss: 0.4120 | [CENTER_] Dice:0.7162 IoU:0.5780 CBL:0.9003 | [CENTER_] Dice:0.6954 IoU:0.5569 CBL:0.8822 | LR:1.3e-05
# Epoch 69/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.66it/s, loss=0.2726]
# Epoch  69 | T_Loss: 0.4230 | [CENTER_] Dice:0.7206 IoU:0.5839 CBL:0.9084 | [CENTER_] Dice:0.7080 IoU:0.5715 CBL:0.8904 | LR:1.3e-05
# Epoch 70/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=0.2487]
# Epoch  70 | T_Loss: 0.4141 | [CENTER_] Dice:0.7232 IoU:0.5857 CBL:0.9083 | [CENTER_] Dice:0.7055 IoU:0.5679 CBL:0.8912 | LR:1.3e-05
# Epoch 71/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.66it/s, loss=0.3194]
# Epoch  71 | T_Loss: 0.4045 | [CENTER_] Dice:0.7235 IoU:0.5852 CBL:0.9065 | [CENTER_] Dice:0.7069 IoU:0.5694 CBL:0.8867 | LR:1.3e-05
# Epoch 72/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.7723]
# Epoch  72 | T_Loss: 0.4121 | [CENTER_] Dice:0.7219 IoU:0.5842 CBL:0.9069 | [CENTER_] Dice:0.7073 IoU:0.5703 CBL:0.8881 | LR:1.3e-05
# Epoch 73/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.65it/s, loss=0.2304]
# Epoch  73 | T_Loss: 0.3983 | [CENTER_] Dice:0.7256 IoU:0.5885 CBL:0.9047 | [CENTER_] Dice:0.6987 IoU:0.5615 CBL:0.8825 | LR:6.3e-06
# Epoch 74/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.4560]
# Epoch  74 | T_Loss: 0.4106 | [CENTER_] Dice:0.7207 IoU:0.5822 CBL:0.9046 | [CENTER_] Dice:0.7023 IoU:0.5644 CBL:0.8830 | LR:6.3e-06
# Epoch 75/150 [Train]: 100%|██████| 183/183 [00:49<00:00,  3.67it/s, loss=0.4620]
# Epoch  75 | T_Loss: 0.3894 | [CENTER_] Dice:0.7280 IoU:0.5902 CBL:0.9056 | [CENTER_] Dice:0.7070 IoU:0.5698 CBL:0.8866 | LR:6.3e-06
# Epoch 76/150 [Train]: 100%|██████| 183/183 [00:50<00:00,  3.64it/s, loss=0.4002]
# Epoch  76 | T_Loss: 0.4148 | [CENTER_] Dice:0.7247 IoU:0.5862 CBL:0.9062 | [CENTER_] Dice:0.7072 IoU:0.5697 CBL:0.8901 | LR:6.3e-06
# Early stopping at epoch 76.
#
# Best Dice (center_shift): 0.7094
# Checkpoint: checkpoints/pga_unet_center_mixed_x3_shift05_psg_attention_512_seed22120196_best.pth
# ['checkpoints/pga_unet_center_mixed_x3_shift05_psg_attention_512_seed22120196_best.pth']

# %%
# -- Quick test on the held-out set: image-level merged, 2 prompt scenarios --
# Loads the checkpoint train.py just wrote in this session (no Drive download).
# Full qualitative panels + per-image CSVs live in Source/File_Test/*/Ablation/.
import os, sys, csv
import numpy as np, torch
from collections import OrderedDict
from torch.utils.data import DataLoader
from tqdm import tqdm
from scipy.ndimage import binary_erosion, distance_transform_edt

os.chdir(PGA_ROOT)
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)
from dataset import PromptSegmentationDataset

IMG_SIZE, SCALE_FACTOR, SHIFT_RATIO = 512, 3.0, 0.5
DEVICE  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DS_ROOT = f"{PGA_ROOT}/dataset_FracAtlas"
CKPT    = f"checkpoints/pga_unet_center_mixed_x3_shift05_psg_attention_512_{RUN_TAG}_best.pth"

VARIANT, ENC, QH, BINP = "psg_attention", 1, 0, 0
if VARIANT == "psg_only":
    from models.networks.prompt_unet_psg_only import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
elif VARIANT == "psg_attention":
    from models.networks.prompt_unet_psg_attention import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
else:
    from models.networks.prompt_unet_2D import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1,
                     use_encoder_prompt=bool(ENC), use_quality_head=bool(QH))
model.load_state_dict(torch.load(CKPT, map_location=DEVICE, weights_only=True))
model.to(DEVICE).eval()
print("loaded", CKPT)


def _hd95(p, g):
    p, g = p.astype(bool), g.astype(bool)
    if not p.any() and not g.any(): return 0.0
    if not p.any() or not g.any():  return float(IMG_SIZE)
    pe, ge = p ^ binary_erosion(p), g ^ binary_erosion(g)
    d1, d2 = distance_transform_edt(~ge)[pe], distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2): return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))


def _metrics(prob, gt):
    pm, gm, eps = (prob > 0.5), (gt > 0.5), 1e-6
    tp, fp, fn = float((pm & gm).sum()), float((pm & ~gm).sum()), float((~pm & gm).sum())
    cbl = 0.0
    if gm.any() and pm.any():
        ys, xs = np.where(gm); yp, xp = np.where(pm)
        diag = np.hypot(ys.max() - ys.min(), xs.max() - xs.min()) + eps
        cbl = float(np.clip(1 - np.hypot(xp.mean() - xs.mean(), yp.mean() - ys.mean()) / diag, 0, 1))
    return dict(dice=(2*tp+eps)/(2*tp+fp+fn+eps), iou=(tp+eps)/(tp+fp+fn+eps),
                pre=tp/(tp+fp+eps), rec=(tp+eps)/(tp+fn+eps), hd95=_hd95(pm, gm), cbl=cbl)


os.makedirs("results", exist_ok=True)
per_image, rows = [], []
for mode in ("center_zoom", "center_shift"):
    ds = PromptSegmentationDataset(f"{DS_ROOT}/test/images", f"{DS_ROOT}/test/annotations",
                                   img_size=IMG_SIZE, is_train=False, prompt_mode=mode,
                                   scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO,
                                   binary_prompt=bool(BINP))
    groups = OrderedDict()
    with torch.no_grad():
        for i, (img, msk, prm) in enumerate(tqdm(DataLoader(ds, batch_size=1, num_workers=2), desc=mode)):
            prob = torch.sigmoid(model(img.to(DEVICE), prm.to(DEVICE)))[0, 0].cpu().numpy()
            gt   = msk[0, 0].numpy()
            name = ds.all_samples[i][0]
            if name not in groups:
                groups[name] = [prob.copy(), gt.copy()]
            else:
                np.maximum(groups[name][0], prob, out=groups[name][0])
                np.maximum(groups[name][1], gt,   out=groups[name][1])
    recs = []
    for name, (p, g) in groups.items():
        m = _metrics(p, g); recs.append(m)
        per_image.append([mode, name] + [m[k] for k in ("dice", "iou", "pre", "rec", "hd95", "cbl")])
    avg = {k: float(np.mean([r[k] for r in recs])) for k in recs[0]}
    rows.append((mode, len(recs), avg))

print(f"\n{'scenario':<14}{'N':>5}{'Dice':>9}{'IoU':>9}{'Prec':>9}{'Rec':>9}{'HD95':>9}{'CBL':>9}")
for mode, n, a in rows:
    print(f"{mode:<14}{n:>5}{a['dice']:>9.4f}{a['iou']:>9.4f}{a['pre']:>9.4f}{a['rec']:>9.4f}{a['hd95']:>9.2f}{a['cbl']:>9.4f}")

csv_path = f"results/ablation_psg_attention_{RUN_TAG}_per_image.csv"
with open(csv_path, "w", newline="") as fh:
    w = csv.writer(fh); w.writerow(["scenario", "img_name", "dice", "iou", "pre", "rec", "hd95", "cbl"])
    w.writerows(per_image)
print("saved", csv_path)
# Out:
# loaded checkpoints/pga_unet_center_mixed_x3_shift05_psg_attention_512_seed22120196_best.pth
# center_zoom: 100%|██████████| 92/92 [00:03<00:00, 29.99it/s]
# center_shift: 100%|██████████| 92/92 [00:02<00:00, 33.73it/s]
# scenario          N     Dice      IoU     Prec      Rec     HD95      CBL
# center_zoom      72   0.6895   0.5478   0.6011   0.8465    14.03   0.8923
# center_shift     72   0.6910   0.5472   0.6060   0.8400    14.10   0.8813
# saved results/ablation_psg_attention_seed22120196_per_image.csv
