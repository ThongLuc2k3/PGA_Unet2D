# %% [markdown]
# # Ablation - PSG with vanilla attention gate (no CAD)
# PromptSpatialGate is used in the encoder (matched to the PSG-only encoder setting); the decoder uses the original attention gate (GridAttentionBlock2D, matching the original Attention U-Net gate) without injecting the prompt into the gating signal. Relative to CAD, the only change is the removal of prompt conditioning.

# %%
import os, sys, shutil
import gdown

BASE = '/kaggle/working' if os.path.exists('/kaggle/working') else '/content'
os.chdir(BASE)

REPO = 'https://github.com/ThongLuc2k3/PGA_Unet2D.git'
REPO_ROOT = f'{BASE}/PGA_Unet2D'
PGA_ROOT = f'{REPO_ROOT}/Source/Prompt-Guided-XRay-Segmentation'
DATASET_NAME = 'dataset_BTXRD'
DATASET_ID = '1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx'
DS_ZIP = f'{BASE}/{DATASET_NAME}.zip'
DS_PATH = f'{PGA_ROOT}/{DATASET_NAME}'

if os.path.exists(REPO_ROOT):
    shutil.rmtree(REPO_ROOT)
# !git clone -q --branch main --single-branch {REPO} {REPO_ROOT}
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)

if not os.path.exists(DS_ZIP):
    gdown.download(f'https://drive.google.com/uc?id={DATASET_ID}', DS_ZIP, quiet=False)
if os.path.exists(DS_PATH):
    shutil.rmtree(DS_PATH)
# !unzip -oq {DS_ZIP} -d {PGA_ROOT}/

os.makedirs(f'{PGA_ROOT}/checkpoints', exist_ok=True)
os.chdir(PGA_ROOT)
# !pip install -q tqdm opencv-python timm scipy gdown
print(f'✅ Setup completed | base={BASE} | dataset={DATASET_NAME}')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx
# From (redirected): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx&confirm=t&uuid=07b70c3b-10a5-4e4e-ac39-4e04e5108870
# To: /kaggle/working/dataset_BTXRD.zip
# 100%|██████████| 1.71G/1.71G [00:24<00:00, 70.9MB/s]
# ✅ Setup completed | base=/kaggle/working | dataset=dataset_BTXRD

# %% [markdown]
# ## Ablation training via the shared `train.py`
#
# **Configuration: PSG + vanilla attention gate (no CAD).** PSG encoder gate plus an unconditioned attention gate in the decoder, no CAD. The `psg_attention` network class has no QualityHead branch, so `USE_QUALITY_HEAD=0`.
#
# Every ablation configuration is trained through the same `train.py` as the full PGA-UNet, so batch size, optimizer, scheduler, gradient clipping, the 150-epoch / patience-15 early stopping, and **image-level merged `center_shift` validation for checkpoint selection** are identical across the study. Repeat the training cell with `SEED = 1`, `2`, `3` for the multi-seed ablation; `RUN_TAG` keeps the per-seed checkpoints from overwriting each other.
#
# A quick image-level metrics table on the held-out test set is printed by the last cell. For the full qualitative panels and per-image CSVs, run the matching notebook under `Source/File_Test/btxrd/Ablation/`.

# %%
# Repeat with SEED = 1, 2, 3 ... for the multi-seed ablation.
SEED = 22120196
RUN_TAG = f"seed{SEED}"

import os, glob
os.chdir(PGA_ROOT)
os.environ.update({
    "PROMPT_DATASET_ROOT": "dataset_BTXRD",
    "PROMPT_IMG_SIZE": "512",
    "PROMPT_MODE": "center_mixed",
    "PROMPT_SCALE_FACTOR": "3.0",
    "PROMPT_SHIFT_RATIO": "0.5",
    "PROMPT_MIXED_SHIFT_PROB": "0.8",
    "PROMPT_EPOCHS": "150",
    "PROMPT_SEED": str(SEED),
    "RUN_TAG": RUN_TAG,
    "PROMPT_VARIANT": "psg_attention",
    "USE_ENCODER_PROMPT": "1",
    "BINARY_PROMPT": "0",
    "USE_QUALITY_HEAD": "0",
})

# !python train.py

print(sorted(glob.glob(f"checkpoints/pga_unet_center_mixed_x3_shift05_psg_attention_512_{RUN_TAG}_best.pth")))
# Out:
# ==========================================================================================
# TrainPrompt: center_mixed | Device: cuda | Variant: psg_attention | EncoderPrompt: True | BinaryPrompt: False | ImgSize: 512 | DatasetRoot: dataset_BTXRD | Seed: 22120196 | RunTag: seed22120196 | ScaleFactor: 3.0 | ShiftRatio: 0.5 | MixedShiftProb: 0.8
# ==========================================================================================
# Epoch 1/150 [Train]: 100%|███████| 462/462 [01:51<00:00,  4.13it/s, loss=1.4758]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.5543 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.2089 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.2087 | LR:1.0e-04
# Epoch 2/150 [Train]: 100%|███████| 462/462 [01:55<00:00,  4.01it/s, loss=1.3930]
# Epoch   2 | T_Loss: 1.4292 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0227 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0226 | LR:1.0e-04
# Epoch 3/150 [Train]: 100%|███████| 462/462 [01:55<00:00,  4.01it/s, loss=1.2730]
# 🥇 [BEST] Epoch   3 | T_Loss: 1.3447 | [CENTER_] Dice:0.2044 IoU:0.1239 CBL:0.5291 | [CENTER_] Dice:0.2024 IoU:0.1233 CBL:0.5122 | LR:1.0e-04
# Epoch 4/150 [Train]: 100%|███████| 462/462 [01:55<00:00,  4.00it/s, loss=1.2254]
# 🥇 [BEST] Epoch   4 | T_Loss: 1.2691 | [CENTER_] Dice:0.2421 IoU:0.1498 CBL:0.5572 | [CENTER_] Dice:0.2450 IoU:0.1527 CBL:0.5600 | LR:1.0e-04
# Epoch 5/150 [Train]: 100%|███████| 462/462 [01:55<00:00,  4.01it/s, loss=1.1597]
# Epoch   5 | T_Loss: 1.2040 | [CENTER_] Dice:0.1338 IoU:0.0790 CBL:0.3091 | [CENTER_] Dice:0.1353 IoU:0.0801 CBL:0.3081 | LR:1.0e-04
# Epoch 6/150 [Train]: 100%|███████| 462/462 [01:55<00:00,  4.01it/s, loss=1.1112]
# 🥇 [BEST] Epoch   6 | T_Loss: 1.1469 | [CENTER_] Dice:0.3353 IoU:0.2204 CBL:0.6365 | [CENTER_] Dice:0.3207 IoU:0.2109 CBL:0.5908 | LR:1.0e-04
# Epoch 7/150 [Train]: 100%|███████| 462/462 [01:55<00:00,  4.00it/s, loss=1.0401]
# Epoch   7 | T_Loss: 1.0918 | [CENTER_] Dice:0.3279 IoU:0.2371 CBL:0.5566 | [CENTER_] Dice:0.3039 IoU:0.2190 CBL:0.5187 | LR:1.0e-04
# Epoch 8/150 [Train]: 100%|███████| 462/462 [01:55<00:00,  4.01it/s, loss=0.9475]
# 🥇 [BEST] Epoch   8 | T_Loss: 1.0437 | [CENTER_] Dice:0.3711 IoU:0.2642 CBL:0.5849 | [CENTER_] Dice:0.3782 IoU:0.2724 CBL:0.5908 | LR:1.0e-04
# Epoch 9/150 [Train]: 100%|███████| 462/462 [01:55<00:00,  4.02it/s, loss=0.9663]
# 🥇 [BEST] Epoch   9 | T_Loss: 1.0059 | [CENTER_] Dice:0.4361 IoU:0.3058 CBL:0.7310 | [CENTER_] Dice:0.4166 IoU:0.2893 CBL:0.6977 | LR:1.0e-04
# Epoch 10/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=1.0332]
# Epoch  10 | T_Loss: 0.9642 | [CENTER_] Dice:0.3438 IoU:0.2247 CBL:0.6296 | [CENTER_] Dice:0.3446 IoU:0.2267 CBL:0.6103 | LR:1.0e-04
# Epoch 11/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=1.0114]
# Epoch  11 | T_Loss: 0.9344 | [CENTER_] Dice:0.3697 IoU:0.2437 CBL:0.6715 | [CENTER_] Dice:0.3703 IoU:0.2461 CBL:0.6452 | LR:1.0e-04
# Epoch 12/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.9320]
# 🥇 [BEST] Epoch  12 | T_Loss: 0.8886 | [CENTER_] Dice:0.4663 IoU:0.3268 CBL:0.7869 | [CENTER_] Dice:0.4557 IoU:0.3205 CBL:0.7416 | LR:1.0e-04
# Epoch 13/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.7493]
# Epoch  13 | T_Loss: 0.8513 | [CENTER_] Dice:0.4562 IoU:0.3206 CBL:0.7325 | [CENTER_] Dice:0.4468 IoU:0.3147 CBL:0.7057 | LR:1.0e-04
# Epoch 14/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.8922]
# 🥇 [BEST] Epoch  14 | T_Loss: 0.8165 | [CENTER_] Dice:0.5068 IoU:0.3785 CBL:0.7712 | [CENTER_] Dice:0.4823 IoU:0.3549 CBL:0.7395 | LR:1.0e-04
# Epoch 15/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.5885]
# 🥇 [BEST] Epoch  15 | T_Loss: 0.7806 | [CENTER_] Dice:0.5489 IoU:0.4142 CBL:0.7770 | [CENTER_] Dice:0.5290 IoU:0.3948 CBL:0.7586 | LR:1.0e-04
# Epoch 16/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.5876]
# Epoch  16 | T_Loss: 0.7509 | [CENTER_] Dice:0.5424 IoU:0.4130 CBL:0.7764 | [CENTER_] Dice:0.5205 IoU:0.3922 CBL:0.7466 | LR:1.0e-04
# Epoch 17/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.7532]
# Epoch  17 | T_Loss: 0.7209 | [CENTER_] Dice:0.5441 IoU:0.4048 CBL:0.8060 | [CENTER_] Dice:0.5239 IoU:0.3875 CBL:0.7886 | LR:1.0e-04
# Epoch 18/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.5350]
# Epoch  18 | T_Loss: 0.6732 | [CENTER_] Dice:0.5209 IoU:0.3754 CBL:0.8178 | [CENTER_] Dice:0.5111 IoU:0.3674 CBL:0.7957 | LR:1.0e-04
# Epoch 19/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.7270]
# 🥇 [BEST] Epoch  19 | T_Loss: 0.6212 | [CENTER_] Dice:0.6164 IoU:0.4748 CBL:0.8399 | [CENTER_] Dice:0.5834 IoU:0.4429 CBL:0.8039 | LR:1.0e-04
# Epoch 20/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.02it/s, loss=0.8947]
# 🥇 [BEST] Epoch  20 | T_Loss: 0.5849 | [CENTER_] Dice:0.5788 IoU:0.4328 CBL:0.8117 | [CENTER_] Dice:0.6105 IoU:0.4637 CBL:0.8376 | LR:1.0e-04
# Epoch 21/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.6968]
# 🥇 [BEST] Epoch  21 | T_Loss: 0.5589 | [CENTER_] Dice:0.6367 IoU:0.4989 CBL:0.8302 | [CENTER_] Dice:0.6340 IoU:0.4978 CBL:0.8309 | LR:1.0e-04
# Epoch 22/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.5396]
# 🥇 [BEST] Epoch  22 | T_Loss: 0.5429 | [CENTER_] Dice:0.6506 IoU:0.5213 CBL:0.8295 | [CENTER_] Dice:0.6356 IoU:0.5093 CBL:0.8186 | LR:1.0e-04
# Epoch 23/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.3610]
# Epoch  23 | T_Loss: 0.5192 | [CENTER_] Dice:0.6540 IoU:0.5171 CBL:0.8390 | [CENTER_] Dice:0.6215 IoU:0.4852 CBL:0.8127 | LR:1.0e-04
# Epoch 24/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.3796]
# 🥇 [BEST] Epoch  24 | T_Loss: 0.5098 | [CENTER_] Dice:0.6916 IoU:0.5593 CBL:0.8601 | [CENTER_] Dice:0.6906 IoU:0.5577 CBL:0.8573 | LR:1.0e-04
# Epoch 25/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.9610]
# Epoch  25 | T_Loss: 0.4933 | [CENTER_] Dice:0.6185 IoU:0.4824 CBL:0.7720 | [CENTER_] Dice:0.6154 IoU:0.4810 CBL:0.7752 | LR:1.0e-04
# Epoch 26/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.5533]
# Epoch  26 | T_Loss: 0.4822 | [CENTER_] Dice:0.6779 IoU:0.5432 CBL:0.8536 | [CENTER_] Dice:0.6662 IoU:0.5302 CBL:0.8440 | LR:1.0e-04
# Epoch 27/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.9224]
# Epoch  27 | T_Loss: 0.4711 | [CENTER_] Dice:0.6697 IoU:0.5361 CBL:0.8533 | [CENTER_] Dice:0.6659 IoU:0.5330 CBL:0.8528 | LR:1.0e-04
# Epoch 28/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2585]
# Epoch  28 | T_Loss: 0.4492 | [CENTER_] Dice:0.6673 IoU:0.5353 CBL:0.8457 | [CENTER_] Dice:0.6607 IoU:0.5273 CBL:0.8372 | LR:1.0e-04
# Epoch 29/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.4566]
# Epoch  29 | T_Loss: 0.4380 | [CENTER_] Dice:0.6772 IoU:0.5445 CBL:0.8541 | [CENTER_] Dice:0.6868 IoU:0.5576 CBL:0.8626 | LR:1.0e-04
# Epoch 30/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.9314]
# Epoch  30 | T_Loss: 0.4473 | [CENTER_] Dice:0.7083 IoU:0.5729 CBL:0.8769 | [CENTER_] Dice:0.6891 IoU:0.5513 CBL:0.8572 | LR:5.0e-05
# Epoch 31/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.9992]
# 🥇 [BEST] Epoch  31 | T_Loss: 0.4178 | [CENTER_] Dice:0.7177 IoU:0.5872 CBL:0.8775 | [CENTER_] Dice:0.7190 IoU:0.5895 CBL:0.8734 | LR:5.0e-05
# Epoch 32/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.2786]
# Epoch  32 | T_Loss: 0.4143 | [CENTER_] Dice:0.7242 IoU:0.6000 CBL:0.8843 | [CENTER_] Dice:0.7059 IoU:0.5796 CBL:0.8695 | LR:5.0e-05
# Epoch 33/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.7089]
# 🥇 [BEST] Epoch  33 | T_Loss: 0.3892 | [CENTER_] Dice:0.7164 IoU:0.5858 CBL:0.8756 | [CENTER_] Dice:0.7325 IoU:0.6056 CBL:0.8862 | LR:5.0e-05
# Epoch 34/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2727]
# Epoch  34 | T_Loss: 0.3911 | [CENTER_] Dice:0.7270 IoU:0.5981 CBL:0.8787 | [CENTER_] Dice:0.7204 IoU:0.5915 CBL:0.8763 | LR:5.0e-05
# Epoch 35/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.3187]
# 🥇 [BEST] Epoch  35 | T_Loss: 0.3996 | [CENTER_] Dice:0.7405 IoU:0.6129 CBL:0.8931 | [CENTER_] Dice:0.7426 IoU:0.6162 CBL:0.8901 | LR:5.0e-05
# Epoch 36/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.3345]
# Epoch  36 | T_Loss: 0.3813 | [CENTER_] Dice:0.7268 IoU:0.5986 CBL:0.8827 | [CENTER_] Dice:0.7345 IoU:0.6083 CBL:0.8866 | LR:5.0e-05
# Epoch 37/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.2566]
# Epoch  37 | T_Loss: 0.3914 | [CENTER_] Dice:0.7292 IoU:0.5992 CBL:0.8893 | [CENTER_] Dice:0.7217 IoU:0.5922 CBL:0.8863 | LR:5.0e-05
# Epoch 38/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.3184]
# Epoch  38 | T_Loss: 0.3837 | [CENTER_] Dice:0.7409 IoU:0.6173 CBL:0.8822 | [CENTER_] Dice:0.7344 IoU:0.6088 CBL:0.8782 | LR:5.0e-05
# Epoch 39/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.2833]
# 🥇 [BEST] Epoch  39 | T_Loss: 0.3829 | [CENTER_] Dice:0.7514 IoU:0.6263 CBL:0.8980 | [CENTER_] Dice:0.7453 IoU:0.6216 CBL:0.9007 | LR:5.0e-05
# Epoch 40/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2676]
# Epoch  40 | T_Loss: 0.3530 | [CENTER_] Dice:0.7436 IoU:0.6191 CBL:0.8872 | [CENTER_] Dice:0.7387 IoU:0.6154 CBL:0.8873 | LR:5.0e-05
# Epoch 41/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.3754]
# Epoch  41 | T_Loss: 0.3665 | [CENTER_] Dice:0.7505 IoU:0.6248 CBL:0.8985 | [CENTER_] Dice:0.7386 IoU:0.6118 CBL:0.8936 | LR:5.0e-05
# Epoch 42/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.8076]
# Epoch  42 | T_Loss: 0.3644 | [CENTER_] Dice:0.7267 IoU:0.5952 CBL:0.8924 | [CENTER_] Dice:0.7287 IoU:0.5992 CBL:0.8866 | LR:5.0e-05
# Epoch 43/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.1413]
# Epoch  43 | T_Loss: 0.3702 | [CENTER_] Dice:0.7456 IoU:0.6185 CBL:0.8946 | [CENTER_] Dice:0.7368 IoU:0.6090 CBL:0.8857 | LR:5.0e-05
# Epoch 44/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.3284]
# Epoch  44 | T_Loss: 0.3486 | [CENTER_] Dice:0.7352 IoU:0.6126 CBL:0.8834 | [CENTER_] Dice:0.7417 IoU:0.6207 CBL:0.8868 | LR:5.0e-05
# Epoch 45/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.3128]
# 🥇 [BEST] Epoch  45 | T_Loss: 0.3605 | [CENTER_] Dice:0.7478 IoU:0.6246 CBL:0.8849 | [CENTER_] Dice:0.7489 IoU:0.6254 CBL:0.8898 | LR:5.0e-05
# Epoch 46/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.4545]
# Epoch  46 | T_Loss: 0.3629 | [CENTER_] Dice:0.7410 IoU:0.6156 CBL:0.8893 | [CENTER_] Dice:0.7256 IoU:0.5996 CBL:0.8767 | LR:5.0e-05
# Epoch 47/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.2930]
# Epoch  47 | T_Loss: 0.3717 | [CENTER_] Dice:0.7336 IoU:0.6050 CBL:0.8852 | [CENTER_] Dice:0.7321 IoU:0.6060 CBL:0.8781 | LR:5.0e-05
# Epoch 48/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=1.0661]
# Epoch  48 | T_Loss: 0.3629 | [CENTER_] Dice:0.7387 IoU:0.6109 CBL:0.8835 | [CENTER_] Dice:0.7366 IoU:0.6092 CBL:0.8805 | LR:5.0e-05
# Epoch 49/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.7292]
# Epoch  49 | T_Loss: 0.3447 | [CENTER_] Dice:0.7531 IoU:0.6279 CBL:0.8951 | [CENTER_] Dice:0.7460 IoU:0.6233 CBL:0.8844 | LR:5.0e-05
# Epoch 50/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.6387]
# Epoch  50 | T_Loss: 0.3518 | [CENTER_] Dice:0.7491 IoU:0.6268 CBL:0.8910 | [CENTER_] Dice:0.7412 IoU:0.6189 CBL:0.8892 | LR:5.0e-05
# Epoch 51/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.3030]
# Epoch  51 | T_Loss: 0.3603 | [CENTER_] Dice:0.7245 IoU:0.6027 CBL:0.8837 | [CENTER_] Dice:0.7036 IoU:0.5826 CBL:0.8735 | LR:2.5e-05
# Epoch 52/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.4982]
# 🥇 [BEST] Epoch  52 | T_Loss: 0.3551 | [CENTER_] Dice:0.7580 IoU:0.6371 CBL:0.9008 | [CENTER_] Dice:0.7500 IoU:0.6285 CBL:0.8966 | LR:2.5e-05
# Epoch 53/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2158]
# 🥇 [BEST] Epoch  53 | T_Loss: 0.3227 | [CENTER_] Dice:0.7651 IoU:0.6427 CBL:0.9021 | [CENTER_] Dice:0.7528 IoU:0.6289 CBL:0.8944 | LR:2.5e-05
# Epoch 54/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.1628]
# 🥇 [BEST] Epoch  54 | T_Loss: 0.3319 | [CENTER_] Dice:0.7661 IoU:0.6473 CBL:0.9044 | [CENTER_] Dice:0.7548 IoU:0.6362 CBL:0.8907 | LR:2.5e-05
# Epoch 55/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2631]
# 🥇 [BEST] Epoch  55 | T_Loss: 0.3254 | [CENTER_] Dice:0.7679 IoU:0.6482 CBL:0.9040 | [CENTER_] Dice:0.7568 IoU:0.6374 CBL:0.8935 | LR:2.5e-05
# Epoch 56/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2614]
# 🥇 [BEST] Epoch  56 | T_Loss: 0.3358 | [CENTER_] Dice:0.7784 IoU:0.6586 CBL:0.9110 | [CENTER_] Dice:0.7664 IoU:0.6454 CBL:0.9045 | LR:2.5e-05
# Epoch 57/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2837]
# Epoch  57 | T_Loss: 0.3267 | [CENTER_] Dice:0.7699 IoU:0.6512 CBL:0.8996 | [CENTER_] Dice:0.7604 IoU:0.6434 CBL:0.8976 | LR:2.5e-05
# Epoch 58/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.2749]
# 🥇 [BEST] Epoch  58 | T_Loss: 0.3302 | [CENTER_] Dice:0.7727 IoU:0.6529 CBL:0.9022 | [CENTER_] Dice:0.7691 IoU:0.6509 CBL:0.9028 | LR:2.5e-05
# Epoch 59/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.1587]
# Epoch  59 | T_Loss: 0.3276 | [CENTER_] Dice:0.7692 IoU:0.6525 CBL:0.9014 | [CENTER_] Dice:0.7476 IoU:0.6319 CBL:0.8844 | LR:2.5e-05
# Epoch 60/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.2633]
# Epoch  60 | T_Loss: 0.3200 | [CENTER_] Dice:0.7687 IoU:0.6489 CBL:0.8989 | [CENTER_] Dice:0.7565 IoU:0.6370 CBL:0.8946 | LR:2.5e-05
# Epoch 61/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.1225]
# Epoch  61 | T_Loss: 0.3198 | [CENTER_] Dice:0.7753 IoU:0.6569 CBL:0.9068 | [CENTER_] Dice:0.7606 IoU:0.6419 CBL:0.8960 | LR:2.5e-05
# Epoch 62/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.1398]
# Epoch  62 | T_Loss: 0.3172 | [CENTER_] Dice:0.7748 IoU:0.6564 CBL:0.9075 | [CENTER_] Dice:0.7632 IoU:0.6448 CBL:0.9001 | LR:2.5e-05
# Epoch 63/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.01it/s, loss=0.2831]
# 🥇 [BEST] Epoch  63 | T_Loss: 0.3169 | [CENTER_] Dice:0.7786 IoU:0.6561 CBL:0.9116 | [CENTER_] Dice:0.7692 IoU:0.6462 CBL:0.9040 | LR:2.5e-05
# Epoch 64/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.1221]
# Epoch  64 | T_Loss: 0.3247 | [CENTER_] Dice:0.7731 IoU:0.6508 CBL:0.9110 | [CENTER_] Dice:0.7592 IoU:0.6357 CBL:0.9015 | LR:1.3e-05
# Epoch 65/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2335]
# Epoch  65 | T_Loss: 0.3044 | [CENTER_] Dice:0.7764 IoU:0.6565 CBL:0.9049 | [CENTER_] Dice:0.7691 IoU:0.6515 CBL:0.8996 | LR:1.3e-05
# Epoch 66/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.3232]
# Epoch  66 | T_Loss: 0.3057 | [CENTER_] Dice:0.7750 IoU:0.6579 CBL:0.9063 | [CENTER_] Dice:0.7617 IoU:0.6445 CBL:0.8980 | LR:1.3e-05
# Epoch 67/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2772]
# Epoch  67 | T_Loss: 0.3147 | [CENTER_] Dice:0.7789 IoU:0.6607 CBL:0.9113 | [CENTER_] Dice:0.7686 IoU:0.6502 CBL:0.9030 | LR:1.3e-05
# Epoch 68/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2966]
# 🥇 [BEST] Epoch  68 | T_Loss: 0.3099 | [CENTER_] Dice:0.7823 IoU:0.6657 CBL:0.9089 | [CENTER_] Dice:0.7694 IoU:0.6521 CBL:0.9022 | LR:1.3e-05
# Epoch 69/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.6849]
# 🥇 [BEST] Epoch  69 | T_Loss: 0.3061 | [CENTER_] Dice:0.7786 IoU:0.6615 CBL:0.9089 | [CENTER_] Dice:0.7711 IoU:0.6530 CBL:0.9071 | LR:1.3e-05
# Epoch 70/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2180]
# 🥇 [BEST] Epoch  70 | T_Loss: 0.3060 | [CENTER_] Dice:0.7815 IoU:0.6647 CBL:0.9135 | [CENTER_] Dice:0.7759 IoU:0.6604 CBL:0.9094 | LR:1.3e-05
# Epoch 71/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.2275]
# 🥇 [BEST] Epoch  71 | T_Loss: 0.3172 | [CENTER_] Dice:0.7866 IoU:0.6709 CBL:0.9139 | [CENTER_] Dice:0.7763 IoU:0.6598 CBL:0.9066 | LR:1.3e-05
# Epoch 72/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.4664]
# 🥇 [BEST] Epoch  72 | T_Loss: 0.3017 | [CENTER_] Dice:0.7864 IoU:0.6679 CBL:0.9150 | [CENTER_] Dice:0.7789 IoU:0.6611 CBL:0.9119 | LR:1.3e-05
# Epoch 73/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.1507]
# Epoch  73 | T_Loss: 0.2900 | [CENTER_] Dice:0.7765 IoU:0.6606 CBL:0.9120 | [CENTER_] Dice:0.7680 IoU:0.6510 CBL:0.9059 | LR:1.3e-05
# Epoch 74/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.1775]
# Epoch  74 | T_Loss: 0.2947 | [CENTER_] Dice:0.7842 IoU:0.6647 CBL:0.9142 | [CENTER_] Dice:0.7768 IoU:0.6574 CBL:0.9102 | LR:1.3e-05
# Epoch 75/150 [Train]: 100%|██████| 462/462 [01:56<00:00,  3.98it/s, loss=0.1679]
# Epoch  75 | T_Loss: 0.3021 | [CENTER_] Dice:0.7735 IoU:0.6561 CBL:0.9064 | [CENTER_] Dice:0.7686 IoU:0.6508 CBL:0.9009 | LR:1.3e-05
# Epoch 76/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.1458]
# Epoch  76 | T_Loss: 0.2837 | [CENTER_] Dice:0.7845 IoU:0.6692 CBL:0.9107 | [CENTER_] Dice:0.7671 IoU:0.6509 CBL:0.9022 | LR:1.3e-05
# Epoch 77/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.1492]
# Epoch  77 | T_Loss: 0.2911 | [CENTER_] Dice:0.7807 IoU:0.6637 CBL:0.9107 | [CENTER_] Dice:0.7668 IoU:0.6497 CBL:0.9052 | LR:1.3e-05
# Epoch 78/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.3144]
# Epoch  78 | T_Loss: 0.3064 | [CENTER_] Dice:0.7829 IoU:0.6656 CBL:0.9172 | [CENTER_] Dice:0.7705 IoU:0.6538 CBL:0.9050 | LR:6.3e-06
# Epoch 79/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.7182]
# Epoch  79 | T_Loss: 0.3086 | [CENTER_] Dice:0.7840 IoU:0.6671 CBL:0.9136 | [CENTER_] Dice:0.7680 IoU:0.6497 CBL:0.9008 | LR:6.3e-06
# Epoch 80/150 [Train]: 100%|██████| 462/462 [01:56<00:00,  3.98it/s, loss=0.2773]
# Epoch  80 | T_Loss: 0.3113 | [CENTER_] Dice:0.7833 IoU:0.6659 CBL:0.9129 | [CENTER_] Dice:0.7707 IoU:0.6536 CBL:0.9035 | LR:6.3e-06
# Epoch 81/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.9990]
# Epoch  81 | T_Loss: 0.2873 | [CENTER_] Dice:0.7862 IoU:0.6693 CBL:0.9130 | [CENTER_] Dice:0.7743 IoU:0.6572 CBL:0.9043 | LR:6.3e-06
# Epoch 82/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.1590]
# Epoch  82 | T_Loss: 0.3073 | [CENTER_] Dice:0.7880 IoU:0.6718 CBL:0.9143 | [CENTER_] Dice:0.7730 IoU:0.6556 CBL:0.9061 | LR:6.3e-06
# Epoch 83/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.2518]
# Epoch  83 | T_Loss: 0.2972 | [CENTER_] Dice:0.7854 IoU:0.6683 CBL:0.9138 | [CENTER_] Dice:0.7718 IoU:0.6542 CBL:0.9051 | LR:6.3e-06
# Epoch 84/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.3674]
# Epoch  84 | T_Loss: 0.3088 | [CENTER_] Dice:0.7813 IoU:0.6634 CBL:0.9112 | [CENTER_] Dice:0.7728 IoU:0.6552 CBL:0.9085 | LR:3.1e-06
# Epoch 85/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  4.00it/s, loss=0.1045]
# Epoch  85 | T_Loss: 0.2828 | [CENTER_] Dice:0.7839 IoU:0.6666 CBL:0.9109 | [CENTER_] Dice:0.7726 IoU:0.6554 CBL:0.9054 | LR:3.1e-06
# Epoch 86/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.1088]
# Epoch  86 | T_Loss: 0.2985 | [CENTER_] Dice:0.7904 IoU:0.6738 CBL:0.9162 | [CENTER_] Dice:0.7749 IoU:0.6574 CBL:0.9073 | LR:3.1e-06
# Epoch 87/150 [Train]: 100%|██████| 462/462 [01:55<00:00,  3.99it/s, loss=0.2472]
# Epoch  87 | T_Loss: 0.2942 | [CENTER_] Dice:0.7860 IoU:0.6686 CBL:0.9133 | [CENTER_] Dice:0.7762 IoU:0.6588 CBL:0.9085 | LR:3.1e-06
# Early stopping at epoch 87.
#
# Best Dice (center_shift): 0.7789
# Checkpoint: checkpoints/pga_unet_center_mixed_x3_shift05_psg_attention_512_seed22120196_best.pth
# ['checkpoints/pga_unet_center_mixed_x3_shift05_psg_attention_512_seed22120196_best.pth']

# %%
# -- Quick test on the held-out set: image-level merged, 2 prompt scenarios --
# Loads the checkpoint train.py just wrote in this session (no Drive download).
# Full qualitative panels + per-image CSVs live in Source/File_Test/*/Ablation/.
import os, sys, csv
import numpy as np, torch
from collections import OrderedDict
from torch.utils.data import DataLoader
from tqdm import tqdm
from scipy.ndimage import binary_erosion, distance_transform_edt

os.chdir(PGA_ROOT)
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)
from dataset import PromptSegmentationDataset

IMG_SIZE, SCALE_FACTOR, SHIFT_RATIO = 512, 3.0, 0.5
DEVICE  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DS_ROOT = f"{PGA_ROOT}/dataset_BTXRD"
CKPT    = f"checkpoints/pga_unet_center_mixed_x3_shift05_psg_attention_512_{RUN_TAG}_best.pth"

VARIANT, ENC, QH, BINP = "psg_attention", 1, 0, 0
if VARIANT == "psg_only":
    from models.networks.prompt_unet_psg_only import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
elif VARIANT == "psg_attention":
    from models.networks.prompt_unet_psg_attention import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
else:
    from models.networks.prompt_unet_2D import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1,
                     use_encoder_prompt=bool(ENC), use_quality_head=bool(QH))
model.load_state_dict(torch.load(CKPT, map_location=DEVICE, weights_only=True))
model.to(DEVICE).eval()
print("loaded", CKPT)


def _hd95(p, g):
    p, g = p.astype(bool), g.astype(bool)
    if not p.any() and not g.any(): return 0.0
    if not p.any() or not g.any():  return float(IMG_SIZE)
    pe, ge = p ^ binary_erosion(p), g ^ binary_erosion(g)
    d1, d2 = distance_transform_edt(~ge)[pe], distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2): return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))


def _metrics(prob, gt):
    pm, gm, eps = (prob > 0.5), (gt > 0.5), 1e-6
    tp, fp, fn = float((pm & gm).sum()), float((pm & ~gm).sum()), float((~pm & gm).sum())
    cbl = 0.0
    if gm.any() and pm.any():
        ys, xs = np.where(gm); yp, xp = np.where(pm)
        diag = np.hypot(ys.max() - ys.min(), xs.max() - xs.min()) + eps
        cbl = float(np.clip(1 - np.hypot(xp.mean() - xs.mean(), yp.mean() - ys.mean()) / diag, 0, 1))
    return dict(dice=(2*tp+eps)/(2*tp+fp+fn+eps), iou=(tp+eps)/(tp+fp+fn+eps),
                pre=tp/(tp+fp+eps), rec=(tp+eps)/(tp+fn+eps), hd95=_hd95(pm, gm), cbl=cbl)


os.makedirs("results", exist_ok=True)
per_image, rows = [], []
for mode in ("center_zoom", "center_shift"):
    ds = PromptSegmentationDataset(f"{DS_ROOT}/test/images", f"{DS_ROOT}/test/annotations",
                                   img_size=IMG_SIZE, is_train=False, prompt_mode=mode,
                                   scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO,
                                   binary_prompt=bool(BINP))
    groups = OrderedDict()
    with torch.no_grad():
        for i, (img, msk, prm) in enumerate(tqdm(DataLoader(ds, batch_size=1, num_workers=2), desc=mode)):
            prob = torch.sigmoid(model(img.to(DEVICE), prm.to(DEVICE)))[0, 0].cpu().numpy()
            gt   = msk[0, 0].numpy()
            name = ds.all_samples[i][0]
            if name not in groups:
                groups[name] = [prob.copy(), gt.copy()]
            else:
                np.maximum(groups[name][0], prob, out=groups[name][0])
                np.maximum(groups[name][1], gt,   out=groups[name][1])
    recs = []
    for name, (p, g) in groups.items():
        m = _metrics(p, g); recs.append(m)
        per_image.append([mode, name] + [m[k] for k in ("dice", "iou", "pre", "rec", "hd95", "cbl")])
    avg = {k: float(np.mean([r[k] for r in recs])) for k in recs[0]}
    rows.append((mode, len(recs), avg))

print(f"\n{'scenario':<14}{'N':>5}{'Dice':>9}{'IoU':>9}{'Prec':>9}{'Rec':>9}{'HD95':>9}{'CBL':>9}")
for mode, n, a in rows:
    print(f"{mode:<14}{n:>5}{a['dice']:>9.4f}{a['iou']:>9.4f}{a['pre']:>9.4f}{a['rec']:>9.4f}{a['hd95']:>9.2f}{a['cbl']:>9.4f}")

csv_path = f"results/ablation_psg_attention_{RUN_TAG}_per_image.csv"
with open(csv_path, "w", newline="") as fh:
    w = csv.writer(fh); w.writerow(["scenario", "img_name", "dice", "iou", "pre", "rec", "hd95", "cbl"])
    w.writerows(per_image)
print("saved", csv_path)
# Out:
# loaded checkpoints/pga_unet_center_mixed_x3_shift05_psg_attention_512_seed22120196_best.pth
# center_zoom: 100%|██████████| 232/232 [00:10<00:00, 21.97it/s]
# center_shift: 100%|██████████| 232/232 [00:09<00:00, 23.44it/s]
# scenario          N     Dice      IoU     Prec      Rec     HD95      CBL
# center_zoom     187   0.7692   0.6453   0.7461   0.8305    26.38   0.9062
# center_shift    187   0.7572   0.6332   0.7442   0.8123    28.74   0.8957
# saved results/ablation_psg_attention_seed22120196_per_image.csv
