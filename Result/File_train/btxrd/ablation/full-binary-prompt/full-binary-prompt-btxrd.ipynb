# %% [markdown]
# # Ablation - Full PGA with binary prompt
# Full PSG + CAD configuration trained with a binary prompt rather than Gaussian blur.

# %%
import os, sys, shutil
import gdown

BASE = '/kaggle/working' if os.path.exists('/kaggle/working') else '/content'
os.chdir(BASE)

REPO = 'https://github.com/ThongLuc2k3/PGA_Unet2D.git'
REPO_ROOT = f'{BASE}/PGA_Unet2D'
PGA_ROOT = f'{REPO_ROOT}/Source/Prompt-Guided-XRay-Segmentation'
DATASET_NAME = 'dataset_BTXRD'
DATASET_ID = '1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx'
DS_ZIP = f'{BASE}/{DATASET_NAME}.zip'
DS_PATH = f'{PGA_ROOT}/{DATASET_NAME}'

if os.path.exists(REPO_ROOT):
    shutil.rmtree(REPO_ROOT)
# !git clone -q --branch main --single-branch {REPO} {REPO_ROOT}
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)

if not os.path.exists(DS_ZIP):
    gdown.download(f'https://drive.google.com/uc?id={DATASET_ID}', DS_ZIP, quiet=False)
if os.path.exists(DS_PATH):
    shutil.rmtree(DS_PATH)
# !unzip -oq {DS_ZIP} -d {PGA_ROOT}/

os.makedirs(f'{PGA_ROOT}/checkpoints', exist_ok=True)
os.chdir(PGA_ROOT)
# !pip install -q tqdm opencv-python timm scipy gdown
print(f'✅ Setup completed | base={BASE} | dataset={DATASET_NAME}')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx
# From (redirected): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx&confirm=t&uuid=97a84c41-a897-4cd1-9d26-c03c3e20085b
# To: /kaggle/working/dataset_BTXRD.zip
# 100%|██████████| 1.71G/1.71G [00:24<00:00, 70.6MB/s]
# ✅ Setup completed | base=/kaggle/working | dataset=dataset_BTXRD

# %% [markdown]
# ## Ablation training via the shared `train.py`
#
# **Configuration: Full PGA-UNet with a binary prompt.** Full PGA-UNet (PSG + CAD, QualityHead on); the prompt is a hard binary box instead of the Gaussian-smoothed plateau (`BINARY_PROMPT=1`).
#
# Every ablation configuration is trained through the same `train.py` as the full PGA-UNet, so batch size, optimizer, scheduler, gradient clipping, the 150-epoch / patience-15 early stopping, and **image-level merged `center_shift` validation for checkpoint selection** are identical across the study. Repeat the training cell with `SEED = 1`, `2`, `3` for the multi-seed ablation; `RUN_TAG` keeps the per-seed checkpoints from overwriting each other.
#
# A quick image-level metrics table on the held-out test set is printed by the last cell. For the full qualitative panels and per-image CSVs, run the matching notebook under `Source/File_Test/btxrd/Ablation/`.

# %%
# Repeat with SEED = 1, 2, 3 ... for the multi-seed ablation.
SEED = 22120196
RUN_TAG = f"seed{SEED}"

import os, glob
os.chdir(PGA_ROOT)
os.environ.update({
    "PROMPT_DATASET_ROOT": "dataset_BTXRD",
    "PROMPT_IMG_SIZE": "512",
    "PROMPT_MODE": "center_mixed",
    "PROMPT_SCALE_FACTOR": "3.0",
    "PROMPT_SHIFT_RATIO": "0.5",
    "PROMPT_MIXED_SHIFT_PROB": "0.8",
    "PROMPT_EPOCHS": "150",
    "PROMPT_SEED": str(SEED),
    "RUN_TAG": RUN_TAG,
    "PROMPT_VARIANT": "full",
    "USE_ENCODER_PROMPT": "1",
    "BINARY_PROMPT": "1",
    "USE_QUALITY_HEAD": "1",
})

# !python train.py

print(sorted(glob.glob(f"checkpoints/pga_unet_center_mixed_x3_shift05_qhead_binaryprompt_512_{RUN_TAG}_best.pth")))
# Out:
# ==========================================================================================
# TrainPrompt: center_mixed | Device: cuda | Variant: full | EncoderPrompt: True | BinaryPrompt: True | ImgSize: 512 | DatasetRoot: dataset_BTXRD | Seed: 22120196 | RunTag: seed22120196 | ScaleFactor: 3.0 | ShiftRatio: 0.5 | MixedShiftProb: 0.8 | QualityHead: ConfidenceLossWeight=1.0
# ==========================================================================================
# Epoch 1/150 [Train]: 100%|███████| 462/462 [02:25<00:00,  3.18it/s, loss=1.4228]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.4919 | [CENTER_] Dice:0.3100 IoU:0.2029 CBL:0.5550 | [CENTER_] Dice:0.3038 IoU:0.1989 CBL:0.5401 | LR:1.0e-04
# Epoch 2/150 [Train]: 100%|███████| 462/462 [02:31<00:00,  3.06it/s, loss=1.3240]
# 🥇 [BEST] Epoch   2 | T_Loss: 1.3568 | [CENTER_] Dice:0.3923 IoU:0.2643 CBL:0.6928 | [CENTER_] Dice:0.3655 IoU:0.2441 CBL:0.6488 | LR:1.0e-04
# Epoch 3/150 [Train]: 100%|███████| 462/462 [02:30<00:00,  3.06it/s, loss=1.1985]
# 🥇 [BEST] Epoch   3 | T_Loss: 1.2718 | [CENTER_] Dice:0.4456 IoU:0.3025 CBL:0.7800 | [CENTER_] Dice:0.4226 IoU:0.2840 CBL:0.7282 | LR:1.0e-04
# Epoch 4/150 [Train]: 100%|███████| 462/462 [02:31<00:00,  3.06it/s, loss=1.1085]
# 🥇 [BEST] Epoch   4 | T_Loss: 1.1952 | [CENTER_] Dice:0.4741 IoU:0.3255 CBL:0.8075 | [CENTER_] Dice:0.4612 IoU:0.3146 CBL:0.7688 | LR:1.0e-04
# Epoch 5/150 [Train]: 100%|███████| 462/462 [02:31<00:00,  3.04it/s, loss=0.9807]
# Epoch   5 | T_Loss: 1.1275 | [CENTER_] Dice:0.4481 IoU:0.3037 CBL:0.8080 | [CENTER_] Dice:0.4399 IoU:0.2976 CBL:0.7607 | LR:1.0e-04
# Epoch 6/150 [Train]: 100%|███████| 462/462 [02:31<00:00,  3.05it/s, loss=0.9873]
# 🥇 [BEST] Epoch   6 | T_Loss: 1.0743 | [CENTER_] Dice:0.5494 IoU:0.4082 CBL:0.7893 | [CENTER_] Dice:0.5052 IoU:0.3656 CBL:0.7445 | LR:1.0e-04
# Epoch 7/150 [Train]: 100%|███████| 462/462 [02:31<00:00,  3.06it/s, loss=0.8919]
# Epoch   7 | T_Loss: 1.0087 | [CENTER_] Dice:0.4906 IoU:0.3682 CBL:0.7051 | [CENTER_] Dice:0.5032 IoU:0.3806 CBL:0.7119 | LR:1.0e-04
# Epoch 8/150 [Train]: 100%|███████| 462/462 [02:31<00:00,  3.05it/s, loss=0.8835]
# 🥇 [BEST] Epoch   8 | T_Loss: 0.9612 | [CENTER_] Dice:0.5498 IoU:0.4138 CBL:0.7865 | [CENTER_] Dice:0.5110 IoU:0.3780 CBL:0.7474 | LR:1.0e-04
# Epoch 9/150 [Train]: 100%|███████| 462/462 [02:31<00:00,  3.05it/s, loss=1.2053]
# Epoch   9 | T_Loss: 0.9139 | [CENTER_] Dice:0.5516 IoU:0.4095 CBL:0.7791 | [CENTER_] Dice:0.5029 IoU:0.3657 CBL:0.7159 | LR:1.0e-04
# Epoch 10/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.8196]
# Epoch  10 | T_Loss: 0.8674 | [CENTER_] Dice:0.4969 IoU:0.3519 CBL:0.7927 | [CENTER_] Dice:0.4931 IoU:0.3515 CBL:0.7659 | LR:1.0e-04
# Epoch 11/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.06it/s, loss=0.7999]
# Epoch  11 | T_Loss: 0.8288 | [CENTER_] Dice:0.5160 IoU:0.3770 CBL:0.7593 | [CENTER_] Dice:0.5029 IoU:0.3674 CBL:0.7309 | LR:1.0e-04
# Epoch 12/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.5564]
# 🥇 [BEST] Epoch  12 | T_Loss: 0.7880 | [CENTER_] Dice:0.5504 IoU:0.4117 CBL:0.8116 | [CENTER_] Dice:0.5339 IoU:0.3959 CBL:0.7899 | LR:1.0e-04
# Epoch 13/150 [Train]: 100%|██████| 462/462 [02:30<00:00,  3.06it/s, loss=0.6748]
# 🥇 [BEST] Epoch  13 | T_Loss: 0.7535 | [CENTER_] Dice:0.5837 IoU:0.4364 CBL:0.8420 | [CENTER_] Dice:0.5739 IoU:0.4286 CBL:0.8209 | LR:1.0e-04
# Epoch 14/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.9323]
# 🥇 [BEST] Epoch  14 | T_Loss: 0.7195 | [CENTER_] Dice:0.6109 IoU:0.4702 CBL:0.8223 | [CENTER_] Dice:0.6143 IoU:0.4736 CBL:0.8099 | LR:1.0e-04
# Epoch 15/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.6245]
# 🥇 [BEST] Epoch  15 | T_Loss: 0.6863 | [CENTER_] Dice:0.6517 IoU:0.5160 CBL:0.8638 | [CENTER_] Dice:0.6273 IoU:0.4867 CBL:0.8453 | LR:1.0e-04
# Epoch 16/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.06it/s, loss=0.4760]
# Epoch  16 | T_Loss: 0.6510 | [CENTER_] Dice:0.5889 IoU:0.4581 CBL:0.8301 | [CENTER_] Dice:0.5547 IoU:0.4263 CBL:0.8008 | LR:1.0e-04
# Epoch 17/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.6255]
# Epoch  17 | T_Loss: 0.6009 | [CENTER_] Dice:0.6400 IoU:0.5096 CBL:0.8452 | [CENTER_] Dice:0.6116 IoU:0.4810 CBL:0.8270 | LR:1.0e-04
# Epoch 18/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.4498]
# 🥇 [BEST] Epoch  18 | T_Loss: 0.5867 | [CENTER_] Dice:0.6547 IoU:0.5248 CBL:0.8630 | [CENTER_] Dice:0.6461 IoU:0.5167 CBL:0.8475 | LR:1.0e-04
# Epoch 19/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.06it/s, loss=0.4879]
# 🥇 [BEST] Epoch  19 | T_Loss: 0.5646 | [CENTER_] Dice:0.6620 IoU:0.5242 CBL:0.8722 | [CENTER_] Dice:0.6536 IoU:0.5142 CBL:0.8703 | LR:1.0e-04
# Epoch 20/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.5547]
# 🥇 [BEST] Epoch  20 | T_Loss: 0.5360 | [CENTER_] Dice:0.6712 IoU:0.5373 CBL:0.8721 | [CENTER_] Dice:0.6583 IoU:0.5223 CBL:0.8602 | LR:1.0e-04
# Epoch 21/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.5217]
# Epoch  21 | T_Loss: 0.5394 | [CENTER_] Dice:0.6755 IoU:0.5405 CBL:0.8801 | [CENTER_] Dice:0.6521 IoU:0.5165 CBL:0.8586 | LR:1.0e-04
# Epoch 22/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.4775]
# 🥇 [BEST] Epoch  22 | T_Loss: 0.5170 | [CENTER_] Dice:0.6952 IoU:0.5653 CBL:0.8824 | [CENTER_] Dice:0.6809 IoU:0.5512 CBL:0.8734 | LR:1.0e-04
# Epoch 23/150 [Train]: 100%|██████| 462/462 [02:32<00:00,  3.04it/s, loss=0.5374]
# Epoch  23 | T_Loss: 0.4988 | [CENTER_] Dice:0.6748 IoU:0.5424 CBL:0.8697 | [CENTER_] Dice:0.6506 IoU:0.5197 CBL:0.8547 | LR:1.0e-04
# Epoch 24/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.06it/s, loss=0.5608]
# 🥇 [BEST] Epoch  24 | T_Loss: 0.4984 | [CENTER_] Dice:0.6972 IoU:0.5551 CBL:0.8813 | [CENTER_] Dice:0.6963 IoU:0.5587 CBL:0.8728 | LR:1.0e-04
# Epoch 25/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.06it/s, loss=0.3137]
# 🥇 [BEST] Epoch  25 | T_Loss: 0.4837 | [CENTER_] Dice:0.7240 IoU:0.5841 CBL:0.8985 | [CENTER_] Dice:0.6964 IoU:0.5570 CBL:0.8684 | LR:1.0e-04
# Epoch 26/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.3577]
# Epoch  26 | T_Loss: 0.4824 | [CENTER_] Dice:0.6976 IoU:0.5628 CBL:0.8824 | [CENTER_] Dice:0.6651 IoU:0.5287 CBL:0.8508 | LR:1.0e-04
# Epoch 27/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.3493]
# Epoch  27 | T_Loss: 0.4712 | [CENTER_] Dice:0.7184 IoU:0.5889 CBL:0.9018 | [CENTER_] Dice:0.6877 IoU:0.5553 CBL:0.8824 | LR:1.0e-04
# Epoch 28/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.2942]
# 🥇 [BEST] Epoch  28 | T_Loss: 0.4509 | [CENTER_] Dice:0.7163 IoU:0.5905 CBL:0.8910 | [CENTER_] Dice:0.7011 IoU:0.5747 CBL:0.8821 | LR:1.0e-04
# Epoch 29/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.4305]
# Epoch  29 | T_Loss: 0.4727 | [CENTER_] Dice:0.7254 IoU:0.5957 CBL:0.8904 | [CENTER_] Dice:0.6786 IoU:0.5475 CBL:0.8652 | LR:1.0e-04
# Epoch 30/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=1.0942]
# 🥇 [BEST] Epoch  30 | T_Loss: 0.4469 | [CENTER_] Dice:0.7276 IoU:0.5960 CBL:0.8925 | [CENTER_] Dice:0.7155 IoU:0.5840 CBL:0.8856 | LR:1.0e-04
# Epoch 31/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.06it/s, loss=0.3780]
# Epoch  31 | T_Loss: 0.4421 | [CENTER_] Dice:0.6987 IoU:0.5757 CBL:0.8933 | [CENTER_] Dice:0.6853 IoU:0.5610 CBL:0.8777 | LR:1.0e-04
# Epoch 32/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.06it/s, loss=0.4345]
# 🥇 [BEST] Epoch  32 | T_Loss: 0.4496 | [CENTER_] Dice:0.7330 IoU:0.5964 CBL:0.8956 | [CENTER_] Dice:0.7241 IoU:0.5879 CBL:0.8821 | LR:1.0e-04
# Epoch 33/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.8173]
# Epoch  33 | T_Loss: 0.4524 | [CENTER_] Dice:0.6948 IoU:0.5692 CBL:0.8831 | [CENTER_] Dice:0.6857 IoU:0.5606 CBL:0.8754 | LR:1.0e-04
# Epoch 34/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.4834]
# Epoch  34 | T_Loss: 0.4595 | [CENTER_] Dice:0.7245 IoU:0.5980 CBL:0.8986 | [CENTER_] Dice:0.7236 IoU:0.5985 CBL:0.8935 | LR:1.0e-04
# Epoch 35/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.2435]
# 🥇 [BEST] Epoch  35 | T_Loss: 0.4275 | [CENTER_] Dice:0.7493 IoU:0.6156 CBL:0.9027 | [CENTER_] Dice:0.7408 IoU:0.6094 CBL:0.8929 | LR:1.0e-04
# Epoch 36/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.4061]
# Epoch  36 | T_Loss: 0.4323 | [CENTER_] Dice:0.7342 IoU:0.6039 CBL:0.8933 | [CENTER_] Dice:0.7227 IoU:0.5956 CBL:0.8868 | LR:1.0e-04
# Epoch 37/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.3496]
# Epoch  37 | T_Loss: 0.4219 | [CENTER_] Dice:0.7083 IoU:0.5849 CBL:0.8792 | [CENTER_] Dice:0.6921 IoU:0.5674 CBL:0.8768 | LR:1.0e-04
# Epoch 38/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.9430]
# Epoch  38 | T_Loss: 0.4491 | [CENTER_] Dice:0.7375 IoU:0.6109 CBL:0.8929 | [CENTER_] Dice:0.7270 IoU:0.6014 CBL:0.8908 | LR:1.0e-04
# Epoch 39/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=1.1233]
# Epoch  39 | T_Loss: 0.4317 | [CENTER_] Dice:0.7104 IoU:0.5850 CBL:0.8925 | [CENTER_] Dice:0.7177 IoU:0.5981 CBL:0.8989 | LR:1.0e-04
# Epoch 40/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.2504]
# Epoch  40 | T_Loss: 0.4037 | [CENTER_] Dice:0.7501 IoU:0.6272 CBL:0.8979 | [CENTER_] Dice:0.7366 IoU:0.6140 CBL:0.8790 | LR:1.0e-04
# Epoch 41/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.3837]
# Epoch  41 | T_Loss: 0.4129 | [CENTER_] Dice:0.7212 IoU:0.5969 CBL:0.8863 | [CENTER_] Dice:0.7096 IoU:0.5872 CBL:0.8634 | LR:5.0e-05
# Epoch 42/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.2984]
# 🥇 [BEST] Epoch  42 | T_Loss: 0.3802 | [CENTER_] Dice:0.7554 IoU:0.6290 CBL:0.8989 | [CENTER_] Dice:0.7479 IoU:0.6238 CBL:0.8883 | LR:5.0e-05
# Epoch 43/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.4889]
# Epoch  43 | T_Loss: 0.3816 | [CENTER_] Dice:0.7447 IoU:0.6238 CBL:0.8991 | [CENTER_] Dice:0.7313 IoU:0.6099 CBL:0.8837 | LR:5.0e-05
# Epoch 44/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.1605]
# 🥇 [BEST] Epoch  44 | T_Loss: 0.3771 | [CENTER_] Dice:0.7566 IoU:0.6331 CBL:0.9040 | [CENTER_] Dice:0.7522 IoU:0.6314 CBL:0.8933 | LR:5.0e-05
# Epoch 45/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.2481]
# Epoch  45 | T_Loss: 0.3701 | [CENTER_] Dice:0.7532 IoU:0.6311 CBL:0.9036 | [CENTER_] Dice:0.7401 IoU:0.6192 CBL:0.8950 | LR:5.0e-05
# Epoch 46/150 [Train]: 100%|██████| 462/462 [02:32<00:00,  3.04it/s, loss=0.3989]
# 🥇 [BEST] Epoch  46 | T_Loss: 0.3742 | [CENTER_] Dice:0.7596 IoU:0.6372 CBL:0.9015 | [CENTER_] Dice:0.7539 IoU:0.6337 CBL:0.9004 | LR:5.0e-05
# Epoch 47/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.3821]
# Epoch  47 | T_Loss: 0.3602 | [CENTER_] Dice:0.7537 IoU:0.6290 CBL:0.9006 | [CENTER_] Dice:0.7524 IoU:0.6312 CBL:0.8996 | LR:5.0e-05
# Epoch 48/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.2794]
# Epoch  48 | T_Loss: 0.3705 | [CENTER_] Dice:0.7421 IoU:0.6214 CBL:0.9040 | [CENTER_] Dice:0.7313 IoU:0.6118 CBL:0.8993 | LR:5.0e-05
# Epoch 49/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.1738]
# 🥇 [BEST] Epoch  49 | T_Loss: 0.3724 | [CENTER_] Dice:0.7664 IoU:0.6451 CBL:0.9093 | [CENTER_] Dice:0.7597 IoU:0.6401 CBL:0.9016 | LR:5.0e-05
# Epoch 50/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.2122]
# Epoch  50 | T_Loss: 0.3695 | [CENTER_] Dice:0.7512 IoU:0.6254 CBL:0.9096 | [CENTER_] Dice:0.7485 IoU:0.6261 CBL:0.9052 | LR:5.0e-05
# Epoch 51/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.4007]
# Epoch  51 | T_Loss: 0.3766 | [CENTER_] Dice:0.7498 IoU:0.6298 CBL:0.9035 | [CENTER_] Dice:0.7289 IoU:0.6115 CBL:0.8912 | LR:5.0e-05
# Epoch 52/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.06it/s, loss=0.3047]
# 🥇 [BEST] Epoch  52 | T_Loss: 0.3687 | [CENTER_] Dice:0.7734 IoU:0.6549 CBL:0.9068 | [CENTER_] Dice:0.7649 IoU:0.6496 CBL:0.9070 | LR:5.0e-05
# Epoch 53/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.2189]
# Epoch  53 | T_Loss: 0.3514 | [CENTER_] Dice:0.7597 IoU:0.6404 CBL:0.9114 | [CENTER_] Dice:0.7383 IoU:0.6189 CBL:0.8879 | LR:5.0e-05
# Epoch 54/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.2025]
# Epoch  54 | T_Loss: 0.3642 | [CENTER_] Dice:0.7753 IoU:0.6548 CBL:0.9096 | [CENTER_] Dice:0.7629 IoU:0.6440 CBL:0.9050 | LR:5.0e-05
# Epoch 55/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.1648]
# Epoch  55 | T_Loss: 0.3481 | [CENTER_] Dice:0.7452 IoU:0.6279 CBL:0.9017 | [CENTER_] Dice:0.7404 IoU:0.6239 CBL:0.8883 | LR:5.0e-05
# Epoch 56/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.2783]
# Epoch  56 | T_Loss: 0.3553 | [CENTER_] Dice:0.7626 IoU:0.6441 CBL:0.9132 | [CENTER_] Dice:0.7489 IoU:0.6326 CBL:0.9057 | LR:5.0e-05
# Epoch 57/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.6557]
# Epoch  57 | T_Loss: 0.3528 | [CENTER_] Dice:0.7582 IoU:0.6360 CBL:0.9060 | [CENTER_] Dice:0.7538 IoU:0.6367 CBL:0.9025 | LR:5.0e-05
# Epoch 58/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.3801]
# Epoch  58 | T_Loss: 0.3570 | [CENTER_] Dice:0.7728 IoU:0.6527 CBL:0.9105 | [CENTER_] Dice:0.7509 IoU:0.6304 CBL:0.8938 | LR:2.5e-05
# Epoch 59/150 [Train]: 100%|██████| 462/462 [02:32<00:00,  3.04it/s, loss=0.1555]
# Epoch  59 | T_Loss: 0.3473 | [CENTER_] Dice:0.7605 IoU:0.6437 CBL:0.9080 | [CENTER_] Dice:0.7523 IoU:0.6368 CBL:0.8944 | LR:2.5e-05
# Epoch 60/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.1687]
# Epoch  60 | T_Loss: 0.3238 | [CENTER_] Dice:0.7734 IoU:0.6565 CBL:0.9126 | [CENTER_] Dice:0.7621 IoU:0.6456 CBL:0.9078 | LR:2.5e-05
# Epoch 61/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.1940]
# Epoch  61 | T_Loss: 0.3389 | [CENTER_] Dice:0.7740 IoU:0.6571 CBL:0.9130 | [CENTER_] Dice:0.7561 IoU:0.6400 CBL:0.9027 | LR:2.5e-05
# Epoch 62/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.3301]
# Epoch  62 | T_Loss: 0.3319 | [CENTER_] Dice:0.7738 IoU:0.6519 CBL:0.9118 | [CENTER_] Dice:0.7649 IoU:0.6472 CBL:0.9106 | LR:2.5e-05
# Epoch 63/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.8750]
# Epoch  63 | T_Loss: 0.3403 | [CENTER_] Dice:0.7751 IoU:0.6590 CBL:0.9147 | [CENTER_] Dice:0.7592 IoU:0.6442 CBL:0.9105 | LR:2.5e-05
# Epoch 64/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.7846]
# Epoch  64 | T_Loss: 0.3168 | [CENTER_] Dice:0.7733 IoU:0.6573 CBL:0.9136 | [CENTER_] Dice:0.7585 IoU:0.6435 CBL:0.9011 | LR:1.3e-05
# Epoch 65/150 [Train]: 100%|██████| 462/462 [02:32<00:00,  3.03it/s, loss=0.4350]
# Epoch  65 | T_Loss: 0.3214 | [CENTER_] Dice:0.7701 IoU:0.6537 CBL:0.9093 | [CENTER_] Dice:0.7621 IoU:0.6473 CBL:0.9053 | LR:1.3e-05
# Epoch 66/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.2713]
# Epoch  66 | T_Loss: 0.3158 | [CENTER_] Dice:0.7695 IoU:0.6513 CBL:0.9077 | [CENTER_] Dice:0.7639 IoU:0.6484 CBL:0.9097 | LR:1.3e-05
# Epoch 67/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.3314]
# 🥇 [BEST] Epoch  67 | T_Loss: 0.2987 | [CENTER_] Dice:0.7729 IoU:0.6560 CBL:0.9073 | [CENTER_] Dice:0.7667 IoU:0.6522 CBL:0.9095 | LR:1.3e-05
# Epoch 68/150 [Train]: 100%|██████| 462/462 [02:32<00:00,  3.04it/s, loss=0.6633]
# Epoch  68 | T_Loss: 0.3017 | [CENTER_] Dice:0.7737 IoU:0.6569 CBL:0.9102 | [CENTER_] Dice:0.7648 IoU:0.6500 CBL:0.9089 | LR:1.3e-05
# Epoch 69/150 [Train]: 100%|██████| 462/462 [02:32<00:00,  3.04it/s, loss=0.1377]
# Epoch  69 | T_Loss: 0.3131 | [CENTER_] Dice:0.7707 IoU:0.6551 CBL:0.9052 | [CENTER_] Dice:0.7642 IoU:0.6512 CBL:0.9036 | LR:1.3e-05
# Epoch 70/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.1630]
# Epoch  70 | T_Loss: 0.3086 | [CENTER_] Dice:0.7683 IoU:0.6516 CBL:0.9085 | [CENTER_] Dice:0.7623 IoU:0.6494 CBL:0.9042 | LR:1.3e-05
# Epoch 71/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.2072]
# 🥇 [BEST] Epoch  71 | T_Loss: 0.3022 | [CENTER_] Dice:0.7746 IoU:0.6586 CBL:0.9096 | [CENTER_] Dice:0.7677 IoU:0.6541 CBL:0.9097 | LR:1.3e-05
# Epoch 72/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.3868]
# 🥇 [BEST] Epoch  72 | T_Loss: 0.3196 | [CENTER_] Dice:0.7815 IoU:0.6645 CBL:0.9150 | [CENTER_] Dice:0.7734 IoU:0.6573 CBL:0.9140 | LR:1.3e-05
# Epoch 73/150 [Train]: 100%|██████| 462/462 [02:32<00:00,  3.04it/s, loss=0.6765]
# Epoch  73 | T_Loss: 0.3304 | [CENTER_] Dice:0.7738 IoU:0.6575 CBL:0.9115 | [CENTER_] Dice:0.7633 IoU:0.6488 CBL:0.9077 | LR:1.3e-05
# Epoch 74/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.1964]
# Epoch  74 | T_Loss: 0.3159 | [CENTER_] Dice:0.7753 IoU:0.6597 CBL:0.9091 | [CENTER_] Dice:0.7678 IoU:0.6542 CBL:0.9118 | LR:1.3e-05
# Epoch 75/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.8996]
# Epoch  75 | T_Loss: 0.3248 | [CENTER_] Dice:0.7801 IoU:0.6628 CBL:0.9096 | [CENTER_] Dice:0.7669 IoU:0.6519 CBL:0.9119 | LR:1.3e-05
# Epoch 76/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.6199]
# Epoch  76 | T_Loss: 0.3139 | [CENTER_] Dice:0.7745 IoU:0.6587 CBL:0.9065 | [CENTER_] Dice:0.7634 IoU:0.6490 CBL:0.9011 | LR:1.3e-05
# Epoch 77/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.3283]
# Epoch  77 | T_Loss: 0.3226 | [CENTER_] Dice:0.7785 IoU:0.6627 CBL:0.9100 | [CENTER_] Dice:0.7630 IoU:0.6491 CBL:0.9041 | LR:1.3e-05
# Epoch 78/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.2196]
# Epoch  78 | T_Loss: 0.2896 | [CENTER_] Dice:0.7760 IoU:0.6613 CBL:0.9143 | [CENTER_] Dice:0.7631 IoU:0.6507 CBL:0.9076 | LR:6.3e-06
# Epoch 79/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.7256]
# Epoch  79 | T_Loss: 0.3027 | [CENTER_] Dice:0.7807 IoU:0.6666 CBL:0.9112 | [CENTER_] Dice:0.7651 IoU:0.6531 CBL:0.9093 | LR:6.3e-06
# Epoch 80/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.1405]
# Epoch  80 | T_Loss: 0.3005 | [CENTER_] Dice:0.7777 IoU:0.6620 CBL:0.9094 | [CENTER_] Dice:0.7688 IoU:0.6553 CBL:0.9104 | LR:6.3e-06
# Epoch 81/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.1481]
# Epoch  81 | T_Loss: 0.2918 | [CENTER_] Dice:0.7780 IoU:0.6611 CBL:0.9123 | [CENTER_] Dice:0.7660 IoU:0.6523 CBL:0.9082 | LR:6.3e-06
# Epoch 82/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.1687]
# Epoch  82 | T_Loss: 0.3012 | [CENTER_] Dice:0.7763 IoU:0.6586 CBL:0.9152 | [CENTER_] Dice:0.7679 IoU:0.6533 CBL:0.9099 | LR:6.3e-06
# Epoch 83/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.2322]
# Epoch  83 | T_Loss: 0.3152 | [CENTER_] Dice:0.7755 IoU:0.6590 CBL:0.9084 | [CENTER_] Dice:0.7615 IoU:0.6472 CBL:0.9041 | LR:6.3e-06
# Epoch 84/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.04it/s, loss=0.7520]
# Epoch  84 | T_Loss: 0.2924 | [CENTER_] Dice:0.7826 IoU:0.6653 CBL:0.9171 | [CENTER_] Dice:0.7671 IoU:0.6532 CBL:0.9090 | LR:3.1e-06
# Epoch 85/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.3440]
# Epoch  85 | T_Loss: 0.3035 | [CENTER_] Dice:0.7822 IoU:0.6651 CBL:0.9181 | [CENTER_] Dice:0.7677 IoU:0.6543 CBL:0.9084 | LR:3.1e-06
# Epoch 86/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.1613]
# Epoch  86 | T_Loss: 0.3035 | [CENTER_] Dice:0.7737 IoU:0.6575 CBL:0.9125 | [CENTER_] Dice:0.7627 IoU:0.6494 CBL:0.9050 | LR:3.1e-06
# Epoch 87/150 [Train]: 100%|██████| 462/462 [02:31<00:00,  3.05it/s, loss=0.1829]
# Epoch  87 | T_Loss: 0.2989 | [CENTER_] Dice:0.7769 IoU:0.6620 CBL:0.9094 | [CENTER_] Dice:0.7647 IoU:0.6524 CBL:0.9083 | LR:3.1e-06
# Early stopping at epoch 87.
#
# Best Dice (center_shift): 0.7734
# Checkpoint: checkpoints/pga_unet_center_mixed_x3_shift05_qhead_binaryprompt_512_seed22120196_best.pth
# ['checkpoints/pga_unet_center_mixed_x3_shift05_qhead_binaryprompt_512_seed22120196_best.pth']

# %%
# -- Quick test on the held-out set: image-level merged, 2 prompt scenarios --
# Loads the checkpoint train.py just wrote in this session (no Drive download).
# Full qualitative panels + per-image CSVs live in Source/File_Test/*/Ablation/.
import os, sys, csv
import numpy as np, torch
from collections import OrderedDict
from torch.utils.data import DataLoader
from tqdm import tqdm
from scipy.ndimage import binary_erosion, distance_transform_edt

os.chdir(PGA_ROOT)
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)
from dataset import PromptSegmentationDataset

IMG_SIZE, SCALE_FACTOR, SHIFT_RATIO = 512, 3.0, 0.5
DEVICE  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DS_ROOT = f"{PGA_ROOT}/dataset_BTXRD"
CKPT    = f"checkpoints/pga_unet_center_mixed_x3_shift05_qhead_binaryprompt_512_{RUN_TAG}_best.pth"

VARIANT, ENC, QH, BINP = "full", 1, 1, 1
if VARIANT == "psg_only":
    from models.networks.prompt_unet_psg_only import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
elif VARIANT == "psg_attention":
    from models.networks.prompt_unet_psg_attention import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
else:
    from models.networks.prompt_unet_2D import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1,
                     use_encoder_prompt=bool(ENC), use_quality_head=bool(QH))
model.load_state_dict(torch.load(CKPT, map_location=DEVICE, weights_only=True))
model.to(DEVICE).eval()
print("loaded", CKPT)


def _hd95(p, g):
    p, g = p.astype(bool), g.astype(bool)
    if not p.any() and not g.any(): return 0.0
    if not p.any() or not g.any():  return float(IMG_SIZE)
    pe, ge = p ^ binary_erosion(p), g ^ binary_erosion(g)
    d1, d2 = distance_transform_edt(~ge)[pe], distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2): return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))


def _metrics(prob, gt):
    pm, gm, eps = (prob > 0.5), (gt > 0.5), 1e-6
    tp, fp, fn = float((pm & gm).sum()), float((pm & ~gm).sum()), float((~pm & gm).sum())
    cbl = 0.0
    if gm.any() and pm.any():
        ys, xs = np.where(gm); yp, xp = np.where(pm)
        diag = np.hypot(ys.max() - ys.min(), xs.max() - xs.min()) + eps
        cbl = float(np.clip(1 - np.hypot(xp.mean() - xs.mean(), yp.mean() - ys.mean()) / diag, 0, 1))
    return dict(dice=(2*tp+eps)/(2*tp+fp+fn+eps), iou=(tp+eps)/(tp+fp+fn+eps),
                pre=tp/(tp+fp+eps), rec=(tp+eps)/(tp+fn+eps), hd95=_hd95(pm, gm), cbl=cbl)


os.makedirs("results", exist_ok=True)
per_image, rows = [], []
for mode in ("center_zoom", "center_shift"):
    ds = PromptSegmentationDataset(f"{DS_ROOT}/test/images", f"{DS_ROOT}/test/annotations",
                                   img_size=IMG_SIZE, is_train=False, prompt_mode=mode,
                                   scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO,
                                   binary_prompt=bool(BINP))
    groups = OrderedDict()
    with torch.no_grad():
        for i, (img, msk, prm) in enumerate(tqdm(DataLoader(ds, batch_size=1, num_workers=2), desc=mode)):
            prob = torch.sigmoid(model(img.to(DEVICE), prm.to(DEVICE)))[0, 0].cpu().numpy()
            gt   = msk[0, 0].numpy()
            name = ds.all_samples[i][0]
            if name not in groups:
                groups[name] = [prob.copy(), gt.copy()]
            else:
                np.maximum(groups[name][0], prob, out=groups[name][0])
                np.maximum(groups[name][1], gt,   out=groups[name][1])
    recs = []
    for name, (p, g) in groups.items():
        m = _metrics(p, g); recs.append(m)
        per_image.append([mode, name] + [m[k] for k in ("dice", "iou", "pre", "rec", "hd95", "cbl")])
    avg = {k: float(np.mean([r[k] for r in recs])) for k in recs[0]}
    rows.append((mode, len(recs), avg))

print(f"\n{'scenario':<14}{'N':>5}{'Dice':>9}{'IoU':>9}{'Prec':>9}{'Rec':>9}{'HD95':>9}{'CBL':>9}")
for mode, n, a in rows:
    print(f"{mode:<14}{n:>5}{a['dice']:>9.4f}{a['iou']:>9.4f}{a['pre']:>9.4f}{a['rec']:>9.4f}{a['hd95']:>9.2f}{a['cbl']:>9.4f}")

csv_path = f"results/ablation_qhead_binaryprompt_{RUN_TAG}_per_image.csv"
with open(csv_path, "w", newline="") as fh:
    w = csv.writer(fh); w.writerow(["scenario", "img_name", "dice", "iou", "pre", "rec", "hd95", "cbl"])
    w.writerows(per_image)
print("saved", csv_path)
# Out:
# loaded checkpoints/pga_unet_center_mixed_x3_shift05_qhead_binaryprompt_512_seed22120196_best.pth
# center_zoom: 100%|██████████| 232/232 [00:06<00:00, 34.26it/s]
# center_shift: 100%|██████████| 232/232 [00:06<00:00, 34.39it/s]
# scenario          N     Dice      IoU     Prec      Rec     HD95      CBL
# center_zoom     187   0.7880   0.6684   0.7869   0.8157    23.11   0.9141
# center_shift    187   0.7703   0.6512   0.7841   0.7894    28.48   0.8999
# saved results/ablation_qhead_binaryprompt_seed22120196_per_image.csv
