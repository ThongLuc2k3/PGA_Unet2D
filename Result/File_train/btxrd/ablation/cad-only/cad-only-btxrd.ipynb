# %% [markdown]
# # Ablation - CAD only (no PSG)
# `use_encoder_prompt=False`: uses only the Conditioned Attention Decoder.

# %%
import os, sys, shutil
import gdown

BASE = '/kaggle/working' if os.path.exists('/kaggle/working') else '/content'
os.chdir(BASE)

REPO = 'https://github.com/ThongLuc2k3/PGA_Unet2D.git'
REPO_ROOT = f'{BASE}/PGA_Unet2D'
PGA_ROOT = f'{REPO_ROOT}/Source/Prompt-Guided-XRay-Segmentation'
DATASET_NAME = 'dataset_BTXRD'
DATASET_ID = '1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx'
DS_ZIP = f'{BASE}/{DATASET_NAME}.zip'
DS_PATH = f'{PGA_ROOT}/{DATASET_NAME}'

if os.path.exists(REPO_ROOT):
    shutil.rmtree(REPO_ROOT)
# !git clone -q --branch main --single-branch {REPO} {REPO_ROOT}
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)

if not os.path.exists(DS_ZIP):
    gdown.download(f'https://drive.google.com/uc?id={DATASET_ID}', DS_ZIP, quiet=False)
if os.path.exists(DS_PATH):
    shutil.rmtree(DS_PATH)
# !unzip -oq {DS_ZIP} -d {PGA_ROOT}/

os.makedirs(f'{PGA_ROOT}/checkpoints', exist_ok=True)
os.chdir(PGA_ROOT)
# !pip install -q tqdm opencv-python timm scipy gdown
print(f'✅ Setup completed | base={BASE} | dataset={DATASET_NAME}')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx
# From (redirected): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx&confirm=t&uuid=67b58656-b1f4-45ef-abb3-b60347d08855
# To: /kaggle/working/dataset_BTXRD.zip
# 100%|██████████| 1.71G/1.71G [00:26<00:00, 65.6MB/s]
# ✅ Setup completed | base=/kaggle/working | dataset=dataset_BTXRD

# %% [markdown]
# ## Ablation training via the shared `train.py`
#
# **Configuration: CAD only (no PSG).** CAD decoder attention only, PSG encoder gate disabled (`USE_ENCODER_PROMPT=0`). QualityHead stays on so this row matches the main PGA-UNet training objective.
#
# Every ablation configuration is trained through the same `train.py` as the full PGA-UNet, so batch size, optimizer, scheduler, gradient clipping, the 150-epoch / patience-15 early stopping, and **image-level merged `center_shift` validation for checkpoint selection** are identical across the study. Repeat the training cell with `SEED = 1`, `2`, `3` for the multi-seed ablation; `RUN_TAG` keeps the per-seed checkpoints from overwriting each other.
#
# A quick image-level metrics table on the held-out test set is printed by the last cell. For the full qualitative panels and per-image CSVs, run the matching notebook under `Source/File_Test/btxrd/Ablation/`.

# %%
# Repeat with SEED = 1, 2, 3 ... for the multi-seed ablation.
SEED = 22120196
RUN_TAG = f"seed{SEED}"

import os, glob
os.chdir(PGA_ROOT)
os.environ.update({
    "PROMPT_DATASET_ROOT": "dataset_BTXRD",
    "PROMPT_IMG_SIZE": "512",
    "PROMPT_MODE": "center_mixed",
    "PROMPT_SCALE_FACTOR": "3.0",
    "PROMPT_SHIFT_RATIO": "0.5",
    "PROMPT_MIXED_SHIFT_PROB": "0.8",
    "PROMPT_EPOCHS": "150",
    "PROMPT_SEED": str(SEED),
    "RUN_TAG": RUN_TAG,
    "PROMPT_VARIANT": "full",
    "USE_ENCODER_PROMPT": "0",
    "BINARY_PROMPT": "0",
    "USE_QUALITY_HEAD": "1",
})

# !python train.py

print(sorted(glob.glob(f"checkpoints/pga_unet_center_mixed_x3_shift05_qhead_nopsg_512_{RUN_TAG}_best.pth")))
# Out:
# ==========================================================================================
# TrainPrompt: center_mixed | Device: cuda | Variant: full | EncoderPrompt: False | BinaryPrompt: False | ImgSize: 512 | DatasetRoot: dataset_BTXRD | Seed: 22120196 | RunTag: seed22120196 | ScaleFactor: 3.0 | ShiftRatio: 0.5 | MixedShiftProb: 0.8 | QualityHead: ConfidenceLossWeight=1.0
# ==========================================================================================
# Epoch 1/150 [Train]: 100%|███████| 462/462 [02:23<00:00,  3.23it/s, loss=1.3553]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.5013 | [CENTER_] Dice:0.3873 IoU:0.2553 CBL:0.6236 | [CENTER_] Dice:0.3652 IoU:0.2374 CBL:0.5843 | LR:1.0e-04
# Epoch 2/150 [Train]: 100%|███████| 462/462 [02:28<00:00,  3.11it/s, loss=1.3271]
# 🥇 [BEST] Epoch   2 | T_Loss: 1.3542 | [CENTER_] Dice:0.4468 IoU:0.3061 CBL:0.6745 | [CENTER_] Dice:0.4496 IoU:0.3102 CBL:0.6476 | LR:1.0e-04
# Epoch 3/150 [Train]: 100%|███████| 462/462 [02:28<00:00,  3.12it/s, loss=1.2811]
# Epoch   3 | T_Loss: 1.2703 | [CENTER_] Dice:0.4786 IoU:0.3369 CBL:0.7344 | [CENTER_] Dice:0.4475 IoU:0.3103 CBL:0.6857 | LR:1.0e-04
# Epoch 4/150 [Train]: 100%|███████| 462/462 [02:28<00:00,  3.11it/s, loss=1.1417]
# Epoch   4 | T_Loss: 1.1959 | [CENTER_] Dice:0.4392 IoU:0.3019 CBL:0.7620 | [CENTER_] Dice:0.4376 IoU:0.3043 CBL:0.7327 | LR:1.0e-04
# Epoch 5/150 [Train]: 100%|███████| 462/462 [02:28<00:00,  3.11it/s, loss=1.1262]
# 🥇 [BEST] Epoch   5 | T_Loss: 1.1322 | [CENTER_] Dice:0.4709 IoU:0.3202 CBL:0.8206 | [CENTER_] Dice:0.4689 IoU:0.3197 CBL:0.7881 | LR:1.0e-04
# Epoch 6/150 [Train]: 100%|███████| 462/462 [02:27<00:00,  3.12it/s, loss=1.0849]
# 🥇 [BEST] Epoch   6 | T_Loss: 1.0689 | [CENTER_] Dice:0.4958 IoU:0.3466 CBL:0.8489 | [CENTER_] Dice:0.4908 IoU:0.3421 CBL:0.8131 | LR:1.0e-04
# Epoch 7/150 [Train]: 100%|███████| 462/462 [02:28<00:00,  3.11it/s, loss=0.9032]
# 🥇 [BEST] Epoch   7 | T_Loss: 1.0046 | [CENTER_] Dice:0.5207 IoU:0.3724 CBL:0.8248 | [CENTER_] Dice:0.5098 IoU:0.3623 CBL:0.7789 | LR:1.0e-04
# Epoch 8/150 [Train]: 100%|███████| 462/462 [02:28<00:00,  3.11it/s, loss=0.9927]
# Epoch   8 | T_Loss: 0.9460 | [CENTER_] Dice:0.4830 IoU:0.3429 CBL:0.7871 | [CENTER_] Dice:0.4736 IoU:0.3363 CBL:0.7484 | LR:1.0e-04
# Epoch 9/150 [Train]: 100%|███████| 462/462 [02:27<00:00,  3.12it/s, loss=0.8451]
# 🥇 [BEST] Epoch   9 | T_Loss: 0.9102 | [CENTER_] Dice:0.5393 IoU:0.3905 CBL:0.8232 | [CENTER_] Dice:0.5431 IoU:0.3951 CBL:0.8016 | LR:1.0e-04
# Epoch 10/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.7851]
# Epoch  10 | T_Loss: 0.8689 | [CENTER_] Dice:0.5201 IoU:0.3804 CBL:0.8274 | [CENTER_] Dice:0.5070 IoU:0.3697 CBL:0.7938 | LR:1.0e-04
# Epoch 11/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.8385]
# 🥇 [BEST] Epoch  11 | T_Loss: 0.8260 | [CENTER_] Dice:0.5906 IoU:0.4504 CBL:0.8263 | [CENTER_] Dice:0.5585 IoU:0.4194 CBL:0.7908 | LR:1.0e-04
# Epoch 12/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.12it/s, loss=1.1463]
# Epoch  12 | T_Loss: 0.7954 | [CENTER_] Dice:0.5468 IoU:0.4023 CBL:0.8425 | [CENTER_] Dice:0.5484 IoU:0.4051 CBL:0.8272 | LR:1.0e-04
# Epoch 13/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.7346]
# 🥇 [BEST] Epoch  13 | T_Loss: 0.7600 | [CENTER_] Dice:0.5897 IoU:0.4453 CBL:0.8428 | [CENTER_] Dice:0.5804 IoU:0.4375 CBL:0.8036 | LR:1.0e-04
# Epoch 14/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.5101]
# 🥇 [BEST] Epoch  14 | T_Loss: 0.7249 | [CENTER_] Dice:0.5976 IoU:0.4499 CBL:0.8562 | [CENTER_] Dice:0.5902 IoU:0.4427 CBL:0.8487 | LR:1.0e-04
# Epoch 15/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.6328]
# 🥇 [BEST] Epoch  15 | T_Loss: 0.6884 | [CENTER_] Dice:0.6301 IoU:0.4827 CBL:0.8567 | [CENTER_] Dice:0.6243 IoU:0.4783 CBL:0.8442 | LR:1.0e-04
# Epoch 16/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.4201]
# 🥇 [BEST] Epoch  16 | T_Loss: 0.6681 | [CENTER_] Dice:0.6453 IoU:0.5044 CBL:0.8621 | [CENTER_] Dice:0.6356 IoU:0.4936 CBL:0.8610 | LR:1.0e-04
# Epoch 17/150 [Train]: 100%|██████| 462/462 [02:27<00:00,  3.12it/s, loss=0.5858]
# 🥇 [BEST] Epoch  17 | T_Loss: 0.6163 | [CENTER_] Dice:0.6810 IoU:0.5388 CBL:0.8800 | [CENTER_] Dice:0.6544 IoU:0.5101 CBL:0.8581 | LR:1.0e-04
# Epoch 18/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.09it/s, loss=0.6126]
# 🥇 [BEST] Epoch  18 | T_Loss: 0.5762 | [CENTER_] Dice:0.7002 IoU:0.5587 CBL:0.8840 | [CENTER_] Dice:0.6760 IoU:0.5325 CBL:0.8635 | LR:1.0e-04
# Epoch 19/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.3670]
# Epoch  19 | T_Loss: 0.5773 | [CENTER_] Dice:0.6835 IoU:0.5492 CBL:0.8711 | [CENTER_] Dice:0.6633 IoU:0.5244 CBL:0.8674 | LR:1.0e-04
# Epoch 20/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.3674]
# Epoch  20 | T_Loss: 0.5522 | [CENTER_] Dice:0.6919 IoU:0.5620 CBL:0.8778 | [CENTER_] Dice:0.6543 IoU:0.5196 CBL:0.8519 | LR:1.0e-04
# Epoch 21/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.3209]
# 🥇 [BEST] Epoch  21 | T_Loss: 0.5231 | [CENTER_] Dice:0.7038 IoU:0.5692 CBL:0.8903 | [CENTER_] Dice:0.6906 IoU:0.5539 CBL:0.8850 | LR:1.0e-04
# Epoch 22/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.2053]
# Epoch  22 | T_Loss: 0.5411 | [CENTER_] Dice:0.6822 IoU:0.5456 CBL:0.8827 | [CENTER_] Dice:0.6636 IoU:0.5244 CBL:0.8684 | LR:1.0e-04
# Epoch 23/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.12it/s, loss=0.3052]
# 🥇 [BEST] Epoch  23 | T_Loss: 0.5168 | [CENTER_] Dice:0.7125 IoU:0.5779 CBL:0.9024 | [CENTER_] Dice:0.7075 IoU:0.5716 CBL:0.8992 | LR:1.0e-04
# Epoch 24/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.7989]
# Epoch  24 | T_Loss: 0.4952 | [CENTER_] Dice:0.7024 IoU:0.5712 CBL:0.8828 | [CENTER_] Dice:0.6810 IoU:0.5472 CBL:0.8740 | LR:1.0e-04
# Epoch 25/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.3698]
# 🥇 [BEST] Epoch  25 | T_Loss: 0.4956 | [CENTER_] Dice:0.7164 IoU:0.5825 CBL:0.8892 | [CENTER_] Dice:0.7104 IoU:0.5747 CBL:0.8837 | LR:1.0e-04
# Epoch 26/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.4182]
# Epoch  26 | T_Loss: 0.4752 | [CENTER_] Dice:0.7258 IoU:0.5940 CBL:0.8928 | [CENTER_] Dice:0.7037 IoU:0.5692 CBL:0.8793 | LR:1.0e-04
# Epoch 27/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.2651]
# 🥇 [BEST] Epoch  27 | T_Loss: 0.4880 | [CENTER_] Dice:0.7156 IoU:0.5779 CBL:0.8921 | [CENTER_] Dice:0.7238 IoU:0.5877 CBL:0.8996 | LR:1.0e-04
# Epoch 28/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.4781]
# Epoch  28 | T_Loss: 0.4697 | [CENTER_] Dice:0.7158 IoU:0.5849 CBL:0.8931 | [CENTER_] Dice:0.6895 IoU:0.5542 CBL:0.8770 | LR:1.0e-04
# Epoch 29/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.8281]
# Epoch  29 | T_Loss: 0.4568 | [CENTER_] Dice:0.7345 IoU:0.6007 CBL:0.8993 | [CENTER_] Dice:0.7209 IoU:0.5862 CBL:0.8893 | LR:1.0e-04
# Epoch 30/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.4400]
# Epoch  30 | T_Loss: 0.4617 | [CENTER_] Dice:0.7245 IoU:0.5969 CBL:0.8968 | [CENTER_] Dice:0.7091 IoU:0.5803 CBL:0.8820 | LR:1.0e-04
# Epoch 31/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.4799]
# Epoch  31 | T_Loss: 0.4437 | [CENTER_] Dice:0.7360 IoU:0.6045 CBL:0.8946 | [CENTER_] Dice:0.7225 IoU:0.5873 CBL:0.8841 | LR:1.0e-04
# Epoch 32/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.2304]
# Epoch  32 | T_Loss: 0.4344 | [CENTER_] Dice:0.7253 IoU:0.5956 CBL:0.8966 | [CENTER_] Dice:0.7190 IoU:0.5887 CBL:0.8932 | LR:1.0e-04
# Epoch 33/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.6717]
# Epoch  33 | T_Loss: 0.4593 | [CENTER_] Dice:0.7382 IoU:0.6046 CBL:0.8997 | [CENTER_] Dice:0.7172 IoU:0.5819 CBL:0.8769 | LR:5.0e-05
# Epoch 34/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.3756]
# 🥇 [BEST] Epoch  34 | T_Loss: 0.4294 | [CENTER_] Dice:0.7359 IoU:0.6067 CBL:0.8910 | [CENTER_] Dice:0.7394 IoU:0.6124 CBL:0.8935 | LR:5.0e-05
# Epoch 35/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.2917]
# Epoch  35 | T_Loss: 0.4413 | [CENTER_] Dice:0.7529 IoU:0.6294 CBL:0.9055 | [CENTER_] Dice:0.7289 IoU:0.6022 CBL:0.8857 | LR:5.0e-05
# Epoch 36/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.2702]
# 🥇 [BEST] Epoch  36 | T_Loss: 0.4030 | [CENTER_] Dice:0.7627 IoU:0.6371 CBL:0.9092 | [CENTER_] Dice:0.7450 IoU:0.6146 CBL:0.8966 | LR:5.0e-05
# Epoch 37/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.4323]
# 🥇 [BEST] Epoch  37 | T_Loss: 0.4154 | [CENTER_] Dice:0.7609 IoU:0.6361 CBL:0.9088 | [CENTER_] Dice:0.7464 IoU:0.6186 CBL:0.8966 | LR:5.0e-05
# Epoch 38/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.7797]
# 🥇 [BEST] Epoch  38 | T_Loss: 0.4089 | [CENTER_] Dice:0.7628 IoU:0.6386 CBL:0.9076 | [CENTER_] Dice:0.7478 IoU:0.6202 CBL:0.8943 | LR:5.0e-05
# Epoch 39/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.09it/s, loss=0.3369]
# Epoch  39 | T_Loss: 0.4177 | [CENTER_] Dice:0.7475 IoU:0.6231 CBL:0.8953 | [CENTER_] Dice:0.7407 IoU:0.6154 CBL:0.8957 | LR:5.0e-05
# Epoch 40/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.09it/s, loss=0.1708]
# 🥇 [BEST] Epoch  40 | T_Loss: 0.4175 | [CENTER_] Dice:0.7637 IoU:0.6387 CBL:0.9101 | [CENTER_] Dice:0.7626 IoU:0.6385 CBL:0.9104 | LR:5.0e-05
# Epoch 41/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.2460]
# Epoch  41 | T_Loss: 0.3895 | [CENTER_] Dice:0.7502 IoU:0.6290 CBL:0.9035 | [CENTER_] Dice:0.7405 IoU:0.6189 CBL:0.8960 | LR:5.0e-05
# Epoch 42/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.3746]
# Epoch  42 | T_Loss: 0.3919 | [CENTER_] Dice:0.7521 IoU:0.6298 CBL:0.9016 | [CENTER_] Dice:0.7469 IoU:0.6243 CBL:0.9036 | LR:5.0e-05
# Epoch 43/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.4228]
# Epoch  43 | T_Loss: 0.3819 | [CENTER_] Dice:0.7665 IoU:0.6449 CBL:0.9098 | [CENTER_] Dice:0.7533 IoU:0.6307 CBL:0.8970 | LR:5.0e-05
# Epoch 44/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.3016]
# Epoch  44 | T_Loss: 0.3921 | [CENTER_] Dice:0.7627 IoU:0.6400 CBL:0.9148 | [CENTER_] Dice:0.7496 IoU:0.6245 CBL:0.9023 | LR:5.0e-05
# Epoch 45/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.1572]
# Epoch  45 | T_Loss: 0.3844 | [CENTER_] Dice:0.7582 IoU:0.6356 CBL:0.9057 | [CENTER_] Dice:0.7537 IoU:0.6275 CBL:0.9041 | LR:5.0e-05
# Epoch 46/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.2137]
# Epoch  46 | T_Loss: 0.3798 | [CENTER_] Dice:0.7550 IoU:0.6312 CBL:0.9015 | [CENTER_] Dice:0.7562 IoU:0.6328 CBL:0.9053 | LR:2.5e-05
# Epoch 47/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.3406]
# Epoch  47 | T_Loss: 0.3700 | [CENTER_] Dice:0.7658 IoU:0.6464 CBL:0.9018 | [CENTER_] Dice:0.7622 IoU:0.6406 CBL:0.9060 | LR:2.5e-05
# Epoch 48/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.8778]
# 🥇 [BEST] Epoch  48 | T_Loss: 0.3511 | [CENTER_] Dice:0.7764 IoU:0.6561 CBL:0.9089 | [CENTER_] Dice:0.7683 IoU:0.6452 CBL:0.9105 | LR:2.5e-05
# Epoch 49/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.1297]
# Epoch  49 | T_Loss: 0.3624 | [CENTER_] Dice:0.7501 IoU:0.6306 CBL:0.8986 | [CENTER_] Dice:0.7358 IoU:0.6135 CBL:0.8931 | LR:2.5e-05
# Epoch 50/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.2853]
# Epoch  50 | T_Loss: 0.3723 | [CENTER_] Dice:0.7631 IoU:0.6438 CBL:0.9097 | [CENTER_] Dice:0.7586 IoU:0.6367 CBL:0.9076 | LR:2.5e-05
# Epoch 51/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.1910]
# Epoch  51 | T_Loss: 0.3596 | [CENTER_] Dice:0.7659 IoU:0.6455 CBL:0.8997 | [CENTER_] Dice:0.7618 IoU:0.6408 CBL:0.8994 | LR:2.5e-05
# Epoch 52/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.3453]
# Epoch  52 | T_Loss: 0.3649 | [CENTER_] Dice:0.7735 IoU:0.6539 CBL:0.9069 | [CENTER_] Dice:0.7638 IoU:0.6424 CBL:0.9002 | LR:2.5e-05
# Epoch 53/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.3831]
# Epoch  53 | T_Loss: 0.3671 | [CENTER_] Dice:0.7578 IoU:0.6403 CBL:0.9008 | [CENTER_] Dice:0.7460 IoU:0.6245 CBL:0.8940 | LR:2.5e-05
# Epoch 54/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.09it/s, loss=0.2877]
# Epoch  54 | T_Loss: 0.3501 | [CENTER_] Dice:0.7663 IoU:0.6460 CBL:0.9056 | [CENTER_] Dice:0.7644 IoU:0.6422 CBL:0.9049 | LR:1.3e-05
# Epoch 55/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.09it/s, loss=0.5250]
# Epoch  55 | T_Loss: 0.3654 | [CENTER_] Dice:0.7692 IoU:0.6513 CBL:0.9046 | [CENTER_] Dice:0.7608 IoU:0.6400 CBL:0.9038 | LR:1.3e-05
# Epoch 56/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.1416]
# Epoch  56 | T_Loss: 0.3484 | [CENTER_] Dice:0.7697 IoU:0.6511 CBL:0.9017 | [CENTER_] Dice:0.7636 IoU:0.6434 CBL:0.8977 | LR:1.3e-05
# Epoch 57/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.3569]
# Epoch  57 | T_Loss: 0.3449 | [CENTER_] Dice:0.7690 IoU:0.6507 CBL:0.9043 | [CENTER_] Dice:0.7628 IoU:0.6430 CBL:0.9032 | LR:1.3e-05
# Epoch 58/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.7933]
# 🥇 [BEST] Epoch  58 | T_Loss: 0.3486 | [CENTER_] Dice:0.7743 IoU:0.6564 CBL:0.9074 | [CENTER_] Dice:0.7696 IoU:0.6480 CBL:0.9091 | LR:1.3e-05
# Epoch 59/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.2146]
# Epoch  59 | T_Loss: 0.3497 | [CENTER_] Dice:0.7714 IoU:0.6522 CBL:0.9106 | [CENTER_] Dice:0.7640 IoU:0.6420 CBL:0.9082 | LR:1.3e-05
# Epoch 60/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.3003]
# Epoch  60 | T_Loss: 0.3605 | [CENTER_] Dice:0.7677 IoU:0.6491 CBL:0.9115 | [CENTER_] Dice:0.7630 IoU:0.6416 CBL:0.9046 | LR:1.3e-05
# Epoch 61/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.1764]
# Epoch  61 | T_Loss: 0.3241 | [CENTER_] Dice:0.7755 IoU:0.6575 CBL:0.9113 | [CENTER_] Dice:0.7675 IoU:0.6467 CBL:0.9063 | LR:1.3e-05
# Epoch 62/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.2154]
# Epoch  62 | T_Loss: 0.3356 | [CENTER_] Dice:0.7602 IoU:0.6417 CBL:0.9019 | [CENTER_] Dice:0.7500 IoU:0.6295 CBL:0.9021 | LR:1.3e-05
# Epoch 63/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.09it/s, loss=0.2526]
# Epoch  63 | T_Loss: 0.3422 | [CENTER_] Dice:0.7756 IoU:0.6573 CBL:0.9070 | [CENTER_] Dice:0.7689 IoU:0.6492 CBL:0.9017 | LR:1.3e-05
# Epoch 64/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.1977]
# Epoch  64 | T_Loss: 0.3472 | [CENTER_] Dice:0.7692 IoU:0.6513 CBL:0.9042 | [CENTER_] Dice:0.7644 IoU:0.6450 CBL:0.9062 | LR:6.3e-06
# Epoch 65/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.1588]
# Epoch  65 | T_Loss: 0.3260 | [CENTER_] Dice:0.7636 IoU:0.6460 CBL:0.9028 | [CENTER_] Dice:0.7599 IoU:0.6407 CBL:0.9023 | LR:6.3e-06
# Epoch 66/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.2800]
# Epoch  66 | T_Loss: 0.3435 | [CENTER_] Dice:0.7673 IoU:0.6496 CBL:0.9037 | [CENTER_] Dice:0.7610 IoU:0.6406 CBL:0.9055 | LR:6.3e-06
# Epoch 67/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.3771]
# Epoch  67 | T_Loss: 0.3316 | [CENTER_] Dice:0.7720 IoU:0.6536 CBL:0.9046 | [CENTER_] Dice:0.7668 IoU:0.6475 CBL:0.9020 | LR:6.3e-06
# Epoch 68/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.1424]
# Epoch  68 | T_Loss: 0.3204 | [CENTER_] Dice:0.7739 IoU:0.6569 CBL:0.9070 | [CENTER_] Dice:0.7682 IoU:0.6491 CBL:0.9020 | LR:6.3e-06
# Epoch 69/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.5127]
# 🥇 [BEST] Epoch  69 | T_Loss: 0.3171 | [CENTER_] Dice:0.7764 IoU:0.6582 CBL:0.9064 | [CENTER_] Dice:0.7740 IoU:0.6549 CBL:0.9025 | LR:6.3e-06
# Epoch 70/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.2567]
# Epoch  70 | T_Loss: 0.3311 | [CENTER_] Dice:0.7745 IoU:0.6579 CBL:0.9050 | [CENTER_] Dice:0.7675 IoU:0.6481 CBL:0.9030 | LR:6.3e-06
# Epoch 71/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.2588]
# Epoch  71 | T_Loss: 0.3268 | [CENTER_] Dice:0.7698 IoU:0.6532 CBL:0.9069 | [CENTER_] Dice:0.7641 IoU:0.6445 CBL:0.9020 | LR:6.3e-06
# Epoch 72/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.2538]
# Epoch  72 | T_Loss: 0.3209 | [CENTER_] Dice:0.7708 IoU:0.6528 CBL:0.9083 | [CENTER_] Dice:0.7635 IoU:0.6436 CBL:0.9051 | LR:6.3e-06
# Epoch 73/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.4753]
# Epoch  73 | T_Loss: 0.3493 | [CENTER_] Dice:0.7703 IoU:0.6522 CBL:0.9081 | [CENTER_] Dice:0.7629 IoU:0.6427 CBL:0.9050 | LR:6.3e-06
# Epoch 74/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.2406]
# Epoch  74 | T_Loss: 0.3462 | [CENTER_] Dice:0.7751 IoU:0.6584 CBL:0.9110 | [CENTER_] Dice:0.7688 IoU:0.6492 CBL:0.9070 | LR:6.3e-06
# Epoch 75/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.09it/s, loss=0.1414]
# Epoch  75 | T_Loss: 0.3357 | [CENTER_] Dice:0.7700 IoU:0.6524 CBL:0.9028 | [CENTER_] Dice:0.7646 IoU:0.6451 CBL:0.9001 | LR:3.1e-06
# Epoch 76/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.1782]
# Epoch  76 | T_Loss: 0.3439 | [CENTER_] Dice:0.7705 IoU:0.6534 CBL:0.9046 | [CENTER_] Dice:0.7645 IoU:0.6453 CBL:0.9030 | LR:3.1e-06
# Epoch 77/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.09it/s, loss=0.2914]
# Epoch  77 | T_Loss: 0.3252 | [CENTER_] Dice:0.7726 IoU:0.6558 CBL:0.9059 | [CENTER_] Dice:0.7643 IoU:0.6454 CBL:0.9018 | LR:3.1e-06
# Epoch 78/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.09it/s, loss=0.1176]
# Epoch  78 | T_Loss: 0.3408 | [CENTER_] Dice:0.7736 IoU:0.6580 CBL:0.9017 | [CENTER_] Dice:0.7670 IoU:0.6494 CBL:0.8985 | LR:3.1e-06
# Epoch 79/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.09it/s, loss=0.2495]
# Epoch  79 | T_Loss: 0.3091 | [CENTER_] Dice:0.7724 IoU:0.6557 CBL:0.9049 | [CENTER_] Dice:0.7659 IoU:0.6477 CBL:0.9033 | LR:3.1e-06
# Epoch 80/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.2256]
# Epoch  80 | T_Loss: 0.3196 | [CENTER_] Dice:0.7747 IoU:0.6583 CBL:0.9056 | [CENTER_] Dice:0.7688 IoU:0.6502 CBL:0.9079 | LR:3.1e-06
# Epoch 81/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.7063]
# Epoch  81 | T_Loss: 0.3196 | [CENTER_] Dice:0.7761 IoU:0.6594 CBL:0.9101 | [CENTER_] Dice:0.7705 IoU:0.6513 CBL:0.9075 | LR:1.6e-06
# Epoch 82/150 [Train]: 100%|██████| 462/462 [02:29<00:00,  3.10it/s, loss=0.1533]
# Epoch  82 | T_Loss: 0.3190 | [CENTER_] Dice:0.7756 IoU:0.6590 CBL:0.9057 | [CENTER_] Dice:0.7663 IoU:0.6476 CBL:0.9027 | LR:1.6e-06
# Epoch 83/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.10it/s, loss=0.3916]
# Epoch  83 | T_Loss: 0.3259 | [CENTER_] Dice:0.7743 IoU:0.6568 CBL:0.9043 | [CENTER_] Dice:0.7681 IoU:0.6495 CBL:0.9029 | LR:1.6e-06
# Epoch 84/150 [Train]: 100%|██████| 462/462 [02:28<00:00,  3.11it/s, loss=0.2963]
# Epoch  84 | T_Loss: 0.3275 | [CENTER_] Dice:0.7711 IoU:0.6545 CBL:0.9000 | [CENTER_] Dice:0.7637 IoU:0.6457 CBL:0.8977 | LR:1.6e-06
# Early stopping at epoch 84.
#
# Best Dice (center_shift): 0.7740
# Checkpoint: checkpoints/pga_unet_center_mixed_x3_shift05_qhead_nopsg_512_seed22120196_best.pth
# ['checkpoints/pga_unet_center_mixed_x3_shift05_qhead_nopsg_512_seed22120196_best.pth']

# %%
# -- Quick test on the held-out set: image-level merged, 2 prompt scenarios --
# Loads the checkpoint train.py just wrote in this session (no Drive download).
# Full qualitative panels + per-image CSVs live in Source/File_Test/*/Ablation/.
import os, sys, csv
import numpy as np, torch
from collections import OrderedDict
from torch.utils.data import DataLoader
from tqdm import tqdm
from scipy.ndimage import binary_erosion, distance_transform_edt

os.chdir(PGA_ROOT)
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)
from dataset import PromptSegmentationDataset

IMG_SIZE, SCALE_FACTOR, SHIFT_RATIO = 512, 3.0, 0.5
DEVICE  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DS_ROOT = f"{PGA_ROOT}/dataset_BTXRD"
CKPT    = f"checkpoints/pga_unet_center_mixed_x3_shift05_qhead_nopsg_512_{RUN_TAG}_best.pth"

VARIANT, ENC, QH, BINP = "full", 0, 1, 0
if VARIANT == "psg_only":
    from models.networks.prompt_unet_psg_only import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
elif VARIANT == "psg_attention":
    from models.networks.prompt_unet_psg_attention import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
else:
    from models.networks.prompt_unet_2D import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1,
                     use_encoder_prompt=bool(ENC), use_quality_head=bool(QH))
model.load_state_dict(torch.load(CKPT, map_location=DEVICE, weights_only=True))
model.to(DEVICE).eval()
print("loaded", CKPT)


def _hd95(p, g):
    p, g = p.astype(bool), g.astype(bool)
    if not p.any() and not g.any(): return 0.0
    if not p.any() or not g.any():  return float(IMG_SIZE)
    pe, ge = p ^ binary_erosion(p), g ^ binary_erosion(g)
    d1, d2 = distance_transform_edt(~ge)[pe], distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2): return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))


def _metrics(prob, gt):
    pm, gm, eps = (prob > 0.5), (gt > 0.5), 1e-6
    tp, fp, fn = float((pm & gm).sum()), float((pm & ~gm).sum()), float((~pm & gm).sum())
    cbl = 0.0
    if gm.any() and pm.any():
        ys, xs = np.where(gm); yp, xp = np.where(pm)
        diag = np.hypot(ys.max() - ys.min(), xs.max() - xs.min()) + eps
        cbl = float(np.clip(1 - np.hypot(xp.mean() - xs.mean(), yp.mean() - ys.mean()) / diag, 0, 1))
    return dict(dice=(2*tp+eps)/(2*tp+fp+fn+eps), iou=(tp+eps)/(tp+fp+fn+eps),
                pre=tp/(tp+fp+eps), rec=(tp+eps)/(tp+fn+eps), hd95=_hd95(pm, gm), cbl=cbl)


os.makedirs("results", exist_ok=True)
per_image, rows = [], []
for mode in ("center_zoom", "center_shift"):
    ds = PromptSegmentationDataset(f"{DS_ROOT}/test/images", f"{DS_ROOT}/test/annotations",
                                   img_size=IMG_SIZE, is_train=False, prompt_mode=mode,
                                   scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO,
                                   binary_prompt=bool(BINP))
    groups = OrderedDict()
    with torch.no_grad():
        for i, (img, msk, prm) in enumerate(tqdm(DataLoader(ds, batch_size=1, num_workers=2), desc=mode)):
            prob = torch.sigmoid(model(img.to(DEVICE), prm.to(DEVICE)))[0, 0].cpu().numpy()
            gt   = msk[0, 0].numpy()
            name = ds.all_samples[i][0]
            if name not in groups:
                groups[name] = [prob.copy(), gt.copy()]
            else:
                np.maximum(groups[name][0], prob, out=groups[name][0])
                np.maximum(groups[name][1], gt,   out=groups[name][1])
    recs = []
    for name, (p, g) in groups.items():
        m = _metrics(p, g); recs.append(m)
        per_image.append([mode, name] + [m[k] for k in ("dice", "iou", "pre", "rec", "hd95", "cbl")])
    avg = {k: float(np.mean([r[k] for r in recs])) for k in recs[0]}
    rows.append((mode, len(recs), avg))

print(f"\n{'scenario':<14}{'N':>5}{'Dice':>9}{'IoU':>9}{'Prec':>9}{'Rec':>9}{'HD95':>9}{'CBL':>9}")
for mode, n, a in rows:
    print(f"{mode:<14}{n:>5}{a['dice']:>9.4f}{a['iou']:>9.4f}{a['pre']:>9.4f}{a['rec']:>9.4f}{a['hd95']:>9.2f}{a['cbl']:>9.4f}")

csv_path = f"results/ablation_qhead_nopsg_{RUN_TAG}_per_image.csv"
with open(csv_path, "w", newline="") as fh:
    w = csv.writer(fh); w.writerow(["scenario", "img_name", "dice", "iou", "pre", "rec", "hd95", "cbl"])
    w.writerows(per_image)
print("saved", csv_path)
# Out:
# loaded checkpoints/pga_unet_center_mixed_x3_shift05_qhead_nopsg_512_seed22120196_best.pth
# center_zoom: 100%|██████████| 232/232 [00:08<00:00, 26.05it/s]
# center_shift: 100%|██████████| 232/232 [00:08<00:00, 27.65it/s]
# scenario          N     Dice      IoU     Prec      Rec     HD95      CBL
# center_zoom     187   0.7713   0.6487   0.7611   0.8166    23.09   0.9146
# center_shift    187   0.7588   0.6354   0.7618   0.8019    24.24   0.9054
# saved results/ablation_qhead_nopsg_seed22120196_per_image.csv
