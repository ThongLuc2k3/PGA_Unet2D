# %% [markdown]
# # Ablation - PSG only (no CAD)
# PromptSpatialGate in the encoder, with a plain skip decoder without prompt-conditioned attention (PromptAttention not used).

# %%
import os, sys, shutil
import gdown

BASE = '/kaggle/working' if os.path.exists('/kaggle/working') else '/content'
os.chdir(BASE)

REPO = 'https://github.com/ThongLuc2k3/PGA_Unet2D.git'
REPO_ROOT = f'{BASE}/PGA_Unet2D'
PGA_ROOT = f'{REPO_ROOT}/Source/Prompt-Guided-XRay-Segmentation'
DATASET_NAME = 'dataset_BTXRD'
DATASET_ID = '1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx'
DS_ZIP = f'{BASE}/{DATASET_NAME}.zip'
DS_PATH = f'{PGA_ROOT}/{DATASET_NAME}'

if os.path.exists(REPO_ROOT):
    shutil.rmtree(REPO_ROOT)
# !git clone -q --branch main --single-branch {REPO} {REPO_ROOT}
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)

if not os.path.exists(DS_ZIP):
    gdown.download(f'https://drive.google.com/uc?id={DATASET_ID}', DS_ZIP, quiet=False)
if os.path.exists(DS_PATH):
    shutil.rmtree(DS_PATH)
# !unzip -oq {DS_ZIP} -d {PGA_ROOT}/

os.makedirs(f'{PGA_ROOT}/checkpoints', exist_ok=True)
os.chdir(PGA_ROOT)
# !pip install -q tqdm opencv-python timm scipy gdown
print(f'✅ Setup completed | base={BASE} | dataset={DATASET_NAME}')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx
# From (redirected): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx&confirm=t&uuid=aa649209-5933-4a18-aaa5-b96884993efc
# To: /kaggle/working/dataset_BTXRD.zip
# 100%|██████████| 1.71G/1.71G [00:21<00:00, 77.9MB/s]
# ✅ Setup completed | base=/kaggle/working | dataset=dataset_BTXRD

# %% [markdown]
# ## Ablation training via the shared `train.py`
#
# **Configuration: PSG only (no CAD).** PSG encoder gate only, plain decoder, no CAD. The `psg_only` network class has no QualityHead branch, so `USE_QUALITY_HEAD=0`.
#
# Every ablation configuration is trained through the same `train.py` as the full PGA-UNet, so batch size, optimizer, scheduler, gradient clipping, the 150-epoch / patience-15 early stopping, and **image-level merged `center_shift` validation for checkpoint selection** are identical across the study. Repeat the training cell with `SEED = 1`, `2`, `3` for the multi-seed ablation; `RUN_TAG` keeps the per-seed checkpoints from overwriting each other.
#
# A quick image-level metrics table on the held-out test set is printed by the last cell. For the full qualitative panels and per-image CSVs, run the matching notebook under `Source/File_Test/btxrd/Ablation/`.

# %%
# Repeat with SEED = 1, 2, 3 ... for the multi-seed ablation.
SEED = 22120196
RUN_TAG = f"seed{SEED}"

import os, glob
os.chdir(PGA_ROOT)
os.environ.update({
    "PROMPT_DATASET_ROOT": "dataset_BTXRD",
    "PROMPT_IMG_SIZE": "512",
    "PROMPT_MODE": "center_mixed",
    "PROMPT_SCALE_FACTOR": "3.0",
    "PROMPT_SHIFT_RATIO": "0.5",
    "PROMPT_MIXED_SHIFT_PROB": "0.8",
    "PROMPT_EPOCHS": "150",
    "PROMPT_SEED": str(SEED),
    "RUN_TAG": RUN_TAG,
    "PROMPT_VARIANT": "psg_only",
    "USE_ENCODER_PROMPT": "1",
    "BINARY_PROMPT": "0",
    "USE_QUALITY_HEAD": "0",
})

# !python train.py

print(sorted(glob.glob(f"checkpoints/pga_unet_center_mixed_x3_shift05_psg_only_512_{RUN_TAG}_best.pth")))
# Out:
# ==========================================================================================
# TrainPrompt: center_mixed | Device: cuda | Variant: psg_only | EncoderPrompt: True | BinaryPrompt: False | ImgSize: 512 | DatasetRoot: dataset_BTXRD | Seed: 22120196 | RunTag: seed22120196 | ScaleFactor: 3.0 | ShiftRatio: 0.5 | MixedShiftProb: 0.8
# ==========================================================================================
# Epoch 1/150 [Train]: 100%|███████| 462/462 [01:34<00:00,  4.88it/s, loss=1.2785]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.3773 | [CENTER_] Dice:0.0001 IoU:0.0000 CBL:0.0727 | [CENTER_] Dice:0.0001 IoU:0.0000 CBL:0.0727 | LR:1.0e-04
# Epoch 2/150 [Train]: 100%|███████| 462/462 [01:36<00:00,  4.77it/s, loss=1.2429]
# Epoch   2 | T_Loss: 1.2658 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0000 | [CENTER_] Dice:0.0000 IoU:0.0000 CBL:0.0000 | LR:1.0e-04
# Epoch 3/150 [Train]: 100%|███████| 462/462 [01:37<00:00,  4.76it/s, loss=1.1739]
# 🥇 [BEST] Epoch   3 | T_Loss: 1.1901 | [CENTER_] Dice:0.1970 IoU:0.1364 CBL:0.3319 | [CENTER_] Dice:0.2026 IoU:0.1418 CBL:0.3340 | LR:1.0e-04
# Epoch 4/150 [Train]: 100%|███████| 462/462 [01:36<00:00,  4.78it/s, loss=1.0622]
# Epoch   4 | T_Loss: 1.1310 | [CENTER_] Dice:0.1311 IoU:0.0893 CBL:0.2653 | [CENTER_] Dice:0.1292 IoU:0.0876 CBL:0.2564 | LR:1.0e-04
# Epoch 5/150 [Train]: 100%|███████| 462/462 [01:36<00:00,  4.76it/s, loss=1.0500]
# Epoch   5 | T_Loss: 1.0866 | [CENTER_] Dice:0.1594 IoU:0.1004 CBL:0.3179 | [CENTER_] Dice:0.1602 IoU:0.1013 CBL:0.3116 | LR:1.0e-04
# Epoch 6/150 [Train]: 100%|███████| 462/462 [01:36<00:00,  4.77it/s, loss=0.9544]
# Epoch   6 | T_Loss: 1.0416 | [CENTER_] Dice:0.1541 IoU:0.0937 CBL:0.3056 | [CENTER_] Dice:0.1547 IoU:0.0946 CBL:0.3048 | LR:1.0e-04
# Epoch 7/150 [Train]: 100%|███████| 462/462 [01:36<00:00,  4.79it/s, loss=0.9827]
# 🥇 [BEST] Epoch   7 | T_Loss: 1.0075 | [CENTER_] Dice:0.3707 IoU:0.2600 CBL:0.6230 | [CENTER_] Dice:0.3679 IoU:0.2576 CBL:0.6223 | LR:1.0e-04
# Epoch 8/150 [Train]: 100%|███████| 462/462 [01:36<00:00,  4.77it/s, loss=0.9644]
# Epoch   8 | T_Loss: 0.9660 | [CENTER_] Dice:0.3651 IoU:0.2368 CBL:0.7029 | [CENTER_] Dice:0.3634 IoU:0.2373 CBL:0.6779 | LR:1.0e-04
# Epoch 9/150 [Train]: 100%|███████| 462/462 [01:36<00:00,  4.77it/s, loss=1.0323]
# 🥇 [BEST] Epoch   9 | T_Loss: 0.9272 | [CENTER_] Dice:0.4289 IoU:0.3007 CBL:0.7159 | [CENTER_] Dice:0.4226 IoU:0.2955 CBL:0.6787 | LR:1.0e-04
# Epoch 10/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.8485]
# 🥇 [BEST] Epoch  10 | T_Loss: 0.8905 | [CENTER_] Dice:0.4412 IoU:0.3080 CBL:0.7431 | [CENTER_] Dice:0.4478 IoU:0.3153 CBL:0.7511 | LR:1.0e-04
# Epoch 11/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.7780]
# 🥇 [BEST] Epoch  11 | T_Loss: 0.8603 | [CENTER_] Dice:0.4525 IoU:0.3162 CBL:0.7347 | [CENTER_] Dice:0.4525 IoU:0.3165 CBL:0.7113 | LR:1.0e-04
# Epoch 12/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.78it/s, loss=0.6494]
# 🥇 [BEST] Epoch  12 | T_Loss: 0.8230 | [CENTER_] Dice:0.5131 IoU:0.3727 CBL:0.7893 | [CENTER_] Dice:0.5136 IoU:0.3759 CBL:0.7764 | LR:1.0e-04
# Epoch 13/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.8062]
# Epoch  13 | T_Loss: 0.7894 | [CENTER_] Dice:0.4887 IoU:0.3465 CBL:0.8111 | [CENTER_] Dice:0.4716 IoU:0.3344 CBL:0.7712 | LR:1.0e-04
# Epoch 14/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.5925]
# 🥇 [BEST] Epoch  14 | T_Loss: 0.7408 | [CENTER_] Dice:0.5221 IoU:0.3842 CBL:0.7550 | [CENTER_] Dice:0.5258 IoU:0.3882 CBL:0.7642 | LR:1.0e-04
# Epoch 15/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=1.0674]
# 🥇 [BEST] Epoch  15 | T_Loss: 0.7111 | [CENTER_] Dice:0.5472 IoU:0.4075 CBL:0.7842 | [CENTER_] Dice:0.5315 IoU:0.3940 CBL:0.7535 | LR:1.0e-04
# Epoch 16/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.76it/s, loss=0.4434]
# Epoch  16 | T_Loss: 0.6957 | [CENTER_] Dice:0.5280 IoU:0.3816 CBL:0.7963 | [CENTER_] Dice:0.5251 IoU:0.3800 CBL:0.7833 | LR:1.0e-04
# Epoch 17/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.78it/s, loss=0.6526]
# 🥇 [BEST] Epoch  17 | T_Loss: 0.6541 | [CENTER_] Dice:0.5588 IoU:0.4158 CBL:0.8132 | [CENTER_] Dice:0.5437 IoU:0.4002 CBL:0.8065 | LR:1.0e-04
# Epoch 18/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.76it/s, loss=0.2978]
# 🥇 [BEST] Epoch  18 | T_Loss: 0.6112 | [CENTER_] Dice:0.6169 IoU:0.4754 CBL:0.8291 | [CENTER_] Dice:0.5865 IoU:0.4473 CBL:0.8036 | LR:1.0e-04
# Epoch 19/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.9023]
# 🥇 [BEST] Epoch  19 | T_Loss: 0.5952 | [CENTER_] Dice:0.6245 IoU:0.4777 CBL:0.8389 | [CENTER_] Dice:0.6124 IoU:0.4655 CBL:0.8256 | LR:1.0e-04
# Epoch 20/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.76it/s, loss=0.6022]
# Epoch  20 | T_Loss: 0.5729 | [CENTER_] Dice:0.6074 IoU:0.4674 CBL:0.8187 | [CENTER_] Dice:0.6020 IoU:0.4626 CBL:0.8097 | LR:1.0e-04
# Epoch 21/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.4878]
# 🥇 [BEST] Epoch  21 | T_Loss: 0.5424 | [CENTER_] Dice:0.6743 IoU:0.5380 CBL:0.8636 | [CENTER_] Dice:0.6588 IoU:0.5230 CBL:0.8537 | LR:1.0e-04
# Epoch 22/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.4385]
# Epoch  22 | T_Loss: 0.5310 | [CENTER_] Dice:0.5068 IoU:0.3688 CBL:0.6636 | [CENTER_] Dice:0.5132 IoU:0.3758 CBL:0.6514 | LR:1.0e-04
# Epoch 23/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.78it/s, loss=1.0039]
# Epoch  23 | T_Loss: 0.5049 | [CENTER_] Dice:0.6699 IoU:0.5290 CBL:0.8541 | [CENTER_] Dice:0.6555 IoU:0.5129 CBL:0.8309 | LR:1.0e-04
# Epoch 24/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.4483]
# Epoch  24 | T_Loss: 0.4969 | [CENTER_] Dice:0.6719 IoU:0.5396 CBL:0.8471 | [CENTER_] Dice:0.6135 IoU:0.4772 CBL:0.8092 | LR:1.0e-04
# Epoch 25/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.78it/s, loss=0.4548]
# 🥇 [BEST] Epoch  25 | T_Loss: 0.4926 | [CENTER_] Dice:0.6776 IoU:0.5438 CBL:0.8608 | [CENTER_] Dice:0.6698 IoU:0.5360 CBL:0.8647 | LR:1.0e-04
# Epoch 26/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.76it/s, loss=0.5507]
# 🥇 [BEST] Epoch  26 | T_Loss: 0.4712 | [CENTER_] Dice:0.6690 IoU:0.5325 CBL:0.8388 | [CENTER_] Dice:0.6730 IoU:0.5362 CBL:0.8400 | LR:1.0e-04
# Epoch 27/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.2620]
# 🥇 [BEST] Epoch  27 | T_Loss: 0.4608 | [CENTER_] Dice:0.6803 IoU:0.5453 CBL:0.8570 | [CENTER_] Dice:0.6842 IoU:0.5479 CBL:0.8500 | LR:1.0e-04
# Epoch 28/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.5137]
# Epoch  28 | T_Loss: 0.4677 | [CENTER_] Dice:0.6586 IoU:0.5171 CBL:0.8198 | [CENTER_] Dice:0.6619 IoU:0.5214 CBL:0.8226 | LR:1.0e-04
# Epoch 29/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.4424]
# Epoch  29 | T_Loss: 0.4403 | [CENTER_] Dice:0.6791 IoU:0.5374 CBL:0.8454 | [CENTER_] Dice:0.6771 IoU:0.5356 CBL:0.8417 | LR:1.0e-04
# Epoch 30/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.6336]
# Epoch  30 | T_Loss: 0.4431 | [CENTER_] Dice:0.6909 IoU:0.5504 CBL:0.8625 | [CENTER_] Dice:0.6733 IoU:0.5323 CBL:0.8508 | LR:1.0e-04
# Epoch 31/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.4659]
# Epoch  31 | T_Loss: 0.4498 | [CENTER_] Dice:0.6957 IoU:0.5638 CBL:0.8604 | [CENTER_] Dice:0.6780 IoU:0.5438 CBL:0.8503 | LR:1.0e-04
# Epoch 32/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.4665]
# 🥇 [BEST] Epoch  32 | T_Loss: 0.4324 | [CENTER_] Dice:0.7043 IoU:0.5707 CBL:0.8712 | [CENTER_] Dice:0.7038 IoU:0.5710 CBL:0.8638 | LR:1.0e-04
# Epoch 33/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.3665]
# Epoch  33 | T_Loss: 0.4078 | [CENTER_] Dice:0.6723 IoU:0.5291 CBL:0.8434 | [CENTER_] Dice:0.6621 IoU:0.5196 CBL:0.8374 | LR:1.0e-04
# Epoch 34/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.76it/s, loss=0.3438]
# 🥇 [BEST] Epoch  34 | T_Loss: 0.4223 | [CENTER_] Dice:0.6912 IoU:0.5551 CBL:0.8567 | [CENTER_] Dice:0.7051 IoU:0.5698 CBL:0.8561 | LR:1.0e-04
# Epoch 35/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.2959]
# 🥇 [BEST] Epoch  35 | T_Loss: 0.4159 | [CENTER_] Dice:0.7247 IoU:0.5909 CBL:0.8783 | [CENTER_] Dice:0.7263 IoU:0.5924 CBL:0.8738 | LR:1.0e-04
# Epoch 36/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.3911]
# Epoch  36 | T_Loss: 0.4102 | [CENTER_] Dice:0.7366 IoU:0.6069 CBL:0.8832 | [CENTER_] Dice:0.7117 IoU:0.5776 CBL:0.8662 | LR:1.0e-04
# Epoch 37/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.4508]
# Epoch  37 | T_Loss: 0.4014 | [CENTER_] Dice:0.7108 IoU:0.5808 CBL:0.8657 | [CENTER_] Dice:0.7064 IoU:0.5744 CBL:0.8600 | LR:1.0e-04
# Epoch 38/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.76it/s, loss=0.4640]
# Epoch  38 | T_Loss: 0.3986 | [CENTER_] Dice:0.7149 IoU:0.5817 CBL:0.8790 | [CENTER_] Dice:0.6988 IoU:0.5636 CBL:0.8650 | LR:1.0e-04
# Epoch 39/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.3653]
# Epoch  39 | T_Loss: 0.3951 | [CENTER_] Dice:0.7085 IoU:0.5820 CBL:0.8777 | [CENTER_] Dice:0.6974 IoU:0.5706 CBL:0.8732 | LR:1.0e-04
# Epoch 40/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.1979]
# 🥇 [BEST] Epoch  40 | T_Loss: 0.4051 | [CENTER_] Dice:0.7211 IoU:0.5909 CBL:0.8741 | [CENTER_] Dice:0.7298 IoU:0.5982 CBL:0.8825 | LR:1.0e-04
# Epoch 41/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.2103]
# Epoch  41 | T_Loss: 0.3792 | [CENTER_] Dice:0.7393 IoU:0.6107 CBL:0.8869 | [CENTER_] Dice:0.7265 IoU:0.5969 CBL:0.8702 | LR:1.0e-04
# Epoch 42/150 [Train]: 100%|██████| 462/462 [01:36<00:00,  4.77it/s, loss=0.2239]
# Epoch  42 | T_Loss: 0.3743 | [CENTER_] Dice:0.7154 IoU:0.5927 CBL:0.8740 | [CENTER_] Dice:0.7038 IoU:0.5783 CBL:0.8564 | LR:1.0e-04
# Epoch 43/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.76it/s, loss=0.3700]
# Epoch  43 | T_Loss: 0.3607 | [CENTER_] Dice:0.7181 IoU:0.5866 CBL:0.8723 | [CENTER_] Dice:0.7284 IoU:0.5985 CBL:0.8795 | LR:1.0e-04
# Epoch 44/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.3474]
# 🥇 [BEST] Epoch  44 | T_Loss: 0.3768 | [CENTER_] Dice:0.7588 IoU:0.6353 CBL:0.8981 | [CENTER_] Dice:0.7545 IoU:0.6306 CBL:0.8928 | LR:1.0e-04
# Epoch 45/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.2862]
# Epoch  45 | T_Loss: 0.3805 | [CENTER_] Dice:0.7427 IoU:0.6198 CBL:0.8829 | [CENTER_] Dice:0.7398 IoU:0.6171 CBL:0.8843 | LR:1.0e-04
# Epoch 46/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.4447]
# Epoch  46 | T_Loss: 0.3787 | [CENTER_] Dice:0.7322 IoU:0.6070 CBL:0.8789 | [CENTER_] Dice:0.7220 IoU:0.5949 CBL:0.8715 | LR:1.0e-04
# Epoch 47/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.1863]
# Epoch  47 | T_Loss: 0.3614 | [CENTER_] Dice:0.7314 IoU:0.6057 CBL:0.8815 | [CENTER_] Dice:0.7413 IoU:0.6160 CBL:0.8862 | LR:1.0e-04
# Epoch 48/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.1485]
# Epoch  48 | T_Loss: 0.3678 | [CENTER_] Dice:0.7218 IoU:0.5912 CBL:0.8694 | [CENTER_] Dice:0.7380 IoU:0.6106 CBL:0.8774 | LR:1.0e-04
# Epoch 49/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.2920]
# 🥇 [BEST] Epoch  49 | T_Loss: 0.3793 | [CENTER_] Dice:0.7522 IoU:0.6277 CBL:0.8933 | [CENTER_] Dice:0.7690 IoU:0.6464 CBL:0.9030 | LR:1.0e-04
# Epoch 50/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.3141]
# Epoch  50 | T_Loss: 0.3618 | [CENTER_] Dice:0.7001 IoU:0.5683 CBL:0.8449 | [CENTER_] Dice:0.7011 IoU:0.5697 CBL:0.8377 | LR:1.0e-04
# Epoch 51/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.2451]
# Epoch  51 | T_Loss: 0.3737 | [CENTER_] Dice:0.7436 IoU:0.6191 CBL:0.8871 | [CENTER_] Dice:0.7510 IoU:0.6285 CBL:0.8917 | LR:1.0e-04
# Epoch 52/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.2519]
# Epoch  52 | T_Loss: 0.3486 | [CENTER_] Dice:0.7382 IoU:0.6155 CBL:0.8813 | [CENTER_] Dice:0.7480 IoU:0.6273 CBL:0.8841 | LR:1.0e-04
# Epoch 53/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.1007]
# Epoch  53 | T_Loss: 0.3501 | [CENTER_] Dice:0.7570 IoU:0.6318 CBL:0.8985 | [CENTER_] Dice:0.7330 IoU:0.6073 CBL:0.8864 | LR:1.0e-04
# Epoch 54/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.1682]
# Epoch  54 | T_Loss: 0.3515 | [CENTER_] Dice:0.7582 IoU:0.6348 CBL:0.9011 | [CENTER_] Dice:0.7567 IoU:0.6336 CBL:0.8986 | LR:1.0e-04
# Epoch 55/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.76it/s, loss=1.0460]
# Epoch  55 | T_Loss: 0.3519 | [CENTER_] Dice:0.7559 IoU:0.6297 CBL:0.8840 | [CENTER_] Dice:0.7495 IoU:0.6243 CBL:0.8863 | LR:5.0e-05
# Epoch 56/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.4027]
# Epoch  56 | T_Loss: 0.3354 | [CENTER_] Dice:0.7620 IoU:0.6383 CBL:0.8944 | [CENTER_] Dice:0.7667 IoU:0.6438 CBL:0.9057 | LR:5.0e-05
# Epoch 57/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.2110]
# 🥇 [BEST] Epoch  57 | T_Loss: 0.3035 | [CENTER_] Dice:0.7763 IoU:0.6562 CBL:0.9049 | [CENTER_] Dice:0.7822 IoU:0.6654 CBL:0.9053 | LR:5.0e-05
# Epoch 58/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.72it/s, loss=0.4915]
# Epoch  58 | T_Loss: 0.3296 | [CENTER_] Dice:0.7834 IoU:0.6666 CBL:0.9059 | [CENTER_] Dice:0.7820 IoU:0.6651 CBL:0.9132 | LR:5.0e-05
# Epoch 59/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.72it/s, loss=0.5037]
# Epoch  59 | T_Loss: 0.3007 | [CENTER_] Dice:0.7701 IoU:0.6456 CBL:0.9021 | [CENTER_] Dice:0.7710 IoU:0.6472 CBL:0.9008 | LR:5.0e-05
# Epoch 60/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.4118]
# Epoch  60 | T_Loss: 0.3221 | [CENTER_] Dice:0.7697 IoU:0.6529 CBL:0.9036 | [CENTER_] Dice:0.7600 IoU:0.6423 CBL:0.8956 | LR:5.0e-05
# Epoch 61/150 [Train]: 100%|██████| 462/462 [01:38<00:00,  4.71it/s, loss=0.1633]
# Epoch  61 | T_Loss: 0.3138 | [CENTER_] Dice:0.7693 IoU:0.6547 CBL:0.9089 | [CENTER_] Dice:0.7652 IoU:0.6492 CBL:0.9025 | LR:5.0e-05
# Epoch 62/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.3400]
# Epoch  62 | T_Loss: 0.2985 | [CENTER_] Dice:0.7783 IoU:0.6593 CBL:0.9064 | [CENTER_] Dice:0.7772 IoU:0.6593 CBL:0.9046 | LR:5.0e-05
# Epoch 63/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.76it/s, loss=0.2180]
# Epoch  63 | T_Loss: 0.3107 | [CENTER_] Dice:0.7768 IoU:0.6588 CBL:0.9037 | [CENTER_] Dice:0.7769 IoU:0.6576 CBL:0.9014 | LR:2.5e-05
# Epoch 64/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.7438]
# Epoch  64 | T_Loss: 0.3085 | [CENTER_] Dice:0.7808 IoU:0.6647 CBL:0.9098 | [CENTER_] Dice:0.7702 IoU:0.6531 CBL:0.8968 | LR:2.5e-05
# Epoch 65/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.72it/s, loss=0.2097]
# 🥇 [BEST] Epoch  65 | T_Loss: 0.2904 | [CENTER_] Dice:0.7858 IoU:0.6703 CBL:0.9095 | [CENTER_] Dice:0.7835 IoU:0.6686 CBL:0.9062 | LR:2.5e-05
# Epoch 66/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.1964]
# Epoch  66 | T_Loss: 0.2861 | [CENTER_] Dice:0.7812 IoU:0.6672 CBL:0.9088 | [CENTER_] Dice:0.7776 IoU:0.6622 CBL:0.9032 | LR:2.5e-05
# Epoch 67/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.2335]
# Epoch  67 | T_Loss: 0.2826 | [CENTER_] Dice:0.7768 IoU:0.6612 CBL:0.9097 | [CENTER_] Dice:0.7684 IoU:0.6537 CBL:0.9040 | LR:2.5e-05
# Epoch 68/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.1252]
# Epoch  68 | T_Loss: 0.2844 | [CENTER_] Dice:0.7862 IoU:0.6683 CBL:0.9079 | [CENTER_] Dice:0.7821 IoU:0.6633 CBL:0.9024 | LR:2.5e-05
# Epoch 69/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.2109]
# 🥇 [BEST] Epoch  69 | T_Loss: 0.2885 | [CENTER_] Dice:0.7833 IoU:0.6686 CBL:0.9070 | [CENTER_] Dice:0.7841 IoU:0.6698 CBL:0.9136 | LR:2.5e-05
# Epoch 70/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.3247]
# Epoch  70 | T_Loss: 0.2756 | [CENTER_] Dice:0.7788 IoU:0.6652 CBL:0.9122 | [CENTER_] Dice:0.7759 IoU:0.6623 CBL:0.9102 | LR:2.5e-05
# Epoch 71/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.72it/s, loss=0.1268]
# Epoch  71 | T_Loss: 0.2841 | [CENTER_] Dice:0.7823 IoU:0.6675 CBL:0.9121 | [CENTER_] Dice:0.7798 IoU:0.6649 CBL:0.9137 | LR:2.5e-05
# Epoch 72/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.1862]
# Epoch  72 | T_Loss: 0.2925 | [CENTER_] Dice:0.7796 IoU:0.6648 CBL:0.9103 | [CENTER_] Dice:0.7760 IoU:0.6619 CBL:0.9061 | LR:2.5e-05
# Epoch 73/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.2019]
# Epoch  73 | T_Loss: 0.2935 | [CENTER_] Dice:0.7789 IoU:0.6634 CBL:0.9034 | [CENTER_] Dice:0.7748 IoU:0.6584 CBL:0.9013 | LR:2.5e-05
# Epoch 74/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.6975]
# Epoch  74 | T_Loss: 0.2770 | [CENTER_] Dice:0.7760 IoU:0.6624 CBL:0.9025 | [CENTER_] Dice:0.7742 IoU:0.6599 CBL:0.9000 | LR:2.5e-05
# Epoch 75/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.2258]
# 🥇 [BEST] Epoch  75 | T_Loss: 0.2875 | [CENTER_] Dice:0.7882 IoU:0.6732 CBL:0.9106 | [CENTER_] Dice:0.7874 IoU:0.6739 CBL:0.9092 | LR:2.5e-05
# Epoch 76/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.1142]
# Epoch  76 | T_Loss: 0.2740 | [CENTER_] Dice:0.7882 IoU:0.6753 CBL:0.9114 | [CENTER_] Dice:0.7852 IoU:0.6730 CBL:0.9096 | LR:2.5e-05
# Epoch 77/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.3042]
# Epoch  77 | T_Loss: 0.2755 | [CENTER_] Dice:0.7826 IoU:0.6704 CBL:0.9064 | [CENTER_] Dice:0.7820 IoU:0.6721 CBL:0.9059 | LR:2.5e-05
# Epoch 78/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.72it/s, loss=0.1775]
# Epoch  78 | T_Loss: 0.2783 | [CENTER_] Dice:0.7847 IoU:0.6684 CBL:0.9143 | [CENTER_] Dice:0.7772 IoU:0.6606 CBL:0.9092 | LR:2.5e-05
# Epoch 79/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.76it/s, loss=0.2968]
# Epoch  79 | T_Loss: 0.2829 | [CENTER_] Dice:0.7835 IoU:0.6679 CBL:0.9116 | [CENTER_] Dice:0.7778 IoU:0.6620 CBL:0.9073 | LR:2.5e-05
# Epoch 80/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.75it/s, loss=0.1774]
# Epoch  80 | T_Loss: 0.2763 | [CENTER_] Dice:0.7706 IoU:0.6589 CBL:0.9106 | [CENTER_] Dice:0.7597 IoU:0.6487 CBL:0.9056 | LR:2.5e-05
# Epoch 81/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.1769]
# Epoch  81 | T_Loss: 0.2718 | [CENTER_] Dice:0.7775 IoU:0.6669 CBL:0.9078 | [CENTER_] Dice:0.7715 IoU:0.6600 CBL:0.9048 | LR:1.3e-05
# Epoch 82/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.1879]
# Epoch  82 | T_Loss: 0.2705 | [CENTER_] Dice:0.7865 IoU:0.6735 CBL:0.9156 | [CENTER_] Dice:0.7776 IoU:0.6627 CBL:0.9077 | LR:1.3e-05
# Epoch 83/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.1768]
# Epoch  83 | T_Loss: 0.2781 | [CENTER_] Dice:0.7855 IoU:0.6733 CBL:0.9145 | [CENTER_] Dice:0.7811 IoU:0.6687 CBL:0.9128 | LR:1.3e-05
# Epoch 84/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.4800]
# Epoch  84 | T_Loss: 0.2701 | [CENTER_] Dice:0.7865 IoU:0.6746 CBL:0.9149 | [CENTER_] Dice:0.7816 IoU:0.6704 CBL:0.9112 | LR:1.3e-05
# Epoch 85/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.3506]
# Epoch  85 | T_Loss: 0.2678 | [CENTER_] Dice:0.7869 IoU:0.6761 CBL:0.9165 | [CENTER_] Dice:0.7801 IoU:0.6697 CBL:0.9124 | LR:1.3e-05
# Epoch 86/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.3088]
# Epoch  86 | T_Loss: 0.2667 | [CENTER_] Dice:0.7860 IoU:0.6743 CBL:0.9141 | [CENTER_] Dice:0.7806 IoU:0.6689 CBL:0.9118 | LR:1.3e-05
# Epoch 87/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.74it/s, loss=0.1561]
# Epoch  87 | T_Loss: 0.2644 | [CENTER_] Dice:0.7849 IoU:0.6726 CBL:0.9132 | [CENTER_] Dice:0.7804 IoU:0.6680 CBL:0.9096 | LR:6.3e-06
# Epoch 88/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.1571]
# Epoch  88 | T_Loss: 0.2639 | [CENTER_] Dice:0.7914 IoU:0.6807 CBL:0.9181 | [CENTER_] Dice:0.7833 IoU:0.6705 CBL:0.9121 | LR:6.3e-06
# Epoch 89/150 [Train]: 100%|██████| 462/462 [01:38<00:00,  4.71it/s, loss=0.1769]
# Epoch  89 | T_Loss: 0.2460 | [CENTER_] Dice:0.7909 IoU:0.6796 CBL:0.9190 | [CENTER_] Dice:0.7825 IoU:0.6700 CBL:0.9131 | LR:6.3e-06
# Epoch 90/150 [Train]: 100%|██████| 462/462 [01:37<00:00,  4.73it/s, loss=0.2488]
# Epoch  90 | T_Loss: 0.2577 | [CENTER_] Dice:0.7875 IoU:0.6761 CBL:0.9116 | [CENTER_] Dice:0.7796 IoU:0.6682 CBL:0.9053 | LR:6.3e-06
# Early stopping at epoch 90.
#
# Best Dice (center_shift): 0.7874
# Checkpoint: checkpoints/pga_unet_center_mixed_x3_shift05_psg_only_512_seed22120196_best.pth
# ['checkpoints/pga_unet_center_mixed_x3_shift05_psg_only_512_seed22120196_best.pth']

# %%
# -- Quick test on the held-out set: image-level merged, 2 prompt scenarios --
# Loads the checkpoint train.py just wrote in this session (no Drive download).
# Full qualitative panels + per-image CSVs live in Source/File_Test/*/Ablation/.
import os, sys, csv
import numpy as np, torch
from collections import OrderedDict
from torch.utils.data import DataLoader
from tqdm import tqdm
from scipy.ndimage import binary_erosion, distance_transform_edt

os.chdir(PGA_ROOT)
if PGA_ROOT not in sys.path:
    sys.path.insert(0, PGA_ROOT)
from dataset import PromptSegmentationDataset

IMG_SIZE, SCALE_FACTOR, SHIFT_RATIO = 512, 3.0, 0.5
DEVICE  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DS_ROOT = f"{PGA_ROOT}/dataset_BTXRD"
CKPT    = f"checkpoints/pga_unet_center_mixed_x3_shift05_psg_only_512_{RUN_TAG}_best.pth"

VARIANT, ENC, QH, BINP = "psg_only", 1, 0, 0
if VARIANT == "psg_only":
    from models.networks.prompt_unet_psg_only import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
elif VARIANT == "psg_attention":
    from models.networks.prompt_unet_psg_attention import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1)
else:
    from models.networks.prompt_unet_2D import PGA_UNet
    model = PGA_UNet(in_channels=1, n_classes=1,
                     use_encoder_prompt=bool(ENC), use_quality_head=bool(QH))
model.load_state_dict(torch.load(CKPT, map_location=DEVICE, weights_only=True))
model.to(DEVICE).eval()
print("loaded", CKPT)


def _hd95(p, g):
    p, g = p.astype(bool), g.astype(bool)
    if not p.any() and not g.any(): return 0.0
    if not p.any() or not g.any():  return float(IMG_SIZE)
    pe, ge = p ^ binary_erosion(p), g ^ binary_erosion(g)
    d1, d2 = distance_transform_edt(~ge)[pe], distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2): return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))


def _metrics(prob, gt):
    pm, gm, eps = (prob > 0.5), (gt > 0.5), 1e-6
    tp, fp, fn = float((pm & gm).sum()), float((pm & ~gm).sum()), float((~pm & gm).sum())
    cbl = 0.0
    if gm.any() and pm.any():
        ys, xs = np.where(gm); yp, xp = np.where(pm)
        diag = np.hypot(ys.max() - ys.min(), xs.max() - xs.min()) + eps
        cbl = float(np.clip(1 - np.hypot(xp.mean() - xs.mean(), yp.mean() - ys.mean()) / diag, 0, 1))
    return dict(dice=(2*tp+eps)/(2*tp+fp+fn+eps), iou=(tp+eps)/(tp+fp+fn+eps),
                pre=tp/(tp+fp+eps), rec=(tp+eps)/(tp+fn+eps), hd95=_hd95(pm, gm), cbl=cbl)


os.makedirs("results", exist_ok=True)
per_image, rows = [], []
for mode in ("center_zoom", "center_shift"):
    ds = PromptSegmentationDataset(f"{DS_ROOT}/test/images", f"{DS_ROOT}/test/annotations",
                                   img_size=IMG_SIZE, is_train=False, prompt_mode=mode,
                                   scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO,
                                   binary_prompt=bool(BINP))
    groups = OrderedDict()
    with torch.no_grad():
        for i, (img, msk, prm) in enumerate(tqdm(DataLoader(ds, batch_size=1, num_workers=2), desc=mode)):
            prob = torch.sigmoid(model(img.to(DEVICE), prm.to(DEVICE)))[0, 0].cpu().numpy()
            gt   = msk[0, 0].numpy()
            name = ds.all_samples[i][0]
            if name not in groups:
                groups[name] = [prob.copy(), gt.copy()]
            else:
                np.maximum(groups[name][0], prob, out=groups[name][0])
                np.maximum(groups[name][1], gt,   out=groups[name][1])
    recs = []
    for name, (p, g) in groups.items():
        m = _metrics(p, g); recs.append(m)
        per_image.append([mode, name] + [m[k] for k in ("dice", "iou", "pre", "rec", "hd95", "cbl")])
    avg = {k: float(np.mean([r[k] for r in recs])) for k in recs[0]}
    rows.append((mode, len(recs), avg))

print(f"\n{'scenario':<14}{'N':>5}{'Dice':>9}{'IoU':>9}{'Prec':>9}{'Rec':>9}{'HD95':>9}{'CBL':>9}")
for mode, n, a in rows:
    print(f"{mode:<14}{n:>5}{a['dice']:>9.4f}{a['iou']:>9.4f}{a['pre']:>9.4f}{a['rec']:>9.4f}{a['hd95']:>9.2f}{a['cbl']:>9.4f}")

csv_path = f"results/ablation_psg_only_{RUN_TAG}_per_image.csv"
with open(csv_path, "w", newline="") as fh:
    w = csv.writer(fh); w.writerow(["scenario", "img_name", "dice", "iou", "pre", "rec", "hd95", "cbl"])
    w.writerows(per_image)
print("saved", csv_path)
# Out:
# loaded checkpoints/pga_unet_center_mixed_x3_shift05_psg_only_512_seed22120196_best.pth
# center_zoom: 100%|██████████| 232/232 [00:09<00:00, 23.36it/s]
# center_shift: 100%|██████████| 232/232 [00:09<00:00, 24.52it/s]
# scenario          N     Dice      IoU     Prec      Rec     HD95      CBL
# center_zoom     187   0.7792   0.6598   0.7495   0.8352    29.37   0.9078
# center_shift    187   0.7711   0.6512   0.7572   0.8190    28.35   0.9015
# saved results/ablation_psg_only_seed22120196_per_image.csv
