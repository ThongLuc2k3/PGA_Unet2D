# %% [markdown]
# **Full environment, dataset, and code setup** (BTXRD, 512x512, center_zoom prompt: x3, shift up to 30%)

# %%
# =========================================================
# CELL 1 - FULL SETUP COLAB / KAGGLE
# =========================================================
# ===== CHANGE DIRECTORY (auto-detect Colab / Kaggle) =====
import os
BASE = "/kaggle/working" if os.path.exists("/kaggle/working") else "/content"
# %cd $BASE
# ===== CHECK GPU =====
import torch

print("=" * 50)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("=" * 50)

# =========================================================
# CLONE GITHUB (research branch: adds the 'center_zoom'/'center_shift' prompt modes)
# =========================================================

# !rm -rf $BASE/PGA_Unet2D
# !git clone -b research/prompt-scale-protocol https://github.com/ThongLuc2k3/PGA_Unet2D.git

# =========================================================
# DOWNLOAD DATASET ZIP FROM GOOGLE DRIVE
# =========================================================

# !gdown --id 1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx

# =========================================================
# UNZIP DATASET
# =========================================================

# !unzip -oq dataset_BTXRD.zip

# =========================================================
# INSPECT DATASET
# =========================================================

print("\nDATASET STRUCTURE:")
# !ls dataset_BTXRD

# =========================================================
# COPY DATASET INTO THE PROJECT
# =========================================================

# !rm -rf PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/dataset_BTXRD
# !mv dataset_BTXRD PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/

# =========================================================
# ENTER THE PROJECT DIRECTORY
# =========================================================

# %cd PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation

# =========================================================
# INSTALL REQUIREMENTS
# =========================================================

# !pip install -q tqdm opencv-python matplotlib scikit-image gdown scipy

print("\nSETUP DONE!")
# Out:
# /kaggle/working
# ==================================================
# CUDA: True
# GPU: Tesla T4
# ==================================================
# Cloning into 'PGA_Unet2D'...
# remote: Enumerating objects: 3929, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 3929 (delta 75), reused 114 (delta 47), pack-reused 3740 (from 2)
# Receiving objects: 100% (3929/3929), 1.22 GiB | 33.64 MiB/s, done.
# Resolving deltas: 100% (2256/2256), done.
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx
# From (redirected): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx&confirm=t&uuid=e082f28a-d11d-4bf9-9620-e1b8b9afa0c2
# To: /kaggle/working/dataset_BTXRD.zip
# 100%|███████████████████████████████████████| 1.71G/1.71G [00:09<00:00, 181MB/s]
#
# DATASET STRUCTURE:
# test  train  val
# /kaggle/working/PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation
#
# SETUP DONE!

# %% [markdown]
# **Train** (covering-only, like the original PGA-UNet protocol)

# %%
# =========================================================
# TRAIN - center_zoom prompt, scale x3 (covering-only, like the original PGA-UNet protocol)
# =========================================================

# !PROMPT_DATASET_ROOT=dataset_BTXRD PROMPT_IMG_SIZE=512 \
 PROMPT_MODE=center_zoom PROMPT_SCALE_FACTOR=3.0 PROMPT_SHIFT_RATIO=0.3 \
 python train.py
# Out:
# ==========================================================================================
# TrainPrompt: center_zoom | Device: cuda | EncoderPrompt: True | ImgSize: 512 | DatasetRoot: dataset_BTXRD | ScaleFactor: 3.0
# ==========================================================================================
# Epoch 1/100 [Train]: 100%|███████| 462/462 [02:04<00:00,  3.70it/s, loss=1.2510]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.3252 | [CENTER_] Dice:0.4429 IoU:0.3126 CBL:0.6996 | [CENTER_] Dice:0.4307 IoU:0.3030 CBL:0.6750 | LR:1.0e-04
# Epoch 2/100 [Train]: 100%|███████| 462/462 [02:05<00:00,  3.67it/s, loss=1.1689]
# Epoch   2 | T_Loss: 1.1929 | [CENTER_] Dice:0.3897 IoU:0.2506 CBL:0.8311 | [CENTER_] Dice:0.3919 IoU:0.2522 CBL:0.7989 | LR:1.0e-04
# Epoch 3/100 [Train]: 100%|███████| 462/462 [02:05<00:00,  3.70it/s, loss=1.1401]
# 🥇 [BEST] Epoch   3 | T_Loss: 1.1124 | [CENTER_] Dice:0.4432 IoU:0.2958 CBL:0.8435 | [CENTER_] Dice:0.4415 IoU:0.2944 CBL:0.8070 | LR:1.0e-04
# Epoch 4/100 [Train]: 100%|███████| 462/462 [02:05<00:00,  3.69it/s, loss=1.0281]
# 🥇 [BEST] Epoch   4 | T_Loss: 1.0393 | [CENTER_] Dice:0.5626 IoU:0.4151 CBL:0.8222 | [CENTER_] Dice:0.5665 IoU:0.4183 CBL:0.8186 | LR:1.0e-04
# Epoch 5/100 [Train]: 100%|███████| 462/462 [02:05<00:00,  3.69it/s, loss=1.0417]
# Epoch   5 | T_Loss: 0.9746 | [CENTER_] Dice:0.5524 IoU:0.4009 CBL:0.8255 | [CENTER_] Dice:0.5457 IoU:0.3919 CBL:0.8071 | LR:1.0e-04
# Epoch 6/100 [Train]: 100%|███████| 462/462 [02:05<00:00,  3.69it/s, loss=0.9927]
# 🥇 [BEST] Epoch   6 | T_Loss: 0.9194 | [CENTER_] Dice:0.5862 IoU:0.4336 CBL:0.8517 | [CENTER_] Dice:0.5737 IoU:0.4216 CBL:0.8209 | LR:1.0e-04
# Epoch 7/100 [Train]: 100%|███████| 462/462 [02:05<00:00,  3.68it/s, loss=0.8569]
# Epoch   7 | T_Loss: 0.8513 | [CENTER_] Dice:0.5747 IoU:0.4413 CBL:0.8175 | [CENTER_] Dice:0.5627 IoU:0.4246 CBL:0.8115 | LR:1.0e-04
# Epoch 8/100 [Train]: 100%|███████| 462/462 [02:05<00:00,  3.69it/s, loss=0.9326]
# 🥇 [BEST] Epoch   8 | T_Loss: 0.7984 | [CENTER_] Dice:0.6321 IoU:0.4889 CBL:0.8561 | [CENTER_] Dice:0.6256 IoU:0.4809 CBL:0.8546 | LR:1.0e-04
# Epoch 9/100 [Train]: 100%|███████| 462/462 [02:05<00:00,  3.68it/s, loss=0.5331]
# 🥇 [BEST] Epoch   9 | T_Loss: 0.7220 | [CENTER_] Dice:0.6331 IoU:0.4911 CBL:0.8655 | [CENTER_] Dice:0.6233 IoU:0.4793 CBL:0.8593 | LR:1.0e-04
# Epoch 10/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.70it/s, loss=0.5040]
# Epoch  10 | T_Loss: 0.6818 | [CENTER_] Dice:0.6278 IoU:0.4751 CBL:0.8754 | [CENTER_] Dice:0.6200 IoU:0.4665 CBL:0.8574 | LR:1.0e-04
# Epoch 11/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.8724]
# 🥇 [BEST] Epoch  11 | T_Loss: 0.6115 | [CENTER_] Dice:0.7051 IoU:0.5698 CBL:0.8887 | [CENTER_] Dice:0.6953 IoU:0.5560 CBL:0.8807 | LR:1.0e-04
# Epoch 12/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.5914]
# 🥇 [BEST] Epoch  12 | T_Loss: 0.5645 | [CENTER_] Dice:0.7152 IoU:0.5790 CBL:0.8963 | [CENTER_] Dice:0.6889 IoU:0.5465 CBL:0.8759 | LR:1.0e-04
# Epoch 13/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.3438]
# Epoch  13 | T_Loss: 0.5008 | [CENTER_] Dice:0.7131 IoU:0.5800 CBL:0.8963 | [CENTER_] Dice:0.7029 IoU:0.5672 CBL:0.8842 | LR:1.0e-04
# Epoch 14/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.5086]
# Epoch  14 | T_Loss: 0.4733 | [CENTER_] Dice:0.7010 IoU:0.5526 CBL:0.8982 | [CENTER_] Dice:0.7073 IoU:0.5610 CBL:0.8934 | LR:1.0e-04
# Epoch 15/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.2858]
# 🥇 [BEST] Epoch  15 | T_Loss: 0.4379 | [CENTER_] Dice:0.7304 IoU:0.5971 CBL:0.8954 | [CENTER_] Dice:0.7201 IoU:0.5835 CBL:0.8879 | LR:1.0e-04
# Epoch 16/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.2486]
# 🥇 [BEST] Epoch  16 | T_Loss: 0.4248 | [CENTER_] Dice:0.7490 IoU:0.6166 CBL:0.9080 | [CENTER_] Dice:0.7363 IoU:0.6011 CBL:0.8993 | LR:1.0e-04
# Epoch 17/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.3664]
# Epoch  17 | T_Loss: 0.4323 | [CENTER_] Dice:0.7432 IoU:0.6151 CBL:0.8998 | [CENTER_] Dice:0.7184 IoU:0.5833 CBL:0.8889 | LR:1.0e-04
# Epoch 18/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.2831]
# Epoch  18 | T_Loss: 0.3948 | [CENTER_] Dice:0.7341 IoU:0.6067 CBL:0.8957 | [CENTER_] Dice:0.7071 IoU:0.5705 CBL:0.8821 | LR:1.0e-04
# Epoch 19/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.3825]
# Epoch  19 | T_Loss: 0.3846 | [CENTER_] Dice:0.7279 IoU:0.5992 CBL:0.9022 | [CENTER_] Dice:0.7320 IoU:0.6043 CBL:0.9025 | LR:1.0e-04
# Epoch 20/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.70it/s, loss=0.1775]
# 🥇 [BEST] Epoch  20 | T_Loss: 0.3794 | [CENTER_] Dice:0.7505 IoU:0.6158 CBL:0.9173 | [CENTER_] Dice:0.7289 IoU:0.5881 CBL:0.8963 | LR:1.0e-04
# Epoch 21/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.2230]
# Epoch  21 | T_Loss: 0.3923 | [CENTER_] Dice:0.7186 IoU:0.5966 CBL:0.8908 | [CENTER_] Dice:0.7041 IoU:0.5785 CBL:0.8856 | LR:1.0e-04
# Epoch 22/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.2645]
# 🥇 [BEST] Epoch  22 | T_Loss: 0.3601 | [CENTER_] Dice:0.7550 IoU:0.6257 CBL:0.9082 | [CENTER_] Dice:0.7553 IoU:0.6248 CBL:0.9065 | LR:1.0e-04
# Epoch 23/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.2328]
# Epoch  23 | T_Loss: 0.3426 | [CENTER_] Dice:0.7480 IoU:0.6243 CBL:0.9044 | [CENTER_] Dice:0.7113 IoU:0.5784 CBL:0.8809 | LR:1.0e-04
# Epoch 24/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=1.0670]
# Epoch  24 | T_Loss: 0.3483 | [CENTER_] Dice:0.7515 IoU:0.6314 CBL:0.9145 | [CENTER_] Dice:0.7070 IoU:0.5727 CBL:0.8915 | LR:1.0e-04
# Epoch 25/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.2317]
# 🥇 [BEST] Epoch  25 | T_Loss: 0.3481 | [CENTER_] Dice:0.7635 IoU:0.6399 CBL:0.9147 | [CENTER_] Dice:0.7504 IoU:0.6200 CBL:0.9072 | LR:1.0e-04
# Epoch 26/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.7671]
# Epoch  26 | T_Loss: 0.3410 | [CENTER_] Dice:0.7460 IoU:0.6287 CBL:0.9108 | [CENTER_] Dice:0.7322 IoU:0.6088 CBL:0.9057 | LR:1.0e-04
# Epoch 27/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=1.1923]
# Epoch  27 | T_Loss: 0.3292 | [CENTER_] Dice:0.7530 IoU:0.6320 CBL:0.9164 | [CENTER_] Dice:0.7142 IoU:0.5817 CBL:0.8917 | LR:1.0e-04
# Epoch 28/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.9618]
# 🥇 [BEST] Epoch  28 | T_Loss: 0.3490 | [CENTER_] Dice:0.7718 IoU:0.6479 CBL:0.9188 | [CENTER_] Dice:0.7620 IoU:0.6354 CBL:0.9094 | LR:1.0e-04
# Epoch 29/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.1803]
# 🥇 [BEST] Epoch  29 | T_Loss: 0.3102 | [CENTER_] Dice:0.7780 IoU:0.6592 CBL:0.9220 | [CENTER_] Dice:0.7572 IoU:0.6310 CBL:0.9087 | LR:1.0e-04
# Epoch 30/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.2093]
# 🥇 [BEST] Epoch  30 | T_Loss: 0.3197 | [CENTER_] Dice:0.7796 IoU:0.6569 CBL:0.9196 | [CENTER_] Dice:0.7635 IoU:0.6346 CBL:0.8988 | LR:1.0e-04
# Epoch 31/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.2789]
# 🥇 [BEST] Epoch  31 | T_Loss: 0.3308 | [CENTER_] Dice:0.7871 IoU:0.6670 CBL:0.9263 | [CENTER_] Dice:0.7695 IoU:0.6421 CBL:0.9130 | LR:1.0e-04
# Epoch 32/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.1892]
# Epoch  32 | T_Loss: 0.3115 | [CENTER_] Dice:0.7593 IoU:0.6433 CBL:0.9120 | [CENTER_] Dice:0.7369 IoU:0.6124 CBL:0.8979 | LR:1.0e-04
# Epoch 33/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.3396]
# 🥇 [BEST] Epoch  33 | T_Loss: 0.3079 | [CENTER_] Dice:0.7875 IoU:0.6687 CBL:0.9216 | [CENTER_] Dice:0.7686 IoU:0.6434 CBL:0.9105 | LR:1.0e-04
# Epoch 34/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.2101]
# Epoch  34 | T_Loss: 0.3133 | [CENTER_] Dice:0.7593 IoU:0.6424 CBL:0.9116 | [CENTER_] Dice:0.7209 IoU:0.5937 CBL:0.8887 | LR:1.0e-04
# Epoch 35/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=1.0815]
# Epoch  35 | T_Loss: 0.3187 | [CENTER_] Dice:0.7739 IoU:0.6523 CBL:0.9181 | [CENTER_] Dice:0.7857 IoU:0.6668 CBL:0.9245 | LR:1.0e-04
# Epoch 36/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.1638]
# 🥇 [BEST] Epoch  36 | T_Loss: 0.2953 | [CENTER_] Dice:0.7997 IoU:0.6819 CBL:0.9310 | [CENTER_] Dice:0.7731 IoU:0.6462 CBL:0.9120 | LR:1.0e-04
# Epoch 37/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.2257]
# Epoch  37 | T_Loss: 0.3236 | [CENTER_] Dice:0.7824 IoU:0.6597 CBL:0.9207 | [CENTER_] Dice:0.7734 IoU:0.6486 CBL:0.9108 | LR:1.0e-04
# Epoch 38/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.2229]
# Epoch  38 | T_Loss: 0.3141 | [CENTER_] Dice:0.7924 IoU:0.6743 CBL:0.9228 | [CENTER_] Dice:0.7899 IoU:0.6715 CBL:0.9183 | LR:1.0e-04
# Epoch 39/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.6769]
# Epoch  39 | T_Loss: 0.3069 | [CENTER_] Dice:0.7866 IoU:0.6751 CBL:0.9263 | [CENTER_] Dice:0.7579 IoU:0.6394 CBL:0.9062 | LR:1.0e-04
# Epoch 40/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=1.0456]
# Epoch  40 | T_Loss: 0.3071 | [CENTER_] Dice:0.7830 IoU:0.6617 CBL:0.9169 | [CENTER_] Dice:0.7680 IoU:0.6422 CBL:0.9049 | LR:1.0e-04
# Epoch 41/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.6891]
# Epoch  41 | T_Loss: 0.2955 | [CENTER_] Dice:0.7966 IoU:0.6758 CBL:0.9310 | [CENTER_] Dice:0.7897 IoU:0.6665 CBL:0.9202 | LR:1.0e-04
# Epoch 42/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.0724]
# Epoch  42 | T_Loss: 0.2947 | [CENTER_] Dice:0.7720 IoU:0.6547 CBL:0.9187 | [CENTER_] Dice:0.7668 IoU:0.6484 CBL:0.9080 | LR:5.0e-05
# Epoch 43/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.2300]
# Epoch  43 | T_Loss: 0.2806 | [CENTER_] Dice:0.7967 IoU:0.6852 CBL:0.9266 | [CENTER_] Dice:0.7852 IoU:0.6687 CBL:0.9170 | LR:5.0e-05
# Epoch 44/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.0774]
# Epoch  44 | T_Loss: 0.2699 | [CENTER_] Dice:0.7869 IoU:0.6782 CBL:0.9154 | [CENTER_] Dice:0.7714 IoU:0.6580 CBL:0.9041 | LR:5.0e-05
# Epoch 45/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.1740]
# Epoch  45 | T_Loss: 0.2878 | [CENTER_] Dice:0.7981 IoU:0.6882 CBL:0.9289 | [CENTER_] Dice:0.7775 IoU:0.6602 CBL:0.9085 | LR:5.0e-05
# Epoch 46/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.7095]
# 🥇 [BEST] Epoch  46 | T_Loss: 0.2571 | [CENTER_] Dice:0.8061 IoU:0.6930 CBL:0.9304 | [CENTER_] Dice:0.7993 IoU:0.6852 CBL:0.9238 | LR:5.0e-05
# Epoch 47/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.2146]
# Epoch  47 | T_Loss: 0.2904 | [CENTER_] Dice:0.7931 IoU:0.6845 CBL:0.9265 | [CENTER_] Dice:0.7630 IoU:0.6460 CBL:0.9037 | LR:5.0e-05
# Epoch 48/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1260]
# 🥇 [BEST] Epoch  48 | T_Loss: 0.2656 | [CENTER_] Dice:0.8089 IoU:0.7006 CBL:0.9352 | [CENTER_] Dice:0.7662 IoU:0.6452 CBL:0.9081 | LR:5.0e-05
# Epoch 49/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.7491]
# Epoch  49 | T_Loss: 0.2656 | [CENTER_] Dice:0.8000 IoU:0.6889 CBL:0.9294 | [CENTER_] Dice:0.7767 IoU:0.6591 CBL:0.9133 | LR:5.0e-05
# Epoch 50/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.2032]
# Epoch  50 | T_Loss: 0.2488 | [CENTER_] Dice:0.7815 IoU:0.6698 CBL:0.9156 | [CENTER_] Dice:0.7794 IoU:0.6681 CBL:0.9127 | LR:5.0e-05
# Epoch 51/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1291]
# Epoch  51 | T_Loss: 0.2519 | [CENTER_] Dice:0.8003 IoU:0.6904 CBL:0.9296 | [CENTER_] Dice:0.7829 IoU:0.6666 CBL:0.9146 | LR:5.0e-05
# Epoch 52/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=1.1713]
# Epoch  52 | T_Loss: 0.2800 | [CENTER_] Dice:0.8006 IoU:0.6924 CBL:0.9309 | [CENTER_] Dice:0.7790 IoU:0.6642 CBL:0.9116 | LR:5.0e-05
# Epoch 53/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1201]
# Epoch  53 | T_Loss: 0.2603 | [CENTER_] Dice:0.8046 IoU:0.6940 CBL:0.9310 | [CENTER_] Dice:0.7767 IoU:0.6581 CBL:0.9140 | LR:5.0e-05
# Epoch 54/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.1192]
# 🥇 [BEST] Epoch  54 | T_Loss: 0.2754 | [CENTER_] Dice:0.8092 IoU:0.6914 CBL:0.9340 | [CENTER_] Dice:0.8058 IoU:0.6872 CBL:0.9259 | LR:5.0e-05
# Epoch 55/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.6059]
# 🥇 [BEST] Epoch  55 | T_Loss: 0.2700 | [CENTER_] Dice:0.8109 IoU:0.7009 CBL:0.9316 | [CENTER_] Dice:0.7858 IoU:0.6676 CBL:0.9127 | LR:5.0e-05
# Epoch 56/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1521]
# Epoch  56 | T_Loss: 0.2557 | [CENTER_] Dice:0.7766 IoU:0.6639 CBL:0.9136 | [CENTER_] Dice:0.7667 IoU:0.6507 CBL:0.9004 | LR:5.0e-05
# Epoch 57/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.69it/s, loss=0.2105]
# Epoch  57 | T_Loss: 0.2535 | [CENTER_] Dice:0.7992 IoU:0.6920 CBL:0.9270 | [CENTER_] Dice:0.7639 IoU:0.6460 CBL:0.9021 | LR:5.0e-05
# Epoch 58/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1439]
# Epoch  58 | T_Loss: 0.2609 | [CENTER_] Dice:0.8077 IoU:0.6990 CBL:0.9314 | [CENTER_] Dice:0.7744 IoU:0.6547 CBL:0.9082 | LR:5.0e-05
# Epoch 59/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=1.1863]
# Epoch  59 | T_Loss: 0.2677 | [CENTER_] Dice:0.7930 IoU:0.6796 CBL:0.9275 | [CENTER_] Dice:0.7697 IoU:0.6504 CBL:0.9119 | LR:5.0e-05
# Epoch 60/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.2203]
# 🥇 [BEST] Epoch  60 | T_Loss: 0.2633 | [CENTER_] Dice:0.8136 IoU:0.7041 CBL:0.9351 | [CENTER_] Dice:0.7952 IoU:0.6796 CBL:0.9218 | LR:5.0e-05
# Epoch 61/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1237]
# Epoch  61 | T_Loss: 0.2585 | [CENTER_] Dice:0.8051 IoU:0.6954 CBL:0.9305 | [CENTER_] Dice:0.7840 IoU:0.6669 CBL:0.9132 | LR:5.0e-05
# Epoch 62/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.9307]
# Epoch  62 | T_Loss: 0.2648 | [CENTER_] Dice:0.8122 IoU:0.7013 CBL:0.9322 | [CENTER_] Dice:0.7941 IoU:0.6755 CBL:0.9170 | LR:5.0e-05
# Epoch 63/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.2804]
# 🥇 [BEST] Epoch  63 | T_Loss: 0.2751 | [CENTER_] Dice:0.8140 IoU:0.7036 CBL:0.9313 | [CENTER_] Dice:0.8048 IoU:0.6918 CBL:0.9210 | LR:5.0e-05
# Epoch 64/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.2193]
# Epoch  64 | T_Loss: 0.2351 | [CENTER_] Dice:0.7912 IoU:0.6778 CBL:0.9304 | [CENTER_] Dice:0.7711 IoU:0.6540 CBL:0.9190 | LR:5.0e-05
# Epoch 65/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1497]
# Epoch  65 | T_Loss: 0.2393 | [CENTER_] Dice:0.8023 IoU:0.6931 CBL:0.9308 | [CENTER_] Dice:0.7677 IoU:0.6505 CBL:0.9103 | LR:5.0e-05
# Epoch 66/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1266]
# 🥇 [BEST] Epoch  66 | T_Loss: 0.2444 | [CENTER_] Dice:0.8188 IoU:0.7108 CBL:0.9381 | [CENTER_] Dice:0.7884 IoU:0.6712 CBL:0.9171 | LR:5.0e-05
# Epoch 67/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.0829]
# Epoch  67 | T_Loss: 0.2531 | [CENTER_] Dice:0.7930 IoU:0.6830 CBL:0.9289 | [CENTER_] Dice:0.7723 IoU:0.6573 CBL:0.9140 | LR:5.0e-05
# Epoch 68/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1765]
# Epoch  68 | T_Loss: 0.2466 | [CENTER_] Dice:0.7996 IoU:0.6908 CBL:0.9336 | [CENTER_] Dice:0.7818 IoU:0.6674 CBL:0.9189 | LR:5.0e-05
# Epoch 69/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1386]
# Epoch  69 | T_Loss: 0.2425 | [CENTER_] Dice:0.8147 IoU:0.7024 CBL:0.9342 | [CENTER_] Dice:0.8160 IoU:0.7049 CBL:0.9297 | LR:5.0e-05
# Epoch 70/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.1911]
# Epoch  70 | T_Loss: 0.2370 | [CENTER_] Dice:0.8034 IoU:0.6950 CBL:0.9326 | [CENTER_] Dice:0.7789 IoU:0.6629 CBL:0.9171 | LR:5.0e-05
# Epoch 71/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.8691]
# 🥇 [BEST] Epoch  71 | T_Loss: 0.2373 | [CENTER_] Dice:0.8205 IoU:0.7073 CBL:0.9364 | [CENTER_] Dice:0.7979 IoU:0.6765 CBL:0.9163 | LR:5.0e-05
# Epoch 72/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1684]
# Epoch  72 | T_Loss: 0.2414 | [CENTER_] Dice:0.8105 IoU:0.7017 CBL:0.9302 | [CENTER_] Dice:0.8013 IoU:0.6906 CBL:0.9230 | LR:5.0e-05
# Epoch 73/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1547]
# 🥇 [BEST] Epoch  73 | T_Loss: 0.2408 | [CENTER_] Dice:0.8249 IoU:0.7146 CBL:0.9359 | [CENTER_] Dice:0.7963 IoU:0.6770 CBL:0.9165 | LR:5.0e-05
# Epoch 74/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.9034]
# Epoch  74 | T_Loss: 0.2262 | [CENTER_] Dice:0.8202 IoU:0.7106 CBL:0.9359 | [CENTER_] Dice:0.8053 IoU:0.6917 CBL:0.9240 | LR:5.0e-05
# Epoch 75/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.5152]
# Epoch  75 | T_Loss: 0.2378 | [CENTER_] Dice:0.7973 IoU:0.6900 CBL:0.9254 | [CENTER_] Dice:0.7663 IoU:0.6497 CBL:0.9051 | LR:5.0e-05
# Epoch 76/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1967]
# Epoch  76 | T_Loss: 0.2394 | [CENTER_] Dice:0.8230 IoU:0.7165 CBL:0.9347 | [CENTER_] Dice:0.7905 IoU:0.6739 CBL:0.9151 | LR:5.0e-05
# Epoch 77/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.2105]
# Epoch  77 | T_Loss: 0.2239 | [CENTER_] Dice:0.8173 IoU:0.7074 CBL:0.9357 | [CENTER_] Dice:0.8012 IoU:0.6869 CBL:0.9208 | LR:5.0e-05
# Epoch 78/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.1468]
# Epoch  78 | T_Loss: 0.2295 | [CENTER_] Dice:0.8212 IoU:0.7129 CBL:0.9381 | [CENTER_] Dice:0.8060 IoU:0.6941 CBL:0.9290 | LR:5.0e-05
# Epoch 79/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.1408]
# Epoch  79 | T_Loss: 0.2286 | [CENTER_] Dice:0.8151 IoU:0.7063 CBL:0.9361 | [CENTER_] Dice:0.7929 IoU:0.6769 CBL:0.9157 | LR:2.5e-05
# Epoch 80/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.1190]
# Epoch  80 | T_Loss: 0.2141 | [CENTER_] Dice:0.8120 IoU:0.7080 CBL:0.9361 | [CENTER_] Dice:0.7904 IoU:0.6799 CBL:0.9172 | LR:2.5e-05
# Epoch 81/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.1074]
# Epoch  81 | T_Loss: 0.2350 | [CENTER_] Dice:0.8187 IoU:0.7134 CBL:0.9358 | [CENTER_] Dice:0.8033 IoU:0.6930 CBL:0.9237 | LR:2.5e-05
# Epoch 82/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1000]
# Epoch  82 | T_Loss: 0.2287 | [CENTER_] Dice:0.8153 IoU:0.7102 CBL:0.9381 | [CENTER_] Dice:0.7851 IoU:0.6711 CBL:0.9168 | LR:2.5e-05
# Epoch 83/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.0951]
# Epoch  83 | T_Loss: 0.2157 | [CENTER_] Dice:0.8175 IoU:0.7123 CBL:0.9373 | [CENTER_] Dice:0.7996 IoU:0.6894 CBL:0.9213 | LR:2.5e-05
# Epoch 84/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.67it/s, loss=0.1664]
# Epoch  84 | T_Loss: 0.2252 | [CENTER_] Dice:0.8191 IoU:0.7151 CBL:0.9388 | [CENTER_] Dice:0.7938 IoU:0.6821 CBL:0.9226 | LR:2.5e-05
# Epoch 85/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.1259]
# Epoch  85 | T_Loss: 0.2243 | [CENTER_] Dice:0.8187 IoU:0.7125 CBL:0.9350 | [CENTER_] Dice:0.8025 IoU:0.6910 CBL:0.9229 | LR:1.3e-05
# Epoch 86/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.3333]
# Epoch  86 | T_Loss: 0.2244 | [CENTER_] Dice:0.8136 IoU:0.7093 CBL:0.9358 | [CENTER_] Dice:0.7935 IoU:0.6831 CBL:0.9247 | LR:1.3e-05
# Epoch 87/100 [Train]: 100%|██████| 462/462 [02:06<00:00,  3.66it/s, loss=0.2267]
# Epoch  87 | T_Loss: 0.2236 | [CENTER_] Dice:0.8134 IoU:0.7102 CBL:0.9361 | [CENTER_] Dice:0.7918 IoU:0.6816 CBL:0.9203 | LR:1.3e-05
# Epoch 88/100 [Train]: 100%|██████| 462/462 [02:05<00:00,  3.68it/s, loss=0.1032]
# Epoch  88 | T_Loss: 0.2235 | [CENTER_] Dice:0.8118 IoU:0.7070 CBL:0.9323 | [CENTER_] Dice:0.7947 IoU:0.6848 CBL:0.9170 | LR:1.3e-05
# Early stopping at epoch 88.
#
# Best Dice (center_zoom): 0.8249
# Checkpoint: checkpoints/pga_unet_center_zoom_x3_512_best.pth

# %% [markdown]
# ## Test - Zoom and Zoom + shift (x3, shift up to 30%)

# %%
# @title
"""
test_center_zoom_x3_shift03.py
=====================
Evaluation of two prompt scenarios: 100% Zoom (center_zoom, x3) | 100% Zoom + shift (center_shift, x3, shift up to 30%)
Mirrors the original PGA-UNet dual-condition test (zoom_out / shift), with
the covering-box formula replaced by the center-scaled one this checkpoint
was trained under. No legacy zoom_out/shift comparison here.

Usage:
    python test_center_zoom_x3_shift03.py
"""

import os
import sys
import cv2
import json
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from scipy.ndimage import binary_erosion, distance_transform_edt

import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset
from models.networks.prompt_unet_2D import PGA_UNet

# =========================================================
# CONFIGURATION - edit here
# =========================================================
DEVICE             = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_PATH         = "checkpoints/pga_unet_center_zoom_x3_512_best.pth"
IMG_SIZE           = 512
BATCH_SIZE         = 4
USE_ENCODER_PROMPT = True   # must match the training config above

SCALE_FACTOR = 3.0
SHIFT_RATIO  = 0.3

TEST_IMAGE_DIR = "dataset_BTXRD/test/images"
TEST_JSON_DIR  = "dataset_BTXRD/test/annotations"


# =========================================================
# METRIC HELPERS & POST-PROCESSING
# =========================================================

def extract_lcc(binary_map: np.ndarray) -> np.ndarray:
    if binary_map.sum() == 0:
        return binary_map
    mask_uint8 = binary_map.astype(np.uint8)
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(mask_uint8, connectivity=8)
    if num_labels <= 1:
        return binary_map
    largest_label = 1 + np.argmax(stats[1:, cv2.CC_STAT_AREA])
    return (labels == largest_label).astype(np.float32)

def calc_hd95(pred: np.ndarray, gt: np.ndarray) -> float:
    pred, gt = pred.astype(bool), gt.astype(bool)
    if not pred.any() and not gt.any():
        return 0.0
    if not pred.any() or not gt.any():
        return float(IMG_SIZE)
    pe = pred ^ binary_erosion(pred)
    ge = gt   ^ binary_erosion(gt)
    d1 = distance_transform_edt(~ge)[pe]
    d2 = distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2):
        return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))

def calc_cbl(pred_bin: np.ndarray, gt_bin: np.ndarray):
    if gt_bin.sum() == 0:
        return None
    ys, xs = np.where(gt_bin)
    gt_diag = np.sqrt((ys.max() - ys.min()) ** 2 +
                      (xs.max() - xs.min()) ** 2) + 1e-6
    if pred_bin.sum() == 0:
        return 0.0
    yp, xp = np.where(pred_bin)
    d = np.sqrt((xp.mean() - xs.mean()) ** 2 +
                (yp.mean() - ys.mean()) ** 2)
    return float(np.clip(1.0 - d / gt_diag, 0.0, 1.0))

def get_centroid(binary_map: np.ndarray):
    if binary_map.sum() == 0:
        return None, None
    ys, xs = np.where(binary_map)
    return float(xs.mean()), float(ys.mean())

# =========================================================
# SINGLE-SCENARIO EVALUATION
# =========================================================

def run_eval(model: torch.nn.Module, prompt_mode: str, **ds_kwargs) -> dict:
    ds = PromptSegmentationDataset(
        image_dir=TEST_IMAGE_DIR,
        json_dir=TEST_JSON_DIR,
        img_size=IMG_SIZE,
        is_train=False,
        prompt_mode=prompt_mode,
        **ds_kwargs,
    )
    loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

    smooth = 1e-5
    all_dice, all_iou, all_pre, all_rec, all_hd95, all_cbl = [], [], [], [], [], []

    model.eval()
    with torch.no_grad():
        for images, masks, prompts in loader:
            images  = images.to(DEVICE)
            masks   = masks.to(DEVICE)
            prompts = prompts.to(DEVICE)
            preds   = (torch.sigmoid(model(images, prompts)) > 0.5).float()

            for b in range(images.size(0)):
                pm = preds[b, 0].cpu().numpy()
                gm = masks[b, 0].cpu().numpy()
                pm = extract_lcc(pm)

                tp = (pm * gm).sum()
                fp = (pm * (1 - gm)).sum()
                fn = ((1 - pm) * gm).sum()

                all_dice.append((2 * tp + smooth) / (2 * tp + fp + fn + smooth))
                all_iou.append( (tp + smooth) / (tp + fp + fn + smooth))
                all_pre.append( (tp + smooth) / (tp + fp + smooth))
                all_rec.append( (tp + smooth) / (tp + fn + smooth))
                all_hd95.append(calc_hd95(pm.astype(bool), gm.astype(bool)))

                cbl = calc_cbl(pm.astype(bool), gm.astype(bool))
                if cbl is not None:
                    all_cbl.append(cbl)

    return {
        'dice': np.mean(all_dice),
        'iou':  np.mean(all_iou),
        'pre':  np.mean(all_pre),
        'rec':  np.mean(all_rec),
        'hd95': np.mean(all_hd95),
        'cbl':  np.mean(all_cbl) if all_cbl else 0.0,
        'n':    len(all_dice),
    }

# =========================================================
# TWO-SCENARIO EVALUATION: Zoom (center_zoom) and Zoom + shift (center_shift),
# both at the exact scale_factor/shift_ratio this checkpoint was trained
# under. This mirrors the original PGA-UNet zoom_out/shift dual-condition
# test; no legacy zoom_out/shift comparison is included here.
# =========================================================

def evaluate_all(model: torch.nn.Module) -> dict:
    enc_tag = 'ON' if USE_ENCODER_PROMPT else 'OFF'
    print("\n" + "=" * 72)
    print(f"  TWO-SCENARIO EVALUATION  |  center-zoom x{SCALE_FACTOR:g}  |  encoder_prompt = {enc_tag}")
    print("=" * 72)

    scenarios = {
        'Zoom (center_zoom)':        dict(prompt_mode='center_zoom', scale_factor=SCALE_FACTOR),
        'Zoom + shift (center_shift)': dict(prompt_mode='center_shift', scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO),
    }

    results = {}
    for name, kwargs in scenarios.items():
        results[name] = run_eval(model, **kwargs)
        print(f"  [{name}]  {results[name]['n']} samples, completed.")

    header = (f"\n{'Scenario':<30} {'Dice↑':>7} {'IoU↑':>7} "
              f"{'Pre↑':>7} {'Rec↑':>7} {'HD95↓':>8} {'CBL↑':>7} {'N':>5}")
    print(header)
    print("-" * 82)
    for name, r in results.items():
        print(f"{name:<30} {r['dice']:>7.4f} {r['iou']:>7.4f} "
              f"{r['pre']:>7.4f} {r['rec']:>7.4f} "
              f"{r['hd95']:>8.2f} {r['cbl']:>7.4f} {r['n']:>5}")
    return results

# =========================================================
# LOAD MODEL
# =========================================================
model = PGA_UNet(use_encoder_prompt=USE_ENCODER_PROMPT).to(DEVICE)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval()
print(f"Model loaded from: {MODEL_PATH}")

# =========================================================
# TWO-SCENARIO EVALUATION: summary table
# =========================================================
results = evaluate_all(model)

# =========================================================
# VISUALIZATION - first 10 samples in order (Zoom, center_zoom)
# =========================================================
from IPython.display import display as _ipy_display
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from torch.utils.data import DataLoader
import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset

N_SHOW  = 10
_vis_dl = DataLoader(
    PromptSegmentationDataset(TEST_IMAGE_DIR, TEST_JSON_DIR, img_size=IMG_SIZE, is_train=False,
                              prompt_mode="center_zoom", scale_factor=SCALE_FACTOR),
    batch_size=1, shuffle=False, num_workers=0)

fig, axes = plt.subplots(N_SHOW, 5, figsize=(20, 4 * N_SHOW))
fig.suptitle(f"PGA-UNet center_zoom (x{SCALE_FACTOR:g}) - Visualization (Zoom, first 10 samples)", fontsize=13, y=1.001)
for ax, ct in zip(axes[0], ["Input image", "Image + prompt", "Prediction", "Ground truth", "TP/FP/FN"]):
    ax.set_title(ct, fontsize=10, fontweight="bold")

model.eval()
count = 0
with torch.no_grad():
    for _img, _gt, _hm in _vis_dl:
        if count >= N_SHOW: break
        img_np  = (_img[0,0].cpu().numpy() * 0.5 + 0.5)
        hm_np   = _hm[0,0].cpu().numpy()
        gt_np   = (_gt[0,0].cpu().numpy() > 0.5).astype(float)
        prob_np = torch.sigmoid(model(_img.to(DEVICE), _hm.to(DEVICE)))[0,0].cpu().numpy()
        pred_np = (prob_np > 0.5).astype(float)

        tp=(pred_np*gt_np).sum(); fp=(pred_np*(1-gt_np)).sum(); fn=((1-pred_np)*gt_np).sum(); e=1e-6
        dice=float((2*tp+e)/(2*tp+fp+fn+e)); iou=float((tp+e)/(tp+fp+fn+e))
        pre=float((tp+e)/(tp+fp+e));         rec=float((tp+e)/(tp+fn+e))

        row = axes[count]
        bg  = np.stack([img_np]*3, axis=-1)

        row[0].imshow(img_np, cmap="gray", vmin=0, vmax=1)
        row[0].set_ylabel(f"#{count+1} Dice={dice:.3f}", fontsize=8)

        row[1].imshow(img_np, cmap="gray", vmin=0, vmax=1)
        row[1].imshow(hm_np, cmap="hot", alpha=0.4, vmin=0, vmax=1)

        pr_ov = bg.copy()
        pr_ov[...,0] = np.clip(pr_ov[...,0] + pred_np*0.55, 0, 1)
        pr_ov[...,1] = np.clip(pr_ov[...,1] - pred_np*0.2,  0, 1)
        row[2].imshow(pr_ov)
        row[2].set_title(f"Dice={dice:.3f} IoU={iou:.3f}", fontsize=7, color="darkred", pad=2)

        gt_ov = bg.copy()
        gt_ov[...,1] = np.clip(gt_ov[...,1] + gt_np*0.55, 0, 1)
        gt_ov[...,0] = np.clip(gt_ov[...,0] - gt_np*0.2,  0, 1)
        row[3].imshow(gt_ov)

        inter = bg.copy() * 0.25
        inter[...,1] = np.clip(inter[...,1] + pred_np*gt_np*0.9,     0, 1)
        inter[...,0] = np.clip(inter[...,0] + pred_np*(1-gt_np)*1.0, 0, 1)
        inter[...,2] = np.clip(inter[...,2] + (1-pred_np)*gt_np*1.0, 0, 1)
        row[4].imshow(inter)
        row[4].set_title(f"Pre={pre:.3f} Rec={rec:.3f}", fontsize=7, color="saddlebrown", pad=2)

        for ax in row: ax.axis("off")
        count += 1

fig.legend(handles=[Patch(facecolor="green",label="TP"),Patch(facecolor="red",label="FP"),Patch(facecolor="blue",label="FN")],
           loc="lower center", ncol=3, fontsize=9, bbox_to_anchor=(0.5,-0.01))
plt.tight_layout()
_ipy_display(fig)
plt.close(fig)
# Out:
# Model loaded from: checkpoints/pga_unet_center_zoom_x3_512_best.pth
#
# ========================================================================
#   TWO-SCENARIO EVALUATION  |  center-zoom x3  |  encoder_prompt = ON
# ========================================================================
#   [Zoom (center_zoom)]  232 samples, completed.
#   [Zoom + shift (center_shift)]  232 samples, completed.
#
# Scenario                         Dice↑    IoU↑    Pre↑    Rec↑    HD95↓    CBL↑     N
# ----------------------------------------------------------------------------------
# Zoom (center_zoom)              0.8095  0.6958  0.7777  0.8781    19.87  0.9268   232
# Zoom + shift (center_shift)     0.7818  0.6601  0.7626  0.8391    21.03  0.9078   232
