# %% [markdown]
# **Full environment, dataset, and code setup** (BTXRD, 512x512, center_zoom prompt: x2, shift up to 50%)

# %%
# =========================================================
# CELL 1 - FULL SETUP COLAB / KAGGLE
# =========================================================
# ===== CHANGE DIRECTORY (auto-detect Colab / Kaggle) =====
import os
BASE = "/kaggle/working" if os.path.exists("/kaggle/working") else "/content"
# %cd $BASE
# ===== CHECK GPU =====
import torch

print("=" * 50)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("=" * 50)

# =========================================================
# CLONE GITHUB (research branch: adds the 'center_zoom'/'center_shift' prompt modes)
# =========================================================

# !rm -rf $BASE/PGA_Unet2D
# !git clone -b research/prompt-scale-protocol https://github.com/ThongLuc2k3/PGA_Unet2D.git

# =========================================================
# DOWNLOAD DATASET ZIP FROM GOOGLE DRIVE
# =========================================================

# !gdown --id 1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx

# =========================================================
# UNZIP DATASET
# =========================================================

# !unzip -oq dataset_BTXRD.zip

# =========================================================
# INSPECT DATASET
# =========================================================

print("\nDATASET STRUCTURE:")
# !ls dataset_BTXRD

# =========================================================
# COPY DATASET INTO THE PROJECT
# =========================================================

# !rm -rf PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/dataset_BTXRD
# !mv dataset_BTXRD PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/

# =========================================================
# ENTER THE PROJECT DIRECTORY
# =========================================================

# %cd PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation

# =========================================================
# INSTALL REQUIREMENTS
# =========================================================

# !pip install -q tqdm opencv-python matplotlib scikit-image gdown scipy

print("\nSETUP DONE!")
# Out:
# /kaggle/working
# ==================================================
# CUDA: True
# GPU: Tesla T4
# ==================================================
# Cloning into 'PGA_Unet2D'...
# remote: Enumerating objects: 3929, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 3929 (delta 75), reused 114 (delta 47), pack-reused 3740 (from 2)
# Receiving objects: 100% (3929/3929), 1.22 GiB | 9.58 MiB/s, done.
# Resolving deltas: 100% (2256/2256), done.
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx
# From (redirected): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx&confirm=t&uuid=1ee0ae51-b570-4c20-8bca-f580e1565d8c
# To: /kaggle/working/dataset_BTXRD.zip
# 100%|██████████████████████████████████████| 1.71G/1.71G [00:17<00:00, 95.3MB/s]
#
# DATASET STRUCTURE:
# test  train  val
# /kaggle/working/PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation
#
# SETUP DONE!

# %% [markdown]
# **Train** (covering-only, like the original PGA-UNet protocol)

# %%
# =========================================================
# TRAIN - center_zoom prompt, scale x2 (covering-only, like the original PGA-UNet protocol)
# =========================================================

# !PROMPT_DATASET_ROOT=dataset_BTXRD PROMPT_IMG_SIZE=512 \
 PROMPT_MODE=center_zoom PROMPT_SCALE_FACTOR=2.0 PROMPT_SHIFT_RATIO=0.5 \
 python train.py
# Out:
# ==========================================================================================
# TrainPrompt: center_zoom | Device: cuda | EncoderPrompt: True | ImgSize: 512 | DatasetRoot: dataset_BTXRD | ScaleFactor: 2.0
# ==========================================================================================
# Epoch 1/100 [Train]: 100%|███████| 462/462 [01:57<00:00,  3.92it/s, loss=1.2923]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.4543 | [CENTER_] Dice:0.5809 IoU:0.4251 CBL:0.7837 | [CENTER_] Dice:0.5463 IoU:0.3894 CBL:0.7161 | LR:1.0e-04
# Epoch 2/100 [Train]: 100%|███████| 462/462 [01:58<00:00,  3.91it/s, loss=1.2238]
# 🥇 [BEST] Epoch   2 | T_Loss: 1.3026 | [CENTER_] Dice:0.6773 IoU:0.5334 CBL:0.9055 | [CENTER_] Dice:0.5868 IoU:0.4316 CBL:0.8029 | LR:1.0e-04
# Epoch 3/100 [Train]: 100%|███████| 462/462 [01:58<00:00,  3.91it/s, loss=1.1426]
# 🥇 [BEST] Epoch   3 | T_Loss: 1.2077 | [CENTER_] Dice:0.7144 IoU:0.5756 CBL:0.9194 | [CENTER_] Dice:0.5999 IoU:0.4414 CBL:0.8240 | LR:1.0e-04
# Epoch 4/100 [Train]: 100%|███████| 462/462 [01:58<00:00,  3.91it/s, loss=1.1831]
# Epoch   4 | T_Loss: 1.1269 | [CENTER_] Dice:0.6531 IoU:0.5037 CBL:0.9085 | [CENTER_] Dice:0.6024 IoU:0.4472 CBL:0.8474 | LR:1.0e-04
# Epoch 5/100 [Train]: 100%|███████| 462/462 [01:58<00:00,  3.90it/s, loss=1.0995]
# 🥇 [BEST] Epoch   5 | T_Loss: 1.0492 | [CENTER_] Dice:0.7316 IoU:0.5999 CBL:0.9217 | [CENTER_] Dice:0.6010 IoU:0.4426 CBL:0.8257 | LR:1.0e-04
# Epoch 6/100 [Train]: 100%|███████| 462/462 [01:58<00:00,  3.91it/s, loss=1.0392]
# 🥇 [BEST] Epoch   6 | T_Loss: 0.9825 | [CENTER_] Dice:0.7334 IoU:0.6026 CBL:0.8874 | [CENTER_] Dice:0.5650 IoU:0.4086 CBL:0.7949 | LR:1.0e-04
# Epoch 7/100 [Train]: 100%|███████| 462/462 [01:58<00:00,  3.91it/s, loss=0.8115]
# Epoch   7 | T_Loss: 0.8969 | [CENTER_] Dice:0.7277 IoU:0.5929 CBL:0.9231 | [CENTER_] Dice:0.6066 IoU:0.4496 CBL:0.8241 | LR:1.0e-04
# Epoch 8/100 [Train]: 100%|███████| 462/462 [01:57<00:00,  3.92it/s, loss=0.5856]
# Epoch   8 | T_Loss: 0.8293 | [CENTER_] Dice:0.7051 IoU:0.5759 CBL:0.8389 | [CENTER_] Dice:0.6113 IoU:0.4613 CBL:0.7835 | LR:1.0e-04
# Epoch 9/100 [Train]: 100%|███████| 462/462 [01:58<00:00,  3.90it/s, loss=0.7293]
# 🥇 [BEST] Epoch   9 | T_Loss: 0.7631 | [CENTER_] Dice:0.7358 IoU:0.6070 CBL:0.9160 | [CENTER_] Dice:0.6319 IoU:0.4795 CBL:0.8373 | LR:1.0e-04
# Epoch 10/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.6464]
# 🥇 [BEST] Epoch  10 | T_Loss: 0.6978 | [CENTER_] Dice:0.7378 IoU:0.6069 CBL:0.8825 | [CENTER_] Dice:0.6497 IoU:0.4982 CBL:0.8291 | LR:1.0e-04
# Epoch 11/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.4870]
# 🥇 [BEST] Epoch  11 | T_Loss: 0.6505 | [CENTER_] Dice:0.7617 IoU:0.6431 CBL:0.8888 | [CENTER_] Dice:0.5922 IoU:0.4371 CBL:0.8008 | LR:1.0e-04
# Epoch 12/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.4105]
# 🥇 [BEST] Epoch  12 | T_Loss: 0.6049 | [CENTER_] Dice:0.7692 IoU:0.6484 CBL:0.9214 | [CENTER_] Dice:0.6463 IoU:0.4928 CBL:0.8434 | LR:1.0e-04
# Epoch 13/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.5061]
# Epoch  13 | T_Loss: 0.5578 | [CENTER_] Dice:0.7641 IoU:0.6412 CBL:0.9317 | [CENTER_] Dice:0.6095 IoU:0.4517 CBL:0.8383 | LR:1.0e-04
# Epoch 14/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.7846]
# 🥇 [BEST] Epoch  14 | T_Loss: 0.5157 | [CENTER_] Dice:0.7927 IoU:0.6739 CBL:0.9415 | [CENTER_] Dice:0.6249 IoU:0.4678 CBL:0.8375 | LR:1.0e-04
# Epoch 15/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.2670]
# 🥇 [BEST] Epoch  15 | T_Loss: 0.4576 | [CENTER_] Dice:0.8009 IoU:0.6839 CBL:0.9437 | [CENTER_] Dice:0.6420 IoU:0.4861 CBL:0.8559 | LR:1.0e-04
# Epoch 16/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.8041]
# Epoch  16 | T_Loss: 0.4178 | [CENTER_] Dice:0.7963 IoU:0.6823 CBL:0.9395 | [CENTER_] Dice:0.6388 IoU:0.4846 CBL:0.8531 | LR:1.0e-04
# Epoch 17/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=1.0287]
# 🥇 [BEST] Epoch  17 | T_Loss: 0.4015 | [CENTER_] Dice:0.8162 IoU:0.7014 CBL:0.9443 | [CENTER_] Dice:0.6731 IoU:0.5191 CBL:0.8658 | LR:1.0e-04
# Epoch 18/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.2430]
# 🥇 [BEST] Epoch  18 | T_Loss: 0.3893 | [CENTER_] Dice:0.8221 IoU:0.7085 CBL:0.9480 | [CENTER_] Dice:0.6582 IoU:0.5016 CBL:0.8500 | LR:1.0e-04
# Epoch 19/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.2739]
# 🥇 [BEST] Epoch  19 | T_Loss: 0.3453 | [CENTER_] Dice:0.8229 IoU:0.7094 CBL:0.9483 | [CENTER_] Dice:0.6597 IoU:0.5051 CBL:0.8572 | LR:1.0e-04
# Epoch 20/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.2100]
# 🥇 [BEST] Epoch  20 | T_Loss: 0.3478 | [CENTER_] Dice:0.8356 IoU:0.7268 CBL:0.9517 | [CENTER_] Dice:0.6503 IoU:0.4941 CBL:0.8544 | LR:1.0e-04
# Epoch 21/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.2707]
# Epoch  21 | T_Loss: 0.3365 | [CENTER_] Dice:0.8157 IoU:0.7030 CBL:0.9466 | [CENTER_] Dice:0.6568 IoU:0.5020 CBL:0.8652 | LR:1.0e-04
# Epoch 22/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.1751]
# Epoch  22 | T_Loss: 0.3100 | [CENTER_] Dice:0.8250 IoU:0.7155 CBL:0.9467 | [CENTER_] Dice:0.6763 IoU:0.5248 CBL:0.8682 | LR:1.0e-04
# Epoch 23/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=1.0522]
# Epoch  23 | T_Loss: 0.3313 | [CENTER_] Dice:0.8303 IoU:0.7203 CBL:0.9512 | [CENTER_] Dice:0.6758 IoU:0.5239 CBL:0.8599 | LR:1.0e-04
# Epoch 24/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.2080]
# Epoch  24 | T_Loss: 0.3078 | [CENTER_] Dice:0.8136 IoU:0.6975 CBL:0.9449 | [CENTER_] Dice:0.6688 IoU:0.5159 CBL:0.8656 | LR:1.0e-04
# Epoch 25/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.2128]
# Epoch  25 | T_Loss: 0.2995 | [CENTER_] Dice:0.8231 IoU:0.7104 CBL:0.9431 | [CENTER_] Dice:0.6885 IoU:0.5367 CBL:0.8668 | LR:1.0e-04
# Epoch 26/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.1684]
# Epoch  26 | T_Loss: 0.2943 | [CENTER_] Dice:0.8341 IoU:0.7257 CBL:0.9495 | [CENTER_] Dice:0.7011 IoU:0.5519 CBL:0.8738 | LR:5.0e-05
# Epoch 27/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.0919]
# 🥇 [BEST] Epoch  27 | T_Loss: 0.2741 | [CENTER_] Dice:0.8427 IoU:0.7377 CBL:0.9520 | [CENTER_] Dice:0.7060 IoU:0.5573 CBL:0.8727 | LR:5.0e-05
# Epoch 28/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.1125]
# 🥇 [BEST] Epoch  28 | T_Loss: 0.2849 | [CENTER_] Dice:0.8435 IoU:0.7390 CBL:0.9509 | [CENTER_] Dice:0.7146 IoU:0.5689 CBL:0.8763 | LR:5.0e-05
# Epoch 29/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.2398]
# Epoch  29 | T_Loss: 0.2817 | [CENTER_] Dice:0.8315 IoU:0.7228 CBL:0.9498 | [CENTER_] Dice:0.6816 IoU:0.5305 CBL:0.8713 | LR:5.0e-05
# Epoch 30/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.9187]
# Epoch  30 | T_Loss: 0.2566 | [CENTER_] Dice:0.8340 IoU:0.7268 CBL:0.9506 | [CENTER_] Dice:0.6943 IoU:0.5470 CBL:0.8817 | LR:5.0e-05
# Epoch 31/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.1166]
# 🥇 [BEST] Epoch  31 | T_Loss: 0.2713 | [CENTER_] Dice:0.8527 IoU:0.7527 CBL:0.9539 | [CENTER_] Dice:0.6897 IoU:0.5389 CBL:0.8650 | LR:5.0e-05
# Epoch 32/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1338]
# 🥇 [BEST] Epoch  32 | T_Loss: 0.2594 | [CENTER_] Dice:0.8553 IoU:0.7559 CBL:0.9545 | [CENTER_] Dice:0.7047 IoU:0.5560 CBL:0.8743 | LR:5.0e-05
# Epoch 33/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.2123]
# Epoch  33 | T_Loss: 0.2545 | [CENTER_] Dice:0.8539 IoU:0.7538 CBL:0.9538 | [CENTER_] Dice:0.7168 IoU:0.5712 CBL:0.8802 | LR:5.0e-05
# Epoch 34/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1875]
# Epoch  34 | T_Loss: 0.2812 | [CENTER_] Dice:0.8506 IoU:0.7497 CBL:0.9525 | [CENTER_] Dice:0.6821 IoU:0.5312 CBL:0.8654 | LR:5.0e-05
# Epoch 35/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.8251]
# Epoch  35 | T_Loss: 0.2728 | [CENTER_] Dice:0.8491 IoU:0.7475 CBL:0.9506 | [CENTER_] Dice:0.6949 IoU:0.5456 CBL:0.8693 | LR:5.0e-05
# Epoch 36/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1160]
# Epoch  36 | T_Loss: 0.2595 | [CENTER_] Dice:0.8519 IoU:0.7510 CBL:0.9515 | [CENTER_] Dice:0.7237 IoU:0.5803 CBL:0.8851 | LR:5.0e-05
# Epoch 37/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.1123]
# Epoch  37 | T_Loss: 0.2666 | [CENTER_] Dice:0.8519 IoU:0.7516 CBL:0.9538 | [CENTER_] Dice:0.6867 IoU:0.5360 CBL:0.8676 | LR:5.0e-05
# Epoch 38/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1569]
# Epoch  38 | T_Loss: 0.2598 | [CENTER_] Dice:0.8457 IoU:0.7431 CBL:0.9501 | [CENTER_] Dice:0.7115 IoU:0.5648 CBL:0.8743 | LR:2.5e-05
# Epoch 39/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.91it/s, loss=0.1411]
# Epoch  39 | T_Loss: 0.2629 | [CENTER_] Dice:0.8511 IoU:0.7498 CBL:0.9509 | [CENTER_] Dice:0.7207 IoU:0.5756 CBL:0.8793 | LR:2.5e-05
# Epoch 40/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.2671]
# Epoch  40 | T_Loss: 0.2539 | [CENTER_] Dice:0.8516 IoU:0.7518 CBL:0.9520 | [CENTER_] Dice:0.7226 IoU:0.5780 CBL:0.8818 | LR:2.5e-05
# Epoch 41/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.3303]
# 🥇 [BEST] Epoch  41 | T_Loss: 0.2681 | [CENTER_] Dice:0.8626 IoU:0.7675 CBL:0.9569 | [CENTER_] Dice:0.6954 IoU:0.5453 CBL:0.8703 | LR:2.5e-05
# Epoch 42/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1136]
# Epoch  42 | T_Loss: 0.2486 | [CENTER_] Dice:0.8533 IoU:0.7534 CBL:0.9520 | [CENTER_] Dice:0.7185 IoU:0.5729 CBL:0.8828 | LR:2.5e-05
# Epoch 43/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.8281]
# Epoch  43 | T_Loss: 0.2559 | [CENTER_] Dice:0.8547 IoU:0.7559 CBL:0.9532 | [CENTER_] Dice:0.7194 IoU:0.5742 CBL:0.8806 | LR:2.5e-05
# Epoch 44/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1322]
# Epoch  44 | T_Loss: 0.2410 | [CENTER_] Dice:0.8537 IoU:0.7548 CBL:0.9534 | [CENTER_] Dice:0.7188 IoU:0.5732 CBL:0.8825 | LR:2.5e-05
# Epoch 45/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1950]
# Epoch  45 | T_Loss: 0.2469 | [CENTER_] Dice:0.8554 IoU:0.7569 CBL:0.9532 | [CENTER_] Dice:0.7185 IoU:0.5724 CBL:0.8806 | LR:2.5e-05
# Epoch 46/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.89it/s, loss=0.1111]
# Epoch  46 | T_Loss: 0.2628 | [CENTER_] Dice:0.8550 IoU:0.7564 CBL:0.9544 | [CENTER_] Dice:0.7117 IoU:0.5642 CBL:0.8788 | LR:2.5e-05
# Epoch 47/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1176]
# Epoch  47 | T_Loss: 0.2540 | [CENTER_] Dice:0.8520 IoU:0.7520 CBL:0.9508 | [CENTER_] Dice:0.7193 IoU:0.5730 CBL:0.8782 | LR:1.3e-05
# Epoch 48/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1345]
# Epoch  48 | T_Loss: 0.2551 | [CENTER_] Dice:0.8550 IoU:0.7562 CBL:0.9526 | [CENTER_] Dice:0.7180 IoU:0.5718 CBL:0.8819 | LR:1.3e-05
# Epoch 49/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1093]
# Epoch  49 | T_Loss: 0.2411 | [CENTER_] Dice:0.8589 IoU:0.7614 CBL:0.9542 | [CENTER_] Dice:0.7181 IoU:0.5721 CBL:0.8785 | LR:1.3e-05
# Epoch 50/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.2507]
# Epoch  50 | T_Loss: 0.2350 | [CENTER_] Dice:0.8562 IoU:0.7577 CBL:0.9536 | [CENTER_] Dice:0.7192 IoU:0.5740 CBL:0.8791 | LR:1.3e-05
# Epoch 51/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1697]
# Epoch  51 | T_Loss: 0.2690 | [CENTER_] Dice:0.8570 IoU:0.7590 CBL:0.9545 | [CENTER_] Dice:0.7122 IoU:0.5658 CBL:0.8800 | LR:1.3e-05
# Epoch 52/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1961]
# Epoch  52 | T_Loss: 0.2262 | [CENTER_] Dice:0.8564 IoU:0.7579 CBL:0.9539 | [CENTER_] Dice:0.7124 IoU:0.5655 CBL:0.8768 | LR:1.3e-05
# Epoch 53/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1293]
# Epoch  53 | T_Loss: 0.2453 | [CENTER_] Dice:0.8575 IoU:0.7595 CBL:0.9536 | [CENTER_] Dice:0.7240 IoU:0.5788 CBL:0.8828 | LR:6.3e-06
# Epoch 54/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.89it/s, loss=0.0956]
# Epoch  54 | T_Loss: 0.2357 | [CENTER_] Dice:0.8571 IoU:0.7595 CBL:0.9540 | [CENTER_] Dice:0.7139 IoU:0.5671 CBL:0.8801 | LR:6.3e-06
# Epoch 55/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.1581]
# Epoch  55 | T_Loss: 0.2406 | [CENTER_] Dice:0.8593 IoU:0.7625 CBL:0.9549 | [CENTER_] Dice:0.7132 IoU:0.5665 CBL:0.8770 | LR:6.3e-06
# Epoch 56/100 [Train]: 100%|██████| 462/462 [01:58<00:00,  3.90it/s, loss=0.3158]
# Epoch  56 | T_Loss: 0.2258 | [CENTER_] Dice:0.8598 IoU:0.7633 CBL:0.9546 | [CENTER_] Dice:0.7118 IoU:0.5647 CBL:0.8755 | LR:6.3e-06
# Early stopping at epoch 56.
#
# Best Dice (center_zoom): 0.8626
# Checkpoint: checkpoints/pga_unet_center_zoom_x2_512_best.pth

# %% [markdown]
# ## Test - Zoom and Zoom + shift (x2, shift up to 50%)

# %%
# @title
"""
test_center_zoom_x2_shift05.py
=====================
Evaluation of two prompt scenarios: 100% Zoom (center_zoom, x2) | 100% Zoom + shift (center_shift, x2, shift up to 50%)
Mirrors the original PGA-UNet dual-condition test (zoom_out / shift), with
the covering-box formula replaced by the center-scaled one this checkpoint
was trained under. No legacy zoom_out/shift comparison here.

Usage:
    python test_center_zoom_x2_shift05.py
"""

import os
import sys
import cv2
import json
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from scipy.ndimage import binary_erosion, distance_transform_edt

import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset
from models.networks.prompt_unet_2D import PGA_UNet

# =========================================================
# CONFIGURATION - edit here
# =========================================================
DEVICE             = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_PATH         = "checkpoints/pga_unet_center_zoom_x2_512_best.pth"
IMG_SIZE           = 512
BATCH_SIZE         = 4
USE_ENCODER_PROMPT = True   # must match the training config above

SCALE_FACTOR = 2.0
SHIFT_RATIO  = 0.5

TEST_IMAGE_DIR = "dataset_BTXRD/test/images"
TEST_JSON_DIR  = "dataset_BTXRD/test/annotations"


# =========================================================
# METRIC HELPERS & POST-PROCESSING
# =========================================================

def extract_lcc(binary_map: np.ndarray) -> np.ndarray:
    if binary_map.sum() == 0:
        return binary_map
    mask_uint8 = binary_map.astype(np.uint8)
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(mask_uint8, connectivity=8)
    if num_labels <= 1:
        return binary_map
    largest_label = 1 + np.argmax(stats[1:, cv2.CC_STAT_AREA])
    return (labels == largest_label).astype(np.float32)

def calc_hd95(pred: np.ndarray, gt: np.ndarray) -> float:
    pred, gt = pred.astype(bool), gt.astype(bool)
    if not pred.any() and not gt.any():
        return 0.0
    if not pred.any() or not gt.any():
        return float(IMG_SIZE)
    pe = pred ^ binary_erosion(pred)
    ge = gt   ^ binary_erosion(gt)
    d1 = distance_transform_edt(~ge)[pe]
    d2 = distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2):
        return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))

def calc_cbl(pred_bin: np.ndarray, gt_bin: np.ndarray):
    if gt_bin.sum() == 0:
        return None
    ys, xs = np.where(gt_bin)
    gt_diag = np.sqrt((ys.max() - ys.min()) ** 2 +
                      (xs.max() - xs.min()) ** 2) + 1e-6
    if pred_bin.sum() == 0:
        return 0.0
    yp, xp = np.where(pred_bin)
    d = np.sqrt((xp.mean() - xs.mean()) ** 2 +
                (yp.mean() - ys.mean()) ** 2)
    return float(np.clip(1.0 - d / gt_diag, 0.0, 1.0))

def get_centroid(binary_map: np.ndarray):
    if binary_map.sum() == 0:
        return None, None
    ys, xs = np.where(binary_map)
    return float(xs.mean()), float(ys.mean())

# =========================================================
# SINGLE-SCENARIO EVALUATION
# =========================================================

def run_eval(model: torch.nn.Module, prompt_mode: str, **ds_kwargs) -> dict:
    ds = PromptSegmentationDataset(
        image_dir=TEST_IMAGE_DIR,
        json_dir=TEST_JSON_DIR,
        img_size=IMG_SIZE,
        is_train=False,
        prompt_mode=prompt_mode,
        **ds_kwargs,
    )
    loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

    smooth = 1e-5
    all_dice, all_iou, all_pre, all_rec, all_hd95, all_cbl = [], [], [], [], [], []

    model.eval()
    with torch.no_grad():
        for images, masks, prompts in loader:
            images  = images.to(DEVICE)
            masks   = masks.to(DEVICE)
            prompts = prompts.to(DEVICE)
            preds   = (torch.sigmoid(model(images, prompts)) > 0.5).float()

            for b in range(images.size(0)):
                pm = preds[b, 0].cpu().numpy()
                gm = masks[b, 0].cpu().numpy()
                pm = extract_lcc(pm)

                tp = (pm * gm).sum()
                fp = (pm * (1 - gm)).sum()
                fn = ((1 - pm) * gm).sum()

                all_dice.append((2 * tp + smooth) / (2 * tp + fp + fn + smooth))
                all_iou.append( (tp + smooth) / (tp + fp + fn + smooth))
                all_pre.append( (tp + smooth) / (tp + fp + smooth))
                all_rec.append( (tp + smooth) / (tp + fn + smooth))
                all_hd95.append(calc_hd95(pm.astype(bool), gm.astype(bool)))

                cbl = calc_cbl(pm.astype(bool), gm.astype(bool))
                if cbl is not None:
                    all_cbl.append(cbl)

    return {
        'dice': np.mean(all_dice),
        'iou':  np.mean(all_iou),
        'pre':  np.mean(all_pre),
        'rec':  np.mean(all_rec),
        'hd95': np.mean(all_hd95),
        'cbl':  np.mean(all_cbl) if all_cbl else 0.0,
        'n':    len(all_dice),
    }

# =========================================================
# TWO-SCENARIO EVALUATION: Zoom (center_zoom) and Zoom + shift (center_shift),
# both at the exact scale_factor/shift_ratio this checkpoint was trained
# under. This mirrors the original PGA-UNet zoom_out/shift dual-condition
# test; no legacy zoom_out/shift comparison is included here.
# =========================================================

def evaluate_all(model: torch.nn.Module) -> dict:
    enc_tag = 'ON' if USE_ENCODER_PROMPT else 'OFF'
    print("\n" + "=" * 72)
    print(f"  TWO-SCENARIO EVALUATION  |  center-zoom x{SCALE_FACTOR:g}  |  encoder_prompt = {enc_tag}")
    print("=" * 72)

    scenarios = {
        'Zoom (center_zoom)':        dict(prompt_mode='center_zoom', scale_factor=SCALE_FACTOR),
        'Zoom + shift (center_shift)': dict(prompt_mode='center_shift', scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO),
    }

    results = {}
    for name, kwargs in scenarios.items():
        results[name] = run_eval(model, **kwargs)
        print(f"  [{name}]  {results[name]['n']} samples, completed.")

    header = (f"\n{'Scenario':<30} {'Dice↑':>7} {'IoU↑':>7} "
              f"{'Pre↑':>7} {'Rec↑':>7} {'HD95↓':>8} {'CBL↑':>7} {'N':>5}")
    print(header)
    print("-" * 82)
    for name, r in results.items():
        print(f"{name:<30} {r['dice']:>7.4f} {r['iou']:>7.4f} "
              f"{r['pre']:>7.4f} {r['rec']:>7.4f} "
              f"{r['hd95']:>8.2f} {r['cbl']:>7.4f} {r['n']:>5}")
    return results

# =========================================================
# LOAD MODEL
# =========================================================
model = PGA_UNet(use_encoder_prompt=USE_ENCODER_PROMPT).to(DEVICE)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval()
print(f"Model loaded from: {MODEL_PATH}")

# =========================================================
# TWO-SCENARIO EVALUATION: summary table
# =========================================================
results = evaluate_all(model)

# =========================================================
# VISUALIZATION - first 10 samples in order (Zoom, center_zoom)
# =========================================================
from IPython.display import display as _ipy_display
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from torch.utils.data import DataLoader
import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset

N_SHOW  = 10
_vis_dl = DataLoader(
    PromptSegmentationDataset(TEST_IMAGE_DIR, TEST_JSON_DIR, img_size=IMG_SIZE, is_train=False,
                              prompt_mode="center_zoom", scale_factor=SCALE_FACTOR),
    batch_size=1, shuffle=False, num_workers=0)

fig, axes = plt.subplots(N_SHOW, 5, figsize=(20, 4 * N_SHOW))
fig.suptitle(f"PGA-UNet center_zoom (x{SCALE_FACTOR:g}) - Visualization (Zoom, first 10 samples)", fontsize=13, y=1.001)
for ax, ct in zip(axes[0], ["Input image", "Image + prompt", "Prediction", "Ground truth", "TP/FP/FN"]):
    ax.set_title(ct, fontsize=10, fontweight="bold")

model.eval()
count = 0
with torch.no_grad():
    for _img, _gt, _hm in _vis_dl:
        if count >= N_SHOW: break
        img_np  = (_img[0,0].cpu().numpy() * 0.5 + 0.5)
        hm_np   = _hm[0,0].cpu().numpy()
        gt_np   = (_gt[0,0].cpu().numpy() > 0.5).astype(float)
        prob_np = torch.sigmoid(model(_img.to(DEVICE), _hm.to(DEVICE)))[0,0].cpu().numpy()
        pred_np = (prob_np > 0.5).astype(float)

        tp=(pred_np*gt_np).sum(); fp=(pred_np*(1-gt_np)).sum(); fn=((1-pred_np)*gt_np).sum(); e=1e-6
        dice=float((2*tp+e)/(2*tp+fp+fn+e)); iou=float((tp+e)/(tp+fp+fn+e))
        pre=float((tp+e)/(tp+fp+e));         rec=float((tp+e)/(tp+fn+e))

        row = axes[count]
        bg  = np.stack([img_np]*3, axis=-1)

        row[0].imshow(img_np, cmap="gray", vmin=0, vmax=1)
        row[0].set_ylabel(f"#{count+1} Dice={dice:.3f}", fontsize=8)

        row[1].imshow(img_np, cmap="gray", vmin=0, vmax=1)
        row[1].imshow(hm_np, cmap="hot", alpha=0.4, vmin=0, vmax=1)

        pr_ov = bg.copy()
        pr_ov[...,0] = np.clip(pr_ov[...,0] + pred_np*0.55, 0, 1)
        pr_ov[...,1] = np.clip(pr_ov[...,1] - pred_np*0.2,  0, 1)
        row[2].imshow(pr_ov)
        row[2].set_title(f"Dice={dice:.3f} IoU={iou:.3f}", fontsize=7, color="darkred", pad=2)

        gt_ov = bg.copy()
        gt_ov[...,1] = np.clip(gt_ov[...,1] + gt_np*0.55, 0, 1)
        gt_ov[...,0] = np.clip(gt_ov[...,0] - gt_np*0.2,  0, 1)
        row[3].imshow(gt_ov)

        inter = bg.copy() * 0.25
        inter[...,1] = np.clip(inter[...,1] + pred_np*gt_np*0.9,     0, 1)
        inter[...,0] = np.clip(inter[...,0] + pred_np*(1-gt_np)*1.0, 0, 1)
        inter[...,2] = np.clip(inter[...,2] + (1-pred_np)*gt_np*1.0, 0, 1)
        row[4].imshow(inter)
        row[4].set_title(f"Pre={pre:.3f} Rec={rec:.3f}", fontsize=7, color="saddlebrown", pad=2)

        for ax in row: ax.axis("off")
        count += 1

fig.legend(handles=[Patch(facecolor="green",label="TP"),Patch(facecolor="red",label="FP"),Patch(facecolor="blue",label="FN")],
           loc="lower center", ncol=3, fontsize=9, bbox_to_anchor=(0.5,-0.01))
plt.tight_layout()
_ipy_display(fig)
plt.close(fig)
# Out:
# Model loaded from: checkpoints/pga_unet_center_zoom_x2_512_best.pth
#
# ========================================================================
#   TWO-SCENARIO EVALUATION  |  center-zoom x2  |  encoder_prompt = ON
# ========================================================================
#   [Zoom (center_zoom)]  232 samples, completed.
#   [Zoom + shift (center_shift)]  232 samples, completed.
#
# Scenario                         Dice↑    IoU↑    Pre↑    Rec↑    HD95↓    CBL↑     N
# ----------------------------------------------------------------------------------
# Zoom (center_zoom)              0.8579  0.7605  0.8290  0.9028    10.38  0.9549   232
# Zoom + shift (center_shift)     0.6855  0.5333  0.6940  0.6998    17.99  0.8555   232
