# %% [markdown]
# **Full environment, dataset, and code setup** (BTXRD, 512x512, center_zoom prompt: x3, shift up to 50%)

# %%
# =========================================================
# CELL 1 - FULL SETUP COLAB / KAGGLE
# =========================================================
# ===== CHANGE DIRECTORY (auto-detect Colab / Kaggle) =====
import os
BASE = "/kaggle/working" if os.path.exists("/kaggle/working") else "/content"
# %cd $BASE
# ===== CHECK GPU =====
import torch

print("=" * 50)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("=" * 50)

# =========================================================
# CLONE GITHUB (research branch: adds the 'center_zoom'/'center_shift' prompt modes)
# =========================================================

# !rm -rf $BASE/PGA_Unet2D
# !git clone -b research/prompt-scale-protocol https://github.com/ThongLuc2k3/PGA_Unet2D.git

# =========================================================
# DOWNLOAD DATASET ZIP FROM GOOGLE DRIVE
# =========================================================

# !gdown --id 1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx

# =========================================================
# UNZIP DATASET
# =========================================================

# !unzip -oq dataset_BTXRD.zip

# =========================================================
# INSPECT DATASET
# =========================================================

print("\nDATASET STRUCTURE:")
# !ls dataset_BTXRD

# =========================================================
# COPY DATASET INTO THE PROJECT
# =========================================================

# !rm -rf PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/dataset_BTXRD
# !mv dataset_BTXRD PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/

# =========================================================
# ENTER THE PROJECT DIRECTORY
# =========================================================

# %cd PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation

# =========================================================
# INSTALL REQUIREMENTS
# =========================================================

# !pip install -q tqdm opencv-python matplotlib scikit-image gdown scipy

print("\nSETUP DONE!")
# Out:
# /kaggle/working
# ==================================================
# CUDA: True
# GPU: Tesla T4
# ==================================================
# Cloning into 'PGA_Unet2D'...
# remote: Enumerating objects: 3929, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 3929 (delta 75), reused 114 (delta 47), pack-reused 3740 (from 2)
# Receiving objects: 100% (3929/3929), 1.22 GiB | 5.77 MiB/s, done.
# Resolving deltas: 100% (2256/2256), done.
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx
# From (redirected): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx&confirm=t&uuid=f0311d62-2d70-4228-8f87-461205b3837d
# To: /kaggle/working/dataset_BTXRD.zip
# 100%|███████████████████████████████████████| 1.71G/1.71G [00:14<00:00, 115MB/s]
#
# DATASET STRUCTURE:
# test  train  val
# /kaggle/working/PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation
#
# SETUP DONE!

# %% [markdown]
# **Train** (covering-only, like the original PGA-UNet protocol)

# %%
# =========================================================
# TRAIN - center_zoom prompt, scale x3 (covering-only, like the original PGA-UNet protocol)
# =========================================================

# !PROMPT_DATASET_ROOT=dataset_BTXRD PROMPT_IMG_SIZE=512 \
 PROMPT_MODE=center_zoom PROMPT_SCALE_FACTOR=3.0 PROMPT_SHIFT_RATIO=0.5 \
 python train.py
# Out:
# ==========================================================================================
# TrainPrompt: center_zoom | Device: cuda | EncoderPrompt: True | ImgSize: 512 | DatasetRoot: dataset_BTXRD | ScaleFactor: 3.0
# ==========================================================================================
# Epoch 1/100 [Train]: 100%|███████| 462/462 [01:57<00:00,  3.93it/s, loss=1.3180]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.3680 | [CENTER_] Dice:0.4551 IoU:0.3230 CBL:0.6335 | [CENTER_] Dice:0.4158 IoU:0.2863 CBL:0.5828 | LR:1.0e-04
# Epoch 2/100 [Train]: 100%|███████| 462/462 [02:02<00:00,  3.76it/s, loss=1.1949]
# 🥇 [BEST] Epoch   2 | T_Loss: 1.2262 | [CENTER_] Dice:0.5438 IoU:0.4031 CBL:0.7123 | [CENTER_] Dice:0.4947 IoU:0.3555 CBL:0.6684 | LR:1.0e-04
# Epoch 3/100 [Train]: 100%|███████| 462/462 [02:02<00:00,  3.76it/s, loss=1.1543]
# Epoch   3 | T_Loss: 1.1239 | [CENTER_] Dice:0.5428 IoU:0.3954 CBL:0.8180 | [CENTER_] Dice:0.4280 IoU:0.2921 CBL:0.7295 | LR:1.0e-04
# Epoch 4/100 [Train]: 100%|███████| 462/462 [02:03<00:00,  3.76it/s, loss=1.1003]
# Epoch   4 | T_Loss: 1.0434 | [CENTER_] Dice:0.4744 IoU:0.3222 CBL:0.8370 | [CENTER_] Dice:0.4710 IoU:0.3197 CBL:0.7781 | LR:1.0e-04
# Epoch 5/100 [Train]: 100%|███████| 462/462 [02:02<00:00,  3.76it/s, loss=0.8248]
# 🥇 [BEST] Epoch   5 | T_Loss: 0.9733 | [CENTER_] Dice:0.5638 IoU:0.4185 CBL:0.7971 | [CENTER_] Dice:0.5369 IoU:0.3925 CBL:0.7523 | LR:1.0e-04
# Epoch 6/100 [Train]: 100%|███████| 462/462 [02:02<00:00,  3.77it/s, loss=0.8525]
# 🥇 [BEST] Epoch   6 | T_Loss: 0.9051 | [CENTER_] Dice:0.5983 IoU:0.4677 CBL:0.8215 | [CENTER_] Dice:0.5129 IoU:0.3770 CBL:0.7703 | LR:1.0e-04
# Epoch 7/100 [Train]: 100%|███████| 462/462 [02:03<00:00,  3.75it/s, loss=0.6418]
# Epoch   7 | T_Loss: 0.8446 | [CENTER_] Dice:0.5916 IoU:0.4387 CBL:0.8497 | [CENTER_] Dice:0.5234 IoU:0.3729 CBL:0.7747 | LR:1.0e-04
# Epoch 8/100 [Train]: 100%|███████| 462/462 [02:02<00:00,  3.76it/s, loss=0.7006]
# 🥇 [BEST] Epoch   8 | T_Loss: 0.7810 | [CENTER_] Dice:0.6231 IoU:0.4875 CBL:0.8365 | [CENTER_] Dice:0.5322 IoU:0.3921 CBL:0.7685 | LR:1.0e-04
# Epoch 9/100 [Train]: 100%|███████| 462/462 [02:03<00:00,  3.76it/s, loss=0.9929]
# Epoch   9 | T_Loss: 0.7336 | [CENTER_] Dice:0.5777 IoU:0.4244 CBL:0.8531 | [CENTER_] Dice:0.5441 IoU:0.3888 CBL:0.8010 | LR:1.0e-04
# Epoch 10/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.7986]
# 🥇 [BEST] Epoch  10 | T_Loss: 0.6742 | [CENTER_] Dice:0.6564 IoU:0.5225 CBL:0.8687 | [CENTER_] Dice:0.5818 IoU:0.4382 CBL:0.8125 | LR:1.0e-04
# Epoch 11/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.6551]
# Epoch  11 | T_Loss: 0.6185 | [CENTER_] Dice:0.6468 IoU:0.5076 CBL:0.8822 | [CENTER_] Dice:0.5708 IoU:0.4195 CBL:0.8232 | LR:1.0e-04
# Epoch 12/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.4158]
# 🥇 [BEST] Epoch  12 | T_Loss: 0.5570 | [CENTER_] Dice:0.6757 IoU:0.5369 CBL:0.8757 | [CENTER_] Dice:0.6355 IoU:0.4879 CBL:0.8423 | LR:1.0e-04
# Epoch 13/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.3868]
# 🥇 [BEST] Epoch  13 | T_Loss: 0.5239 | [CENTER_] Dice:0.7059 IoU:0.5736 CBL:0.8931 | [CENTER_] Dice:0.5772 IoU:0.4286 CBL:0.8145 | LR:1.0e-04
# Epoch 14/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=1.0202]
# Epoch  14 | T_Loss: 0.4777 | [CENTER_] Dice:0.6732 IoU:0.5278 CBL:0.8961 | [CENTER_] Dice:0.5963 IoU:0.4425 CBL:0.8234 | LR:1.0e-04
# Epoch 15/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.77it/s, loss=0.2991]
# 🥇 [BEST] Epoch  15 | T_Loss: 0.4475 | [CENTER_] Dice:0.7104 IoU:0.5745 CBL:0.9022 | [CENTER_] Dice:0.6307 IoU:0.4832 CBL:0.8569 | LR:1.0e-04
# Epoch 16/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.5470]
# 🥇 [BEST] Epoch  16 | T_Loss: 0.4399 | [CENTER_] Dice:0.7114 IoU:0.5734 CBL:0.8937 | [CENTER_] Dice:0.6427 IoU:0.4928 CBL:0.8454 | LR:1.0e-04
# Epoch 17/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.76it/s, loss=0.2229]
# 🥇 [BEST] Epoch  17 | T_Loss: 0.4294 | [CENTER_] Dice:0.7189 IoU:0.5814 CBL:0.9003 | [CENTER_] Dice:0.6043 IoU:0.4557 CBL:0.8289 | LR:1.0e-04
# Epoch 18/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.76it/s, loss=0.2671]
# 🥇 [BEST] Epoch  18 | T_Loss: 0.4454 | [CENTER_] Dice:0.7271 IoU:0.5956 CBL:0.8996 | [CENTER_] Dice:0.6205 IoU:0.4721 CBL:0.8349 | LR:1.0e-04
# Epoch 19/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.77it/s, loss=0.2376]
# 🥇 [BEST] Epoch  19 | T_Loss: 0.4069 | [CENTER_] Dice:0.7323 IoU:0.5961 CBL:0.9071 | [CENTER_] Dice:0.6526 IoU:0.5019 CBL:0.8450 | LR:1.0e-04
# Epoch 20/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.76it/s, loss=0.3706]
# Epoch  20 | T_Loss: 0.3894 | [CENTER_] Dice:0.7275 IoU:0.5970 CBL:0.9014 | [CENTER_] Dice:0.6351 IoU:0.4896 CBL:0.8470 | LR:1.0e-04
# Epoch 21/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.4369]
# Epoch  21 | T_Loss: 0.3935 | [CENTER_] Dice:0.7275 IoU:0.5962 CBL:0.9078 | [CENTER_] Dice:0.6432 IoU:0.4969 CBL:0.8587 | LR:1.0e-04
# Epoch 22/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.76it/s, loss=0.2812]
# Epoch  22 | T_Loss: 0.3877 | [CENTER_] Dice:0.7273 IoU:0.5949 CBL:0.9000 | [CENTER_] Dice:0.6234 IoU:0.4774 CBL:0.8468 | LR:1.0e-04
# Epoch 23/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.2213]
# 🥇 [BEST] Epoch  23 | T_Loss: 0.3759 | [CENTER_] Dice:0.7465 IoU:0.6086 CBL:0.9136 | [CENTER_] Dice:0.6558 IoU:0.5034 CBL:0.8451 | LR:1.0e-04
# Epoch 24/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.2082]
# Epoch  24 | T_Loss: 0.3665 | [CENTER_] Dice:0.7335 IoU:0.6006 CBL:0.9043 | [CENTER_] Dice:0.6829 IoU:0.5426 CBL:0.8639 | LR:1.0e-04
# Epoch 25/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.2707]
# 🥇 [BEST] Epoch  25 | T_Loss: 0.3886 | [CENTER_] Dice:0.7565 IoU:0.6281 CBL:0.9145 | [CENTER_] Dice:0.6561 IoU:0.5087 CBL:0.8590 | LR:1.0e-04
# Epoch 26/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.76it/s, loss=0.2664]
# Epoch  26 | T_Loss: 0.3644 | [CENTER_] Dice:0.6967 IoU:0.5715 CBL:0.8930 | [CENTER_] Dice:0.6318 IoU:0.4947 CBL:0.8571 | LR:1.0e-04
# Epoch 27/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.77it/s, loss=0.2454]
# Epoch  27 | T_Loss: 0.3707 | [CENTER_] Dice:0.7172 IoU:0.5923 CBL:0.8997 | [CENTER_] Dice:0.6029 IoU:0.4593 CBL:0.8354 | LR:1.0e-04
# Epoch 28/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.8146]
# Epoch  28 | T_Loss: 0.3504 | [CENTER_] Dice:0.7386 IoU:0.6120 CBL:0.9011 | [CENTER_] Dice:0.6492 IoU:0.5064 CBL:0.8536 | LR:1.0e-04
# Epoch 29/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.4133]
# 🥇 [BEST] Epoch  29 | T_Loss: 0.3489 | [CENTER_] Dice:0.7576 IoU:0.6299 CBL:0.9138 | [CENTER_] Dice:0.6460 IoU:0.4979 CBL:0.8441 | LR:1.0e-04
# Epoch 30/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.2509]
# Epoch  30 | T_Loss: 0.3310 | [CENTER_] Dice:0.7372 IoU:0.6105 CBL:0.9109 | [CENTER_] Dice:0.6599 IoU:0.5176 CBL:0.8646 | LR:1.0e-04
# Epoch 31/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.2061]
# Epoch  31 | T_Loss: 0.3410 | [CENTER_] Dice:0.7266 IoU:0.6031 CBL:0.9072 | [CENTER_] Dice:0.6159 IoU:0.4752 CBL:0.8475 | LR:1.0e-04
# Epoch 32/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.3808]
# 🥇 [BEST] Epoch  32 | T_Loss: 0.3426 | [CENTER_] Dice:0.7702 IoU:0.6446 CBL:0.9145 | [CENTER_] Dice:0.6888 IoU:0.5445 CBL:0.8613 | LR:1.0e-04
# Epoch 33/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.2465]
# Epoch  33 | T_Loss: 0.3280 | [CENTER_] Dice:0.7684 IoU:0.6437 CBL:0.9186 | [CENTER_] Dice:0.7128 IoU:0.5774 CBL:0.8761 | LR:1.0e-04
# Epoch 34/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.3835]
# 🥇 [BEST] Epoch  34 | T_Loss: 0.3186 | [CENTER_] Dice:0.7738 IoU:0.6508 CBL:0.9236 | [CENTER_] Dice:0.6802 IoU:0.5371 CBL:0.8668 | LR:1.0e-04
# Epoch 35/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1403]
# 🥇 [BEST] Epoch  35 | T_Loss: 0.3498 | [CENTER_] Dice:0.7842 IoU:0.6614 CBL:0.9298 | [CENTER_] Dice:0.6771 IoU:0.5330 CBL:0.8671 | LR:1.0e-04
# Epoch 36/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.4113]
# Epoch  36 | T_Loss: 0.3378 | [CENTER_] Dice:0.7598 IoU:0.6315 CBL:0.9213 | [CENTER_] Dice:0.6275 IoU:0.4829 CBL:0.8511 | LR:1.0e-04
# Epoch 37/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.9850]
# Epoch  37 | T_Loss: 0.3219 | [CENTER_] Dice:0.7793 IoU:0.6558 CBL:0.9229 | [CENTER_] Dice:0.6978 IoU:0.5569 CBL:0.8665 | LR:1.0e-04
# Epoch 38/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1160]
# Epoch  38 | T_Loss: 0.3113 | [CENTER_] Dice:0.7653 IoU:0.6417 CBL:0.9112 | [CENTER_] Dice:0.6973 IoU:0.5591 CBL:0.8762 | LR:1.0e-04
# Epoch 39/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1779]
# Epoch  39 | T_Loss: 0.3308 | [CENTER_] Dice:0.7828 IoU:0.6635 CBL:0.9223 | [CENTER_] Dice:0.7077 IoU:0.5698 CBL:0.8788 | LR:1.0e-04
# Epoch 40/100 [Train]: 100%|██████| 462/462 [02:02<00:00,  3.76it/s, loss=0.2165]
# 🥇 [BEST] Epoch  40 | T_Loss: 0.3069 | [CENTER_] Dice:0.7870 IoU:0.6673 CBL:0.9236 | [CENTER_] Dice:0.7141 IoU:0.5770 CBL:0.8784 | LR:1.0e-04
# Epoch 41/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1567]
# 🥇 [BEST] Epoch  41 | T_Loss: 0.3374 | [CENTER_] Dice:0.7909 IoU:0.6712 CBL:0.9265 | [CENTER_] Dice:0.6656 IoU:0.5227 CBL:0.8516 | LR:1.0e-04
# Epoch 42/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1652]
# Epoch  42 | T_Loss: 0.3423 | [CENTER_] Dice:0.7899 IoU:0.6660 CBL:0.9196 | [CENTER_] Dice:0.7237 IoU:0.5869 CBL:0.8789 | LR:1.0e-04
# Epoch 43/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1769]
# Epoch  43 | T_Loss: 0.3157 | [CENTER_] Dice:0.7628 IoU:0.6383 CBL:0.9115 | [CENTER_] Dice:0.7097 IoU:0.5736 CBL:0.8803 | LR:1.0e-04
# Epoch 44/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.73it/s, loss=0.1670]
# 🥇 [BEST] Epoch  44 | T_Loss: 0.3245 | [CENTER_] Dice:0.7927 IoU:0.6747 CBL:0.9250 | [CENTER_] Dice:0.7190 IoU:0.5835 CBL:0.8825 | LR:1.0e-04
# Epoch 45/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=1.0227]
# Epoch  45 | T_Loss: 0.3014 | [CENTER_] Dice:0.7534 IoU:0.6358 CBL:0.9227 | [CENTER_] Dice:0.6072 IoU:0.4668 CBL:0.8466 | LR:1.0e-04
# Epoch 46/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1428]
# Epoch  46 | T_Loss: 0.3006 | [CENTER_] Dice:0.7824 IoU:0.6616 CBL:0.9187 | [CENTER_] Dice:0.7173 IoU:0.5805 CBL:0.8832 | LR:1.0e-04
# Epoch 47/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1085]
# Epoch  47 | T_Loss: 0.3230 | [CENTER_] Dice:0.7712 IoU:0.6493 CBL:0.9235 | [CENTER_] Dice:0.6916 IoU:0.5551 CBL:0.8817 | LR:1.0e-04
# Epoch 48/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1791]
# Epoch  48 | T_Loss: 0.3097 | [CENTER_] Dice:0.7678 IoU:0.6464 CBL:0.9216 | [CENTER_] Dice:0.7271 IoU:0.5952 CBL:0.8893 | LR:1.0e-04
# Epoch 49/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.2138]
# Epoch  49 | T_Loss: 0.3137 | [CENTER_] Dice:0.7836 IoU:0.6642 CBL:0.9216 | [CENTER_] Dice:0.7191 IoU:0.5862 CBL:0.8876 | LR:1.0e-04
# Epoch 50/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1419]
# 🥇 [BEST] Epoch  50 | T_Loss: 0.3061 | [CENTER_] Dice:0.7972 IoU:0.6804 CBL:0.9242 | [CENTER_] Dice:0.7229 IoU:0.5881 CBL:0.8744 | LR:1.0e-04
# Epoch 51/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.4014]
# Epoch  51 | T_Loss: 0.2873 | [CENTER_] Dice:0.7619 IoU:0.6425 CBL:0.9262 | [CENTER_] Dice:0.6720 IoU:0.5356 CBL:0.8712 | LR:1.0e-04
# Epoch 52/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1795]
# Epoch  52 | T_Loss: 0.2960 | [CENTER_] Dice:0.7599 IoU:0.6421 CBL:0.9190 | [CENTER_] Dice:0.6505 IoU:0.5106 CBL:0.8634 | LR:1.0e-04
# Epoch 53/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1809]
# Epoch  53 | T_Loss: 0.2895 | [CENTER_] Dice:0.7763 IoU:0.6539 CBL:0.9205 | [CENTER_] Dice:0.6848 IoU:0.5442 CBL:0.8732 | LR:1.0e-04
# Epoch 54/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.73it/s, loss=0.2434]
# 🥇 [BEST] Epoch  54 | T_Loss: 0.3024 | [CENTER_] Dice:0.8025 IoU:0.6884 CBL:0.9300 | [CENTER_] Dice:0.7273 IoU:0.5930 CBL:0.8845 | LR:1.0e-04
# Epoch 55/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1893]
# Epoch  55 | T_Loss: 0.3016 | [CENTER_] Dice:0.8012 IoU:0.6837 CBL:0.9278 | [CENTER_] Dice:0.7406 IoU:0.6066 CBL:0.8840 | LR:1.0e-04
# Epoch 56/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.73it/s, loss=0.1081]
# Epoch  56 | T_Loss: 0.2953 | [CENTER_] Dice:0.7755 IoU:0.6605 CBL:0.9171 | [CENTER_] Dice:0.7046 IoU:0.5744 CBL:0.8757 | LR:1.0e-04
# Epoch 57/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.3793]
# Epoch  57 | T_Loss: 0.2834 | [CENTER_] Dice:0.7885 IoU:0.6724 CBL:0.9224 | [CENTER_] Dice:0.7201 IoU:0.5880 CBL:0.8846 | LR:1.0e-04
# Epoch 58/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.5545]
# Epoch  58 | T_Loss: 0.2749 | [CENTER_] Dice:0.7945 IoU:0.6752 CBL:0.9298 | [CENTER_] Dice:0.7350 IoU:0.6018 CBL:0.8905 | LR:1.0e-04
# Epoch 59/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.73it/s, loss=0.1016]
# Epoch  59 | T_Loss: 0.2769 | [CENTER_] Dice:0.7977 IoU:0.6810 CBL:0.9229 | [CENTER_] Dice:0.7172 IoU:0.5824 CBL:0.8806 | LR:1.0e-04
# Epoch 60/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.5606]
# Epoch  60 | T_Loss: 0.2919 | [CENTER_] Dice:0.7929 IoU:0.6739 CBL:0.9263 | [CENTER_] Dice:0.7176 IoU:0.5816 CBL:0.8849 | LR:5.0e-05
# Epoch 61/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.3033]
# 🥇 [BEST] Epoch  61 | T_Loss: 0.2710 | [CENTER_] Dice:0.8156 IoU:0.7027 CBL:0.9321 | [CENTER_] Dice:0.7422 IoU:0.6095 CBL:0.8927 | LR:5.0e-05
# Epoch 62/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1499]
# Epoch  62 | T_Loss: 0.2575 | [CENTER_] Dice:0.8083 IoU:0.6957 CBL:0.9314 | [CENTER_] Dice:0.7242 IoU:0.5896 CBL:0.8860 | LR:5.0e-05
# Epoch 63/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1302]
# Epoch  63 | T_Loss: 0.2621 | [CENTER_] Dice:0.7909 IoU:0.6803 CBL:0.9200 | [CENTER_] Dice:0.7228 IoU:0.5934 CBL:0.8850 | LR:5.0e-05
# Epoch 64/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1823]
# 🥇 [BEST] Epoch  64 | T_Loss: 0.2599 | [CENTER_] Dice:0.8168 IoU:0.7069 CBL:0.9330 | [CENTER_] Dice:0.7330 IoU:0.6003 CBL:0.8878 | LR:5.0e-05
# Epoch 65/100 [Train]: 100%|██████| 462/462 [02:04<00:00,  3.72it/s, loss=0.1089]
# Epoch  65 | T_Loss: 0.2572 | [CENTER_] Dice:0.8105 IoU:0.6951 CBL:0.9289 | [CENTER_] Dice:0.7532 IoU:0.6229 CBL:0.8923 | LR:5.0e-05
# Epoch 66/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1369]
# Epoch  66 | T_Loss: 0.2489 | [CENTER_] Dice:0.8057 IoU:0.6935 CBL:0.9257 | [CENTER_] Dice:0.7547 IoU:0.6287 CBL:0.8969 | LR:5.0e-05
# Epoch 67/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1332]
# Epoch  67 | T_Loss: 0.2595 | [CENTER_] Dice:0.7996 IoU:0.6892 CBL:0.9231 | [CENTER_] Dice:0.7084 IoU:0.5762 CBL:0.8829 | LR:5.0e-05
# Epoch 68/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1261]
# Epoch  68 | T_Loss: 0.2538 | [CENTER_] Dice:0.8147 IoU:0.7014 CBL:0.9321 | [CENTER_] Dice:0.7415 IoU:0.6093 CBL:0.8852 | LR:5.0e-05
# Epoch 69/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.2817]
# 🥇 [BEST] Epoch  69 | T_Loss: 0.2575 | [CENTER_] Dice:0.8264 IoU:0.7190 CBL:0.9376 | [CENTER_] Dice:0.7263 IoU:0.5913 CBL:0.8789 | LR:5.0e-05
# Epoch 70/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1638]
# Epoch  70 | T_Loss: 0.2572 | [CENTER_] Dice:0.8153 IoU:0.7030 CBL:0.9322 | [CENTER_] Dice:0.7421 IoU:0.6096 CBL:0.8911 | LR:5.0e-05
# Epoch 71/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1430]
# Epoch  71 | T_Loss: 0.2360 | [CENTER_] Dice:0.8006 IoU:0.6893 CBL:0.9279 | [CENTER_] Dice:0.7178 IoU:0.5830 CBL:0.8769 | LR:5.0e-05
# Epoch 72/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1465]
# Epoch  72 | T_Loss: 0.2555 | [CENTER_] Dice:0.8172 IoU:0.7050 CBL:0.9313 | [CENTER_] Dice:0.7504 IoU:0.6207 CBL:0.8917 | LR:5.0e-05
# Epoch 73/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.7168]
# Epoch  73 | T_Loss: 0.2649 | [CENTER_] Dice:0.8009 IoU:0.6888 CBL:0.9282 | [CENTER_] Dice:0.7270 IoU:0.5952 CBL:0.8921 | LR:5.0e-05
# Epoch 74/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.3555]
# Epoch  74 | T_Loss: 0.2473 | [CENTER_] Dice:0.8097 IoU:0.6991 CBL:0.9287 | [CENTER_] Dice:0.7485 IoU:0.6221 CBL:0.8958 | LR:5.0e-05
# Epoch 75/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.0923]
# Epoch  75 | T_Loss: 0.2491 | [CENTER_] Dice:0.8062 IoU:0.6926 CBL:0.9301 | [CENTER_] Dice:0.7462 IoU:0.6176 CBL:0.8978 | LR:2.5e-05
# Epoch 76/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1106]
# Epoch  76 | T_Loss: 0.2304 | [CENTER_] Dice:0.8135 IoU:0.7038 CBL:0.9325 | [CENTER_] Dice:0.7233 IoU:0.5902 CBL:0.8818 | LR:2.5e-05
# Epoch 77/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1752]
# Epoch  77 | T_Loss: 0.2473 | [CENTER_] Dice:0.8146 IoU:0.7053 CBL:0.9297 | [CENTER_] Dice:0.7410 IoU:0.6110 CBL:0.8891 | LR:2.5e-05
# Epoch 78/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1332]
# Epoch  78 | T_Loss: 0.2263 | [CENTER_] Dice:0.8176 IoU:0.7081 CBL:0.9353 | [CENTER_] Dice:0.7372 IoU:0.6050 CBL:0.8890 | LR:2.5e-05
# Epoch 79/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.75it/s, loss=0.1803]
# Epoch  79 | T_Loss: 0.2435 | [CENTER_] Dice:0.8189 IoU:0.7100 CBL:0.9326 | [CENTER_] Dice:0.7490 IoU:0.6184 CBL:0.8912 | LR:2.5e-05
# Epoch 80/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.73it/s, loss=0.1053]
# Epoch  80 | T_Loss: 0.2327 | [CENTER_] Dice:0.8097 IoU:0.7016 CBL:0.9293 | [CENTER_] Dice:0.7137 IoU:0.5803 CBL:0.8827 | LR:2.5e-05
# Epoch 81/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1804]
# Epoch  81 | T_Loss: 0.2374 | [CENTER_] Dice:0.8126 IoU:0.7036 CBL:0.9301 | [CENTER_] Dice:0.7325 IoU:0.6002 CBL:0.8874 | LR:1.3e-05
# Epoch 82/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.4860]
# Epoch  82 | T_Loss: 0.2336 | [CENTER_] Dice:0.8124 IoU:0.7023 CBL:0.9294 | [CENTER_] Dice:0.7242 IoU:0.5907 CBL:0.8871 | LR:1.3e-05
# Epoch 83/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.73it/s, loss=0.1841]
# Epoch  83 | T_Loss: 0.2381 | [CENTER_] Dice:0.8230 IoU:0.7157 CBL:0.9360 | [CENTER_] Dice:0.7390 IoU:0.6068 CBL:0.8911 | LR:1.3e-05
# Epoch 84/100 [Train]: 100%|██████| 462/462 [02:03<00:00,  3.74it/s, loss=0.1129]
# Epoch  84 | T_Loss: 0.2336 | [CENTER_] Dice:0.8209 IoU:0.7137 CBL:0.9342 | [CENTER_] Dice:0.7243 IoU:0.5911 CBL:0.8840 | LR:1.3e-05
# Early stopping at epoch 84.
#
# Best Dice (center_zoom): 0.8264
# Checkpoint: checkpoints/pga_unet_center_zoom_x3_512_best.pth

# %% [markdown]
# ## Test - Zoom and Zoom + shift (x3, shift up to 50%)

# %%
# @title
"""
test_center_zoom_x3_shift05.py
=====================
Evaluation of two prompt scenarios: 100% Zoom (center_zoom, x3) | 100% Zoom + shift (center_shift, x3, shift up to 50%)
Mirrors the original PGA-UNet dual-condition test (zoom_out / shift), with
the covering-box formula replaced by the center-scaled one this checkpoint
was trained under. No legacy zoom_out/shift comparison here.

Usage:
    python test_center_zoom_x3_shift05.py
"""

import os
import sys
import cv2
import json
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from scipy.ndimage import binary_erosion, distance_transform_edt

import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset
from models.networks.prompt_unet_2D import PGA_UNet

# =========================================================
# CONFIGURATION - edit here
# =========================================================
DEVICE             = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_PATH         = "checkpoints/pga_unet_center_zoom_x3_512_best.pth"
IMG_SIZE           = 512
BATCH_SIZE         = 4
USE_ENCODER_PROMPT = True   # must match the training config above

SCALE_FACTOR = 3.0
SHIFT_RATIO  = 0.5

TEST_IMAGE_DIR = "dataset_BTXRD/test/images"
TEST_JSON_DIR  = "dataset_BTXRD/test/annotations"


# =========================================================
# METRIC HELPERS & POST-PROCESSING
# =========================================================

def extract_lcc(binary_map: np.ndarray) -> np.ndarray:
    if binary_map.sum() == 0:
        return binary_map
    mask_uint8 = binary_map.astype(np.uint8)
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(mask_uint8, connectivity=8)
    if num_labels <= 1:
        return binary_map
    largest_label = 1 + np.argmax(stats[1:, cv2.CC_STAT_AREA])
    return (labels == largest_label).astype(np.float32)

def calc_hd95(pred: np.ndarray, gt: np.ndarray) -> float:
    pred, gt = pred.astype(bool), gt.astype(bool)
    if not pred.any() and not gt.any():
        return 0.0
    if not pred.any() or not gt.any():
        return float(IMG_SIZE)
    pe = pred ^ binary_erosion(pred)
    ge = gt   ^ binary_erosion(gt)
    d1 = distance_transform_edt(~ge)[pe]
    d2 = distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2):
        return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))

def calc_cbl(pred_bin: np.ndarray, gt_bin: np.ndarray):
    if gt_bin.sum() == 0:
        return None
    ys, xs = np.where(gt_bin)
    gt_diag = np.sqrt((ys.max() - ys.min()) ** 2 +
                      (xs.max() - xs.min()) ** 2) + 1e-6
    if pred_bin.sum() == 0:
        return 0.0
    yp, xp = np.where(pred_bin)
    d = np.sqrt((xp.mean() - xs.mean()) ** 2 +
                (yp.mean() - ys.mean()) ** 2)
    return float(np.clip(1.0 - d / gt_diag, 0.0, 1.0))

def get_centroid(binary_map: np.ndarray):
    if binary_map.sum() == 0:
        return None, None
    ys, xs = np.where(binary_map)
    return float(xs.mean()), float(ys.mean())

# =========================================================
# SINGLE-SCENARIO EVALUATION
# =========================================================

def run_eval(model: torch.nn.Module, prompt_mode: str, **ds_kwargs) -> dict:
    ds = PromptSegmentationDataset(
        image_dir=TEST_IMAGE_DIR,
        json_dir=TEST_JSON_DIR,
        img_size=IMG_SIZE,
        is_train=False,
        prompt_mode=prompt_mode,
        **ds_kwargs,
    )
    loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

    smooth = 1e-5
    all_dice, all_iou, all_pre, all_rec, all_hd95, all_cbl = [], [], [], [], [], []

    model.eval()
    with torch.no_grad():
        for images, masks, prompts in loader:
            images  = images.to(DEVICE)
            masks   = masks.to(DEVICE)
            prompts = prompts.to(DEVICE)
            preds   = (torch.sigmoid(model(images, prompts)) > 0.5).float()

            for b in range(images.size(0)):
                pm = preds[b, 0].cpu().numpy()
                gm = masks[b, 0].cpu().numpy()
                pm = extract_lcc(pm)

                tp = (pm * gm).sum()
                fp = (pm * (1 - gm)).sum()
                fn = ((1 - pm) * gm).sum()

                all_dice.append((2 * tp + smooth) / (2 * tp + fp + fn + smooth))
                all_iou.append( (tp + smooth) / (tp + fp + fn + smooth))
                all_pre.append( (tp + smooth) / (tp + fp + smooth))
                all_rec.append( (tp + smooth) / (tp + fn + smooth))
                all_hd95.append(calc_hd95(pm.astype(bool), gm.astype(bool)))

                cbl = calc_cbl(pm.astype(bool), gm.astype(bool))
                if cbl is not None:
                    all_cbl.append(cbl)

    return {
        'dice': np.mean(all_dice),
        'iou':  np.mean(all_iou),
        'pre':  np.mean(all_pre),
        'rec':  np.mean(all_rec),
        'hd95': np.mean(all_hd95),
        'cbl':  np.mean(all_cbl) if all_cbl else 0.0,
        'n':    len(all_dice),
    }

# =========================================================
# TWO-SCENARIO EVALUATION: Zoom (center_zoom) and Zoom + shift (center_shift),
# both at the exact scale_factor/shift_ratio this checkpoint was trained
# under. This mirrors the original PGA-UNet zoom_out/shift dual-condition
# test; no legacy zoom_out/shift comparison is included here.
# =========================================================

def evaluate_all(model: torch.nn.Module) -> dict:
    enc_tag = 'ON' if USE_ENCODER_PROMPT else 'OFF'
    print("\n" + "=" * 72)
    print(f"  TWO-SCENARIO EVALUATION  |  center-zoom x{SCALE_FACTOR:g}  |  encoder_prompt = {enc_tag}")
    print("=" * 72)

    scenarios = {
        'Zoom (center_zoom)':        dict(prompt_mode='center_zoom', scale_factor=SCALE_FACTOR),
        'Zoom + shift (center_shift)': dict(prompt_mode='center_shift', scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO),
    }

    results = {}
    for name, kwargs in scenarios.items():
        results[name] = run_eval(model, **kwargs)
        print(f"  [{name}]  {results[name]['n']} samples, completed.")

    header = (f"\n{'Scenario':<30} {'Dice↑':>7} {'IoU↑':>7} "
              f"{'Pre↑':>7} {'Rec↑':>7} {'HD95↓':>8} {'CBL↑':>7} {'N':>5}")
    print(header)
    print("-" * 82)
    for name, r in results.items():
        print(f"{name:<30} {r['dice']:>7.4f} {r['iou']:>7.4f} "
              f"{r['pre']:>7.4f} {r['rec']:>7.4f} "
              f"{r['hd95']:>8.2f} {r['cbl']:>7.4f} {r['n']:>5}")
    return results

# =========================================================
# LOAD MODEL
# =========================================================
model = PGA_UNet(use_encoder_prompt=USE_ENCODER_PROMPT).to(DEVICE)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval()
print(f"Model loaded from: {MODEL_PATH}")

# =========================================================
# TWO-SCENARIO EVALUATION: summary table
# =========================================================
results = evaluate_all(model)

# =========================================================
# VISUALIZATION - first 10 samples in order (Zoom, center_zoom)
# =========================================================
from IPython.display import display as _ipy_display
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from torch.utils.data import DataLoader
import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset

N_SHOW  = 10
_vis_dl = DataLoader(
    PromptSegmentationDataset(TEST_IMAGE_DIR, TEST_JSON_DIR, img_size=IMG_SIZE, is_train=False,
                              prompt_mode="center_zoom", scale_factor=SCALE_FACTOR),
    batch_size=1, shuffle=False, num_workers=0)

fig, axes = plt.subplots(N_SHOW, 5, figsize=(20, 4 * N_SHOW))
fig.suptitle(f"PGA-UNet center_zoom (x{SCALE_FACTOR:g}) - Visualization (Zoom, first 10 samples)", fontsize=13, y=1.001)
for ax, ct in zip(axes[0], ["Input image", "Image + prompt", "Prediction", "Ground truth", "TP/FP/FN"]):
    ax.set_title(ct, fontsize=10, fontweight="bold")

model.eval()
count = 0
with torch.no_grad():
    for _img, _gt, _hm in _vis_dl:
        if count >= N_SHOW: break
        img_np  = (_img[0,0].cpu().numpy() * 0.5 + 0.5)
        hm_np   = _hm[0,0].cpu().numpy()
        gt_np   = (_gt[0,0].cpu().numpy() > 0.5).astype(float)
        prob_np = torch.sigmoid(model(_img.to(DEVICE), _hm.to(DEVICE)))[0,0].cpu().numpy()
        pred_np = (prob_np > 0.5).astype(float)

        tp=(pred_np*gt_np).sum(); fp=(pred_np*(1-gt_np)).sum(); fn=((1-pred_np)*gt_np).sum(); e=1e-6
        dice=float((2*tp+e)/(2*tp+fp+fn+e)); iou=float((tp+e)/(tp+fp+fn+e))
        pre=float((tp+e)/(tp+fp+e));         rec=float((tp+e)/(tp+fn+e))

        row = axes[count]
        bg  = np.stack([img_np]*3, axis=-1)

        row[0].imshow(img_np, cmap="gray", vmin=0, vmax=1)
        row[0].set_ylabel(f"#{count+1} Dice={dice:.3f}", fontsize=8)

        row[1].imshow(img_np, cmap="gray", vmin=0, vmax=1)
        row[1].imshow(hm_np, cmap="hot", alpha=0.4, vmin=0, vmax=1)

        pr_ov = bg.copy()
        pr_ov[...,0] = np.clip(pr_ov[...,0] + pred_np*0.55, 0, 1)
        pr_ov[...,1] = np.clip(pr_ov[...,1] - pred_np*0.2,  0, 1)
        row[2].imshow(pr_ov)
        row[2].set_title(f"Dice={dice:.3f} IoU={iou:.3f}", fontsize=7, color="darkred", pad=2)

        gt_ov = bg.copy()
        gt_ov[...,1] = np.clip(gt_ov[...,1] + gt_np*0.55, 0, 1)
        gt_ov[...,0] = np.clip(gt_ov[...,0] - gt_np*0.2,  0, 1)
        row[3].imshow(gt_ov)

        inter = bg.copy() * 0.25
        inter[...,1] = np.clip(inter[...,1] + pred_np*gt_np*0.9,     0, 1)
        inter[...,0] = np.clip(inter[...,0] + pred_np*(1-gt_np)*1.0, 0, 1)
        inter[...,2] = np.clip(inter[...,2] + (1-pred_np)*gt_np*1.0, 0, 1)
        row[4].imshow(inter)
        row[4].set_title(f"Pre={pre:.3f} Rec={rec:.3f}", fontsize=7, color="saddlebrown", pad=2)

        for ax in row: ax.axis("off")
        count += 1

fig.legend(handles=[Patch(facecolor="green",label="TP"),Patch(facecolor="red",label="FP"),Patch(facecolor="blue",label="FN")],
           loc="lower center", ncol=3, fontsize=9, bbox_to_anchor=(0.5,-0.01))
plt.tight_layout()
_ipy_display(fig)
plt.close(fig)
# Out:
# Model loaded from: checkpoints/pga_unet_center_zoom_x3_512_best.pth
#
# ========================================================================
#   TWO-SCENARIO EVALUATION  |  center-zoom x3  |  encoder_prompt = ON
# ========================================================================
#   [Zoom (center_zoom)]  232 samples, completed.
#   [Zoom + shift (center_shift)]  232 samples, completed.
#
# Scenario                         Dice↑    IoU↑    Pre↑    Rec↑    HD95↓    CBL↑     N
# ----------------------------------------------------------------------------------
# Zoom (center_zoom)              0.8088  0.7007  0.8091  0.8370    15.87  0.9288   232
# Zoom + shift (center_shift)     0.7173  0.5830  0.7484  0.7277    21.48  0.8776   232
