# %% [markdown]
# **Full environment, dataset, and code setup** (BTXRD, 512x512, center_zoom prompt: x2, shift up to 30%)

# %%
# =========================================================
# CELL 1 - FULL SETUP COLAB / KAGGLE
# =========================================================
# ===== CHANGE DIRECTORY (auto-detect Colab / Kaggle) =====
import os
BASE = "/kaggle/working" if os.path.exists("/kaggle/working") else "/content"
# %cd $BASE
# ===== CHECK GPU =====
import torch

print("=" * 50)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("=" * 50)

# =========================================================
# CLONE GITHUB (research branch: adds the 'center_zoom'/'center_shift' prompt modes)
# =========================================================

# !rm -rf $BASE/PGA_Unet2D
# !git clone -b research/prompt-scale-protocol https://github.com/ThongLuc2k3/PGA_Unet2D.git

# =========================================================
# DOWNLOAD DATASET ZIP FROM GOOGLE DRIVE
# =========================================================

# !gdown --id 1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx

# =========================================================
# UNZIP DATASET
# =========================================================

# !unzip -oq dataset_BTXRD.zip

# =========================================================
# INSPECT DATASET
# =========================================================

print("\nDATASET STRUCTURE:")
# !ls dataset_BTXRD

# =========================================================
# COPY DATASET INTO THE PROJECT
# =========================================================

# !rm -rf PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/dataset_BTXRD
# !mv dataset_BTXRD PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation/

# =========================================================
# ENTER THE PROJECT DIRECTORY
# =========================================================

# %cd PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation

# =========================================================
# INSTALL REQUIREMENTS
# =========================================================

# !pip install -q tqdm opencv-python matplotlib scikit-image gdown scipy

print("\nSETUP DONE!")
# Out:
# /kaggle/working
# ==================================================
# CUDA: True
# GPU: Tesla T4
# ==================================================
# Cloning into 'PGA_Unet2D'...
# remote: Enumerating objects: 3945, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 3945 (delta 84), reused 128 (delta 54), pack-reused 3740 (from 2)
# Receiving objects: 100% (3945/3945), 1.23 GiB | 41.02 MiB/s, done.
# Resolving deltas: 100% (2265/2265), done.
# Updating files: 100% (219/219), done.
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx
# From (redirected): https://drive.google.com/uc?id=1Ep3w8GujpCQ5Qb6nlXKxXhsCxlc3k8gx&confirm=t&uuid=f363b439-25ca-4d19-976c-17d1a012715a
# To: /kaggle/working/dataset_BTXRD.zip
# 100%|███████████████████████████████████████| 1.71G/1.71G [00:14<00:00, 117MB/s]
#
# DATASET STRUCTURE:
# test  train  val
# /kaggle/working/PGA_Unet2D/Source/Prompt-Guided-XRay-Segmentation
#
# SETUP DONE!

# %% [markdown]
# **Train** (covering-only, like the original PGA-UNet protocol, 150 epochs max)

# %%
# =========================================================
# TRAIN - center_zoom prompt, scale x2 (covering-only, like the original PGA-UNet protocol)
# =========================================================

# !PROMPT_DATASET_ROOT=dataset_BTXRD PROMPT_IMG_SIZE=512 \
 PROMPT_MODE=center_zoom PROMPT_SCALE_FACTOR=2.0 PROMPT_SHIFT_RATIO=0.3 PROMPT_EPOCHS=150 \
 python train.py
# Out:
# ==========================================================================================
# TrainPrompt: center_zoom | Device: cuda | EncoderPrompt: True | ImgSize: 512 | DatasetRoot: dataset_BTXRD | ScaleFactor: 2.0
# ==========================================================================================
# Epoch 1/150 [Train]: 100%|███████| 462/462 [01:52<00:00,  4.11it/s, loss=1.2408]
# 🥇 [BEST] Epoch   1 | T_Loss: 1.3573 | [CENTER_] Dice:0.5086 IoU:0.3604 CBL:0.7961 | [CENTER_] Dice:0.5093 IoU:0.3621 CBL:0.7619 | LR:1.0e-04
# Epoch 2/150 [Train]: 100%|███████| 462/462 [01:59<00:00,  3.88it/s, loss=1.0659]
# 🥇 [BEST] Epoch   2 | T_Loss: 1.1945 | [CENTER_] Dice:0.5690 IoU:0.4096 CBL:0.9041 | [CENTER_] Dice:0.5658 IoU:0.4066 CBL:0.8644 | LR:1.0e-04
# Epoch 3/150 [Train]: 100%|███████| 462/462 [01:59<00:00,  3.88it/s, loss=1.1023]
# 🥇 [BEST] Epoch   3 | T_Loss: 1.0886 | [CENTER_] Dice:0.6459 IoU:0.4961 CBL:0.9203 | [CENTER_] Dice:0.6157 IoU:0.4606 CBL:0.8773 | LR:1.0e-04
# Epoch 4/150 [Train]: 100%|███████| 462/462 [01:59<00:00,  3.88it/s, loss=1.0298]
# 🥇 [BEST] Epoch   4 | T_Loss: 0.9986 | [CENTER_] Dice:0.6799 IoU:0.5399 CBL:0.8997 | [CENTER_] Dice:0.6466 IoU:0.4993 CBL:0.8527 | LR:1.0e-04
# Epoch 5/150 [Train]: 100%|███████| 462/462 [01:59<00:00,  3.88it/s, loss=1.0352]
# 🥇 [BEST] Epoch   5 | T_Loss: 0.9172 | [CENTER_] Dice:0.6914 IoU:0.5581 CBL:0.9013 | [CENTER_] Dice:0.6547 IoU:0.5096 CBL:0.8705 | LR:1.0e-04
# Epoch 6/150 [Train]: 100%|███████| 462/462 [01:59<00:00,  3.87it/s, loss=0.8405]
# 🥇 [BEST] Epoch   6 | T_Loss: 0.8247 | [CENTER_] Dice:0.7303 IoU:0.6013 CBL:0.9147 | [CENTER_] Dice:0.6816 IoU:0.5402 CBL:0.8741 | LR:1.0e-04
# Epoch 7/150 [Train]: 100%|███████| 462/462 [01:58<00:00,  3.88it/s, loss=0.7065]
# Epoch   7 | T_Loss: 0.7461 | [CENTER_] Dice:0.7249 IoU:0.5960 CBL:0.9068 | [CENTER_] Dice:0.6647 IoU:0.5209 CBL:0.8610 | LR:1.0e-04
# Epoch 8/150 [Train]: 100%|███████| 462/462 [01:59<00:00,  3.87it/s, loss=1.0479]
# 🥇 [BEST] Epoch   8 | T_Loss: 0.6759 | [CENTER_] Dice:0.7316 IoU:0.6010 CBL:0.9241 | [CENTER_] Dice:0.6907 IoU:0.5469 CBL:0.8914 | LR:1.0e-04
# Epoch 9/150 [Train]: 100%|███████| 462/462 [01:59<00:00,  3.87it/s, loss=0.9218]
# 🥇 [BEST] Epoch   9 | T_Loss: 0.6130 | [CENTER_] Dice:0.7456 IoU:0.6169 CBL:0.9207 | [CENTER_] Dice:0.7343 IoU:0.6013 CBL:0.9124 | LR:1.0e-04
# Epoch 10/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.88it/s, loss=0.8853]
# 🥇 [BEST] Epoch  10 | T_Loss: 0.5548 | [CENTER_] Dice:0.7808 IoU:0.6562 CBL:0.9316 | [CENTER_] Dice:0.7475 IoU:0.6120 CBL:0.9046 | LR:1.0e-04
# Epoch 11/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.2859]
# Epoch  11 | T_Loss: 0.4641 | [CENTER_] Dice:0.7744 IoU:0.6522 CBL:0.9352 | [CENTER_] Dice:0.7234 IoU:0.5829 CBL:0.9016 | LR:1.0e-04
# Epoch 12/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.88it/s, loss=0.8008]
# 🥇 [BEST] Epoch  12 | T_Loss: 0.4332 | [CENTER_] Dice:0.7883 IoU:0.6650 CBL:0.9269 | [CENTER_] Dice:0.7742 IoU:0.6448 CBL:0.9131 | LR:1.0e-04
# Epoch 13/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.88it/s, loss=1.0184]
# 🥇 [BEST] Epoch  13 | T_Loss: 0.3803 | [CENTER_] Dice:0.8112 IoU:0.6950 CBL:0.9366 | [CENTER_] Dice:0.7818 IoU:0.6541 CBL:0.9180 | LR:1.0e-04
# Epoch 14/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1544]
# 🥇 [BEST] Epoch  14 | T_Loss: 0.3525 | [CENTER_] Dice:0.8199 IoU:0.7057 CBL:0.9410 | [CENTER_] Dice:0.7497 IoU:0.6113 CBL:0.8954 | LR:1.0e-04
# Epoch 15/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.88it/s, loss=0.2223]
# Epoch  15 | T_Loss: 0.3348 | [CENTER_] Dice:0.7903 IoU:0.6739 CBL:0.9337 | [CENTER_] Dice:0.7651 IoU:0.6390 CBL:0.9183 | LR:1.0e-04
# Epoch 16/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.3380]
# Epoch  16 | T_Loss: 0.3332 | [CENTER_] Dice:0.8177 IoU:0.7039 CBL:0.9406 | [CENTER_] Dice:0.7687 IoU:0.6374 CBL:0.9111 | LR:1.0e-04
# Epoch 17/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1442]
# Epoch  17 | T_Loss: 0.2848 | [CENTER_] Dice:0.8135 IoU:0.6993 CBL:0.9342 | [CENTER_] Dice:0.7640 IoU:0.6313 CBL:0.8985 | LR:1.0e-04
# Epoch 18/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.7951]
# Epoch  18 | T_Loss: 0.3119 | [CENTER_] Dice:0.8070 IoU:0.6884 CBL:0.9457 | [CENTER_] Dice:0.7507 IoU:0.6149 CBL:0.9146 | LR:1.0e-04
# Epoch 19/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.88it/s, loss=0.8720]
# 🥇 [BEST] Epoch  19 | T_Loss: 0.3108 | [CENTER_] Dice:0.8357 IoU:0.7292 CBL:0.9491 | [CENTER_] Dice:0.7784 IoU:0.6494 CBL:0.9158 | LR:1.0e-04
# Epoch 20/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1929]
# Epoch  20 | T_Loss: 0.2972 | [CENTER_] Dice:0.8311 IoU:0.7226 CBL:0.9451 | [CENTER_] Dice:0.7735 IoU:0.6442 CBL:0.9157 | LR:1.0e-04
# Epoch 21/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1718]
# Epoch  21 | T_Loss: 0.2894 | [CENTER_] Dice:0.8279 IoU:0.7186 CBL:0.9472 | [CENTER_] Dice:0.7811 IoU:0.6539 CBL:0.9126 | LR:1.0e-04
# Epoch 22/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.2105]
# Epoch  22 | T_Loss: 0.2907 | [CENTER_] Dice:0.8270 IoU:0.7169 CBL:0.9475 | [CENTER_] Dice:0.7789 IoU:0.6513 CBL:0.9161 | LR:1.0e-04
# Epoch 23/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.2511]
# Epoch  23 | T_Loss: 0.2915 | [CENTER_] Dice:0.8211 IoU:0.7092 CBL:0.9426 | [CENTER_] Dice:0.7905 IoU:0.6655 CBL:0.9200 | LR:1.0e-04
# Epoch 24/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1347]
# 🥇 [BEST] Epoch  24 | T_Loss: 0.2757 | [CENTER_] Dice:0.8424 IoU:0.7391 CBL:0.9494 | [CENTER_] Dice:0.7978 IoU:0.6769 CBL:0.9207 | LR:1.0e-04
# Epoch 25/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1519]
# 🥇 [BEST] Epoch  25 | T_Loss: 0.2853 | [CENTER_] Dice:0.8445 IoU:0.7408 CBL:0.9521 | [CENTER_] Dice:0.7643 IoU:0.6320 CBL:0.9095 | LR:1.0e-04
# Epoch 26/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1797]
# Epoch  26 | T_Loss: 0.2798 | [CENTER_] Dice:0.8294 IoU:0.7203 CBL:0.9399 | [CENTER_] Dice:0.8129 IoU:0.6972 CBL:0.9231 | LR:1.0e-04
# Epoch 27/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1168]
# Epoch  27 | T_Loss: 0.2789 | [CENTER_] Dice:0.8439 IoU:0.7401 CBL:0.9520 | [CENTER_] Dice:0.8005 IoU:0.6793 CBL:0.9228 | LR:1.0e-04
# Epoch 28/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.8217]
# Epoch  28 | T_Loss: 0.2776 | [CENTER_] Dice:0.8395 IoU:0.7335 CBL:0.9515 | [CENTER_] Dice:0.7720 IoU:0.6421 CBL:0.9171 | LR:1.0e-04
# Epoch 29/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=1.0018]
# 🥇 [BEST] Epoch  29 | T_Loss: 0.2676 | [CENTER_] Dice:0.8461 IoU:0.7434 CBL:0.9497 | [CENTER_] Dice:0.7844 IoU:0.6586 CBL:0.9111 | LR:1.0e-04
# Epoch 30/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1467]
# 🥇 [BEST] Epoch  30 | T_Loss: 0.2632 | [CENTER_] Dice:0.8495 IoU:0.7496 CBL:0.9517 | [CENTER_] Dice:0.7840 IoU:0.6576 CBL:0.9132 | LR:1.0e-04
# Epoch 31/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1874]
# 🥇 [BEST] Epoch  31 | T_Loss: 0.2597 | [CENTER_] Dice:0.8505 IoU:0.7496 CBL:0.9526 | [CENTER_] Dice:0.7969 IoU:0.6746 CBL:0.9192 | LR:1.0e-04
# Epoch 32/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.4733]
# Epoch  32 | T_Loss: 0.2475 | [CENTER_] Dice:0.8466 IoU:0.7447 CBL:0.9504 | [CENTER_] Dice:0.7896 IoU:0.6659 CBL:0.9126 | LR:1.0e-04
# Epoch 33/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.0970]
# Epoch  33 | T_Loss: 0.2606 | [CENTER_] Dice:0.8365 IoU:0.7320 CBL:0.9470 | [CENTER_] Dice:0.8149 IoU:0.7017 CBL:0.9271 | LR:1.0e-04
# Epoch 34/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1463]
# 🥇 [BEST] Epoch  34 | T_Loss: 0.2392 | [CENTER_] Dice:0.8526 IoU:0.7517 CBL:0.9530 | [CENTER_] Dice:0.8194 IoU:0.7045 CBL:0.9313 | LR:1.0e-04
# Epoch 35/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1328]
# Epoch  35 | T_Loss: 0.2805 | [CENTER_] Dice:0.8524 IoU:0.7537 CBL:0.9519 | [CENTER_] Dice:0.7928 IoU:0.6695 CBL:0.9172 | LR:1.0e-04
# Epoch 36/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.7782]
# Epoch  36 | T_Loss: 0.2714 | [CENTER_] Dice:0.8443 IoU:0.7425 CBL:0.9456 | [CENTER_] Dice:0.8111 IoU:0.6945 CBL:0.9290 | LR:1.0e-04
# Epoch 37/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.85it/s, loss=0.1845]
# 🥇 [BEST] Epoch  37 | T_Loss: 0.2649 | [CENTER_] Dice:0.8539 IoU:0.7540 CBL:0.9497 | [CENTER_] Dice:0.8163 IoU:0.7005 CBL:0.9316 | LR:1.0e-04
# Epoch 38/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1088]
# Epoch  38 | T_Loss: 0.2673 | [CENTER_] Dice:0.8525 IoU:0.7530 CBL:0.9513 | [CENTER_] Dice:0.8024 IoU:0.6830 CBL:0.9189 | LR:1.0e-04
# Epoch 39/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.0775]
# Epoch  39 | T_Loss: 0.2682 | [CENTER_] Dice:0.8520 IoU:0.7531 CBL:0.9490 | [CENTER_] Dice:0.8136 IoU:0.6984 CBL:0.9251 | LR:1.0e-04
# Epoch 40/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.0828]
# Epoch  40 | T_Loss: 0.2536 | [CENTER_] Dice:0.8385 IoU:0.7354 CBL:0.9426 | [CENTER_] Dice:0.8254 IoU:0.7157 CBL:0.9352 | LR:1.0e-04
# Epoch 41/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1016]
# 🥇 [BEST] Epoch  41 | T_Loss: 0.2652 | [CENTER_] Dice:0.8634 IoU:0.7698 CBL:0.9562 | [CENTER_] Dice:0.8105 IoU:0.6935 CBL:0.9275 | LR:1.0e-04
# Epoch 42/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1164]
# Epoch  42 | T_Loss: 0.2676 | [CENTER_] Dice:0.8555 IoU:0.7589 CBL:0.9502 | [CENTER_] Dice:0.8141 IoU:0.6998 CBL:0.9249 | LR:1.0e-04
# Epoch 43/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1363]
# Epoch  43 | T_Loss: 0.2591 | [CENTER_] Dice:0.8352 IoU:0.7300 CBL:0.9480 | [CENTER_] Dice:0.7981 IoU:0.6805 CBL:0.9304 | LR:1.0e-04
# Epoch 44/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.7005]
# Epoch  44 | T_Loss: 0.2518 | [CENTER_] Dice:0.8391 IoU:0.7343 CBL:0.9462 | [CENTER_] Dice:0.8110 IoU:0.6936 CBL:0.9263 | LR:1.0e-04
# Epoch 45/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1581]
# Epoch  45 | T_Loss: 0.2608 | [CENTER_] Dice:0.8556 IoU:0.7587 CBL:0.9507 | [CENTER_] Dice:0.8245 IoU:0.7121 CBL:0.9339 | LR:1.0e-04
# Epoch 46/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.2934]
# Epoch  46 | T_Loss: 0.2484 | [CENTER_] Dice:0.8571 IoU:0.7587 CBL:0.9512 | [CENTER_] Dice:0.8214 IoU:0.7073 CBL:0.9331 | LR:1.0e-04
# Epoch 47/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1291]
# Epoch  47 | T_Loss: 0.2564 | [CENTER_] Dice:0.8588 IoU:0.7621 CBL:0.9529 | [CENTER_] Dice:0.8132 IoU:0.6965 CBL:0.9234 | LR:5.0e-05
# Epoch 48/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.85it/s, loss=0.6734]
# Epoch  48 | T_Loss: 0.2260 | [CENTER_] Dice:0.8594 IoU:0.7636 CBL:0.9550 | [CENTER_] Dice:0.8102 IoU:0.6935 CBL:0.9285 | LR:5.0e-05
# Epoch 49/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.0996]
# Epoch  49 | T_Loss: 0.2374 | [CENTER_] Dice:0.8614 IoU:0.7667 CBL:0.9505 | [CENTER_] Dice:0.8348 IoU:0.7267 CBL:0.9381 | LR:5.0e-05
# Epoch 50/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.85it/s, loss=0.9831]
# 🥇 [BEST] Epoch  50 | T_Loss: 0.2496 | [CENTER_] Dice:0.8638 IoU:0.7697 CBL:0.9545 | [CENTER_] Dice:0.8223 IoU:0.7090 CBL:0.9269 | LR:5.0e-05
# Epoch 51/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1013]
# 🥇 [BEST] Epoch  51 | T_Loss: 0.2396 | [CENTER_] Dice:0.8691 IoU:0.7766 CBL:0.9584 | [CENTER_] Dice:0.8186 IoU:0.7029 CBL:0.9304 | LR:5.0e-05
# Epoch 52/150 [Train]: 100%|██████| 462/462 [02:00<00:00,  3.85it/s, loss=0.1508]
# Epoch  52 | T_Loss: 0.2463 | [CENTER_] Dice:0.8648 IoU:0.7710 CBL:0.9550 | [CENTER_] Dice:0.8135 IoU:0.6962 CBL:0.9243 | LR:5.0e-05
# Epoch 53/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.2410]
# Epoch  53 | T_Loss: 0.2414 | [CENTER_] Dice:0.8668 IoU:0.7747 CBL:0.9553 | [CENTER_] Dice:0.8176 IoU:0.7035 CBL:0.9274 | LR:5.0e-05
# Epoch 54/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1203]
# Epoch  54 | T_Loss: 0.2370 | [CENTER_] Dice:0.8685 IoU:0.7769 CBL:0.9559 | [CENTER_] Dice:0.8236 IoU:0.7105 CBL:0.9297 | LR:5.0e-05
# Epoch 55/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1068]
# Epoch  55 | T_Loss: 0.2409 | [CENTER_] Dice:0.8641 IoU:0.7707 CBL:0.9552 | [CENTER_] Dice:0.8313 IoU:0.7218 CBL:0.9334 | LR:5.0e-05
# Epoch 56/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.85it/s, loss=0.1532]
# Epoch  56 | T_Loss: 0.2271 | [CENTER_] Dice:0.8615 IoU:0.7670 CBL:0.9535 | [CENTER_] Dice:0.8318 IoU:0.7231 CBL:0.9340 | LR:5.0e-05
# Epoch 57/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1423]
# Epoch  57 | T_Loss: 0.2394 | [CENTER_] Dice:0.8656 IoU:0.7735 CBL:0.9545 | [CENTER_] Dice:0.8296 IoU:0.7206 CBL:0.9346 | LR:2.5e-05
# Epoch 58/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.85it/s, loss=0.0917]
# Epoch  58 | T_Loss: 0.2219 | [CENTER_] Dice:0.8683 IoU:0.7772 CBL:0.9561 | [CENTER_] Dice:0.8240 IoU:0.7116 CBL:0.9304 | LR:2.5e-05
# Epoch 59/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1390]
# 🥇 [BEST] Epoch  59 | T_Loss: 0.2102 | [CENTER_] Dice:0.8711 IoU:0.7812 CBL:0.9570 | [CENTER_] Dice:0.8301 IoU:0.7198 CBL:0.9311 | LR:2.5e-05
# Epoch 60/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1345]
# Epoch  60 | T_Loss: 0.2347 | [CENTER_] Dice:0.8669 IoU:0.7752 CBL:0.9552 | [CENTER_] Dice:0.8289 IoU:0.7187 CBL:0.9321 | LR:2.5e-05
# Epoch 61/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1636]
# 🥇 [BEST] Epoch  61 | T_Loss: 0.2252 | [CENTER_] Dice:0.8711 IoU:0.7808 CBL:0.9576 | [CENTER_] Dice:0.8183 IoU:0.7033 CBL:0.9259 | LR:2.5e-05
# Epoch 62/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1311]
# Epoch  62 | T_Loss: 0.2119 | [CENTER_] Dice:0.8706 IoU:0.7803 CBL:0.9563 | [CENTER_] Dice:0.8204 IoU:0.7060 CBL:0.9248 | LR:2.5e-05
# Epoch 63/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.0882]
# Epoch  63 | T_Loss: 0.2225 | [CENTER_] Dice:0.8575 IoU:0.7608 CBL:0.9515 | [CENTER_] Dice:0.8343 IoU:0.7259 CBL:0.9354 | LR:2.5e-05
# Epoch 64/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.5607]
# Epoch  64 | T_Loss: 0.2321 | [CENTER_] Dice:0.8679 IoU:0.7759 CBL:0.9563 | [CENTER_] Dice:0.8237 IoU:0.7103 CBL:0.9308 | LR:2.5e-05
# Epoch 65/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.2373]
# Epoch  65 | T_Loss: 0.2253 | [CENTER_] Dice:0.8611 IoU:0.7670 CBL:0.9545 | [CENTER_] Dice:0.8207 IoU:0.7065 CBL:0.9311 | LR:1.3e-05
# Epoch 66/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.0961]
# Epoch  66 | T_Loss: 0.2235 | [CENTER_] Dice:0.8692 IoU:0.7783 CBL:0.9566 | [CENTER_] Dice:0.8146 IoU:0.6988 CBL:0.9250 | LR:1.3e-05
# Epoch 67/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1119]
# Epoch  67 | T_Loss: 0.2186 | [CENTER_] Dice:0.8654 IoU:0.7728 CBL:0.9556 | [CENTER_] Dice:0.8302 IoU:0.7207 CBL:0.9337 | LR:1.3e-05
# Epoch 68/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1041]
# Epoch  68 | T_Loss: 0.2385 | [CENTER_] Dice:0.8679 IoU:0.7755 CBL:0.9576 | [CENTER_] Dice:0.8332 IoU:0.7240 CBL:0.9362 | LR:1.3e-05
# Epoch 69/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1836]
# Epoch  69 | T_Loss: 0.2188 | [CENTER_] Dice:0.8693 IoU:0.7780 CBL:0.9565 | [CENTER_] Dice:0.8323 IoU:0.7222 CBL:0.9340 | LR:1.3e-05
# Epoch 70/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.85it/s, loss=0.0708]
# Epoch  70 | T_Loss: 0.2132 | [CENTER_] Dice:0.8707 IoU:0.7803 CBL:0.9575 | [CENTER_] Dice:0.8300 IoU:0.7199 CBL:0.9329 | LR:1.3e-05
# Epoch 71/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1883]
# Epoch  71 | T_Loss: 0.2176 | [CENTER_] Dice:0.8689 IoU:0.7780 CBL:0.9577 | [CENTER_] Dice:0.8276 IoU:0.7162 CBL:0.9328 | LR:6.3e-06
# Epoch 72/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.2323]
# 🥇 [BEST] Epoch  72 | T_Loss: 0.2027 | [CENTER_] Dice:0.8720 IoU:0.7820 CBL:0.9592 | [CENTER_] Dice:0.8269 IoU:0.7152 CBL:0.9315 | LR:6.3e-06
# Epoch 73/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1592]
# Epoch  73 | T_Loss: 0.2157 | [CENTER_] Dice:0.8717 IoU:0.7815 CBL:0.9580 | [CENTER_] Dice:0.8290 IoU:0.7179 CBL:0.9328 | LR:6.3e-06
# Epoch 74/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1194]
# Epoch  74 | T_Loss: 0.2011 | [CENTER_] Dice:0.8702 IoU:0.7797 CBL:0.9572 | [CENTER_] Dice:0.8303 IoU:0.7203 CBL:0.9332 | LR:6.3e-06
# Epoch 75/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.7802]
# Epoch  75 | T_Loss: 0.2195 | [CENTER_] Dice:0.8684 IoU:0.7773 CBL:0.9576 | [CENTER_] Dice:0.8267 IoU:0.7153 CBL:0.9332 | LR:6.3e-06
# Epoch 76/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1203]
# Epoch  76 | T_Loss: 0.2236 | [CENTER_] Dice:0.8685 IoU:0.7771 CBL:0.9574 | [CENTER_] Dice:0.8275 IoU:0.7163 CBL:0.9324 | LR:6.3e-06
# Epoch 77/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1626]
# Epoch  77 | T_Loss: 0.1899 | [CENTER_] Dice:0.8674 IoU:0.7755 CBL:0.9559 | [CENTER_] Dice:0.8327 IoU:0.7233 CBL:0.9349 | LR:6.3e-06
# Epoch 78/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.85it/s, loss=0.3659]
# Epoch  78 | T_Loss: 0.2214 | [CENTER_] Dice:0.8714 IoU:0.7811 CBL:0.9587 | [CENTER_] Dice:0.8249 IoU:0.7120 CBL:0.9304 | LR:3.1e-06
# Epoch 79/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1646]
# Epoch  79 | T_Loss: 0.2194 | [CENTER_] Dice:0.8703 IoU:0.7796 CBL:0.9580 | [CENTER_] Dice:0.8282 IoU:0.7169 CBL:0.9322 | LR:3.1e-06
# Epoch 80/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1050]
# Epoch  80 | T_Loss: 0.2045 | [CENTER_] Dice:0.8688 IoU:0.7772 CBL:0.9577 | [CENTER_] Dice:0.8291 IoU:0.7180 CBL:0.9329 | LR:3.1e-06
# Epoch 81/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1044]
# Epoch  81 | T_Loss: 0.1975 | [CENTER_] Dice:0.8712 IoU:0.7807 CBL:0.9583 | [CENTER_] Dice:0.8319 IoU:0.7220 CBL:0.9339 | LR:3.1e-06
# Epoch 82/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1058]
# Epoch  82 | T_Loss: 0.2165 | [CENTER_] Dice:0.8699 IoU:0.7790 CBL:0.9578 | [CENTER_] Dice:0.8299 IoU:0.7195 CBL:0.9328 | LR:3.1e-06
# Epoch 83/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.85it/s, loss=0.1355]
# Epoch  83 | T_Loss: 0.2040 | [CENTER_] Dice:0.8700 IoU:0.7792 CBL:0.9574 | [CENTER_] Dice:0.8295 IoU:0.7191 CBL:0.9338 | LR:3.1e-06
# Epoch 84/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.0887]
# Epoch  84 | T_Loss: 0.2050 | [CENTER_] Dice:0.8700 IoU:0.7790 CBL:0.9576 | [CENTER_] Dice:0.8325 IoU:0.7234 CBL:0.9335 | LR:1.6e-06
# Epoch 85/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.1170]
# Epoch  85 | T_Loss: 0.2030 | [CENTER_] Dice:0.8704 IoU:0.7797 CBL:0.9574 | [CENTER_] Dice:0.8295 IoU:0.7191 CBL:0.9325 | LR:1.6e-06
# Epoch 86/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.86it/s, loss=0.0994]
# Epoch  86 | T_Loss: 0.2142 | [CENTER_] Dice:0.8701 IoU:0.7791 CBL:0.9571 | [CENTER_] Dice:0.8306 IoU:0.7205 CBL:0.9332 | LR:1.6e-06
# Epoch 87/150 [Train]: 100%|██████| 462/462 [01:59<00:00,  3.87it/s, loss=0.1114]
# Epoch  87 | T_Loss: 0.2060 | [CENTER_] Dice:0.8688 IoU:0.7775 CBL:0.9575 | [CENTER_] Dice:0.8259 IoU:0.7136 CBL:0.9319 | LR:1.6e-06
# Early stopping at epoch 87.
#
# Best Dice (center_zoom): 0.8720
# Checkpoint: checkpoints/pga_unet_center_zoom_x2_512_best.pth

# %% [markdown]
# ## Test - Zoom and Zoom + shift (x2, shift up to 30%)

# %%
# @title
"""
test_center_zoom_x2_shift03.py
=====================
Evaluation of two prompt scenarios: 100% Zoom (center_zoom, x2) | 100% Zoom + shift (center_shift, x2, shift up to 30%)
Mirrors the original PGA-UNet dual-condition test (zoom_out / shift), with
the covering-box formula replaced by the center-scaled one this checkpoint
was trained under. No legacy zoom_out/shift comparison here.

Usage:
    python test_center_zoom_x2_shift03.py
"""

import os
import sys
import cv2
import json
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from scipy.ndimage import binary_erosion, distance_transform_edt

import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset
from models.networks.prompt_unet_2D import PGA_UNet

# =========================================================
# CONFIGURATION - edit here
# =========================================================
DEVICE             = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_PATH         = "checkpoints/pga_unet_center_zoom_x2_512_best.pth"
IMG_SIZE           = 512
BATCH_SIZE         = 4
USE_ENCODER_PROMPT = True   # must match the training config above

SCALE_FACTOR = 2.0
SHIFT_RATIO  = 0.3

TEST_IMAGE_DIR = "dataset_BTXRD/test/images"
TEST_JSON_DIR  = "dataset_BTXRD/test/annotations"


# =========================================================
# METRIC HELPERS & POST-PROCESSING
# =========================================================

def extract_lcc(binary_map: np.ndarray) -> np.ndarray:
    if binary_map.sum() == 0:
        return binary_map
    mask_uint8 = binary_map.astype(np.uint8)
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(mask_uint8, connectivity=8)
    if num_labels <= 1:
        return binary_map
    largest_label = 1 + np.argmax(stats[1:, cv2.CC_STAT_AREA])
    return (labels == largest_label).astype(np.float32)

def calc_hd95(pred: np.ndarray, gt: np.ndarray) -> float:
    pred, gt = pred.astype(bool), gt.astype(bool)
    if not pred.any() and not gt.any():
        return 0.0
    if not pred.any() or not gt.any():
        return float(IMG_SIZE)
    pe = pred ^ binary_erosion(pred)
    ge = gt   ^ binary_erosion(gt)
    d1 = distance_transform_edt(~ge)[pe]
    d2 = distance_transform_edt(~pe)[ge]
    if not len(d1) or not len(d2):
        return float(IMG_SIZE)
    return float(max(np.percentile(d1, 95), np.percentile(d2, 95)))

def calc_cbl(pred_bin: np.ndarray, gt_bin: np.ndarray):
    if gt_bin.sum() == 0:
        return None
    ys, xs = np.where(gt_bin)
    gt_diag = np.sqrt((ys.max() - ys.min()) ** 2 +
                      (xs.max() - xs.min()) ** 2) + 1e-6
    if pred_bin.sum() == 0:
        return 0.0
    yp, xp = np.where(pred_bin)
    d = np.sqrt((xp.mean() - xs.mean()) ** 2 +
                (yp.mean() - ys.mean()) ** 2)
    return float(np.clip(1.0 - d / gt_diag, 0.0, 1.0))

def get_centroid(binary_map: np.ndarray):
    if binary_map.sum() == 0:
        return None, None
    ys, xs = np.where(binary_map)
    return float(xs.mean()), float(ys.mean())

# =========================================================
# SINGLE-SCENARIO EVALUATION
# =========================================================

def run_eval(model: torch.nn.Module, prompt_mode: str, **ds_kwargs) -> dict:
    ds = PromptSegmentationDataset(
        image_dir=TEST_IMAGE_DIR,
        json_dir=TEST_JSON_DIR,
        img_size=IMG_SIZE,
        is_train=False,
        prompt_mode=prompt_mode,
        **ds_kwargs,
    )
    loader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

    smooth = 1e-5
    all_dice, all_iou, all_pre, all_rec, all_hd95, all_cbl = [], [], [], [], [], []

    model.eval()
    with torch.no_grad():
        for images, masks, prompts in loader:
            images  = images.to(DEVICE)
            masks   = masks.to(DEVICE)
            prompts = prompts.to(DEVICE)
            preds   = (torch.sigmoid(model(images, prompts)) > 0.5).float()

            for b in range(images.size(0)):
                pm = preds[b, 0].cpu().numpy()
                gm = masks[b, 0].cpu().numpy()
                pm = extract_lcc(pm)

                tp = (pm * gm).sum()
                fp = (pm * (1 - gm)).sum()
                fn = ((1 - pm) * gm).sum()

                all_dice.append((2 * tp + smooth) / (2 * tp + fp + fn + smooth))
                all_iou.append( (tp + smooth) / (tp + fp + fn + smooth))
                all_pre.append( (tp + smooth) / (tp + fp + smooth))
                all_rec.append( (tp + smooth) / (tp + fn + smooth))
                all_hd95.append(calc_hd95(pm.astype(bool), gm.astype(bool)))

                cbl = calc_cbl(pm.astype(bool), gm.astype(bool))
                if cbl is not None:
                    all_cbl.append(cbl)

    return {
        'dice': np.mean(all_dice),
        'iou':  np.mean(all_iou),
        'pre':  np.mean(all_pre),
        'rec':  np.mean(all_rec),
        'hd95': np.mean(all_hd95),
        'cbl':  np.mean(all_cbl) if all_cbl else 0.0,
        'n':    len(all_dice),
    }

# =========================================================
# TWO-SCENARIO EVALUATION: Zoom (center_zoom) and Zoom + shift (center_shift),
# both at the exact scale_factor/shift_ratio this checkpoint was trained
# under. This mirrors the original PGA-UNet zoom_out/shift dual-condition
# test; no legacy zoom_out/shift comparison is included here.
# =========================================================

def evaluate_all(model: torch.nn.Module) -> dict:
    enc_tag = 'ON' if USE_ENCODER_PROMPT else 'OFF'
    print("\n" + "=" * 72)
    print(f"  TWO-SCENARIO EVALUATION  |  center-zoom x{SCALE_FACTOR:g}  |  encoder_prompt = {enc_tag}")
    print("=" * 72)

    scenarios = {
        'Zoom (center_zoom)':        dict(prompt_mode='center_zoom', scale_factor=SCALE_FACTOR),
        'Zoom + shift (center_shift)': dict(prompt_mode='center_shift', scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO),
    }

    results = {}
    for name, kwargs in scenarios.items():
        results[name] = run_eval(model, **kwargs)
        print(f"  [{name}]  {results[name]['n']} samples, completed.")

    header = (f"\n{'Scenario':<30} {'Dice↑':>7} {'IoU↑':>7} "
              f"{'Pre↑':>7} {'Rec↑':>7} {'HD95↓':>8} {'CBL↑':>7} {'N':>5}")
    print(header)
    print("-" * 82)
    for name, r in results.items():
        print(f"{name:<30} {r['dice']:>7.4f} {r['iou']:>7.4f} "
              f"{r['pre']:>7.4f} {r['rec']:>7.4f} "
              f"{r['hd95']:>8.2f} {r['cbl']:>7.4f} {r['n']:>5}")
    return results

# =========================================================
# LOAD MODEL
# =========================================================
model = PGA_UNet(use_encoder_prompt=USE_ENCODER_PROMPT).to(DEVICE)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval()
print(f"Model loaded from: {MODEL_PATH}")

# =========================================================
# TWO-SCENARIO EVALUATION: summary table
# =========================================================
results = evaluate_all(model)

# =========================================================
# VISUALIZATION - first 10 samples in order, both test scenarios
# (Zoom and Zoom + shift), matching the two rows reported above.
# =========================================================
from IPython.display import display as _ipy_display
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from torch.utils.data import DataLoader
import importlib as _importlib
if 'dataset' in sys.modules: del sys.modules['dataset']
_importlib.invalidate_caches()
from dataset import PromptSegmentationDataset

N_SHOW = 10
VIS_SCENARIOS = {
    'Zoom (center_zoom)':          dict(prompt_mode='center_zoom', scale_factor=SCALE_FACTOR),
    'Zoom + shift (center_shift)': dict(prompt_mode='center_shift', scale_factor=SCALE_FACTOR, shift_ratio=SHIFT_RATIO),
}

def _show_scenario(scenario_name, ds_kwargs):
    _vis_dl = DataLoader(
        PromptSegmentationDataset(TEST_IMAGE_DIR, TEST_JSON_DIR, img_size=IMG_SIZE, is_train=False, **ds_kwargs),
        batch_size=1, shuffle=False, num_workers=0)

    fig, axes = plt.subplots(N_SHOW, 5, figsize=(20, 4 * N_SHOW))
    fig.suptitle(f"PGA-UNet center_zoom (x{SCALE_FACTOR:g}) - Visualization ({scenario_name}, first 10 samples)", fontsize=13, y=1.001)
    for ax, ct in zip(axes[0], ["Input image", "Image + prompt", "Prediction", "Ground truth", "TP/FP/FN"]):
        ax.set_title(ct, fontsize=10, fontweight="bold")

    model.eval()
    count = 0
    with torch.no_grad():
        for _img, _gt, _hm in _vis_dl:
            if count >= N_SHOW: break
            img_np  = (_img[0,0].cpu().numpy() * 0.5 + 0.5)
            hm_np   = _hm[0,0].cpu().numpy()
            gt_np   = (_gt[0,0].cpu().numpy() > 0.5).astype(float)
            prob_np = torch.sigmoid(model(_img.to(DEVICE), _hm.to(DEVICE)))[0,0].cpu().numpy()
            pred_np = (prob_np > 0.5).astype(float)

            tp=(pred_np*gt_np).sum(); fp=(pred_np*(1-gt_np)).sum(); fn=((1-pred_np)*gt_np).sum(); e=1e-6
            dice=float((2*tp+e)/(2*tp+fp+fn+e)); iou=float((tp+e)/(tp+fp+fn+e))
            pre=float((tp+e)/(tp+fp+e));         rec=float((tp+e)/(tp+fn+e))

            row = axes[count]
            bg  = np.stack([img_np]*3, axis=-1)

            row[0].imshow(img_np, cmap="gray", vmin=0, vmax=1)
            row[0].set_ylabel(f"#{count+1} Dice={dice:.3f}", fontsize=8)

            row[1].imshow(img_np, cmap="gray", vmin=0, vmax=1)
            row[1].imshow(hm_np, cmap="hot", alpha=0.4, vmin=0, vmax=1)

            pr_ov = bg.copy()
            pr_ov[...,0] = np.clip(pr_ov[...,0] + pred_np*0.55, 0, 1)
            pr_ov[...,1] = np.clip(pr_ov[...,1] - pred_np*0.2,  0, 1)
            row[2].imshow(pr_ov)
            row[2].set_title(f"Dice={dice:.3f} IoU={iou:.3f}", fontsize=7, color="darkred", pad=2)

            gt_ov = bg.copy()
            gt_ov[...,1] = np.clip(gt_ov[...,1] + gt_np*0.55, 0, 1)
            gt_ov[...,0] = np.clip(gt_ov[...,0] - gt_np*0.2,  0, 1)
            row[3].imshow(gt_ov)

            inter = bg.copy() * 0.25
            inter[...,1] = np.clip(inter[...,1] + pred_np*gt_np*0.9,     0, 1)
            inter[...,0] = np.clip(inter[...,0] + pred_np*(1-gt_np)*1.0, 0, 1)
            inter[...,2] = np.clip(inter[...,2] + (1-pred_np)*gt_np*1.0, 0, 1)
            row[4].imshow(inter)
            row[4].set_title(f"Pre={pre:.3f} Rec={rec:.3f}", fontsize=7, color="saddlebrown", pad=2)

            for ax in row: ax.axis("off")
            count += 1

    fig.legend(handles=[Patch(facecolor="green",label="TP"),Patch(facecolor="red",label="FP"),Patch(facecolor="blue",label="FN")],
               loc="lower center", ncol=3, fontsize=9, bbox_to_anchor=(0.5,-0.01))
    plt.tight_layout()
    _ipy_display(fig)
    plt.close(fig)

for _scenario_name, _ds_kwargs in VIS_SCENARIOS.items():
    _show_scenario(_scenario_name, _ds_kwargs)
# Out:
# Model loaded from: checkpoints/pga_unet_center_zoom_x2_512_best.pth
#
# ========================================================================
#   TWO-SCENARIO EVALUATION  |  center-zoom x2  |  encoder_prompt = ON
# ========================================================================
#   [Zoom (center_zoom)]  232 samples, completed.
#   [Zoom + shift (center_shift)]  232 samples, completed.
#
# Scenario                         Dice↑    IoU↑    Pre↑    Rec↑    HD95↓    CBL↑     N
# ----------------------------------------------------------------------------------
# Zoom (center_zoom)              0.8700  0.7773  0.8590  0.8930     9.47  0.9592   232
# Zoom + shift (center_shift)     0.8195  0.7024  0.8241  0.8309    12.00  0.9245   232
